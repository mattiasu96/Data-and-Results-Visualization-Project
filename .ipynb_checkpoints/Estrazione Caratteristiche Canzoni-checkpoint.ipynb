# %%
import pandas as pd
import spotipy
#from fycharts.SpotifyCharts import SpotifyCharts
from spotipy.oauth2 import SpotifyClientCredentials

# %%
df = pd.read_csv('global_2017-07-14--2017-07-21.csv')

# %%
df

# %%
df.columns = df.iloc[0]

# %%
df = df.iloc[1:].reset_index()

# %%
df.URL.astype('str')

# %%
df.URL = df.URL.apply(lambda x : x[31:])

# %%
df.rename(columns={'URL':'ID'}, inplace=True)

# %%
df

# %%
credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
token = credentials.get_access_token()

spotify = spotipy.Spotify(auth=token)

features = spotify.audio_features(str(df['ID'].iloc[0]))

# %%
features

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        print(features[0]['danceability'])
        dataframe.append({'danceability' : features[0]['danceability'],
        'energy': features[0]['energy'],
        'key' : features[0]['key'],
        'loudness' : features[0]['loudness'],
        'mode' : features[0]['mode'],
        'speechiness' : features[0]['speechiness'],
        'acousticness' : features[0]['acousticness'],
        'instrumentalness' : features[0]['instrumentalness'],
        'liveness' : features[0]['liveness'],
        'valence' : features[0]['valence'],
        'tempo' : features[0]['tempo'],
        'time_signature' : features[0]['time_signature'],
        'duration_ms' : features[0]['duration_ms']}, ignore_index=True)
    return dataframe

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        dataframe.loc[i] = [ features[0]['id'],
        features[0]['danceability'],
        features[0]['energy'],
        features[0]['key'],
        features[0]['loudness'],
        features[0]['mode'],
        features[0]['speechiness'],
        features[0]['acousticness'],
        features[0]['instrumentalness'],
        features[0]['liveness'],
        features[0]['valence'],
        features[0]['tempo'],
        features[0]['time_signature'],
        features[0]['duration_ms']]
    return dataframe

# %%
prova = extract_features(df, n_tracks=200)

# %%
prova

# %%
output = df.join(prova.set_index('id'), on='ID')

# %%
output.to_csv('global_08-2017.csv')

# %%
output

test=output.iloc[9]
print(test)
print(type(test['Track Name']))
if type(test['Track Name']) != float and type(test['Artist']) != float:
    print('no empty')
else: 
    print('empty')

# %% [markdown]
# ## Testing iTunes API for genre labeling
# Simple test of quering on iTunes API

# %%
import requests
import json
entry = 'marcos+&+belutti+aquele+1%+-+ao+vivo'
a = 'https://itunes.apple.com/search?term='+entry+'.&limit=1'
b = requests.get(a).json()
print(b['results'][0]['primaryGenreName'])
print(json.dumps(b, indent=2))
# Out:
# Dance
# {
#   "resultCount": 1,
#   "results": [
#     {
#       "wrapperType": "track",
#       "kind": "song",
#       "artistId": 1519042874,
#       "collectionId": 443402254,
#       "trackId": 443402565,
#       "artistName": "Marcos",
#       "collectionName": "Never Mind the Bollocks\u2026 Here's Paul Oakenfold",
#       "trackName": "Take Cover (Sonic Element Mix)",
#       "collectionCensoredName": "Never Mind the Bollocks\u2026 Here's Paul Oakenfold",
#       "trackCensoredName": "Take Cover (Sonic Element Mix)",
#       "collectionArtistId": 1249423,
#       "collectionArtistName": "Paul Oakenfold",
#       "collectionArtistViewUrl": "https://music.apple.com/us/artist/paul-oakenfold/1249423?uo=4",
#       "artistViewUrl": "https://music.apple.com/us/artist/marcos/1519042874?uo=4",
#       "collectionViewUrl": "https://music.apple.com/us/album/take-cover-sonic-element-mix/443402254?i=443402565&uo=4",
#       "trackViewUrl": "https://music.apple.com/us/album/take-cover-sonic-element-mix/443402254?i=443402565&uo=4",
#       "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/Music/v4/70/da/d5/70dad54c-b1ae-104f-3d66-31dc5f96dfd2/mzaf_1289743337051327008.plus.aac.p.m4a",
#       "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music/v4/d4/09/62/d4096238-e5c9-38fc-4ea5-be719ec63b60/source/30x30bb.jpg",
#       "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music/v4/d4/09/62/d4096238-e5c9-38fc-4ea5-be719ec63b60/source/60x60bb.jpg",
#       "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music/v4/d4/09/62/d4096238-e5c9-38fc-4ea5-be719ec63b60/source/100x100bb.jpg",
#       "collectionPrice": -1.0,
#       "trackPrice": 1.29,
#       "releaseDate": "2011-07-15T12:00:00Z",
#       "collectionExplicitness": "notExplicit",
#       "trackExplicitness": "notExplicit",
#       "discCount": 2,
#       "discNumber": 2,
#       "trackCount": 20,
#       "trackNumber": 9,
#       "trackTimeMillis": 451304,
#       "country": "USA",
#       "currency": "USD",
#       "primaryGenreName": "Dance",
#       "isStreamable": true
#     }
#   ]
# }

# %% [markdown]
# # Automatizing the feature extraction process

# %%
import pandas as pd
import spotipy
#from fycharts.SpotifyCharts import SpotifyCharts
from spotipy.oauth2 import SpotifyClientCredentials
import os
import requests
import json
import time

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        print(features[0]['danceability'])
        dataframe.append({'danceability' : features[0]['danceability'],
        'energy': features[0]['energy'],
        'key' : features[0]['key'],
        'loudness' : features[0]['loudness'],
        'mode' : features[0]['mode'],
        'speechiness' : features[0]['speechiness'],
        'acousticness' : features[0]['acousticness'],
        'instrumentalness' : features[0]['instrumentalness'],
        'liveness' : features[0]['liveness'],
        'valence' : features[0]['valence'],
        'tempo' : features[0]['tempo'],
        'time_signature' : features[0]['time_signature'],
        'duration_ms' : features[0]['duration_ms']}, ignore_index=True)
    return dataframe

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        dataframe.loc[i] = [ features[0]['id'],
        features[0]['danceability'],
        features[0]['energy'],
        features[0]['key'],
        features[0]['loudness'],
        features[0]['mode'],
        features[0]['speechiness'],
        features[0]['acousticness'],
        features[0]['instrumentalness'],
        features[0]['liveness'],
        features[0]['valence'],
        features[0]['tempo'],
        features[0]['time_signature'],
        features[0]['duration_ms']]
    return dataframe

# %%
#checking data integrity. Checks for missing fields in Artist name. Return the rows with missing values + the file name. 
#These data are missing because of copyright issues. They changed the author of the song/removed the song. 
import numpy as np

from IPython.display import display, HTML

path = os.getcwd()
file_folder = os.path.join(path,'br')

for csv_file in os.listdir(file_folder):
    file = os.path.join(file_folder,csv_file)
    #print(csv_file)
    df = pd.read_csv(file)
    #display(df)
    df.columns = df.iloc[0]
    df = df.iloc[1:].reset_index()
    df.URL.astype('str')
    df.URL = df.URL.apply(lambda x : x[31:])
    df.rename(columns={'URL':'ID'}, inplace=True)
    
    res = df.loc[df['Artist'].isnull(), 'index'].tolist()
    if len(res) != 0:
        print(res)
        print(csv_file)
# Out:
# [10, 39, 52, 89]
# br_2017-07-14--2017-07-21.csv
# [178]
# br_2018-01-05--2018-01-12.csv
# [47]
# br_2018-01-12--2018-01-19.csv
# [128]
# br_2020-05-15--2020-05-22.csv
# [93]
# br_2020-05-22--2020-05-29.csv
# [94]
# br_2020-05-29--2020-06-05.csv

# %%
path = os.getcwd()
file_folder = os.path.join(path,'br 2')
save_folder_path = os.path.join(path, "br_features")
#os.mkdir(save_folder_path)

for csv_file in os.listdir(file_folder): 
    print(csv_file)
    file = os.path.join(file_folder,csv_file)
    df = pd.read_csv(file)
    df.columns = df.iloc[0]
    df = df.iloc[1:].reset_index()
    df.URL.astype('str')
    df.URL = df.URL.apply(lambda x : x[31:])
    df.rename(columns={'URL':'ID'}, inplace=True)
    credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
    token = credentials.get_access_token()
    spotify = spotipy.Spotify(auth=token)
    features = spotify.audio_features(str(df['ID'].iloc[0]))
    prova = extract_features(df, n_tracks=200)
    output = df.join(prova.set_index('id'), on='ID')
    output['genre']= "none"
    for index, row in output.iterrows():
        artist = row["Artist"]
        song = row["Track Name"]
        if type(artist) != float and type(song) != float:
            song = song.split('(')[0]
            query_entry = str(artist)+" "+str(song)
            query_entry = query_entry.replace("with", "")
            query_entry= query_entry.replace('Remastered', "")
            query_entry= query_entry.replace('Version', "")

            query_entry = query_entry.replace("'", "")
            query_entry = query_entry.replace('"', "")

            query_entry=query_entry.replace(" ", "+")

            #query_entry = query_entry[0:60]
            query_entry = query_entry.lower()
            print(query_entry)
            a = 'https://itunes.apple.com/search?term='+query_entry+'&limit=1'
            test = requests.get(a)
            print(test)
            b = test.json()
            if b['resultCount'] == 1:

                print(b['results'][0]['primaryGenreName'])
                #assign genre to song
                print(index)
                output.iloc[index, output.columns.get_loc('genre')]= b['results'][0]['primaryGenreName']
            time.sleep(0.5)
            #print(json.dumps(b, indent=2))
    output.to_csv(os.path.join(save_folder_path,csv_file))
# Out:
# br_2019-07-12--2019-07-19.csv
# C:\Users\Mattia\anaconda3\envs\MyEnv\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   app.launch_new_instance()
# marília+mendonça+todo+mundo+vai+sofrer+-+ao+vivo
# <Response [200]>
# Sertanejo
# 0
# joão+gustavo+e+murilo+lençol+dobrado
# <Response [200]>
# Brazilian
# 1
# jorge+&+mateus+tijolão+-+ao+vivo
# <Response [200]>
# Electronic
# 2
# mc+kevin+o+chris+evoluiu
# <Response [200]>
# Baile Funk
# 3
# matheus+&+kauan+vou+ter+que+superar+-+ao+vivo
# <Response [200]>
# Pop
# 4
# lauana+prado+cobaia
# <Response [200]>
# Sertanejo
# 5
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 6
# mc+kevinho+uma+nora+pra+cada+dia
# <Response [200]>
# Brazilian
# 7
# pk+quando+a+vontade+bater+
# <Response [200]>
# Hip-Hop/Rap
# 8
# gusttavo+lima+milu
# <Response [200]>
# Sertanejo
# 9
# luan+santana+quando+a+bad+bater+-+ao+vivo
# <Response [200]>
# Sertanejo
# 10
# mc+kevin+o+chris+ela+é+do+tipo
# <Response [200]>
# Baile Funk
# 11
# felipe+araújo+espaçosa+demais+-+ao+vivo
# <Response [200]>
# Sertanejo
# 12
# marília+mendonça+bebi+liguei+-+ao+vivo
# <Response [200]>
# Sertanejo
# 13
# zé+neto+&+cristiano+estado+decadente+-+acústico
# <Response [200]>
# Brazilian
# 14
# gustavo+mioto+solteiro+não+trai+-+ao+vivo
# <Response [200]>
# Sertanejo
# 15
# lil+nas+x+old+town+road+
# <Response [200]>
# Country
# 16
# diego+&+victor+hugo+a+culpa+é+do+meu+grau+
# <Response [200]>
# Kids & Family
# 17
# matheus+&+kauan+quarta+cadeira+-+ao+vivo
# <Response [200]>
# Pop
# 18
# mc+jottapê+sentou+e+gostou
# <Response [200]>
# Brazilian
# 19
# mano+walter+fingindo+maturidade+-+ao+vivo
# <Response [200]>
# Sertanejo
# 20
# marília+mendonça+bebaça+-+ao+vivo
# <Response [200]>
# Sertanejo
# 21
# maiara+&+maraisa+não+abro+mão+-+ao+vivo
# <Response [200]>
# Society & Culture
# 22
# gusttavo+lima+cem+mil+-+ao+vivo
# <Response [200]>
# Sertanejo
# 23
# hungria+hip+hop+um+pedido
# <Response [200]>
# Hip-Hop/Rap
# 24
# zé+neto+&+cristiano+notificação+preferida+-+ao+vivo
# <Response [200]>
# Brazilian
# 25
# anitta+onda+diferente+
# <Response [200]>
# Latino
# 26
# pineapple+stormtv+poesia+acústica+#7:+céu+azul
# <Response [200]>
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 28
# mc+wm+senta+braba
# <Response [200]>
# Baile Funk
# 29
# diego+&+victor+hugo+infarto
# <Response [200]>
# Kids & Family
# 30
# xand+avião+algo+mais+
# <Response [200]>
# Forró
# 31
# yasmin+santos+para,+pensa+e+volta+-+ao+vivo
# <Response [200]>
# Sertanejo
# 32
# dilsinho+péssimo+negócio+
# <Response [200]>
# Pagode
# 33
# george+henrique+&+rodrigo+bagunça+minha+vida+-+ao+vivo+em+goiânia+/+2019
# <Response [200]>
# Concert Films
# 34
# pocah+não+sou+obrigada
# <Response [200]>
# Baile Funk
# 35
# projota+sei+lá
# <Response [200]>
# Hip-Hop/Rap
# 36
# marília+mendonça+sem+sal+-+ao+vivo
# <Response [200]>
# Sertanejo
# 37
# luísa+sonza+garupa
# <Response [200]>
# Pop
# 38
# felipe+araújo+atrasadinha+-+ao+vivo
# <Response [200]>
# Sertanejo
# 39
# lucas+lucco+posto+24h+
# <Response [200]>
# Sertanejo
# 40
# pedro+sampaio+vai+menina
# <Response [200]>
# Pop
# 41
# melim+ouvi+dizer
# <Response [200]>
# Brazilian
# 42
# diego+&+victor+hugo+do+copo+eu+vim+
# <Response [200]>
# Kids & Family
# 43
# matheus+&+kauan+mágica+-+ao+vivo
# <Response [200]>
# Pop
# 44
# pineapple+stormtv+poesia+acústica+#6:+era+uma+vez
# <Response [200]>
# dynho+alves+malemolência
# <Response [200]>
# Brazilian
# 46
# madonna+faz+gostoso+
# <Response [200]>
# Pop
# 47
# mc+livinho+hoje+eu+vou+parar+na+gaiola
# <Response [200]>
# Baile Funk
# 48
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 49
# mc+kevin+o+chris+vamos+pra+gaiola
# <Response [200]>
# Baile Funk
# 50
# marília+mendonça+serenata+-+ao+vivo
# <Response [200]>
# Sertanejo
# 51
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 52
# marília+mendonça+ciumeira+-+ao+vivo
# <Response [200]>
# Sertanejo
# 53
# vitão+café
# <Response [200]>
# Pop
# 54
# murilo+huff+dois+enganados
# <Response [200]>
# Sertanejo
# 55
# lil+nas+x+old+town+road
# <Response [200]>
# Country
# 56
# melim+meu+abrigo
# <Response [200]>
# Pop
# 57
# post+malone+goodbyes+
# <Response [200]>
# Hip-Hop/Rap
# 58
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 59
# guilherme+&+benuto+flor+que+se+cheira+-+ao+vivo
# <Response [200]>
# Sertanejo
# 60
# israel+&+rodolffo+conselho+-+ao+vivo
# <Response [200]>
# Israeli
# 61
# wesley+safadão+juras+de+amor+
# <Response [200]>
# Forró
# 62
# tropkillaz+bola+rebola
# <Response [200]>
# Pop
# 63
# zé+neto+&+cristiano+long+neck+-+acústico
# <Response [200]>
# Brazilian
# 64
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 65
# lauana+prado+melhor+saída+-+ao+vivo
# <Response [200]>
# Sertanejo
# 66
# henrique+&+diego+espelho+meu+-+ao+vivo
# <Response [200]>
# Pop Latino
# 67
# marília+mendonça+apaixonadinha+-+ao+vivo
# <Response [200]>
# Sertanejo
# 68
# marília+mendonça+bem+pior+que+eu+-+ao+vivo
# <Response [200]>
# Sertanejo
# 69
# billie+eilish+bad+guy+
# <Response [200]>
# Alternative
# 70
# mc+kevinho+facilita
# <Response [200]>
# ludmilla+favela+chegou+-+ao+vivo
# <Response [200]>
# Baile Funk
# 72
# sorriso+maroto+50+vezes+-+ao+vivo
# <Response [200]>
# Pagode
# 73
# wesley+safadão+não+atende+não
# <Response [200]>
# Forró
# 74
# yasmin+santos+então+vou+avisar+-+ao+vivo
# <Response [200]>
# Sertanejo
# 75
# iza+brisa
# <Response [200]>
# Brazilian
# 76
# mano+walter+então+vem+cá+-+ao+vivo
# <Response [200]>
# Forró
# 77
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 78
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 79
# ed+sheeran+south+of+the+border+
# <Response [200]>
# Pop
# 80
# lagum+deixa+
# <Response [200]>
# Pop
# 81
# zé+felipe+tiro+certo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 82
# oriente+praia+do+rosa+-+acústico
# <Response [200]>
# Rap
# 83
# mc+kevin+o+chris+resenha+lá+em+casa
# <Response [200]>
# Brazilian
# 84
# henrique+&+juliano+cidade+vizinha+-+ao+vivo
# <Response [200]>
# Pop Latino
# 85
# thiago+brava+dá+preferência+pra+mim+
# <Response [200]>
# Sertanejo
# 86
# anavitória+pupila
# <Response [200]>
# Pop
# 87
# alok+all+the+lies
# <Response [200]>
# Dance
# 88
# gloria+groove+yoyo
# <Response [200]>
# Pop
# 89
# simone+&+simaria+aperte+o+play+-+ao+vivo
# <Response [200]>
# Jazz
# 90
# dj+henrique+de+ferraz+garupa,+pt.+2
# <Response [200]>
# dilsinho+santo+forte+
# <Response [200]>
# Pagode
# 92
# mc+don+juan+bye+bye
# <Response [200]>
# Baile Funk
# 93
# avine+vinny+maturidade+
# <Response [200]>
# Forró
# 94
# mc+th+rabetão+no+chão
# <Response [200]>
# Baile Funk
# 95
# marshmello+happier
# <Response [200]>
# Dance
# 96
# maiara+&+maraisa+traí+sim+-+ao+vivo
# <Response [200]>
# Society & Culture
# 97
# marília+mendonça+obrigado+por+estragar+tudo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 98
# raí+saia+rodada+bebe+e+vem+me+procurar
# <Response [200]>
# Forró
# 99
# post+malone+sunflower+-+spider-man:+into+the+spider-verse
# <Response [200]>
# Hip-Hop/Rap
# 100
# orochi+balão
# <Response [200]>
# Hip-Hop/Rap
# 101
# gustavo+mioto+pro+nosso+bem+-+ao+vivo
# <Response [200]>
# Sertanejo
# 102
# vitão+edredom
# <Response [200]>
# R&B/Soul
# 103
# gusttavo+lima+zé+da+recaída+-+ao+vivo
# <Response [200]>
# Sertanejo
# 104
# ozuna+muito+calor
# <Response [200]>
# Urbano latino
# 105
# anavitória+ai,+amor
# <Response [200]>
# Pop
# 106
# ed+sheeran+antisocial+
# <Response [200]>
# Pop
# 107
# yasmin+santos+sofro+onde+eu+quiser
# <Response [200]>
# Sertanejo
# 108
# turma+do+pagode+pesquisa+no+google+
# <Response [200]>
# Pagode
# 109
# a+banca+records+outro+dia
# <Response [200]>
# Hip-Hop/Rap
# 110
# marcos+&+belutti+tonelada+de+solidão+
# <Response [200]>
# Dance
# 111
# márcia+fellipe+quem+me+dera
# <Response [200]>
# Forró
# 112
# luan+santana+vingança+-+ao+vivo
# <Response [200]>
# Sertanejo
# 113
# jão+louquinho
# <Response [200]>
# Pop
# 114
# melim+dois+corações
# <Response [200]>
# Pop
# 115
# wesley+safadão+igual+ela+só+uma
# <Response [200]>
# Forró
# 116
# marília+mendonça+passa+mal+-+ao+vivo
# <Response [200]>
# Sertanejo
# 117
# vitor+kley+morena
# <Response [200]>
# Pop
# 118
# jerry+smith+o+pai+tá+livre
# <Response [200]>
# Baile Funk
# 119
# marília+mendonça+love+à+queima+roupa+-+ao+vivo
# <Response [200]>
# Sertanejo
# 120
# iza+dona+de+mim
# <Response [200]>
# Brazilian
# 121
# vitão+embrasa
# <Response [200]>
# R&B/Soul
# 122
# imagine+dragons+believer
# <Response [200]>
# Alternative
# 123
# diego+&+arnaldo+regras+-+ao+vivo
# <Response [200]>
# Kids & Family
# 124
# meduza+piece+of+your+heart+-+alok+remix
# <Response [200]>
# Dance
# 125
# lexa+sapequinha
# <Response [200]>
# Brazilian
# 126
# zé+neto+&+cristiano+enchendo+e+derramando
# <Response [200]>
# Brazilian
# 127
# mc+l+da+vinte+parado+no+bailão
# <Response [200]>
# Baile Funk
# 128
# dennis+dj+agora+é+tudo+meu
# <Response [200]>
# Baile Funk
# 129
# mc+g15+ela+vem
# <Response [200]>
# Brazilian
# 130
# marília+mendonça+bye+bye+-+ao+vivo
# <Response [200]>
# Sertanejo
# 131
# wesley+safadão+só+pra+castigar
# <Response [200]>
# Forró
# 132
# hugo+&+guilherme+teste+da+mãozinha+-+ao+vivo
# <Response [200]>
# Kids & Family
# 133
# gustavo+mioto+fake+news+-+ao+vivo
# <Response [200]>
# Sertanejo
# 134
# vitor+kley+o+sol
# <Response [200]>
# Pop
# 135
# ed+sheeran+shape+of+you
# <Response [200]>
# Pop
# 136
# xand+avião+casal+raiz+-+ao+vivo
# <Response [200]>
# Forró
# 137
# breno+&+caio+cesar+deixa+eu+te+chamar+de+meu+amor
# <Response [200]>
# Hip-Hop/Rap
# 138
# pineapple+stormtv+você+não+ama+ninguém
# <Response [200]>
# Hip-Hop/Rap
# 139
# maria+cecília+&+rodolfo+quase+amor
# <Response [200]>
# Worldwide
# 140
# henrique+&+juliano+quem+pegou,+pegou+-+ao+vivo
# <Response [200]>
# Pop Latino
# 141
# taylor+swift+you+need+to+calm+down
# <Response [200]>
# Pop
# 142
# alok+favela
# <Response [200]>
# Pop
# 143
# bruno+&+marrone+surto+de+amor+-+ao+vivo+em+uberlândia+/+2018
# <Response [200]>
# Comedy
# 144
# maiara+&+maraisa+bebo+litro+-+ao+vivo
# <Response [200]>
# Society & Culture
# 145
# 1kilo+deixe+me+ir+-+acústico
# <Response [200]>
# Pop
# 146
# clau+pouca+pausa
# <Response [200]>
# Pop
# 147
# jorge+&+mateus+propaganda+-+ao+vivo
# <Response [200]>
# Electronic
# 148
# mc+kevin+o+chris+medley+da+gaiola+-+dennis+dj+remix
# <Response [200]>
# Baile Funk
# 149
# orgânico+dizeres
# <Response [200]>
# Hip-Hop/Rap
# 150
# anavitória+fica+-+bonus+track
# <Response [200]>
# nando+reis+pra+você+guardei+o+amor
# <Response [200]>
# MPB
# 152
# anitta+terremoto
# <Response [200]>
# Pop
# 153
# shawn+mendes+if+i+cant+have+you
# <Response [200]>
# Pop
# 154
# gusttavo+lima+respeita+o+nosso+fim+-+ao+vivo
# <Response [200]>
# Sertanejo
# 155
# gusttavo+lima+eu+não+iria+-+ao+vivo
# <Response [200]>
# Sertanejo
# 156
# zé+neto+&+cristiano+status+que+eu+não+queria+-+ao+vivo
# <Response [200]>
# Brazilian
# 157
# delacruz+poesia+acústica+#2:+sobre+nós
# <Response [200]>
# diego+&+victor+hugo+áudio+-+ao+vivo+em+brasília
# <Response [200]>
# Kids & Family
# 159
# queen+bohemian+rhapsody+-+2011+mix
# <Response [200]>
# Rock
# 160
# maroon+5+girls+like+you+
# <Response [200]>
# Pop
# 161
# pineapple+stormtv+poesia+acústica+#3:+capricorniana
# <Response [200]>
# zé+neto+&+cristiano+largado+às+traças+-+ao+vivo
# <Response [200]>
# Brazilian
# 163
# maiara+&+maraisa+nem+tchum+-+ao+vivo
# <Response [200]>
# Society & Culture
# 164
# mc+don+juan+to+gostando+tanto+de+você
# <Response [200]>
# Baile Funk
# 165
# marília+mendonça+ausência+-+ao+vivo+|+acústico
# <Response [200]>
# Sertanejo
# 166
# dilsinho+pouco+a+pouco+
# <Response [200]>
# Pagode
# 167
# yasmin+santos+saudade+nível+hard
# <Response [200]>
# Pop
# 168
# post+malone+rockstar+
# <Response [200]>
# Hip-Hop/Rap
# 169
# casa+worship+a+casa+é+sua
# <Response [200]>
# Christian & Gospel
# 170
# oriente+mandona+-+acústico
# <Response [200]>
# Rap
# 171
# emicida+amarelo+
# <Response [200]>
# Brazilian
# 172
# ariana+grande+thank+u,+next
# <Response [200]>
# Pop
# 173
# lulu+santos+apenas+mais+uma+de+amor
# <Response [200]>
# MPB
# 174
# alok+ocean
# <Response [200]>
# Dance
# 175
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 176
# agnes+nunes+cida
# <Response [200]>
# Pop
# 177
# sam+smith+dancing+with+a+stranger+
# <Response [200]>
# Pop
# 178
# halsey+without+me
# <Response [200]>
# Alternative
# 179
# anavitória+trevo+
# <Response [200]>
# Pop
# 180
# matheus+&+kauan+cerveja,+sal+e+limão+-+ao+vivo
# <Response [200]>
# Pop
# 181
# the+police+every+breath+you+take
# <Response [200]>
# Rock
# 182
# dj+guuga+vidrado+em+você
# <Response [200]>
# Brazilian
# 183
# marília+mendonça+amigo+emprestado+-+ao+vivo
# <Response [200]>
# Sertanejo
# 184
# ed+sheeran+cross+me+
# <Response [200]>
# Pop
# 185
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 186
# péricles+supera+-+ao+vivo
# <Response [200]>
# Samba
# 187
# ed+sheeran+photograph
# <Response [200]>
# Pop
# 188
# marília+mendonça+casa+da+mãe+joana+-+ao+vivo
# <Response [200]>
# Sertanejo
# 189
# imagine+dragons+thunder
# <Response [200]>
# Alternative
# 190
# katy+perry+never+really+over
# <Response [200]>
# Pop
# 191
# jovem+dex+rockstar
# <Response [200]>
# Hip-Hop/Rap
# 192
# gusttavo+lima+online
# <Response [200]>
# Sertanejo
# 193
# turma+do+pagode+sua+mãe+vai+me+amar
# <Response [200]>
# Pagode
# 194
# baco+exu+do+blues+me+desculpa+jay+z
# <Response [200]>
# Hip-Hop/Rap
# 195
# miley+cyrus+mothers+daughter
# <Response [200]>
# Pop
# 196
# mc+ig+3+dias+virado
# <Response [200]>
# Baile Funk
# 197
# matuê+anos+luz
# <Response [200]>
# Hip-Hop/Rap
# 198
# matuê+banco
# <Response [200]>
# Hip-Hop/Rap
# 199
# br_2019-07-19--2019-07-26.csv
# marília+mendonça+todo+mundo+vai+sofrer+-+ao+vivo
# <Response [200]>
# Sertanejo
# 0
# joão+gustavo+e+murilo+lençol+dobrado
# <Response [200]>
# Brazilian
# 1
# jorge+&+mateus+tijolão+-+ao+vivo
# <Response [200]>
# Electronic
# 2
# mc+kevin+o+chris+evoluiu
# <Response [200]>
# Baile Funk
# 3
# luan+santana+quando+a+bad+bater+-+ao+vivo
# <Response [200]>
# Sertanejo
# 4
# matheus+&+kauan+vou+ter+que+superar+-+ao+vivo
# <Response [200]>
# Pop
# 5
# mc+kevinho+uma+nora+pra+cada+dia
# <Response [200]>
# Brazilian
# 6
# lauana+prado+cobaia
# <Response [200]>
# Sertanejo
# 7
# gusttavo+lima+milu
# <Response [200]>
# Sertanejo
# 8
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 9
# mc+jottapê+sentou+e+gostou
# <Response [200]>
# Brazilian
# 10
# pk+quando+a+vontade+bater+
# <Response [200]>
# Hip-Hop/Rap
# 11
# marília+mendonça+bebi+liguei+-+ao+vivo
# <Response [200]>
# Sertanejo
# 12
# matheus+&+kauan+quarta+cadeira+-+ao+vivo
# <Response [200]>
# Pop
# 13
# zé+neto+&+cristiano+estado+decadente+-+acústico
# <Response [200]>
# Brazilian
# 14
# mc+kevin+o+chris+ela+é+do+tipo
# <Response [200]>
# Baile Funk
# 15
# felipe+araújo+espaçosa+demais+-+ao+vivo
# <Response [200]>
# Sertanejo
# 16
# lil+nas+x+old+town+road+
# <Response [200]>
# Country
# 17
# mano+walter+fingindo+maturidade+-+ao+vivo
# <Response [200]>
# Sertanejo
# 18
# diego+&+victor+hugo+a+culpa+é+do+meu+grau+
# <Response [200]>
# Kids & Family
# 19
# xand+avião+algo+mais+
# <Response [200]>
# Forró
# 20
# marília+mendonça+bebaça+-+ao+vivo
# <Response [200]>
# Sertanejo
# 21
# maiara+&+maraisa+não+abro+mão+-+ao+vivo
# <Response [200]>
# Society & Culture
# 22
# pineapple+stormtv+poesia+acústica+#7:+céu+azul
# <Response [200]>
# gustavo+mioto+solteiro+não+trai+-+ao+vivo
# <Response [200]>
# Sertanejo
# 24
# zé+neto+&+cristiano+notificação+preferida+-+ao+vivo
# <Response [200]>
# Brazilian
# 25
# mc+wm+senta+braba
# <Response [200]>
# Baile Funk
# 26
# anitta+onda+diferente+
# <Response [200]>
# Latino
# 27
# projota+sei+lá
# <Response [200]>
# Hip-Hop/Rap
# 28
# hungria+hip+hop+um+pedido
# <Response [200]>
# Hip-Hop/Rap
# 29
# george+henrique+&+rodrigo+bagunça+minha+vida+-+ao+vivo+em+goiânia+/+2019
# <Response [200]>
# Concert Films
# 30
# zé+neto+&+cristiano+ferida+curada
# <Response [200]>
# Brazilian
# 31
# dilsinho+péssimo+negócio+
# <Response [200]>
# Pagode
# 32
# gusttavo+lima+cem+mil+-+ao+vivo
# <Response [200]>
# Sertanejo
# 33
# marília+mendonça+sem+sal+-+ao+vivo
# <Response [200]>
# Sertanejo
# 34
# pocah+não+sou+obrigada
# <Response [200]>
# Baile Funk
# 35
# sam+smith+how+do+you+sleep?
# <Response [200]>
# Pop
# 36
# felipe+araújo+atrasadinha+-+ao+vivo
# <Response [200]>
# Sertanejo
# 37
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 38
# luísa+sonza+garupa
# <Response [200]>
# Pop
# 39
# melim+ouvi+dizer
# <Response [200]>
# Brazilian
# 40
# pedro+sampaio+vai+menina
# <Response [200]>
# Pop
# 41
# lucas+lucco+posto+24h+
# <Response [200]>
# Sertanejo
# 42
# yasmin+santos+para,+pensa+e+volta+-+ao+vivo
# <Response [200]>
# Sertanejo
# 43
# matheus+&+kauan+mágica+-+ao+vivo
# <Response [200]>
# Pop
# 44
# diego+&+victor+hugo+do+copo+eu+vim+
# <Response [200]>
# Kids & Family
# 45
# diego+&+victor+hugo+infarto
# <Response [200]>
# Kids & Family
# 46
# pineapple+stormtv+poesia+acústica+#6:+era+uma+vez
# <Response [200]>
# marília+mendonça+serenata+-+ao+vivo
# <Response [200]>
# Sertanejo
# 48
# dynho+alves+malemolência
# <Response [200]>
# Brazilian
# 49
# guilherme+&+benuto+flor+que+se+cheira+-+ao+vivo
# <Response [200]>
# Sertanejo
# 50
# marília+mendonça+ciumeira+-+ao+vivo
# <Response [200]>
# Sertanejo
# 51
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 52
# anavitória+pupila
# <Response [200]>
# Pop
# 53
# fernando+&+sorocaba+cara+feio+-+ao+vivo
# <Response [200]>
# Pop
# 54
# iza+brisa
# <Response [200]>
# Brazilian
# 55
# melim+meu+abrigo
# <Response [200]>
# Pop
# 56
# mc+kevin+o+chris+vamos+pra+gaiola
# <Response [200]>
# Baile Funk
# 57
# vitão+café
# <Response [200]>
# Pop
# 58
# murilo+huff+dois+enganados
# <Response [200]>
# Sertanejo
# 59
# madonna+faz+gostoso+
# <Response [200]>
# Pop
# 60
# sorriso+maroto+50+vezes+-+ao+vivo
# <Response [200]>
# Pagode
# 61
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 62
# israel+&+rodolffo+conselho+-+ao+vivo
# <Response [200]>
# Israeli
# 63
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 64
# zé+neto+&+cristiano+long+neck+-+acústico
# <Response [200]>
# Brazilian
# 65
# marília+mendonça+apaixonadinha+-+ao+vivo
# <Response [200]>
# Sertanejo
# 66
# lauana+prado+melhor+saída+-+ao+vivo
# <Response [200]>
# Sertanejo
# 67
# mc+kevin+o+chris+resenha+lá+em+casa
# <Response [200]>
# Brazilian
# 68
# tropkillaz+bola+rebola
# <Response [200]>
# Pop
# 69
# henrique+&+diego+espelho+meu+-+ao+vivo
# <Response [200]>
# Pop Latino
# 70
# lil+nas+x+old+town+road
# <Response [200]>
# Country
# 71
# marília+mendonça+bem+pior+que+eu+-+ao+vivo
# <Response [200]>
# Sertanejo
# 72
# raí+saia+rodada+bebe+e+vem+me+procurar
# <Response [200]>
# Forró
# 73
# post+malone+goodbyes+
# <Response [200]>
# Hip-Hop/Rap
# 74
# mc+livinho+hoje+eu+vou+parar+na+gaiola
# <Response [200]>
# Baile Funk
# 75
# wesley+safadão+não+atende+não
# <Response [200]>
# Forró
# 76
# lagum+deixa+
# <Response [200]>
# Pop
# 77
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 78
# mano+walter+então+vem+cá+-+ao+vivo
# <Response [200]>
# Forró
# 79
# yasmin+santos+então+vou+avisar+-+ao+vivo
# <Response [200]>
# Sertanejo
# 80
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 81
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 82
# henrique+&+juliano+cidade+vizinha+-+ao+vivo
# <Response [200]>
# Pop Latino
# 83
# wesley+safadão+juras+de+amor+
# <Response [200]>
# Forró
# 84
# ludmilla+favela+chegou+-+ao+vivo
# <Response [200]>
# Baile Funk
# 85
# oriente+praia+do+rosa+-+acústico
# <Response [200]>
# Rap
# 86
# mc+kevinho+facilita
# <Response [200]>
# thiago+brava+dá+preferência+pra+mim+
# <Response [200]>
# Sertanejo
# 88
# simone+&+simaria+aperte+o+play+-+ao+vivo
# <Response [200]>
# Jazz
# 89
# dilsinho+santo+forte+
# <Response [200]>
# Pagode
# 90
# alok+all+the+lies
# <Response [200]>
# Dance
# 91
# marília+mendonça+obrigado+por+estragar+tudo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 92
# israel+&+rodolffo+também+sei+fazer+falta+-+ao+vivo
# <Response [200]>
# Israeli
# 93
# mc+th+rabetão+no+chão
# <Response [200]>
# Baile Funk
# 94
# avine+vinny+maturidade+
# <Response [200]>
# Forró
# 95
# marshmello+happier
# <Response [200]>
# Dance
# 96
# zé+felipe+tiro+certo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 97
# turma+do+pagode+pesquisa+no+google+
# <Response [200]>
# Pagode
# 98
# maiara+&+maraisa+traí+sim+-+ao+vivo
# <Response [200]>
# Society & Culture
# 99
# a+banca+records+outro+dia
# <Response [200]>
# Hip-Hop/Rap
# 100
# dj+henrique+de+ferraz+garupa,+pt.+2
# <Response [200]>
# billie+eilish+bad+guy+
# <Response [200]>
# Alternative
# 102
# mc+don+juan+bye+bye
# <Response [200]>
# Baile Funk
# 103
# post+malone+sunflower+-+spider-man:+into+the+spider-verse
# <Response [200]>
# Hip-Hop/Rap
# 104
# gustavo+mioto+pro+nosso+bem+-+ao+vivo
# <Response [200]>
# Sertanejo
# 105
# gloria+groove+yoyo
# <Response [200]>
# Pop
# 106
# gusttavo+lima+zé+da+recaída+-+ao+vivo
# <Response [200]>
# Sertanejo
# 107
# orochi+balão
# <Response [200]>
# Hip-Hop/Rap
# 108
# vitão+edredom
# <Response [200]>
# R&B/Soul
# 109
# dj+guuga+vidrado+em+você
# <Response [200]>
# Brazilian
# 110
# melim+dois+corações
# <Response [200]>
# Pop
# 111
# meduza+piece+of+your+heart+-+alok+remix
# <Response [200]>
# Dance
# 112
# luan+santana+vingança+-+ao+vivo
# <Response [200]>
# Sertanejo
# 113
# yasmin+santos+sofro+onde+eu+quiser
# <Response [200]>
# Sertanejo
# 114
# marcos+&+belutti+tonelada+de+solidão+
# <Response [200]>
# Dance
# 115
# vitor+kley+morena
# <Response [200]>
# Pop
# 116
# marília+mendonça+passa+mal+-+ao+vivo
# <Response [200]>
# Sertanejo
# 117
# márcia+fellipe+quem+me+dera
# <Response [200]>
# Forró
# 118
# jerry+smith+o+pai+tá+livre
# <Response [200]>
# Baile Funk
# 119
# marília+mendonça+love+à+queima+roupa+-+ao+vivo
# <Response [200]>
# Sertanejo
# 120
# iza+dona+de+mim
# <Response [200]>
# Brazilian
# 121
# vitão+embrasa
# <Response [200]>
# R&B/Soul
# 122
# wesley+safadão+igual+ela+só+uma
# <Response [200]>
# Forró
# 123
# diego+&+arnaldo+regras+-+ao+vivo
# <Response [200]>
# Kids & Family
# 124
# imagine+dragons+believer
# <Response [200]>
# Alternative
# 125
# mc+g15+ela+vem
# <Response [200]>
# Brazilian
# 126
# hugo+&+guilherme+teste+da+mãozinha+-+ao+vivo
# <Response [200]>
# Kids & Family
# 127
# péricles+supera+-+ao+vivo
# <Response [200]>
# Samba
# 128
# lexa+sapequinha
# <Response [200]>
# Brazilian
# 129
# gustavo+mioto+fake+news+-+ao+vivo
# <Response [200]>
# Sertanejo
# 130
# dennis+dj+agora+é+tudo+meu
# <Response [200]>
# Baile Funk
# 131
# ozuna+muito+calor
# <Response [200]>
# Urbano latino
# 132
# mc+l+da+vinte+parado+no+bailão
# <Response [200]>
# Baile Funk
# 133
# ed+sheeran+south+of+the+border+
# <Response [200]>
# Pop
# 134
# sam+smith+dancing+with+a+stranger+
# <Response [200]>
# Pop
# 135
# marília+mendonça+bye+bye+-+ao+vivo
# <Response [200]>
# Sertanejo
# 136
# wesley+safadão+só+pra+castigar
# <Response [200]>
# Forró
# 137
# vitor+kley+o+sol
# <Response [200]>
# Pop
# 138
# alok+favela
# <Response [200]>
# Pop
# 139
# zé+neto+&+cristiano+enchendo+e+derramando
# <Response [200]>
# Brazilian
# 140
# breno+&+caio+cesar+deixa+eu+te+chamar+de+meu+amor
# <Response [200]>
# Hip-Hop/Rap
# 141
# xand+avião+casal+raiz+-+ao+vivo
# <Response [200]>
# Forró
# 142
# henrique+&+juliano+quem+pegou,+pegou+-+ao+vivo
# <Response [200]>
# Pop Latino
# 143
# nando+reis+pra+você+guardei+o+amor
# <Response [200]>
# MPB
# 144
# bruno+&+marrone+surto+de+amor+-+ao+vivo+em+uberlândia+/+2018
# <Response [200]>
# Comedy
# 145
# anavitória+fica+-+bonus+track
# <Response [200]>
# ed+sheeran+shape+of+you
# <Response [200]>
# Pop
# 147
# beyoncé+spirit+-+from+disneys+the+lion+king
# <Response [200]>
# Pop
# 148
# anavitória+ai,+amor
# <Response [200]>
# Pop
# 149
# zé+neto+&+cristiano+largado+às+traças+-+ao+vivo
# <Response [200]>
# Brazilian
# 150
# jorge+&+mateus+propaganda+-+ao+vivo
# <Response [200]>
# Electronic
# 151
# zé+neto+&+cristiano+status+que+eu+não+queria+-+ao+vivo
# <Response [200]>
# Brazilian
# 152
# clau+pouca+pausa
# <Response [200]>
# Pop
# 153
# mc+kevin+o+chris+medley+da+gaiola+-+dennis+dj+remix
# <Response [200]>
# Baile Funk
# 154
# orgânico+dizeres
# <Response [200]>
# Hip-Hop/Rap
# 155
# pineapple+stormtv+você+não+ama+ninguém
# <Response [200]>
# Hip-Hop/Rap
# 156
# 1kilo+deixe+me+ir+-+acústico
# <Response [200]>
# Pop
# 157
# dilsinho+pouco+a+pouco+
# <Response [200]>
# Pagode
# 158
# maiara+&+maraisa+nem+tchum+-+ao+vivo
# <Response [200]>
# Society & Culture
# 159
# maiara+&+maraisa+bebo+litro+-+ao+vivo
# <Response [200]>
# Society & Culture
# 160
# lulu+santos+apenas+mais+uma+de+amor
# <Response [200]>
# MPB
# 161
# gusttavo+lima+respeita+o+nosso+fim+-+ao+vivo
# <Response [200]>
# Sertanejo
# 162
# gusttavo+lima+eu+não+iria+-+ao+vivo
# <Response [200]>
# Sertanejo
# 163
# mc+kevin+o+chris+namorar+não+dá
# <Response [200]>
# Baile Funk
# 164
# taylor+swift+you+need+to+calm+down
# <Response [200]>
# Pop
# 165
# marília+mendonça+ausência+-+ao+vivo+|+acústico
# <Response [200]>
# Sertanejo
# 166
# yasmin+santos+saudade+nível+hard
# <Response [200]>
# Pop
# 167
# shawn+mendes+if+i+cant+have+you
# <Response [200]>
# Pop
# 168
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 169
# oriente+mandona+-+acústico
# <Response [200]>
# Rap
# 170
# maroon+5+girls+like+you+
# <Response [200]>
# Pop
# 171
# casa+worship+a+casa+é+sua
# <Response [200]>
# Christian & Gospel
# 172
# anitta+terremoto
# <Response [200]>
# Pop
# 173
# queen+bohemian+rhapsody+-+2011+mix
# <Response [200]>
# Rock
# 174
# delacruz+poesia+acústica+#2:+sobre+nós
# <Response [200]>
# pineapple+stormtv+poesia+acústica+#3:+capricorniana
# <Response [200]>
# anavitória+trevo+
# <Response [200]>
# Pop
# 177
# diego+&+victor+hugo+áudio+-+ao+vivo+em+brasília
# <Response [200]>
# Kids & Family
# 178
# mc+don+juan+to+gostando+tanto+de+você
# <Response [200]>
# Baile Funk
# 179
# ferrugem+até+que+enfim+-+ao+vivo
# <Response [200]>
# Brazilian
# 180
# post+malone+rockstar+
# <Response [200]>
# Hip-Hop/Rap
# 181
# agnes+nunes+cida
# <Response [200]>
# Pop
# 182
# ariana+grande+thank+u,+next
# <Response [200]>
# Pop
# 183
# halsey+without+me
# <Response [200]>
# Alternative
# 184
# the+police+every+breath+you+take
# <Response [200]>
# Rock
# 185
# alok+ocean
# <Response [200]>
# Dance
# 186
# marília+mendonça+amigo+emprestado+-+ao+vivo
# <Response [200]>
# Sertanejo
# 187
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 188
# dj+snake+loco+contigo
# <Response [200]>
# Latino
# 189
# lizzo+truth+hurts
# <Response [200]>
# Dance
# 190
# aaron+smith+dancin+
# <Response [200]>
# Dance
# 191
# gustavo+mioto+anti-amor+-+ao+vivo
# <Response [200]>
# Sertanejo
# 192
# imagine+dragons+thunder
# <Response [200]>
# Alternative
# 193
# gusttavo+lima+online
# <Response [200]>
# Sertanejo
# 194
# marília+mendonça+casa+da+mãe+joana+-+ao+vivo
# <Response [200]>
# Sertanejo
# 195
# turma+do+pagode+sua+mãe+vai+me+amar
# <Response [200]>
# Pagode
# 196
# legião+urbana+tempo+perdido
# <Response [200]>
# Rock
# 197
# baco+exu+do+blues+me+desculpa+jay+z
# <Response [200]>
# Hip-Hop/Rap
# 198
# jovem+dex+rockstar
# <Response [200]>
# Hip-Hop/Rap
# 199
# br_2019-07-26--2019-08-02.csv
# marília+mendonça+todo+mundo+vai+sofrer+-+ao+vivo
# <Response [200]>
# Sertanejo
# 0
# joão+gustavo+e+murilo+lençol+dobrado
# <Response [200]>
# Brazilian
# 1
# jorge+&+mateus+tijolão+-+ao+vivo
# <Response [200]>
# Electronic
# 2
# mc+kevin+o+chris+evoluiu
# <Response [200]>
# Baile Funk
# 3
# luan+santana+quando+a+bad+bater+-+ao+vivo
# <Response [200]>
# Sertanejo
# 4
# matheus+&+kauan+vou+ter+que+superar+-+ao+vivo
# <Response [200]>
# Pop
# 5
# mc+kevinho+uma+nora+pra+cada+dia
# <Response [200]>
# Brazilian
# 6
# pk+quando+a+vontade+bater+
# <Response [200]>
# Hip-Hop/Rap
# 7
# lauana+prado+cobaia
# <Response [200]>
# Sertanejo
# 8
# mc+jottapê+sentou+e+gostou
# <Response [200]>
# Brazilian
# 9
# gusttavo+lima+milu
# <Response [200]>
# Sertanejo
# 10
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 11
# matheus+&+kauan+quarta+cadeira+-+ao+vivo
# <Response [200]>
# Pop
# 12
# marília+mendonça+bebi+liguei+-+ao+vivo
# <Response [200]>
# Sertanejo
# 13
# zé+neto+&+cristiano+ferida+curada
# <Response [200]>
# Brazilian
# 14
# xand+avião+algo+mais+
# <Response [200]>
# Forró
# 15
# zé+neto+&+cristiano+estado+decadente+-+acústico
# <Response [200]>
# Brazilian
# 16
# felipe+araújo+espaçosa+demais+-+ao+vivo
# <Response [200]>
# Sertanejo
# 17
# mc+kevin+o+chris+ela+é+do+tipo
# <Response [200]>
# Baile Funk
# 18
# diego+&+victor+hugo+a+culpa+é+do+meu+grau+
# <Response [200]>
# Kids & Family
# 19
# mano+walter+fingindo+maturidade+-+ao+vivo
# <Response [200]>
# Sertanejo
# 20
# marília+mendonça+bebaça+-+ao+vivo
# <Response [200]>
# Sertanejo
# 21
# pabllo+vittar+flash+pose
# <Response [200]>
# Pop
# 22
# lil+nas+x+old+town+road+-+remix
# <Response [200]>
# Country
# 23
# maiara+&+maraisa+não+abro+mão+-+ao+vivo
# <Response [200]>
# Society & Culture
# 24
# gustavo+mioto+solteiro+não+trai+-+ao+vivo
# <Response [200]>
# Sertanejo
# 25
# hungria+hip+hop+um+pedido
# <Response [200]>
# Hip-Hop/Rap
# 26
# anitta+onda+diferente+
# <Response [200]>
# Latino
# 27
# pineapple+stormtv+poesia+acústica+#7:+céu+azul
# <Response [200]>
# projota+sei+lá
# <Response [200]>
# Hip-Hop/Rap
# 29
# mc+wm+senta+braba
# <Response [200]>
# Baile Funk
# 30
# zé+neto+&+cristiano+notificação+preferida+-+ao+vivo
# <Response [200]>
# Brazilian
# 31
# dilsinho+péssimo+negócio+
# <Response [200]>
# Pagode
# 32
# gusttavo+lima+cem+mil+-+ao+vivo
# <Response [200]>
# Sertanejo
# 33
# marília+mendonça+sem+sal+-+ao+vivo
# <Response [200]>
# Sertanejo
# 34
# anavitória+pupila
# <Response [200]>
# Pop
# 35
# george+henrique+&+rodrigo+bagunça+minha+vida+-+ao+vivo+em+goiânia+/+2019
# <Response [200]>
# Concert Films
# 36
# pocah+não+sou+obrigada
# <Response [200]>
# Baile Funk
# 37
# yasmin+santos+para,+pensa+e+volta+-+ao+vivo
# <Response [200]>
# Sertanejo
# 38
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 39
# sam+smith+how+do+you+sleep?
# <Response [200]>
# Pop
# 40
# melim+ouvi+dizer
# <Response [200]>
# Brazilian
# 41
# luísa+sonza+garupa
# <Response [200]>
# Pop
# 42
# marília+mendonça+serenata+-+ao+vivo
# <Response [200]>
# Sertanejo
# 43
# pedro+sampaio+vai+menina
# <Response [200]>
# Pop
# 44
# matheus+&+kauan+mágica+-+ao+vivo
# <Response [200]>
# Pop
# 45
# lucas+lucco+posto+24h+
# <Response [200]>
# Sertanejo
# 46
# diego+&+victor+hugo+do+copo+eu+vim+
# <Response [200]>
# Kids & Family
# 47
# iza+brisa
# <Response [200]>
# Brazilian
# 48
# pineapple+stormtv+poesia+acústica+#6:+era+uma+vez
# <Response [200]>
# a+banca+records+outro+dia
# <Response [200]>
# Hip-Hop/Rap
# 50
# melim+meu+abrigo
# <Response [200]>
# Pop
# 51
# dynho+alves+malemolência
# <Response [200]>
# Brazilian
# 52
# vitão+café
# <Response [200]>
# Pop
# 53
# marília+mendonça+ciumeira+-+ao+vivo
# <Response [200]>
# Sertanejo
# 54
# guilherme+&+benuto+flor+que+se+cheira+-+ao+vivo
# <Response [200]>
# Sertanejo
# 55
# felipe+araújo+atrasadinha+-+ao+vivo
# <Response [200]>
# Sertanejo
# 56
# sorriso+maroto+50+vezes+-+ao+vivo
# <Response [200]>
# Pagode
# 57
# marília+mendonça+apaixonadinha+-+ao+vivo
# <Response [200]>
# Sertanejo
# 58
# murilo+huff+dois+enganados
# <Response [200]>
# Sertanejo
# 59
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 60
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 61
# mc+kevin+o+chris+resenha+lá+em+casa
# <Response [200]>
# Brazilian
# 62
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 63
# raí+saia+rodada+bebe+e+vem+me+procurar
# <Response [200]>
# Forró
# 64
# madonna+faz+gostoso+
# <Response [200]>
# Pop
# 65
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 66
# fernando+&+sorocaba+cara+feio+-+ao+vivo
# <Response [200]>
# Pop
# 67
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 68
# tropkillaz+bola+rebola
# <Response [200]>
# Pop
# 69
# post+malone+goodbyes+
# <Response [200]>
# Hip-Hop/Rap
# 70
# henrique+&+diego+espelho+meu+-+ao+vivo
# <Response [200]>
# Pop Latino
# 71
# mc+g15+ela+vem
# <Response [200]>
# Brazilian
# 72
# lagum+deixa+
# <Response [200]>
# Pop
# 73
# lauana+prado+melhor+saída+-+ao+vivo
# <Response [200]>
# Sertanejo
# 74
# israel+&+rodolffo+conselho+-+ao+vivo
# <Response [200]>
# Israeli
# 75
# mano+walter+então+vem+cá+-+ao+vivo
# <Response [200]>
# Forró
# 76
# zé+neto+&+cristiano+long+neck+-+acústico
# <Response [200]>
# Brazilian
# 77
# ludmilla+favela+chegou+-+ao+vivo
# <Response [200]>
# Baile Funk
# 78
# oriente+praia+do+rosa+-+acústico
# <Response [200]>
# Rap
# 79
# yasmin+santos+então+vou+avisar+-+ao+vivo
# <Response [200]>
# Sertanejo
# 80
# mc+livinho+hoje+eu+vou+parar+na+gaiola
# <Response [200]>
# Baile Funk
# 81
# mc+kevin+o+chris+vamos+pra+gaiola
# <Response [200]>
# Baile Funk
# 82
# henrique+&+juliano+cidade+vizinha+-+ao+vivo
# <Response [200]>
# Pop Latino
# 83
# diego+&+victor+hugo+infarto
# <Response [200]>
# Kids & Family
# 84
# dilsinho+santo+forte+
# <Response [200]>
# Pagode
# 85
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 86
# israel+&+rodolffo+também+sei+fazer+falta+-+ao+vivo
# <Response [200]>
# Israeli
# 87
# wesley+safadão+não+atende+não
# <Response [200]>
# Forró
# 88
# marília+mendonça+obrigado+por+estragar+tudo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 89
# marília+mendonça+bem+pior+que+eu+-+ao+vivo
# <Response [200]>
# Sertanejo
# 90
# alok+all+the+lies
# <Response [200]>
# Dance
# 91
# turma+do+pagode+pesquisa+no+google+
# <Response [200]>
# Pagode
# 92
# avine+vinny+maturidade+
# <Response [200]>
# Forró
# 93
# ferrugem+até+que+enfim+-+ao+vivo
# <Response [200]>
# Brazilian
# 94
# dj+snake+fuego+
# <Response [200]>
# Dance
# 95
# mc+kevinho+facilita
# <Response [200]>
# simone+&+simaria+aperte+o+play+-+ao+vivo
# <Response [200]>
# Jazz
# 97
# marshmello+happier
# <Response [200]>
# Dance
# 98
# zé+felipe+tiro+certo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 99
# wesley+safadão+juras+de+amor+
# <Response [200]>
# Forró
# 100
# gloria+groove+yoyo
# <Response [200]>
# Pop
# 101
# vitão+edredom
# <Response [200]>
# R&B/Soul
# 102
# dj+henrique+de+ferraz+garupa,+pt.+2
# <Response [200]>
# mc+th+rabetão+no+chão
# <Response [200]>
# Baile Funk
# 104
# billie+eilish+bad+guy+
# <Response [200]>
# Alternative
# 105
# lil+nas+x+old+town+road+
# <Response [200]>
# Country
# 106
# meduza+piece+of+your+heart+-+alok+remix
# <Response [200]>
# Dance
# 107
# mc+don+juan+bye+bye
# <Response [200]>
# Baile Funk
# 108
# orochi+balão
# <Response [200]>
# Hip-Hop/Rap
# 109
# thiago+brava+dá+preferência+pra+mim+
# <Response [200]>
# Sertanejo
# 110
# gustavo+mioto+pro+nosso+bem+-+ao+vivo
# <Response [200]>
# Sertanejo
# 111
# post+malone+sunflower+-+spider-man:+into+the+spider-verse
# <Response [200]>
# Hip-Hop/Rap
# 112
# gusttavo+lima+zé+da+recaída+-+ao+vivo
# <Response [200]>
# Sertanejo
# 113
# dj+guuga+vidrado+em+você
# <Response [200]>
# Brazilian
# 114
# melim+dois+corações
# <Response [200]>
# Pop
# 115
# iza+dona+de+mim
# <Response [200]>
# Brazilian
# 116
# marcos+&+belutti+tonelada+de+solidão+
# <Response [200]>
# Dance
# 117
# vitor+kley+morena
# <Response [200]>
# Pop
# 118
# marília+mendonça+passa+mal+-+ao+vivo
# <Response [200]>
# Sertanejo
# 119
# marília+mendonça+love+à+queima+roupa+-+ao+vivo
# <Response [200]>
# Sertanejo
# 120
# vitão+embrasa
# <Response [200]>
# R&B/Soul
# 121
# luan+santana+vingança+-+ao+vivo
# <Response [200]>
# Sertanejo
# 122
# hugo+&+guilherme+namorada+reserva+-+ao+vivo
# <Response [200]>
# Kids & Family
# 123
# yasmin+santos+sofro+onde+eu+quiser
# <Response [200]>
# Sertanejo
# 124
# wesley+safadão+igual+ela+só+uma
# <Response [200]>
# Forró
# 125
# gustavo+mioto+fake+news+-+ao+vivo
# <Response [200]>
# Sertanejo
# 126
# imagine+dragons+believer
# <Response [200]>
# Alternative
# 127
# márcia+fellipe+quem+me+dera
# <Response [200]>
# Forró
# 128
# péricles+supera+-+ao+vivo
# <Response [200]>
# Samba
# 129
# diego+&+arnaldo+regras+-+ao+vivo
# <Response [200]>
# Kids & Family
# 130
# dennis+dj+agora+é+tudo+meu
# <Response [200]>
# Baile Funk
# 131
# lexa+sapequinha
# <Response [200]>
# Brazilian
# 132
# hugo+&+guilherme+teste+da+mãozinha+-+ao+vivo
# <Response [200]>
# Kids & Family
# 133
# marília+mendonça+bye+bye+-+ao+vivo
# <Response [200]>
# Sertanejo
# 134
# xand+avião+casal+raiz+-+ao+vivo
# <Response [200]>
# Forró
# 135
# felipe+original+hit+contagiante
# <Response [200]>
# Baile Funk
# 136
# alok+favela
# <Response [200]>
# Pop
# 137
# vitor+kley+o+sol
# <Response [200]>
# Pop
# 138
# bruno+&+marrone+surto+de+amor+-+ao+vivo+em+uberlândia+/+2018
# <Response [200]>
# Comedy
# 139
# nando+reis+pra+você+guardei+o+amor
# <Response [200]>
# MPB
# 140
# ozuna+muito+calor
# <Response [200]>
# Urbano latino
# 141
# wesley+safadão+só+pra+castigar
# <Response [200]>
# Forró
# 142
# dilsinho+pouco+a+pouco+
# <Response [200]>
# Pagode
# 143
# orgânico+dizeres
# <Response [200]>
# Hip-Hop/Rap
# 144
# diego+&+victor+hugo+áudio+-+ao+vivo+em+brasília
# <Response [200]>
# Kids & Family
# 145
# casa+worship+a+casa+é+sua
# <Response [200]>
# Christian & Gospel
# 146
# pineapple+stormtv+você+não+ama+ninguém
# <Response [200]>
# Hip-Hop/Rap
# 147
# anavitória+fica+-+bonus+track
# <Response [200]>
# anavitória+ai,+amor
# <Response [200]>
# Pop
# 149
# maiara+&+maraisa+nem+tchum+-+ao+vivo
# <Response [200]>
# Society & Culture
# 150
# mc+l+da+vinte+parado+no+bailão
# <Response [200]>
# Baile Funk
# 151
# sam+smith+dancing+with+a+stranger+
# <Response [200]>
# Pop
# 152
# breno+&+caio+cesar+deixa+eu+te+chamar+de+meu+amor
# <Response [200]>
# Hip-Hop/Rap
# 153
# henrique+&+juliano+quem+pegou,+pegou+-+ao+vivo
# <Response [200]>
# Pop Latino
# 154
# 1kilo+deixe+me+ir+-+acústico
# <Response [200]>
# Pop
# 155
# zé+neto+&+cristiano+largado+às+traças+-+ao+vivo
# <Response [200]>
# Brazilian
# 156
# ed+sheeran+shape+of+you
# <Response [200]>
# Pop
# 157
# gusttavo+lima+respeita+o+nosso+fim+-+ao+vivo
# <Response [200]>
# Sertanejo
# 158
# jorge+&+mateus+propaganda+-+ao+vivo
# <Response [200]>
# Electronic
# 159
# clau+pouca+pausa
# <Response [200]>
# Pop
# 160
# mc+kevin+o+chris+namorar+não+dá
# <Response [200]>
# Baile Funk
# 161
# zé+neto+&+cristiano+enchendo+e+derramando
# <Response [200]>
# Brazilian
# 162
# anitta+terremoto
# <Response [200]>
# Pop
# 163
# mc+kevin+o+chris+medley+da+gaiola+-+dennis+dj+remix
# <Response [200]>
# Baile Funk
# 164
# zé+neto+&+cristiano+status+que+eu+não+queria+-+ao+vivo
# <Response [200]>
# Brazilian
# 165
# lulu+santos+apenas+mais+uma+de+amor
# <Response [200]>
# MPB
# 166
# oriente+mandona+-+acústico
# <Response [200]>
# Rap
# 167
# taylor+swift+the+archer
# <Response [200]>
# Pop
# 168
# ludmilla+invocada+
# <Response [200]>
# Brazilian
# 169
# gusttavo+lima+eu+não+iria+-+ao+vivo
# <Response [200]>
# Sertanejo
# 170
# maiara+&+maraisa+bebo+litro+-+ao+vivo
# <Response [200]>
# Society & Culture
# 171
# marília+mendonça+ausência+-+ao+vivo+|+acústico
# <Response [200]>
# Sertanejo
# 172
# shawn+mendes+if+i+cant+have+you
# <Response [200]>
# Pop
# 173
# dj+snake+loco+contigo+
# <Response [200]>
# Latino
# 174
# anavitória+trevo+
# <Response [200]>
# Pop
# 175
# delacruz+poesia+acústica+#2:+sobre+nós
# <Response [200]>
# maroon+5+girls+like+you+
# <Response [200]>
# Pop
# 177
# queen+bohemian+rhapsody+-+2011+mix
# <Response [200]>
# Rock
# 178
# pineapple+stormtv+poesia+acústica+#3:+capricorniana
# <Response [200]>
# agnes+nunes+cida
# <Response [200]>
# Pop
# 180
# yasmin+santos+saudade+nível+hard
# <Response [200]>
# Pop
# 181
# lagum+oi
# <Response [200]>
# Pop
# 182
# boyzinho+o+rei+da+bregadeira+trip+do+boyzinho
# <Response [200]>
# Worldwide
# 183
# marília+mendonça+amigo+emprestado+-+ao+vivo
# <Response [200]>
# Sertanejo
# 184
# mc+don+juan+to+gostando+tanto+de+você
# <Response [200]>
# Baile Funk
# 185
# post+malone+rockstar+
# <Response [200]>
# Hip-Hop/Rap
# 186
# liu+nave+espacial+-+radio+edit
# <Response [200]>
# House
# 187
# ed+sheeran+south+of+the+border+
# <Response [200]>
# Pop
# 188
# halsey+without+me
# <Response [200]>
# Alternative
# 189
# lil+nas+x+old+town+road
# <Response [200]>
# Country
# 190
# alok+ocean
# <Response [200]>
# Dance
# 191
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 192
# ferrugem+é+natural+
# <Response [200]>
# Pagode
# 193
# mc+du+black+gaiola+é+o+troco
# <Response [200]>
# Baile Funk
# 194
# lizzo+truth+hurts
# <Response [200]>
# Dance
# 195
# ariana+grande+thank+u,+next
# <Response [200]>
# Pop
# 196
# gustavo+mioto+anti-amor+-+ao+vivo
# <Response [200]>
# Sertanejo
# 197
# emicida+amarelo+
# <Response [200]>
# Brazilian
# 198
# turma+do+pagode+sua+mãe+vai+me+amar
# <Response [200]>
# Pagode
# 199
# br_2019-08-02--2019-08-09.csv
# marília+mendonça+todo+mundo+vai+sofrer+-+ao+vivo
# <Response [200]>
# Sertanejo
# 0
# jorge+&+mateus+tijolão+-+ao+vivo
# <Response [200]>
# Electronic
# 1
# joão+gustavo+e+murilo+lençol+dobrado
# <Response [200]>
# Brazilian
# 2
# luan+santana+quando+a+bad+bater+-+ao+vivo
# <Response [200]>
# Sertanejo
# 3
# mc+kevinho+uma+nora+pra+cada+dia
# <Response [200]>
# Brazilian
# 4
# mc+kevin+o+chris+evoluiu
# <Response [200]>
# Baile Funk
# 5
# matheus+&+kauan+vou+ter+que+superar+-+ao+vivo
# <Response [200]>
# Pop
# 6
# gusttavo+lima+milu
# <Response [200]>
# Sertanejo
# 7
# pk+quando+a+vontade+bater+
# <Response [200]>
# Hip-Hop/Rap
# 8
# mc+jottapê+sentou+e+gostou
# <Response [200]>
# Brazilian
# 9
# lauana+prado+cobaia
# <Response [200]>
# Sertanejo
# 10
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 11
# matheus+&+kauan+quarta+cadeira+-+ao+vivo
# <Response [200]>
# Pop
# 12
# xand+avião+algo+mais+
# <Response [200]>
# Forró
# 13
# zé+neto+&+cristiano+ferida+curada
# <Response [200]>
# Brazilian
# 14
# marília+mendonça+bebi+liguei+-+ao+vivo
# <Response [200]>
# Sertanejo
# 15
# felipe+original+hit+contagiante
# <Response [200]>
# Baile Funk
# 16
# zé+neto+&+cristiano+estado+decadente+-+acústico
# <Response [200]>
# Brazilian
# 17
# diego+&+victor+hugo+a+culpa+é+do+meu+grau+
# <Response [200]>
# Kids & Family
# 18
# felipe+araújo+espaçosa+demais+-+ao+vivo
# <Response [200]>
# Sertanejo
# 19
# mc+kevin+o+chris+ela+é+do+tipo
# <Response [200]>
# Baile Funk
# 20
# lil+nas+x+old+town+road+-+remix
# <Response [200]>
# Country
# 21
# marília+mendonça+bebaça+-+ao+vivo
# <Response [200]>
# Sertanejo
# 22
# mano+walter+fingindo+maturidade+-+ao+vivo
# <Response [200]>
# Sertanejo
# 23
# maiara+&+maraisa+não+abro+mão+-+ao+vivo
# <Response [200]>
# Society & Culture
# 24
# anavitória+pupila
# <Response [200]>
# Pop
# 25
# pineapple+stormtv+poesia+acústica+#7:+céu+azul
# <Response [200]>
# gustavo+mioto+solteiro+não+trai+-+ao+vivo
# <Response [200]>
# Sertanejo
# 27
# dilsinho+péssimo+negócio+
# <Response [200]>
# Pagode
# 28
# hungria+hip+hop+um+pedido
# <Response [200]>
# Hip-Hop/Rap
# 29
# projota+sei+lá
# <Response [200]>
# Hip-Hop/Rap
# 30
# ariana+grande+boyfriend+
# <Response [200]>
# Pop
# 31
# anitta+onda+diferente+
# <Response [200]>
# Latino
# 32
# zé+neto+&+cristiano+notificação+preferida+-+ao+vivo
# <Response [200]>
# Brazilian
# 33
# mc+wm+senta+braba
# <Response [200]>
# Baile Funk
# 34
# george+henrique+&+rodrigo+bagunça+minha+vida+-+ao+vivo+em+goiânia+/+2019
# <Response [200]>
# Concert Films
# 35
# marília+mendonça+sem+sal+-+ao+vivo
# <Response [200]>
# Sertanejo
# 36
# gusttavo+lima+cem+mil+-+ao+vivo
# <Response [200]>
# Sertanejo
# 37
# iza+brisa
# <Response [200]>
# Brazilian
# 38
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 39
# yasmin+santos+para,+pensa+e+volta+-+ao+vivo
# <Response [200]>
# Sertanejo
# 40
# marília+mendonça+serenata+-+ao+vivo
# <Response [200]>
# Sertanejo
# 41
# pocah+não+sou+obrigada
# <Response [200]>
# Baile Funk
# 42
# raí+saia+rodada+bebe+e+vem+me+procurar
# <Response [200]>
# Forró
# 43
# pedro+sampaio+vai+menina
# <Response [200]>
# Pop
# 44
# a+banca+records+outro+dia
# <Response [200]>
# Hip-Hop/Rap
# 45
# matheus+&+kauan+mágica+-+ao+vivo
# <Response [200]>
# Pop
# 46
# pineapple+stormtv+poesia+acústica+#6:+era+uma+vez
# <Response [200]>
# sam+smith+how+do+you+sleep?
# <Response [200]>
# Pop
# 48
# luísa+sonza+garupa
# <Response [200]>
# Pop
# 49
# vitão+café
# <Response [200]>
# Pop
# 50
# lucas+lucco+posto+24h+
# <Response [200]>
# Sertanejo
# 51
# murilo+huff+dois+enganados
# <Response [200]>
# Sertanejo
# 52
# melim+meu+abrigo
# <Response [200]>
# Pop
# 53
# sorriso+maroto+50+vezes+-+ao+vivo
# <Response [200]>
# Pagode
# 54
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 55
# diego+&+victor+hugo+do+copo+eu+vim+
# <Response [200]>
# Kids & Family
# 56
# marília+mendonça+apaixonadinha+-+ao+vivo
# <Response [200]>
# Sertanejo
# 57
# melim+ouvi+dizer
# <Response [200]>
# Brazilian
# 58
# diego+&+victor+hugo+áudio+-+ao+vivo+em+brasília
# <Response [200]>
# Kids & Family
# 59
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 60
# dynho+alves+malemolência
# <Response [200]>
# Brazilian
# 61
# guilherme+&+benuto+flor+que+se+cheira+-+ao+vivo
# <Response [200]>
# Sertanejo
# 62
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 63
# marília+mendonça+ciumeira+-+ao+vivo
# <Response [200]>
# Sertanejo
# 64
# pabllo+vittar+flash+pose
# <Response [200]>
# Pop
# 65
# avine+vinny+volta+vai+
# <Response [200]>
# Forró
# 66
# felipe+araújo+atrasadinha+-+ao+vivo
# <Response [200]>
# Sertanejo
# 67
# mc+g15+ela+vem
# <Response [200]>
# Brazilian
# 68
# israel+&+rodolffo+também+sei+fazer+falta+-+ao+vivo
# <Response [200]>
# Israeli
# 69
# lagum+deixa+
# <Response [200]>
# Pop
# 70
# fernando+&+sorocaba+cara+feio+-+ao+vivo
# <Response [200]>
# Pop
# 71
# mc+kevin+o+chris+resenha+lá+em+casa
# <Response [200]>
# Brazilian
# 72
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 73
# madonna+faz+gostoso+
# <Response [200]>
# Pop
# 74
# oriente+praia+do+rosa+-+acústico
# <Response [200]>
# Rap
# 75
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 76
# henrique+&+diego+espelho+meu+-+ao+vivo
# <Response [200]>
# Pop Latino
# 77
# tropkillaz+bola+rebola
# <Response [200]>
# Pop
# 78
# post+malone+goodbyes+
# <Response [200]>
# Hip-Hop/Rap
# 79
# lauana+prado+melhor+saída+-+ao+vivo
# <Response [200]>
# Sertanejo
# 80
# ferrugem+até+que+enfim+-+ao+vivo
# <Response [200]>
# Brazilian
# 81
# mano+walter+então+vem+cá+-+ao+vivo
# <Response [200]>
# Forró
# 82
# dilsinho+santo+forte+
# <Response [200]>
# Pagode
# 83
# yasmin+santos+então+vou+avisar+-+ao+vivo
# <Response [200]>
# Sertanejo
# 84
# marília+mendonça+obrigado+por+estragar+tudo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 85
# zé+neto+&+cristiano+long+neck+-+acústico
# <Response [200]>
# Brazilian
# 86
# henrique+&+juliano+cidade+vizinha+-+ao+vivo
# <Response [200]>
# Pop Latino
# 87
# avine+vinny+maturidade+
# <Response [200]>
# Forró
# 88
# mc+ysa+baile+da+colômbia+
# <Response [200]>
# Baile Funk
# 89
# boyzinho+o+rei+da+bregadeira+trip+do+boyzinho
# <Response [200]>
# Worldwide
# 90
# turma+do+pagode+pesquisa+no+google+
# <Response [200]>
# Pagode
# 91
# marshmello+happier
# <Response [200]>
# Dance
# 92
# diego+&+victor+hugo+infarto
# <Response [200]>
# Kids & Family
# 93
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 94
# mc+livinho+hoje+eu+vou+parar+na+gaiola
# <Response [200]>
# Baile Funk
# 95
# vitão+edredom
# <Response [200]>
# R&B/Soul
# 96
# mc+du+black+gaiola+é+o+troco
# <Response [200]>
# Baile Funk
# 97
# wesley+safadão+não+atende+não
# <Response [200]>
# Forró
# 98
# marília+mendonça+bem+pior+que+eu+-+ao+vivo
# <Response [200]>
# Sertanejo
# 99
# mc+kevin+o+chris+vamos+pra+gaiola
# <Response [200]>
# Baile Funk
# 100
# iza+dona+de+mim
# <Response [200]>
# Brazilian
# 101
# zé+felipe+tiro+certo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 102
# orochi+balão
# <Response [200]>
# Hip-Hop/Rap
# 103
# post+malone+sunflower+-+spider-man:+into+the+spider-verse
# <Response [200]>
# Hip-Hop/Rap
# 104
# dj+guuga+vidrado+em+você
# <Response [200]>
# Brazilian
# 105
# israel+&+rodolffo+conselho+-+ao+vivo
# <Response [200]>
# Israeli
# 106
# gustavo+mioto+pro+nosso+bem+-+ao+vivo
# <Response [200]>
# Sertanejo
# 107
# simone+&+simaria+aperte+o+play+-+ao+vivo
# <Response [200]>
# Jazz
# 108
# melim+dois+corações
# <Response [200]>
# Pop
# 109
# mc+kevinho+facilita
# <Response [200]>
# lil+nas+x+old+town+road
# <Response [200]>
# Country
# 111
# gloria+groove+yoyo
# <Response [200]>
# Pop
# 112
# mc+don+juan+bye+bye
# <Response [200]>
# Baile Funk
# 113
# gusttavo+lima+zé+da+recaída+-+ao+vivo
# <Response [200]>
# Sertanejo
# 114
# meduza+piece+of+your+heart+-+alok+remix
# <Response [200]>
# Dance
# 115
# mc+th+rabetão+no+chão
# <Response [200]>
# Baile Funk
# 116
# dj+henrique+de+ferraz+garupa,+pt.+2
# <Response [200]>
# vitão+embrasa
# <Response [200]>
# R&B/Soul
# 118
# billie+eilish+bad+guy+
# <Response [200]>
# Alternative
# 119
# vitor+kley+morena
# <Response [200]>
# Pop
# 120
# marcos+&+belutti+tonelada+de+solidão+
# <Response [200]>
# Dance
# 121
# hugo+&+guilherme+namorada+reserva+-+ao+vivo
# <Response [200]>
# Kids & Family
# 122
# thiago+brava+dá+preferência+pra+mim+
# <Response [200]>
# Sertanejo
# 123
# marília+mendonça+love+à+queima+roupa+-+ao+vivo
# <Response [200]>
# Sertanejo
# 124
# dj+snake+fuego+
# <Response [200]>
# Dance
# 125
# ludmilla+favela+chegou+-+ao+vivo
# <Response [200]>
# Baile Funk
# 126
# gustavo+mioto+fake+news+-+ao+vivo
# <Response [200]>
# Sertanejo
# 127
# marília+mendonça+passa+mal+-+ao+vivo
# <Response [200]>
# Sertanejo
# 128
# wesley+safadão+igual+ela+só+uma
# <Response [200]>
# Forró
# 129
# yasmin+santos+sofro+onde+eu+quiser
# <Response [200]>
# Sertanejo
# 130
# imagine+dragons+believer
# <Response [200]>
# Alternative
# 131
# péricles+supera+-+ao+vivo
# <Response [200]>
# Samba
# 132
# luan+santana+vingança+-+ao+vivo
# <Response [200]>
# Sertanejo
# 133
# márcia+fellipe+quem+me+dera
# <Response [200]>
# Forró
# 134
# casa+worship+a+casa+é+sua
# <Response [200]>
# Christian & Gospel
# 135
# maiara+&+maraisa+nem+tchum+-+ao+vivo
# <Response [200]>
# Society & Culture
# 136
# xand+avião+casal+raiz+-+ao+vivo
# <Response [200]>
# Forró
# 137
# dilsinho+pouco+a+pouco+
# <Response [200]>
# Pagode
# 138
# nando+reis+pra+você+guardei+o+amor
# <Response [200]>
# MPB
# 139
# alok+all+the+lies
# <Response [200]>
# Dance
# 140
# diego+&+arnaldo+regras+-+ao+vivo
# <Response [200]>
# Kids & Family
# 141
# orgânico+dizeres
# <Response [200]>
# Hip-Hop/Rap
# 142
# anavitória+fica+-+bonus+track
# <Response [200]>
# pineapple+stormtv+você+não+ama+ninguém
# <Response [200]>
# Hip-Hop/Rap
# 144
# lagum+oi
# <Response [200]>
# Pop
# 145
# marília+mendonça+bye+bye+-+ao+vivo
# <Response [200]>
# Sertanejo
# 146
# ludmilla+invocada+
# <Response [200]>
# Brazilian
# 147
# anavitória+ai,+amor
# <Response [200]>
# Pop
# 148
# vitor+kley+o+sol
# <Response [200]>
# Pop
# 149
# dennis+dj+agora+é+tudo+meu
# <Response [200]>
# Baile Funk
# 150
# sam+smith+dancing+with+a+stranger+
# <Response [200]>
# Pop
# 151
# alok+favela
# <Response [200]>
# Pop
# 152
# oriente+mandona+-+acústico
# <Response [200]>
# Rap
# 153
# bruno+&+marrone+surto+de+amor+-+ao+vivo+em+uberlândia+/+2018
# <Response [200]>
# Comedy
# 154
# lulu+santos+apenas+mais+uma+de+amor
# <Response [200]>
# MPB
# 155
# zé+neto+&+cristiano+largado+às+traças+-+ao+vivo
# <Response [200]>
# Brazilian
# 156
# gusttavo+lima+respeita+o+nosso+fim+-+ao+vivo
# <Response [200]>
# Sertanejo
# 157
# 1kilo+deixe+me+ir+-+acústico
# <Response [200]>
# Pop
# 158
# chris+brown+no+guidance+
# <Response [200]>
# R&B/Soul
# 159
# clau+pouca+pausa
# <Response [200]>
# Pop
# 160
# agnes+nunes+cida
# <Response [200]>
# Pop
# 161
# lexa+sapequinha
# <Response [200]>
# Brazilian
# 162
# hugo+&+guilherme+teste+da+mãozinha+-+ao+vivo
# <Response [200]>
# Kids & Family
# 163
# dj+snake+loco+contigo+
# <Response [200]>
# Latino
# 164
# wesley+safadão+só+pra+castigar
# <Response [200]>
# Forró
# 165
# mc+kevin+o+chris+namorar+não+dá
# <Response [200]>
# Baile Funk
# 166
# ed+sheeran+shape+of+you
# <Response [200]>
# Pop
# 167
# zé+neto+&+cristiano+enchendo+e+derramando
# <Response [200]>
# Brazilian
# 168
# breno+&+caio+cesar+deixa+eu+te+chamar+de+meu+amor
# <Response [200]>
# Hip-Hop/Rap
# 169
# wesley+safadão+juras+de+amor+
# <Response [200]>
# Forró
# 170
# anavitória+trevo+
# <Response [200]>
# Pop
# 171
# jorge+&+mateus+propaganda+-+ao+vivo
# <Response [200]>
# Electronic
# 172
# henrique+&+juliano+quem+pegou,+pegou+-+ao+vivo
# <Response [200]>
# Pop Latino
# 173
# gusttavo+lima+eu+não+iria+-+ao+vivo
# <Response [200]>
# Sertanejo
# 174
# halsey+without+me
# <Response [200]>
# Alternative
# 175
# marília+mendonça+ausência+-+ao+vivo+|+acústico
# <Response [200]>
# Sertanejo
# 176
# mc+l+da+vinte+parado+no+bailão
# <Response [200]>
# Baile Funk
# 177
# shawn+mendes+if+i+cant+have+you
# <Response [200]>
# Pop
# 178
# ozuna+muito+calor
# <Response [200]>
# Urbano latino
# 179
# delacruz+poesia+acústica+#2:+sobre+nós
# <Response [200]>
# pineapple+stormtv+poesia+acústica+#3:+capricorniana
# <Response [200]>
# queen+bohemian+rhapsody+-+2011+mix
# <Response [200]>
# Rock
# 182
# anuel+aa+china
# <Response [200]>
# Urbano latino
# 183
# anitta+terremoto
# <Response [200]>
# Pop
# 184
# ariana+grande+thank+u,+next
# <Response [200]>
# Pop
# 185
# ferrugem+pra+você+acreditar+-+ao+vivo
# <Response [200]>
# Pagode
# 186
# maroon+5+girls+like+you+
# <Response [200]>
# Pop
# 187
# ferrugem+é+natural+
# <Response [200]>
# Pagode
# 188
# zé+neto+&+cristiano+status+que+eu+não+queria+-+ao+vivo
# <Response [200]>
# Brazilian
# 189
# maiara+&+maraisa+bebo+litro+-+ao+vivo
# <Response [200]>
# Society & Culture
# 190
# mc+kevin+o+chris+medley+da+gaiola+-+dennis+dj+remix
# <Response [200]>
# Baile Funk
# 191
# pixote+nem+de+graça
# <Response [200]>
# Pagode
# 192
# liu+nave+espacial+-+radio+edit
# <Response [200]>
# House
# 193
# atitude+67+tão+linda
# <Response [200]>
# Pagode
# 194
# gusttavo+lima+online
# <Response [200]>
# Sertanejo
# 195
# turma+do+pagode+sua+mãe+vai+me+amar
# <Response [200]>
# ...
# Axé
# 168
# luan+santana+sofrendo+feito+um+louco+-+summer+version
# <Response [200]>
# Sertanejo
# 169
# mc+kevin+o+chris+deixa+a+pepeca+-+ao+vivo
# <Response [200]>
# Brazilian
# 170
# meduza+piece+of+your+heart+-+alok+remix
# <Response [200]>
# Dance
# 171
# dua+lipa+physical
# <Response [200]>
# Pop
# 172
# pineapple+stormtv+poesia+acústica+#7:+céu+azul
# <Response [200]>
# vitão+café
# <Response [200]>
# Pop
# 174
# the+weeknd+after+hours
# <Response [200]>
# R&B/Soul
# 175
# hugo+&+guilherme+namorada+reserva+-+ao+vivo
# <Response [200]>
# Kids & Family
# 176
# iza+dona+de+mim
# <Response [200]>
# Brazilian
# 177
# marília+mendonça+bebaça+-+ao+vivo
# <Response [200]>
# Sertanejo
# 178
# ludmilla+pulando+na+pipoca
# <Response [200]>
# Brazilian
# 179
# camila+cabello+my+oh+my+
# <Response [200]>
# Pop
# 180
# gusttavo+lima+milu
# <Response [200]>
# Sertanejo
# 181
# doja+cat+say+so
# <Response [200]>
# R&B/Soul
# 182
# dj+pernambuco+vem+me+satisfazer+-+remix+brega+funk
# <Response [200]>
# Brazilian
# 183
# henrique+&+juliano+conheço+meu+gado+-+ao+vivo
# <Response [200]>
# Pop Latino
# 184
# melim+dois+corações
# <Response [200]>
# Pop
# 185
# mc+wm+para+não
# <Response [200]>
# Brazilian
# 186
# guilherme+&+benuto+declaração+pro+bar+-+ao+vivo
# <Response [200]>
# Sertanejo
# 187
# henrique+&+juliano+se+eu+fosse+você+-+ao+vivo
# <Response [200]>
# Pop Latino
# 188
# selena+gomez+feel+me
# <Response [200]>
# Pop
# 189
# thiaguinho+deixa+tudo+como+tá+-+ao+vivo
# <Response [200]>
# Pagode
# 190
# dj+felipe+único+mochila+nas+costas+/+empurra+empurra
# <Response [200]>
# Baile Funk
# 191
# bts+black+swan
# <Response [200]>
# K-Pop
# 192
# regard+ride+it
# <Response [200]>
# Dance
# 193
# lil+nas+x+old+town+road+-+remix
# <Response [200]>
# Country
# 194
# mc+bola+positividade
# <Response [200]>
# Brazilian
# 195
# dj+guuga+7+dias+7+corpos
# <Response [200]>
# Brazilian
# 196
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 197
# dennis+dj+isso+que+é+vida
# <Response [200]>
# Baile Funk
# 198
# os+barões+da+pisadinha+chupadinha
# <Response [200]>
# Pop
# 199
# br_2020-02-28--2020-03-06.csv
# henrique+&+juliano+liberdade+provisória+-+ao+vivo
# <Response [200]>
# Pop Latino
# 0
# gusttavo+lima+a+gente+fez+amor+-+ao+vivo
# <Response [200]>
# Sertanejo
# 1
# pedro+sampaio+sentadão
# <Response [200]>
# Brazilian
# 2
# thiaguinho+mt+tudo+ok
# <Response [200]>
# Pop
# 3
# matheus+&+kauan+litrão+-+ao+vivo
# <Response [200]>
# Pop
# 4
# marília+mendonça+graveto+-+ao+vivo
# <Response [200]>
# Sertanejo
# 5
# major+lazer+rave+de+favela+
# <Response [200]>
# Brazilian
# 6
# mc+ingryd+vem+me+satisfazer
# <Response [200]>
# Baile Funk
# 7
# gustavo+mioto+com+ou+sem+mim+-+ao+vivo
# <Response [200]>
# Sertanejo
# 8
# tones+and+i+dance+monkey
# <Response [200]>
# Alternative
# 9
# luíza+&+maurílio+s+de+saudade
# <Response [200]>
# Jazz
# 10
# zé+neto+&+cristiano+bebi+minha+bicicleta+
# <Response [200]>
# Brazilian
# 11
# jorge+&+mateus+cheirosa+-+ao+vivo
# <Response [200]>
# Electronic
# 12
# anitta+combatchy+
# <Response [200]>
# Brazilian
# 13
# lady+gaga+stupid+love
# <Response [200]>
# Pop
# 14
# guilherme+&+benuto+3+batidas+-+ao+vivo
# <Response [200]>
# Sertanejo
# 15
# os+parazim+porta+mala
# <Response [200]>
# Sertanejo
# 16
# dua+lipa+dont+start+now
# <Response [200]>
# Electronic
# 17
# marília+mendonça+supera+-+ao+vivo
# <Response [200]>
# Sertanejo
# 18
# dadá+boladão+surtada+-+remix+brega+funk
# <Response [200]>
# Baile Funk
# 19
# henrique+&+juliano+volta+por+baixo+-+ao+vivo
# <Response [200]>
# Pop Latino
# 20
# maiara+&+maraisa+aí+eu+bebo+-+ao+vivo
# <Response [200]>
# Society & Culture
# 21
# giulia+be+menina+solta
# <Response [200]>
# Electronic
# 22
# pabllo+vittar+amor+de+que
# <Response [200]>
# Pop
# 23
# wc+no+beat+balança
# <Response [200]>
# Baile Funk
# 24
# jorge+&+mateus+tijolão+-+ao+vivo
# <Response [200]>
# Electronic
# 25
# henrique+&+juliano+briga+feia+-+ao+vivo
# <Response [200]>
# Pop Latino
# 26
# dennis+dj+te+prometo
# <Response [200]>
# Baile Funk
# 27
# anitta+some+que+ele+vem+atrás
# <Response [200]>
# Brazilian
# 28
# ludmilla+verdinha
# <Response [200]>
# Brazilian
# 29
# mc+jottapê+eterna+sacanagem
# <Response [200]>
# Brazilian
# 30
# mc+du+black+gaiola+é+o+troco
# <Response [200]>
# Baile Funk
# 31
# mc+kevinho+paredão
# <Response [200]>
# Brazilian
# 32
# joão+gustavo+e+murilo+lençol+dobrado
# <Response [200]>
# Brazilian
# 33
# lexa+chama+ela+
# <Response [200]>
# Brazilian
# 34
# gusttavo+lima+quem+traiu+levou+-+ao+vivo
# <Response [200]>
# Sertanejo
# 35
# leo+santana+contatinho+-+ao+vivo
# <Response [200]>
# Axé
# 36
# felipe+original+hit+contagiante
# <Response [200]>
# Baile Funk
# 37
# marília+mendonça+serenata+-+ao+vivo
# <Response [200]>
# Sertanejo
# 38
# gusttavo+lima+carreira+solo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 39
# wesley+safadão+dois+lados
# <Response [200]>
# Sertanejo
# 40
# diego+&+victor+hugo+áudio+-+ao+vivo+em+brasília
# <Response [200]>
# Kids & Family
# 41
# matheus+&+kauan+quarta+cadeira+-+ao+vivo
# <Response [200]>
# Pop
# 42
# zé+felipe+tiro+certo+-+ao+vivo
# <Response [200]>
# Sertanejo
# 43
# zé+neto+&+cristiano+barzinho+aleatório+-+ao+vivo
# <Response [200]>
# Brazilian
# 44
# diego+&+arnaldo+relógio+parado+
# <Response [200]>
# Kids & Family
# 45
# anavitória+pupila
# <Response [200]>
# Pop
# 46
# the+weeknd+blinding+lights
# <Response [200]>
# R&B/Soul
# 47
# justin+bieber+yummy
# <Response [200]>
# Pop
# 48
# roddy+ricch+the+box
# <Response [200]>
# Hip-Hop/Rap
# 49
# zé+neto+&+cristiano+ferida+curada
# <Response [200]>
# Brazilian
# 50
# matuê+kenny+g
# <Response [200]>
# Rap
# 51
# jorge+&+mateus+mil+anos+-+recorded+at+mosh+studios,+são+paulo
# <Response [200]>
# Electronic
# 52
# gusttavo+lima+perrengue+-+ao+vivo
# <Response [200]>
# Sertanejo
# 53
# humberto+&+ronaldo+tchau+brigado+-+ao+vivo
# <Response [200]>
# Dance
# 54
# vitão+complicado
# <Response [200]>
# R&B/Soul
# 55
# gustavo+mioto+fake+news+-+ao+vivo
# <Response [200]>
# Sertanejo
# 56
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 57
# luan+santana+choque+térmico+-+ao+vivo
# <Response [200]>
# Sertanejo
# 58
# doja+cat+say+so
# <Response [200]>
# R&B/Soul
# 59
# felipe+araújo+mentira+-+ao+vivo
# <Response [200]>
# Sertanejo
# 60
# marília+mendonça+tentativas
# <Response [200]>
# Sertanejo
# 61
# pk+quando+a+vontade+bater+
# <Response [200]>
# Hip-Hop/Rap
# 62
# orochi+amor+de+fim+de+noite
# <Response [200]>
# Hip-Hop/Rap
# 63
# justin+bieber+intentions+
# <Response [200]>
# Pop
# 64
# matheus+&+kauan+vou+ter+que+superar+-+ao+vivo
# <Response [200]>
# Pop
# 65
# yasmin+santos+para,+pensa+e+volta+-+ao+vivo
# <Response [200]>
# Sertanejo
# 66
# priscilla+alcantara+girassol
# <Response [200]>
# Christian & Gospel
# 67
# trevor+daniel+falling
# <Response [200]>
# Pop
# 68
# mc+poze+do+rodo+to+voando+alto
# <Response [200]>
# Baile Funk
# 69
# diego+&+victor+hugo+erro+antigo+-+ao+vivo
# <Response [200]>
# Kids & Family
# 70
# atitude+67+tão+linda
# <Response [200]>
# Pagode
# 71
# simone+&+simaria+amoreco
# <Response [200]>
# Jazz
# 72
# ludmilla+invocada+
# <Response [200]>
# Brazilian
# 73
# marcos+&+belutti+certo+e+duvidoso+
# <Response [200]>
# Dance
# 74
# karol+g+tusa
# <Response [200]>
# Urbano latino
# 75
# mc+g15+ela+vem
# <Response [200]>
# Brazilian
# 76
# mc+jottapê+bate+palma
# <Response [200]>
# Brazilian
# 77
# dayvi+baila+conmigo+
# <Response [200]>
# Pop Latino
# 78
# alok+on+&+on
# <Response [200]>
# Dance
# 79
# melim+meu+abrigo
# <Response [200]>
# Pop
# 80
# luan+santana+quando+a+bad+bater+-+ao+vivo
# <Response [200]>
# Sertanejo
# 81
# black+eyed+peas+ritmo+
# <Response [200]>
# Pop
# 82
# rennan+da+penha+carnaval+chegando
# <Response [200]>
# Baile Funk
# 83
# meduza+lose+control
# <Response [200]>
# Dance
# 84
# xand+avião+algo+mais+
# <Response [200]>
# Forró
# 85
# zé+neto+&+cristiano+textão+-+ao+vivo
# <Response [200]>
# Brazilian
# 86
# sidoka+não+me+sinto+mal+mais
# <Response [200]>
# Hip-Hop/Rap
# 87
# post+malone+circles
# <Response [200]>
# House
# 88
# mc+jottapê+sentou+e+gostou
# <Response [200]>
# Brazilian
# 89
# pabllo+vittar+parabéns
# <Response [200]>
# Pop
# 90
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 91
# felipe+araújo+espaçosa+demais+-+ao+vivo
# <Response [200]>
# Sertanejo
# 92
# pineapple+stormtv+poesia+acústica+#8:+amor+e+samba
# <Response [200]>
# pixote+nem+de+graça+/+saudade+arregaça+-+ao+vivo
# <Response [200]>
# Pagode
# 94
# melim+gelo
# <Response [200]>
# Pop
# 95
# projota+sei+lá
# <Response [200]>
# Hip-Hop/Rap
# 96
# melim+ouvi+dizer
# <Response [200]>
# Brazilian
# 97
# marília+mendonça+todo+mundo+vai+sofrer+-+ao+vivo
# <Response [200]>
# Sertanejo
# 98
# mc+kevin+o+chris+resenha+lá+em+casa
# <Response [200]>
# Brazilian
# 99
# joão+bosco+&+vinicius+segunda+taça+-+ao+vivo
# <Response [200]>
# MPB
# 100
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 101
# pineapple+stormtv+poesia+acústica+#6:+era+uma+vez
# <Response [200]>
# mc+livinho+se+prepara+2
# <Response [200]>
# Brazilian
# 103
# mc+anônimo+pagou+de+superada
# <Response [200]>
# Latino
# 104
# gustavo+mioto+solteiro+não+trai+-+ao+vivo
# <Response [200]>
# Sertanejo
# 105
# arizona+zervas+roxanne
# <Response [200]>
# Hip-Hop/Rap
# 106
# diego+&+victor+hugo+a+culpa+é+do+meu+grau+
# <Response [200]>
# Kids & Family
# 107
# mc+lele+jp+sou+vitorioso
# <Response [200]>
# Brazilian
# 108
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 109
# gusttavo+lima+chora+até+perder+a+fala+-+ao+vivo
# <Response [200]>
# Sertanejo
# 110
# maroon+5+memories
# <Response [200]>
# Pop
# 111
# vou+pro+sereno+teu+segredo+-+ao+vivo
# <Response [200]>
# Pagode
# 112
# lauana+prado+cobaia
# <Response [200]>
# Sertanejo
# 113
# henrique+&+juliano+não+gosto+eu+amo+-+ao+vivo
# <Response [200]>
# Pop Latino
# 114
# marília+mendonça+bebi+liguei+-+ao+vivo
# <Response [200]>
# Sertanejo
# 115
# harry+styles+adore+you
# <Response [200]>
# Pop
# 116
# henrique+&+juliano+alô+bebê+-+ao+vivo
# <Response [200]>
# Pop Latino
# 117
# lagum+deixa+
# <Response [200]>
# Pop
# 118
# dilsinho+péssimo+negócio+
# <Response [200]>
# Pagode
# 119
# pocah+não+sou+obrigada
# <Response [200]>
# Baile Funk
# 120
# mano+walter+fingindo+maturidade+-+ao+vivo
# <Response [200]>
# Sertanejo
# 121
# iza+meu+talismã
# <Response [200]>
# Brazilian
# 122
# murilo+huff+dois+enganados
# <Response [200]>
# Sertanejo
# 123
# henrique+&+juliano+não+tenho+coragem+-+ao+vivo
# <Response [200]>
# Pop Latino
# 124
# gustavo+mioto+plaquinha+de+aviso+-+ao+vivo
# <Response [200]>
# Sertanejo
# 125
# lexa+aquecimento+da+lexa
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [WinError 10060] Impossibile stabilire la connessione. Risposta non corretta della parte connessa dopo l'intervallo di tempo oppure mancata risposta dall'host collegato
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     171             raise NewConnectionError(
# --> 172                 self, "Failed to establish a new connection: %s" % e
#     173             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001D1EBC42808>: Failed to establish a new connection: [WinError 10060] Impossibile stabilire la connessione. Risposta non corretta della parte connessa dopo l'intervallo di tempo oppure mancata risposta dall'host collegato
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\envs\MyEnv\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     726             retries = retries.increment(
# --> 727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728             )
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#
# MaxRetryError: HTTPSConnectionPool(host='itunes.apple.com', port=443): Max retries exceeded with url: /search?term=lexa+aquecimento+da+lexa&limit=1 (Caused by NewConnectionError("<urllib3.connection.HTTPSConnection object at 0x000001D1EBC42808>: Failed to establish a new connection: [WinError 10060] Impossibile stabilire la connessione. Risposta non corretta della parte connessa dopo l'intervallo di tempo oppure mancata risposta dall'host collegato"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-29-70a247d52b98> in <module>
#      39             print(query_entry)
#      40             a = 'https://itunes.apple.com/search?term='+query_entry+'&limit=1'
# ---> 41             test = requests.get(a)
#      42             print(test)
#      43             b = test.json()
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\MyEnv\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='itunes.apple.com', port=443): Max retries exceeded with url: /search?term=lexa+aquecimento+da+lexa&limit=1 (Caused by NewConnectionError("<urllib3.connection.HTTPSConnection object at 0x000001D1EBC42808>: Failed to establish a new connection: [WinError 10060] Impossibile stabilire la connessione. Risposta non corretta della parte connessa dopo l'intervallo di tempo oppure mancata risposta dall'host collegato"))

# %%
#Testing on spotify release date.

credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)
features = spotify.audio_features(str(df['ID'].iloc[0]))
result = spotify.track('5CtI0qwDJkDQGwXD1H1cLb')
print(result)
