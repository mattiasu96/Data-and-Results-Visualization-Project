# %%
import pandas as pd
import spotipy
#from fycharts.SpotifyCharts import SpotifyCharts
from spotipy.oauth2 import SpotifyClientCredentials

# %%
df = pd.read_csv('global_2017-07-14--2017-07-21.csv')

# %%
df

# %%
df.columns = df.iloc[0]

# %%
df = df.iloc[1:].reset_index()

# %%
df.URL.astype('str')

# %%
df.URL = df.URL.apply(lambda x : x[31:])

# %%
df.rename(columns={'URL':'ID'}, inplace=True)

# %%
df

# %%
credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
token = credentials.get_access_token()

spotify = spotipy.Spotify(auth=token)

features = spotify.audio_features(str(df['ID'].iloc[0]))

# %%
features

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        print(features[0]['danceability'])
        dataframe.append({'danceability' : features[0]['danceability'],
        'energy': features[0]['energy'],
        'key' : features[0]['key'],
        'loudness' : features[0]['loudness'],
        'mode' : features[0]['mode'],
        'speechiness' : features[0]['speechiness'],
        'acousticness' : features[0]['acousticness'],
        'instrumentalness' : features[0]['instrumentalness'],
        'liveness' : features[0]['liveness'],
        'valence' : features[0]['valence'],
        'tempo' : features[0]['tempo'],
        'time_signature' : features[0]['time_signature'],
        'duration_ms' : features[0]['duration_ms']}, ignore_index=True)
    return dataframe

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        dataframe.loc[i] = [ features[0]['id'],
        features[0]['danceability'],
        features[0]['energy'],
        features[0]['key'],
        features[0]['loudness'],
        features[0]['mode'],
        features[0]['speechiness'],
        features[0]['acousticness'],
        features[0]['instrumentalness'],
        features[0]['liveness'],
        features[0]['valence'],
        features[0]['tempo'],
        features[0]['time_signature'],
        features[0]['duration_ms']]
    return dataframe

# %%
prova = extract_features(df, n_tracks=200)

# %%
prova

# %%
output = df.join(prova.set_index('id'), on='ID')

# %%
output.to_csv('global_08-2017.csv')

# %%
output

test=output.iloc[9]
print(test)
print(type(test['Track Name']))
if type(test['Track Name']) != float and type(test['Artist']) != float:
    print('no empty')
else: 
    print('empty')

# %% [markdown]
# ## Testing iTunes API for genre labeling
# Simple test of quering on iTunes API

# %%
import requests
import json
entry = 'post+malone+circles'
a = 'https://itunes.apple.com/search?term='+entry+'.&limit=1'
b = requests.get(a).json()
print(b['results'][0]['primaryGenreName'])
print(json.dumps(b, indent=2))

# %% [markdown]
# # Automatizing the feature extraction process

# %%
import pandas as pd
import spotipy
#from fycharts.SpotifyCharts import SpotifyCharts
from spotipy.oauth2 import SpotifyClientCredentials
import os
import requests
import json
import time

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        print(features[0]['danceability'])
        dataframe.append({'danceability' : features[0]['danceability'],
        'energy': features[0]['energy'],
        'key' : features[0]['key'],
        'loudness' : features[0]['loudness'],
        'mode' : features[0]['mode'],
        'speechiness' : features[0]['speechiness'],
        'acousticness' : features[0]['acousticness'],
        'instrumentalness' : features[0]['instrumentalness'],
        'liveness' : features[0]['liveness'],
        'valence' : features[0]['valence'],
        'tempo' : features[0]['tempo'],
        'time_signature' : features[0]['time_signature'],
        'duration_ms' : features[0]['duration_ms']}, ignore_index=True)
    return dataframe

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        dataframe.loc[i] = [ features[0]['id'],
        features[0]['danceability'],
        features[0]['energy'],
        features[0]['key'],
        features[0]['loudness'],
        features[0]['mode'],
        features[0]['speechiness'],
        features[0]['acousticness'],
        features[0]['instrumentalness'],
        features[0]['liveness'],
        features[0]['valence'],
        features[0]['tempo'],
        features[0]['time_signature'],
        features[0]['duration_ms']]
    return dataframe

# %%
#checking data integrity. Checks for missing fields in Artist name. Return the rows with missing values + the file name. 
#These data are missing because of copyright issues. They changed the author of the song/removed the song. 
import numpy as np

from IPython.display import display, HTML

path = os.getcwd()
file_folder = os.path.join(path,'gb')

for csv_file in os.listdir(file_folder):
    file = os.path.join(file_folder,csv_file)
    #print(csv_file)
    df = pd.read_csv(file)
    #display(df)
    df.columns = df.iloc[0]
    df = df.iloc[1:].reset_index()
    df.URL.astype('str')
    df.URL = df.URL.apply(lambda x : x[31:])
    df.rename(columns={'URL':'ID'}, inplace=True)
    
    res = df.loc[df['Artist'].isnull(), 'index'].tolist()
    if len(res) != 0:
        print(res)
        print(csv_file)
# Out:
# [7, 30, 42, 60]
# gb_2017-07-14--2017-07-21.csv

# %%
path = os.getcwd()
file_folder = os.path.join(path,'de 2')
save_folder_path = os.path.join(path, "de_features")
#os.mkdir(save_folder_path)

for csv_file in os.listdir(file_folder): 
    print(csv_file)
    file = os.path.join(file_folder,csv_file)
    df = pd.read_csv(file)
    df.columns = df.iloc[0]
    df = df.iloc[1:].reset_index()
    df.URL.astype('str')
    df.URL = df.URL.apply(lambda x : x[31:])
    df.rename(columns={'URL':'ID'}, inplace=True)
    credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
    token = credentials.get_access_token()
    spotify = spotipy.Spotify(auth=token)
    features = spotify.audio_features(str(df['ID'].iloc[0]))
    prova = extract_features(df, n_tracks=200)
    output = df.join(prova.set_index('id'), on='ID')
    output['genre']= "none"
    for index, row in output.iterrows():
        artist = row["Artist"]
        song = row["Track Name"]
        if type(artist) != float and type(song) != float:
            song = song.split('(')[0]
            query_entry = str(artist)+" "+str(song)
            query_entry = query_entry.replace("with", "")
            query_entry= query_entry.replace('Remastered', "")
            query_entry= query_entry.replace('Version', "")

            query_entry = query_entry.replace("'", "")
            query_entry = query_entry.replace('"', "")

            query_entry=query_entry.replace(" ", "+")

            #query_entry = query_entry[0:60]
            query_entry = query_entry.lower()
            print(query_entry)
            a = 'https://itunes.apple.com/search?term='+query_entry+'&limit=1'
            test = requests.get(a)
            print(test)
            b = test.json()
            if b['resultCount'] == 1:

                print(b['results'][0]['primaryGenreName'])
                #assign genre to song
                print(index)
                output.iloc[index, output.columns.get_loc('genre')]= b['results'][0]['primaryGenreName']
            time.sleep(0.5)
            #print(json.dumps(b, indent=2))
    output.to_csv(os.path.join(save_folder_path,csv_file))
# Out:
# de_2019-05-10--2019-05-17.csv
# C:\Users\Mattia\anaconda3\envs\TrapGenerator\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   app.launch_new_instance()
# shindy+nautilus
# <Response [200]>
# Rap
# 0
# juju+vermissen+
# <Response [200]>
# Hip-Hop/Rap
# 1
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 2
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 3
# lx+perdono
# <Response [200]>
# Hip-Hop/Rap
# 4
# samra+ghetto
# <Response [200]>
# Hip-Hop/Rap
# 5
# lil+nas+x+old+town+road+
# <Response [200]>
# Country
# 6
# capital+bra+rolex
# <Response [200]>
# Hip-Hop/Rap
# 7
# dardan+coco+mama
# <Response [200]>
# Hip-Hop
# 8
# capital+bra+cherry+lady
# <Response [200]>
# Hip-Hop/Rap
# 9
# bausa+mary
# <Response [200]>
# Hip-Hop/Rap
# 10
# avicii+sos
# <Response [200]>
# Dance
# 11
# ardian+bujupi+wie+im+traum
# <Response [200]>
# Pop
# 12
# lil+nas+x+old+town+road
# <Response [200]>
# Country
# 13
# sero+el+mero+ohne+sinn
# <Response [200]>
# Hip-Hop/Rap
# 14
# sosmula+1k+shotz
# <Response [200]>
# Hip-Hop/Rap
# 15
# ufo361+next
# <Response [200]>
# Hip-Hop/Rap
# 16
# sido+wie+papa
# <Response [200]>
# Hip-Hop/Rap
# 17
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 18
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 19
# samra+harami
# <Response [200]>
# Hip-Hop/Rap
# 20
# shawn+mendes+if+i+cant+have+you
# <Response [200]>
# Pop
# 21
# eno+blackberry+sky
# <Response [200]>
# Hip-Hop/Rap
# 22
# kontra+k+blei+
# <Response [200]>
# Hip-Hop/Rap
# 23
# kc+rebell+quarterback
# <Response [200]>
# Hip-Hop/Rap
# 24
# mero+wolke+10
# <Response [200]>
# Hip-Hop/Rap
# 25
# shindy+affalterbach
# <Response [200]>
# Rap
# 26
# pietro+lombardi+bella+donna
# <Response [200]>
# Pop
# 27
# kc+rebell+dna
# <Response [200]>
# Hip-Hop/Rap
# 28
# capital+bra+wir+ticken
# <Response [200]>
# Hip-Hop/Rap
# 29
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 30
# capital+bra+prinzessa
# <Response [200]>
# Hip-Hop/Rap
# 31
# kc+rebell+alleen
# <Response [200]>
# Hip-Hop/Rap
# 32
# taylor+swift+me!+
# <Response [200]>
# Country
# 33
# dominic+fike+3+nights
# <Response [200]>
# Alternative
# 34
# imagine+dragons+bad+liar
# <Response [200]>
# Alternative
# 35
# c+arma+yapma
# <Response [200]>
# R&B/Soul
# 36
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 37
# ava+max+sweet+but+psycho
# <Response [200]>
# Pop
# 38
# gaullin+moonlight
# <Response [200]>
# Dance
# 39
# samra+shoote+ma+shoote
# <Response [200]>
# Hip-Hop/Rap
# 40
# fero47+puerto+rico
# <Response [200]>
# Hip-Hop/Rap
# 41
# apache+207+brot+nach+hause
# <Response [200]>
# Hip-Hop/Rap
# 42
# shirin+david+gib+ihm
# <Response [200]>
# Hip-Hop/Rap
# 43
# eno+souvenir
# <Response [200]>
# Hip-Hop/Rap
# 44
# majan+1975
# <Response [200]>
# Hip-Hop/Rap
# 45
# lena+dont+lie+to+me
# <Response [200]>
# Pop
# 46
# ava+max+so+am+i
# <Response [200]>
# Pop
# 47
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 48
# capital+bra+benzema
# <Response [200]>
# Hip-Hop/Rap
# 49
# logic+homicide+
# <Response [200]>
# Hip-Hop/Rap
# 50
# lx+mercy+mercy
# <Response [200]>
# Indie Rock
# 51
# marshmello+here+with+me
# <Response [200]>
# Dance
# 52
# kygo+carry+on+
# <Response [200]>
# Dance
# 53
# bonez+mc+500+ps
# <Response [200]>
# Hip-Hop/Rap
# 54
# mathea+2x
# <Response [200]>
# Pop
# 55
# gringo+blue+lagoon
# <Response [200]>
# Hip-Hop/Rap
# 56
# capital+bra+bye+bye
# <Response [200]>
# Hip-Hop/Rap
# 57
# dennis+lloyd+never+go+back
# <Response [200]>
# Alternative
# 58
# alec+benjamin+let+me+down+slowly
# <Response [200]>
# Pop
# 59
# post+malone+wow.
# <Response [200]>
# Hip-Hop/Rap
# 60
# lauv+im+so+tired...
# <Response [200]>
# Pop
# 61
# ufo361+pass+auf+wen+du+liebst
# <Response [200]>
# Hip-Hop/Rap
# 62
# the+prince+karma+later+bitches
# <Response [200]>
# Dance
# 63
# martin+garrix+summer+days+
# <Response [200]>
# Dance
# 64
# king+khalil+bundesweit+
# <Response [200]>
# michael+schulte+back+to+the+start
# <Response [200]>
# Pop
# 66
# panic!+at+the+disco+high+hopes
# <Response [200]>
# Alternative
# 67
# billie+eilish+bury+a+friend
# <Response [200]>
# Alternative
# 68
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 69
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 70
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 71
# matt+simons+open+up
# <Response [200]>
# Pop
# 72
# rammstein+deutschland
# <Response [200]>
# Metal
# 73
# mero+jay+jay
# <Response [200]>
# Hip-Hop/Rap
# 74
# luciano+millies
# <Response [200]>
# Hip-Hop/Rap
# 75
# robin+schulz+speechless+
# <Response [200]>
# Dance
# 76
# kitschkrieg+standard+
# <Response [200]>
# Hip-Hop/Rap
# 77
# fero47+jaja
# <Response [200]>
# Hip-Hop/Rap
# 78
# samra+mosaik
# <Response [200]>
# Hip-Hop/Rap
# 79
# kalim+bis+um+3
# <Response [200]>
# Hip-Hop/Rap
# 80
# khalid+talk+
# <Response [200]>
# R&B/Soul
# 81
# eno+ferrari
# <Response [200]>
# Hip-Hop/Rap
# 82
# seeed+ticket
# <Response [200]>
# Pop
# 83
# azet+fragen
# <Response [200]>
# Hip-Hop/Rap
# 84
# juju+hardcore+high
# <Response [200]>
# Hip-Hop/Rap
# 85
# luciano+ya+salame
# <Response [200]>
# Hip-Hop/Rap
# 86
# mero+baller+los
# <Response [200]>
# Hip-Hop/Rap
# 87
# bazzi+paradise
# <Response [200]>
# Pop
# 88
# 18+karat+fmfl+3.0
# <Response [200]>
# Hip-Hop/Rap
# 89
# capital+bra+capital+bra+je+mappelle
# <Response [200]>
# Hip-Hop/Rap
# 90
# bts+boy+with+luv+
# <Response [200]>
# K-Pop
# 91
# avicii+tough+love
# <Response [200]>
# Dance
# 92
# sido+tausend+tattoos
# <Response [200]>
# Hip-Hop/Rap
# 93
# giant+rooks+wild+stare
# <Response [200]>
# Rock
# 94
# billie+eilish+when+the+partys+over
# <Response [200]>
# Alternative
# 95
# alan+walker+on+my+way
# <Response [200]>
# Dance
# 96
# mero+hobby+hobby
# <Response [200]>
# Hip-Hop/Rap
# 97
# post+malone+sunflower+-+spider-man:+into+the+spider-verse
# <Response [200]>
# Hip-Hop/Rap
# 98
# jigzaw+wer
# <Response [200]>
# Hip-Hop/Rap
# 99
# calvin+harris+giant+
# <Response [200]>
# Dance
# 100
# a+boogie+wit+da+hoodie+swervin+
# <Response [200]>
# Hip-Hop/Rap
# 101
# shindy+dodi
# <Response [200]>
# Rap
# 102
# halsey+without+me
# <Response [200]>
# Alternative
# 103
# qzeng+trance
# <Response [200]>
# Hip-Hop/Rap
# 104
# lil+dicky+earth
# <Response [200]>
# Pop
# 105
# sdp+viva+la+dealer
# <Response [200]>
# Pop
# 106
# summer+cem+casanova
# <Response [200]>
# Hip-Hop/Rap
# 107
# a+boogie+wit+da+hoodie+look+back+at+it
# <Response [200]>
# Hip-Hop/Rap
# 108
# blackpink+kill+this+love
# <Response [200]>
# K-Pop
# 109
# billie+eilish+lovely+
# <Response [200]>
# Pop
# 110
# loud+luxury+body+
# <Response [200]>
# Dance
# 111
# kianush+so+jung
# <Response [200]>
# Hip-Hop/Rap
# 112
# eno+plaza
# <Response [200]>
# Hip-Hop/Rap
# 113
# marshmello+happier
# <Response [200]>
# Dance
# 114
# leon+machère+copacabana
# <Response [200]>
# Pop
# 115
# harris+&+ford+freitag,+samstag
# <Response [200]>
# Action & Adventure
# 116
# capital+bra+van+der+vaart
# <Response [200]>
# Hip-Hop/Rap
# 117
# bonez+mc+kokain
# <Response [200]>
# Hip-Hop/Rap
# 118
# samra+cataleya
# <Response [200]>
# Hip-Hop/Rap
# 119
# rammstein+radio
# <Response [200]>
# Metal
# 120
# rin+dior+2001
# <Response [200]>
# kontra+k+letzte+träne
# <Response [200]>
# Hip-Hop/Rap
# 122
# shirin+david+ice
# <Response [200]>
# Hip-Hop/Rap
# 123
# bausa+was+du+liebe+nennst
# <Response [200]>
# Hip-Hop/Rap
# 124
# lizzo+truth+hurts
# <Response [200]>
# Dance
# 125
# capital+bra+click+click
# <Response [200]>
# Hip-Hop/Rap
# 126
# kool+savas+deine+mutter
# <Response [200]>
# Hip-Hop/Rap
# 127
# jonas+blue+what+i+like+about+you+
# <Response [200]>
# Dance
# 128
# capital+bra+neymar
# <Response [200]>
# Hip-Hop/Rap
# 129
# dj+snake+taki+taki+
# <Response [200]>
# Dance
# 130
# kontra+k+warnung
# <Response [200]>
# Hip-Hop/Rap
# 131
# capital+bra+steh+auf
# <Response [200]>
# Hip-Hop/Rap
# 132
# dardan+facetime
# <Response [200]>
# Hip-Hop
# 133
# dean+lewis+be+alright
# <Response [200]>
# Singer/Songwriter
# 134
# david+guetta+say+my+name
# <Response [200]>
# Dance
# 135
# p!nk+walk+me+home
# <Response [200]>
# Pop
# 136
# capo+lambo+diablo+gt+
# <Response [200]>
# Hip-Hop
# 137
# hugel+wtf+
# <Response [200]>
# Pop
# 138
# lx+haifischnikez+allstars
# <Response [200]>
# Hip-Hop/Rap
# 139
# billie+eilish+wish+you+were+gay
# <Response [200]>
# Alternative
# 140
# capital+bra+schon+ok
# <Response [200]>
# Hip-Hop/Rap
# 141
# bausa+guadalajara+
# <Response [200]>
# Hip-Hop/Rap
# 142
# alle+farben+fading
# <Response [200]>
# Dance
# 143
# sam+smith+dancing+with+a+stranger+
# <Response [200]>
# Pop
# 144
# capital+bra+melodien+
# <Response [200]>
# Hip-Hop/Rap
# 145
# tyga+goddamn+
# <Response [200]>
# Hip-Hop/Rap
# 146
# raf+camora+perfekt+
# <Response [200]>
# Rap
# 147
# bonez+mc+ohne+mein+team
# <Response [200]>
# ellie+goulding+sixteen
# <Response [200]>
# Pop
# 149
# nico+santos+unforgettable
# <Response [200]>
# Pop
# 150
# benny+blanco+eastside+
# <Response [200]>
# Pop
# 151
# ariana+grande+break+up++your+girlfriend,+im+bored
# <Response [200]>
# Pop
# 152
# pietro+lombardi+nur+ein+tanz
# <Response [200]>
# Pop
# 153
# kitschkrieg+5+minuten+
# <Response [200]>
# Hip-Hop/Rap
# 154
# capital+bra+ich+liebe+es+
# <Response [200]>
# Hip-Hop/Rap
# 155
# capital+bra+cabriolet
# <Response [200]>
# Hip-Hop/Rap
# 156
# sami+mary+jane
# <Response [200]>
# Hip-Hop/Rap
# 157
# post+malone+rockstar+
# <Response [200]>
# Hip-Hop/Rap
# 158
# loredana+romeo+&+juliet
# <Response [200]>
# Pop
# 159
# david+guetta+stay+
# <Response [200]>
# Dance
# 160
# lena+thank+you
# <Response [200]>
# Pop
# 161
# summer+cem+tamam+tamam
# <Response [200]>
# Hip-Hop/Rap
# 162
# marshmello+light+it+up+
# <Response [200]>
# Hip-Hop/Rap
# 163
# sza+power+is+power+
# <Response [200]>
# Pop
# 164
# robin+schulz+all+this+love+
# <Response [200]>
# Dance
# 165
# luciano+meer
# <Response [200]>
# Nature
# 166
# dermot+kennedy+power+over+me
# <Response [200]>
# Singer/Songwriter
# 167
# kina+get+you+the+moon+
# <Response [200]>
# R&B/Soul
# 168
# apache+207+kein+problem
# <Response [200]>
# Hip-Hop/Rap
# 169
# the+bosshoss+little+help
# <Response [200]>
# Rock
# 170
# kontra+k+farben
# <Response [200]>
# Hip-Hop/Rap
# 171
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 172
# veysel+uff
# <Response [200]>
# Hip-Hop/Rap
# 173
# azet+hallo+hallo
# <Response [200]>
# Hip-Hop/Rap
# 174
# why+dont+we+i+dont+belong+in+this+club
# <Response [200]>
# Pop
# 175
# galantis+bones+
# <Response [200]>
# Dance
# 176
# soolking+zemër
# <Response [200]>
# Hip-Hop/Rap
# 177
# capital+bra+one+night+stand
# <Response [200]>
# Hip-Hop/Rap
# 178
# wincent+weiss+kaum+erwarten
# <Response [200]>
# Pop
# 179
# eno+hamdullah
# <Response [200]>
# Hip-Hop/Rap
# 180
# jonas+blue+rise
# <Response [200]>
# Dance
# 181
# capital+bra+sollte+so+sein
# <Response [200]>
# Hip-Hop/Rap
# 182
# eno+mercedes
# <Response [200]>
# Hip-Hop/Rap
# 183
# tyga+taste+
# <Response [200]>
# Hip-Hop/Rap
# 184
# mustard+pure+water+
# <Response [200]>
# Hip-Hop/Rap
# 185
# finch+asozial+abfahrt
# <Response [200]>
# Hip-Hop/Rap
# 186
# armin+van+buuren+blah+blah+blah
# <Response [200]>
# Trance
# 187
# kontra+k+kampfgeist+4
# <Response [200]>
# Hip-Hop/Rap
# 188
# billie+eilish+you+should+see+me+in+a+crown
# <Response [200]>
# Alternative
# 189
# calvin+harris+promises+
# <Response [200]>
# Dance
# 190
# linkin+park+in+the+end
# <Response [200]>
# Hard Rock
# 191
# kc+rebell+in+der+nacht
# <Response [200]>
# Hip-Hop/Rap
# 192
# james+arthur+falling+like+the+stars
# <Response [200]>
# Pop
# 193
# billie+eilish+all+the+good+girls+go+to+hell
# <Response [200]>
# Alternative
# 194
# bausa+vagabund
# <Response [200]>
# Hip-Hop/Rap
# 195
# queen+bohemian+rhapsody+-+2011+mix
# <Response [200]>
# Rock
# 196
# notd+so+close
# <Response [200]>
# Dance
# 197
# vize+glad+you+came
# <Response [200]>
# Dance
# 198
# post+malone+better+now
# <Response [200]>
# Hip-Hop/Rap
# 199
# de_2019-05-17--2019-05-24.csv
# samra+wieder+lila
# <Response [200]>
# Hip-Hop/Rap
# 0
# juju+vermissen+
# <Response [200]>
# Hip-Hop/Rap
# 1
# shindy+nautilus
# <Response [200]>
# Rap
# 2
# kontra+k+letzte+träne
# <Response [200]>
# Hip-Hop/Rap
# 3
# ufo361+gib+gas
# <Response [200]>
# Hip-Hop/Rap
# 4
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 5
# shirin+david+fliegst+du+mit
# <Response [200]>
# Pop
# 6
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 7
# lil+nas+x+old+town+road+
# <Response [200]>
# Country
# 8
# dardan+coco+mama
# <Response [200]>
# Hip-Hop
# 9
# capital+bra+rolex
# <Response [200]>
# Hip-Hop/Rap
# 10
# bausa+mary
# <Response [200]>
# Hip-Hop/Rap
# 11
# samra+ghetto
# <Response [200]>
# Hip-Hop/Rap
# 12
# olexesh+barrio
# <Response [200]>
# Hip-Hop/Rap
# 13
# lx+perdono
# <Response [200]>
# Hip-Hop/Rap
# 14
# avicii+sos
# <Response [200]>
# Dance
# 15
# capital+bra+cherry+lady
# <Response [200]>
# Hip-Hop/Rap
# 16
# lil+nas+x+old+town+road
# <Response [200]>
# Country
# 17
# dardan+sorry
# <Response [200]>
# Rap
# 18
# ardian+bujupi+wie+im+traum
# <Response [200]>
# Pop
# 19
# rammstein+deutschland
# <Response [200]>
# Metal
# 20
# rammstein+zeig+dich
# <Response [200]>
# Metal
# 21
# kontra+k+blei+
# <Response [200]>
# Hip-Hop/Rap
# 22
# rammstein+ausländer
# <Response [200]>
# Metal
# 23
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 24
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 25
# sero+el+mero+ohne+sinn
# <Response [200]>
# Hip-Hop/Rap
# 26
# 18+karat+immer+auf+der+straße+
# <Response [200]>
# Hip-Hop/Rap
# 27
# rammstein+puppe
# <Response [200]>
# Metal
# 28
# ufo361+next
# <Response [200]>
# Hip-Hop/Rap
# 29
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 30
# samra+harami
# <Response [200]>
# Hip-Hop/Rap
# 31
# shawn+mendes+if+i+cant+have+you
# <Response [200]>
# Pop
# 32
# mero+wolke+10
# <Response [200]>
# Hip-Hop/Rap
# 33
# shindy+affalterbach
# <Response [200]>
# Rap
# 34
# eno+blackberry+sky
# <Response [200]>
# Hip-Hop/Rap
# 35
# kc+rebell+quarterback
# <Response [200]>
# Hip-Hop/Rap
# 36
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 37
# rammstein+radio
# <Response [200]>
# Metal
# 38
# rammstein+sex
# <Response [200]>
# Metal
# 39
# capital+bra+wir+ticken
# <Response [200]>
# Hip-Hop/Rap
# 40
# lena+dont+lie+to+me
# <Response [200]>
# Pop
# 41
# apache+207+brot+nach+hause
# <Response [200]>
# Hip-Hop/Rap
# 42
# kc+rebell+dna
# <Response [200]>
# Hip-Hop/Rap
# 43
# capital+bra+prinzessa
# <Response [200]>
# Hip-Hop/Rap
# 44
# sido+wie+papa
# <Response [200]>
# Hip-Hop/Rap
# 45
# pietro+lombardi+bella+donna
# <Response [200]>
# Pop
# 46
# dominic+fike+3+nights
# <Response [200]>
# Alternative
# 47
# rammstein+was+ich+liebe
# <Response [200]>
# Metal
# 48
# rammstein+diamant
# <Response [200]>
# Metal
# 49
# rammstein+weit+weg
# <Response [200]>
# Metal
# 50
# sosmula+1k+shotz
# <Response [200]>
# Hip-Hop/Rap
# 51
# rammstein+tattoo
# <Response [200]>
# Metal
# 52
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 53
# shirin+david+gib+ihm
# <Response [200]>
# Hip-Hop/Rap
# 54
# c+arma+yapma
# <Response [200]>
# R&B/Soul
# 55
# imagine+dragons+bad+liar
# <Response [200]>
# Alternative
# 56
# ava+max+sweet+but+psycho
# <Response [200]>
# Pop
# 57
# kc+rebell+alleen
# <Response [200]>
# Hip-Hop/Rap
# 58
# mahmood+soldi
# <Response [200]>
# Pop
# 59
# michael+schulte+back+to+the+start
# <Response [200]>
# Pop
# 60
# samra+shoote+ma+shoote
# <Response [200]>
# Hip-Hop/Rap
# 61
# dennis+lloyd+never+go+back
# <Response [200]>
# Alternative
# 62
# gaullin+moonlight
# <Response [200]>
# Dance
# 63
# fero47+puerto+rico
# <Response [200]>
# Hip-Hop/Rap
# 64
# taylor+swift+me!+
# <Response [200]>
# Country
# 65
# martin+garrix+summer+days+
# <Response [200]>
# Dance
# 66
# capital+bra+bye+bye
# <Response [200]>
# Hip-Hop/Rap
# 67
# ava+max+so+am+i
# <Response [200]>
# Pop
# 68
# rammstein+hallomann
# <Response [200]>
# Metal
# 69
# kygo+carry+on+
# <Response [200]>
# Dance
# 70
# eno+souvenir
# <Response [200]>
# Hip-Hop/Rap
# 71
# capital+bra+benzema
# <Response [200]>
# Hip-Hop/Rap
# 72
# bonez+mc+500+ps
# <Response [200]>
# Hip-Hop/Rap
# 73
# marshmello+here+with+me
# <Response [200]>
# Dance
# 74
# mathea+2x
# <Response [200]>
# Pop
# 75
# duncan+laurence+arcade
# <Response [200]>
# Pop
# 76
# post+malone+wow.
# <Response [200]>
# Hip-Hop/Rap
# 77
# lauv+im+so+tired...
# <Response [200]>
# Pop
# 78
# matt+simons+open+up
# <Response [200]>
# Pop
# 79
# alec+benjamin+let+me+down+slowly
# <Response [200]>
# Pop
# 80
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 81
# panic!+at+the+disco+high+hopes
# <Response [200]>
# Alternative
# 82
# onerepublic+rescue+me
# <Response [200]>
# Pop
# 83
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 84
# ufo361+pass+auf+wen+du+liebst
# <Response [200]>
# Hip-Hop/Rap
# 85
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 86
# the+prince+karma+later+bitches
# <Response [200]>
# Dance
# 87
# billie+eilish+bury+a+friend
# <Response [200]>
# Alternative
# 88
# seeed+ticket
# <Response [200]>
# Pop
# 89
# kitschkrieg+standard+
# <Response [200]>
# Hip-Hop/Rap
# 90
# robin+schulz+speechless+
# <Response [200]>
# Dance
# 91
# gringo+blue+lagoon
# <Response [200]>
# Hip-Hop/Rap
# 92
# kalim+bis+um+3
# <Response [200]>
# Hip-Hop/Rap
# 93
# halsey+nightmare
# <Response [200]>
# Alternative
# 94
# majan+1975
# <Response [200]>
# Hip-Hop/Rap
# 95
# fero47+jaja
# <Response [200]>
# Hip-Hop/Rap
# 96
# azet+fragen
# <Response [200]>
# Hip-Hop/Rap
# 97
# lizzo+truth+hurts
# <Response [200]>
# Dance
# 98
# mero+jay+jay
# <Response [200]>
# Hip-Hop/Rap
# 99
# giant+rooks+wild+stare
# <Response [200]>
# Rock
# 100
# logic+homicide+
# <Response [200]>
# Hip-Hop/Rap
# 101
# mero+baller+los
# <Response [200]>
# Hip-Hop/Rap
# 102
# eno+ferrari
# <Response [200]>
# Hip-Hop/Rap
# 103
# khalid+talk+
# <Response [200]>
# R&B/Soul
# 104
# luciano+ya+salame
# <Response [200]>
# Hip-Hop/Rap
# 105
# jonas+blue+what+i+like+about+you+
# <Response [200]>
# Dance
# 106
# luciano+millies
# <Response [200]>
# Hip-Hop/Rap
# 107
# sido+tausend+tattoos
# <Response [200]>
# Hip-Hop/Rap
# 108
# billie+eilish+when+the+partys+over
# <Response [200]>
# Alternative
# 109
# post+malone+sunflower+-+spider-man:+into+the+spider-verse
# <Response [200]>
# Hip-Hop/Rap
# 110
# qzeng+trance
# <Response [200]>
# Hip-Hop/Rap
# 111
# bazzi+paradise
# <Response [200]>
# Pop
# 112
# capital+bra+capital+bra+je+mappelle
# <Response [200]>
# Hip-Hop/Rap
# 113
# juju+hardcore+high
# <Response [200]>
# Hip-Hop/Rap
# 114
# calvin+harris+giant+
# <Response [200]>
# Dance
# 115
# mero+hobby+hobby
# <Response [200]>
# Hip-Hop/Rap
# 116
# loud+luxury+body+
# <Response [200]>
# Dance
# 117
# luca+hänni+she+got+me
# <Response [200]>
# Pop
# 118
# tyler,+the+creator+earfquake
# <Response [200]>
# Hip-Hop/Rap
# 119
# alan+walker+on+my+way
# <Response [200]>
# Dance
# 120
# kianush+so+jung
# <Response [200]>
# Hip-Hop/Rap
# 121
# halsey+without+me
# <Response [200]>
# Alternative
# 122
# kontra+k+warnung
# <Response [200]>
# Hip-Hop/Rap
# 123
# nico+santos+unforgettable
# <Response [200]>
# Pop
# 124
# summer+cem+casanova
# <Response [200]>
# Hip-Hop/Rap
# 125
# samra+cataleya
# <Response [200]>
# Hip-Hop/Rap
# 126
# malik+montana+7+5+0
# <Response [200]>
# marshmello+happier
# <Response [200]>
# Dance
# 128
# leon+machère+copacabana
# <Response [200]>
# Pop
# 129
# sdp+viva+la+dealer
# <Response [200]>
# Pop
# 130
# billie+eilish+lovely+
# <Response [200]>
# Pop
# 131
# lil+dicky+earth
# <Response [200]>
# Pop
# 132
# a+boogie+wit+da+hoodie+look+back+at+it
# <Response [200]>
# Hip-Hop/Rap
# 133
# a+boogie+wit+da+hoodie+swervin+
# <Response [200]>
# Hip-Hop/Rap
# 134
# ellie+goulding+sixteen
# <Response [200]>
# Pop
# 135
# shindy+dodi
# <Response [200]>
# Rap
# 136
# rin+dior+2001
# <Response [200]>
# bonez+mc+kokain
# <Response [200]>
# Hip-Hop/Rap
# 138
# bausa+was+du+liebe+nennst
# <Response [200]>
# Hip-Hop/Rap
# 139
# shirin+david+ice
# <Response [200]>
# Hip-Hop/Rap
# 140
# sarah+connor+vincent
# <Response [200]>
# Drama
# 141
# capital+bra+neymar
# <Response [200]>
# Hip-Hop/Rap
# 142
# dj+snake+taki+taki+
# <Response [200]>
# Dance
# 143
# r3hab+all+around+the+world+
# <Response [200]>
# Dance
# 144
# dardan+facetime
# <Response [200]>
# Hip-Hop
# 145
# kool+savas+deine+mutter
# <Response [200]>
# Hip-Hop/Rap
# 146
# robin+schulz+all+this+love+
# <Response [200]>
# Dance
# 147
# dean+lewis+be+alright
# <Response [200]>
# Singer/Songwriter
# 148
# david+guetta+say+my+name
# <Response [200]>
# Dance
# 149
# harris+&+ford+freitag,+samstag
# <Response [200]>
# Action & Adventure
# 150
# jax+jones+all+day+and+night+-+jax+jones+&+martin+solveig+present+europa
# <Response [200]>
# Dance
# 151
# kina+get+you+the+moon+
# <Response [200]>
# R&B/Soul
# 152
# kontra+k+farben
# <Response [200]>
# Hip-Hop/Rap
# 153
# hugel+wtf+
# <Response [200]>
# Pop
# 154
# eno+plaza
# <Response [200]>
# Hip-Hop/Rap
# 155
# apache+207+kein+problem
# <Response [200]>
# Hip-Hop/Rap
# 156
# 18+karat+fmfl+3.0
# <Response [200]>
# Hip-Hop/Rap
# 157
# samra+mosaik
# <Response [200]>
# Hip-Hop/Rap
# 158
# alle+farben+fading
# <Response [200]>
# Dance
# 159
# lena+thank+you
# <Response [200]>
# Pop
# 160
# kontra+k+kampfgeist+4
# <Response [200]>
# Hip-Hop/Rap
# 161
# capo+lambo+diablo+gt+
# <Response [200]>
# Hip-Hop
# 162
# vize+glad+you+came
# <Response [200]>
# Dance
# 163
# capital+bra+melodien+
# <Response [200]>
# Hip-Hop/Rap
# 164
# lena+skinny+bitch
# <Response [200]>
# Pop
# 165
# post+malone+rockstar+
# <Response [200]>
# Hip-Hop/Rap
# 166
# capital+bra+click+click
# <Response [200]>
# Hip-Hop/Rap
# 167
# capital+bra+van+der+vaart
# <Response [200]>
# Hip-Hop/Rap
# 168
# bonez+mc+ohne+mein+team
# <Response [200]>
# raf+camora+perfekt+
# <Response [200]>
# Rap
# 170
# benny+blanco+eastside+
# <Response [200]>
# Pop
# 171
# sam+smith+dancing+with+a+stranger+
# <Response [200]>
# Pop
# 172
# blackpink+kill+this+love
# <Response [200]>
# K-Pop
# 173
# bts+boy+with+luv+
# <Response [200]>
# K-Pop
# 174
# capital+bra+steh+auf
# <Response [200]>
# Hip-Hop/Rap
# 175
# dj+khaled+just+us+
# <Response [200]>
# Hip-Hop/Rap
# 176
# lx+haifischnikez+allstars
# <Response [200]>
# Hip-Hop/Rap
# 177
# tyga+goddamn+
# <Response [200]>
# Hip-Hop/Rap
# 178
# dermot+kennedy+power+over+me
# <Response [200]>
# Singer/Songwriter
# 179
# billie+eilish+wish+you+were+gay
# <Response [200]>
# Alternative
# 180
# capital+bra+ich+liebe+es+
# <Response [200]>
# Hip-Hop/Rap
# 181
# galantis+bones+
# <Response [200]>
# Dance
# 182
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 183
# avicii+tough+love
# <Response [200]>
# Dance
# 184
# sami+mary+jane
# <Response [200]>
# Hip-Hop/Rap
# 185
# king+khalil+bundesweit+
# <Response [200]>
# soolking+zemër
# <Response [200]>
# Hip-Hop/Rap
# 187
# luciano+meer
# <Response [200]>
# Nature
# 188
# why+dont+we+i+dont+belong+in+this+club
# <Response [200]>
# Pop
# 189
# summer+cem+tamam+tamam
# <Response [200]>
# Hip-Hop/Rap
# 190
# pietro+lombardi+nur+ein+tanz
# <Response [200]>
# Pop
# 191
# ariana+grande+break+up++your+girlfriend,+im+bored
# <Response [200]>
# Pop
# 192
# kitschkrieg+5+minuten+
# <Response [200]>
# Hip-Hop/Rap
# 193
# dj+khaled+celebrate+
# <Response [200]>
# Hip-Hop/Rap
# 194
# jigzaw+wer
# <Response [200]>
# Hip-Hop/Rap
# 195
# daddy+yankee+con+calma+-+remix
# <Response [200]>
# Urbano latino
# 196
# p!nk+walk+me+home
# <Response [200]>
# Pop
# 197
# loredana+romeo+&+juliet
# <Response [200]>
# Pop
# 198
# jazn+kopf+ist+krieg
# <Response [200]>
# Hip-Hop/Rap
# 199
# de_2019-05-24--2019-05-31.csv
# samra+wieder+lila
# <Response [200]>
# Hip-Hop/Rap
# 0
# juju+vermissen+
# <Response [200]>
# Hip-Hop/Rap
# 1
# samra+marlboro+rot
# <Response [200]>
# Hip-Hop/Rap
# 2
# rin+vintage
# <Response [200]>
# Rock
# 3
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 4
# kontra+k+letzte+träne
# <Response [200]>
# Hip-Hop/Rap
# 5
# shindy+nautilus
# <Response [200]>
# Rap
# 6
# lil+nas+x+old+town+road+
# <Response [200]>
# Country
# 7
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 8
# ufo361+gib+gas
# <Response [200]>
# Hip-Hop/Rap
# 9
# olexesh+barrio
# <Response [200]>
# Hip-Hop/Rap
# 10
# dardan+coco+mama
# <Response [200]>
# Hip-Hop
# 11
# bausa+mary
# <Response [200]>
# Hip-Hop/Rap
# 12
# kontra+k+blei+
# <Response [200]>
# Hip-Hop/Rap
# 13
# capital+bra+rolex
# <Response [200]>
# Hip-Hop/Rap
# 14
# avicii+sos
# <Response [200]>
# Dance
# 15
# capital+bra+cherry+lady
# <Response [200]>
# Hip-Hop/Rap
# 16
# lil+nas+x+old+town+road
# <Response [200]>
# Country
# 17
# sido+das+buch
# <Response [200]>
# Hip-Hop/Rap
# 18
# shirin+david+fliegst+du+mit
# <Response [200]>
# Pop
# 19
# kontra+k+alles+was+sie+will
# <Response [200]>
# Hip-Hop/Rap
# 20
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 21
# ardian+bujupi+wie+im+traum
# <Response [200]>
# Pop
# 22
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 23
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 24
# samra+ghetto
# <Response [200]>
# Hip-Hop/Rap
# 25
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 26
# moe+phoenix+3%+
# <Response [200]>
# Hip-Hop/Rap
# 27
# samra+harami
# <Response [200]>
# Hip-Hop/Rap
# 28
# shawn+mendes+if+i+cant+have+you
# <Response [200]>
# Pop
# 29
# bausa+weiß+noch+nicht+wie
# <Response [200]>
# Hip-Hop/Rap
# 30
# mero+wolke+10
# <Response [200]>
# Hip-Hop/Rap
# 31
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 32
# lena+dont+lie+to+me
# <Response [200]>
# Pop
# 33
# shindy+affalterbach
# <Response [200]>
# Rap
# 34
# gallo+nero+hermès
# <Response [200]>
# Rap
# 35
# rammstein+deutschland
# <Response [200]>
# Metal
# 36
# eno+blackberry+sky
# <Response [200]>
# Hip-Hop/Rap
# 37
# capital+bra+wir+ticken
# <Response [200]>
# Hip-Hop/Rap
# 38
# martin+garrix+summer+days+
# <Response [200]>
# Dance
# 39
# lx+perdono
# <Response [200]>
# Hip-Hop/Rap
# 40
# dominic+fike+3+nights
# <Response [200]>
# Alternative
# 41
# ufo361+next
# <Response [200]>
# Hip-Hop/Rap
# 42
# kc+rebell+quarterback
# <Response [200]>
# Hip-Hop/Rap
# 43
# kc+rebell+dna
# <Response [200]>
# Hip-Hop/Rap
# 44
# dardan+sorry
# <Response [200]>
# Rap
# 45
# ed+sheeran+cross+me+
# <Response [200]>
# Pop
# 46
# capital+bra+prinzessa
# <Response [200]>
# Hip-Hop/Rap
# 47
# michael+schulte+back+to+the+start
# <Response [200]>
# Pop
# 48
# sero+el+mero+ohne+sinn
# <Response [200]>
# Hip-Hop/Rap
# 49
# kontra+k+warnung
# <Response [200]>
# Hip-Hop/Rap
# 50
# c+arma+yapma
# <Response [200]>
# R&B/Soul
# 51
# pietro+lombardi+bella+donna
# <Response [200]>
# Pop
# 52
# ava+max+sweet+but+psycho
# <Response [200]>
# Pop
# 53
# dennis+lloyd+never+go+back
# <Response [200]>
# Alternative
# 54
# imagine+dragons+bad+liar
# <Response [200]>
# Alternative
# 55
# samra+shoote+ma+shoote
# <Response [200]>
# Hip-Hop/Rap
# 56
# taylor+swift+me!+
# <Response [200]>
# Country
# 57
# rammstein+ausländer
# <Response [200]>
# Metal
# 58
# onerepublic+rescue+me
# <Response [200]>
# Pop
# 59
# kc+rebell+alleen
# <Response [200]>
# Hip-Hop/Rap
# 60
# shirin+david+gib+ihm
# <Response [200]>
# Hip-Hop/Rap
# 61
# apache+207+brot+nach+hause
# <Response [200]>
# Hip-Hop/Rap
# 62
# kontra+k+kampfgeist+4
# <Response [200]>
# Hip-Hop/Rap
# 63
# kygo+carry+on+
# <Response [200]>
# Dance
# 64
# capital+bra+bye+bye
# <Response [200]>
# Hip-Hop/Rap
# 65
# kontra+k+weine+nicht
# <Response [200]>
# Hip-Hop/Rap
# 66
# young+thug+the+london+
# <Response [200]>
# Hip-Hop/Rap
# 67
# ava+max+so+am+i
# <Response [200]>
# Pop
# 68
# fero47+puerto+rico
# <Response [200]>
# Hip-Hop/Rap
# 69
# rammstein+radio
# <Response [200]>
# Metal
# 70
# bonez+mc+500+ps
# <Response [200]>
# Hip-Hop/Rap
# 71
# rammstein+zeig+dich
# <Response [200]>
# Metal
# 72
# matt+simons+open+up
# <Response [200]>
# Pop
# 73
# kontra+k+farben
# <Response [200]>
# Hip-Hop/Rap
# 74
# capital+bra+benzema
# <Response [200]>
# Hip-Hop/Rap
# 75
# gaullin+moonlight
# <Response [200]>
# Dance
# 76
# ellie+goulding+sixteen
# <Response [200]>
# Pop
# 77
# mathea+2x
# <Response [200]>
# Pop
# 78
# kontra+k+benzin
# <Response [200]>
# Hip-Hop/Rap
# 79
# 18+karat+immer+auf+der+straße+
# <Response [200]>
# Hip-Hop/Rap
# 80
# marshmello+here+with+me
# <Response [200]>
# Dance
# 81
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 82
# kontra+k+nur+ein+grund+
# <Response [200]>
# Hip-Hop/Rap
# 83
# panic!+at+the+disco+high+hopes
# <Response [200]>
# Alternative
# 84
# rammstein+puppe
# <Response [200]>
# Metal
# 85
# post+malone+wow.
# <Response [200]>
# Hip-Hop/Rap
# 86
# the+prince+karma+later+bitches
# <Response [200]>
# Dance
# 87
# sido+wie+papa
# <Response [200]>
# Hip-Hop/Rap
# 88
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 89
# jonas+blue+what+i+like+about+you+
# <Response [200]>
# Dance
# 90
# nico+santos+unforgettable
# <Response [200]>
# Pop
# 91
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 92
# mahmood+soldi
# <Response [200]>
# Pop
# 93
# kontra+k+ihre+sprache
# <Response [200]>
# Hip-Hop/Rap
# 94
# kitschkrieg+standard+
# <Response [200]>
# Hip-Hop/Rap
# 95
# alec+benjamin+let+me+down+slowly
# <Response [200]>
# Pop
# 96
# seeed+ticket
# <Response [200]>
# Pop
# 97
# robin+schulz+speechless+
# <Response [200]>
# Dance
# 98
# kalim+bis+um+3
# <Response [200]>
# Hip-Hop/Rap
# 99
# tyler,+the+creator+earfquake
# <Response [200]>
# Hip-Hop/Rap
# 100
# billie+eilish+bury+a+friend
# <Response [200]>
# Alternative
# 101
# lauv+im+so+tired...
# <Response [200]>
# Pop
# 102
# sarah+connor+vincent
# <Response [200]>
# Drama
# 103
# azet+fragen
# <Response [200]>
# Hip-Hop/Rap
# 104
# kontra+k+bleib+weg+von+mir+
# <Response [200]>
# Hip-Hop/Rap
# 105
# kontra+k+so+lang+
# <Response [200]>
# Hip-Hop/Rap
# 106
# fero47+jaja
# <Response [200]>
# Hip-Hop/Rap
# 107
# r3hab+all+around+the+world+
# <Response [200]>
# Dance
# 108
# ufo361+pass+auf+wen+du+liebst
# <Response [200]>
# Hip-Hop/Rap
# 109
# vize+glad+you+came
# <Response [200]>
# Dance
# 110
# rammstein+sex
# <Response [200]>
# Metal
# 111
# mero+jay+jay
# <Response [200]>
# Hip-Hop/Rap
# 112
# giant+rooks+wild+stare
# <Response [200]>
# Rock
# 113
# rin+dior+2001
# <Response [200]>
# mero+baller+los
# <Response [200]>
# Hip-Hop/Rap
# 115
# kontra+k+immer+weiter
# <Response [200]>
# Hip-Hop/Rap
# 116
# lizzo+truth+hurts
# <Response [200]>
# Dance
# 117
# luciano+ya+salame
# <Response [200]>
# Hip-Hop/Rap
# 118
# eno+souvenir
# <Response [200]>
# Hip-Hop/Rap
# 119
# eno+ferrari
# <Response [200]>
# Hip-Hop/Rap
# 120
# rammstein+was+ich+liebe
# <Response [200]>
# Metal
# 121
# sido+tausend+tattoos
# <Response [200]>
# Hip-Hop/Rap
# 122
# qzeng+trance
# <Response [200]>
# Hip-Hop/Rap
# 123
# rammstein+diamant
# <Response [200]>
# Metal
# 124
# kontra+k+schicksal
# <Response [200]>
# Hip-Hop/Rap
# 125
# halsey+nightmare
# <Response [200]>
# Alternative
# 126
# post+malone+sunflower+-+spider-man:+into+the+spider-verse
# <Response [200]>
# Hip-Hop/Rap
# 127
# khalid+talk+
# <Response [200]>
# R&B/Soul
# 128
# rammstein+weit+weg
# <Response [200]>
# Metal
# 129
# kianush+so+jung
# <Response [200]>
# Hip-Hop/Rap
# 130
# summer+cem+casanova
# <Response [200]>
# Hip-Hop/Rap
# 131
# yg+go+loko+
# <Response [200]>
# Hip-Hop/Rap
# 132
# kontra+k+alles+weg
# <Response [200]>
# Hip-Hop/Rap
# 133
# alan+walker+on+my+way
# <Response [200]>
# Dance
# 134
# calvin+harris+giant+
# <Response [200]>
# Dance
# 135
# mero+hobby+hobby
# <Response [200]>
# Hip-Hop/Rap
# 136
# billie+eilish+when+the+partys+over
# <Response [200]>
# Alternative
# 137
# loud+luxury+body+
# <Response [200]>
# Dance
# 138
# elias+aquafina
# <Response [200]>
# Hip-Hop/Rap
# 139
# rammstein+tattoo
# <Response [200]>
# Metal
# 140
# samra+cataleya
# <Response [200]>
# Hip-Hop/Rap
# 141
# kontra+k+skimaske+
# <Response [200]>
# Hip-Hop/Rap
# 142
# leon+machère+copacabana
# <Response [200]>
# Pop
# 143
# halsey+without+me
# <Response [200]>
# Alternative
# 144
# kontra+k+sag+mir+wo+
# <Response [200]>
# Hip-Hop/Rap
# 145
# sosmula+1k+shotz
# <Response [200]>
# Hip-Hop/Rap
# 146
# luciano+millies
# <Response [200]>
# Hip-Hop/Rap
# 147
# marshmello+happier
# <Response [200]>
# Dance
# 148
# capital+bra+capital+bra+je+mappelle
# <Response [200]>
# Hip-Hop/Rap
# 149
# 5+seconds+of+summer+easier
# <Response [200]>
# Pop
# 150
# kontra+k+honig+
# <Response [200]>
# Hip-Hop/Rap
# 151
# bazzi+paradise
# <Response [200]>
# Pop
# 152
# kontra+k+zu+viele+
# <Response [200]>
# Hip-Hop/Rap
# 153
# sdp+viva+la+dealer
# <Response [200]>
# Pop
# 154
# bausa+was+du+liebe+nennst
# <Response [200]>
# Hip-Hop/Rap
# 155
# billie+eilish+lovely+
# <Response [200]>
# Pop
# 156
# juju+hardcore+high
# <Response [200]>
# Hip-Hop/Rap
# 157
# bonez+mc+kokain
# <Response [200]>
# Hip-Hop/Rap
# 158
# a+boogie+wit+da+hoodie+look+back+at+it
# <Response [200]>
# Hip-Hop/Rap
# 159
# duncan+laurence+arcade
# <Response [200]>
# Pop
# 160
# jax+jones+all+day+and+night+-+jax+jones+&+martin+solveig+present+europa
# <Response [200]>
# Dance
# 161
# kontra+k+niemals+vergessen
# <Response [200]>
# Hip-Hop/Rap
# 162
# a+boogie+wit+da+hoodie+swervin+
# <Response [200]>
# Hip-Hop/Rap
# 163
# capital+bra+neymar
# <Response [200]>
# Hip-Hop/Rap
# 164
# dj+snake+taki+taki+
# <Response [200]>
# Dance
# 165
# shindy+dodi
# <Response [200]>
# Rap
# 166
# joyner+lucas+isis
# <Response [200]>
# Hip-Hop
# 167
# dardan+facetime
# <Response [200]>
# Hip-Hop
# 168
# david+guetta+say+my+name
# <Response [200]>
# Dance
# 169
# dean+lewis+be+alright
# <Response [200]>
# Singer/Songwriter
# 170
# kygo+not+ok
# <Response [200]>
# Dance
# 171
# bonez+mc+ohne+mein+team
# <Response [200]>
# kool+savas+deine+mutter
# <Response [200]>
# Hip-Hop/Rap
# 173
# logic+homicide+
# <Response [200]>
# Hip-Hop/Rap
# 174
# harris+&+ford+freitag,+samstag
# <Response [200]>
# Action & Adventure
# 175
# hugel+wtf+
# <Response [200]>
# Pop
# 176
# kina+get+you+the+moon+
# <Response [200]>
# R&B/Soul
# 177
# majan+1975
# <Response [200]>
# Hip-Hop/Rap
# 178
# finch+asozial+abfahrt
# <Response [200]>
# Hip-Hop/Rap
# 179
# lil+dicky+earth
# <Response [200]>
# Pop
# 180
# post+malone+rockstar+
# <Response [200]>
# Hip-Hop/Rap
# 181
# capital+bra+melodien+
# <Response [200]>
# Hip-Hop/Rap
# 182
# alle+farben+fading
# <Response [200]>
# Dance
# 183
# rammstein+hallomann
# <Response [200]>
# Metal
# 184
# benny+blanco+eastside+
# <Response [200]>
# Pop
# 185
# capo+lambo+diablo+gt+
# <Response [200]>
# Hip-Hop
# 186
# gringo+blue+lagoon
# <Response [200]>
# Hip-Hop/Rap
# 187
# sam+smith+dancing+with+a+stranger+
# <Response [200]>
# Pop
# 188
# raf+camora+perfekt+
# <Response [200]>
# Rap
# 189
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 190
# shirin+david+ice
# <Response [200]>
# Hip-Hop/Rap
# 191
# robin+schulz+all+this+love+
# <Response [200]>
# Dance
# 192
# capital+bra+click+click
# <Response [200]>
# Hip-Hop/Rap
# 193
# apache+207+kein+problem
# <Response [200]>
# Hip-Hop/Rap
# 194
# lena+thank+you
# <Response [200]>
# Pop
# 195
# galantis+bones+
# <Response [200]>
# Dance
# 196
# summer+cem+tamam+tamam
# <Response [200]>
# Hip-Hop/Rap
# 197
# daddy+yankee+con+calma+-+remix
# <Response [200]>
# Urbano latino
# 198
# tyga+goddamn+
# <Response [200]>
# Hip-Hop/Rap
# 199
# de_2019-05-31--2019-06-07.csv
# luciano+la+haine
# <Response [200]>
# Hip-Hop/Rap
# 0
# samra+wieder+lila
# <Response [200]>
# Hip-Hop/Rap
# 1
# juju+vermissen+
# <Response [200]>
# Hip-Hop/Rap
# 2
# mero+malediven
# <Response [200]>
# Hip-Hop/Rap
# 3
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 4
# rin+vintage
# <Response [200]>
# Rock
# 5
# samra+marlboro+rot
# <Response [200]>
# Hip-Hop/Rap
# 6
# lil+nas+x+old+town+road+
# <Response [200]>
# Country
# 7
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 8
# shindy+nautilus
# <Response [200]>
# Rap
# 9
# kontra+k+letzte+träne
# <Response [200]>
# Hip-Hop/Rap
# 10
# dardan+a+milly
# <Response [200]>
# Rap
# 11
# olexesh+barrio
# <Response [200]>
# Hip-Hop/Rap
# 12
# dardan+coco+mama
# <Response [200]>
# Hip-Hop
# 13
# bausa+mary
# <Response [200]>
# Hip-Hop/Rap
# 14
# avicii+sos
# <Response [200]>
# Dance
# 15
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 16
# kontra+k+blei+
# <Response [200]>
# Hip-Hop/Rap
# 17
# shirin+david+fliegst+du+mit
# <Response [200]>
# Pop
# 18
# lil+nas+x+old+town+road
# <Response [200]>
# Country
# 19
# capital+bra+rolex
# <Response [200]>
# Hip-Hop/Rap
# 20
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 21
# capital+bra+cherry+lady
# <Response [200]>
# Hip-Hop/Rap
# 22
# martin+garrix+summer+days+
# <Response [200]>
# Dance
# 23
# ardian+bujupi+wie+im+traum
# <Response [200]>
# Pop
# 24
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 25
# lena+dont+lie+to+me
# <Response [200]>
# Pop
# 26
# shawn+mendes+if+i+cant+have+you
# <Response [200]>
# Pop
# 27
# ufo361+gib+gas
# <Response [200]>
# Hip-Hop/Rap
# 28
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 29
# dominic+fike+3+nights
# <Response [200]>
# Alternative
# 30
# michael+schulte+back+to+the+start
# <Response [200]>
# Pop
# 31
# onerepublic+rescue+me
# <Response [200]>
# Pop
# 32
# c+arma+yapma
# <Response [200]>
# R&B/Soul
# 33
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 34
# moe+phoenix+3%+
# <Response [200]>
# Hip-Hop/Rap
# 35
# dennis+lloyd+never+go+back
# <Response [200]>
# Alternative
# 36
# mero+wolke+10
# <Response [200]>
# Hip-Hop/Rap
# 37
# samra+harami
# <Response [200]>
# Hip-Hop/Rap
# 38
# eno+blackberry+sky
# <Response [200]>
# Hip-Hop/Rap
# 39
# samra+ghetto
# <Response [200]>
# Hip-Hop/Rap
# 40
# shindy+affalterbach
# <Response [200]>
# Rap
# 41
# juju+live+bitch
# <Response [200]>
# Hip-Hop/Rap
# 42
# kc+rebell+dna
# <Response [200]>
# Hip-Hop/Rap
# 43
# rammstein+deutschland
# <Response [200]>
# Metal
# 44
# capital+bra+wir+ticken
# <Response [200]>
# Hip-Hop/Rap
# 45
# lil+lano+20+tausend+euro+bar
# <Response [200]>
# Hip-Hop/Rap
# 46
# ed+sheeran+cross+me+
# <Response [200]>
# Pop
# 47
# sarah+connor+vincent
# <Response [200]>
# Drama
# 48
# kontra+k+alles+was+sie+will
# <Response [200]>
# Hip-Hop/Rap
# 49
# vize+glad+you+came
# <Response [200]>
# Dance
# 50
# pietro+lombardi+bella+donna
# <Response [200]>
# Pop
# 51
# capital+bra+prinzessa
# <Response [200]>
# Hip-Hop/Rap
# 52
# sido+das+buch
# <Response [200]>
# Hip-Hop/Rap
# 53
# kygo+carry+on+
# <Response [200]>
# Dance
# 54
# kc+rebell+quarterback
# <Response [200]>
# Hip-Hop/Rap
# 55
# capital+bra+bye+bye
# <Response [200]>
# Hip-Hop/Rap
# 56
# imagine+dragons+bad+liar
# <Response [200]>
# Alternative
# 57
# 18+karat+mafia+
# <Response [200]>
# Hip-Hop/Rap
# 58
# young+thug+the+london+
# <Response [200]>
# Hip-Hop/Rap
# 59
# ava+max+sweet+but+psycho
# <Response [200]>
# Pop
# 60
# ufo361+next
# <Response [200]>
# Hip-Hop/Rap
# 61
# ellie+goulding+sixteen
# <Response [200]>
# Pop
# 62
# nico+santos+unforgettable
# <Response [200]>
# Pop
# 63
# matt+simons+open+up
# <Response [200]>
# Pop
# 64
# lx+perdono
# <Response [200]>
# Hip-Hop/Rap
# 65
# r3hab+all+around+the+world+
# <Response [200]>
# Dance
# 66
# the+chainsmokers+call+you+mine
# <Response [200]>
# Dance
# 67
# shirin+david+gib+ihm
# <Response [200]>
# Hip-Hop/Rap
# 68
# kc+rebell+alleen
# <Response [200]>
# Hip-Hop/Rap
# 69
# sero+el+mero+ohne+sinn
# <Response [200]>
# Hip-Hop/Rap
# 70
# rammstein+ausländer
# <Response [200]>
# Metal
# 71
# bonez+mc+500+ps
# <Response [200]>
# Hip-Hop/Rap
# 72
# samra+shoote+ma+shoote
# <Response [200]>
# Hip-Hop/Rap
# 73
# jonas+blue+what+i+like+about+you+
# <Response [200]>
# Dance
# 74
# apache+207+brot+nach+hause
# <Response [200]>
# Hip-Hop/Rap
# 75
# kontra+k+warnung
# <Response [200]>
# Hip-Hop/Rap
# 76
# taylor+swift+me!+
# <Response [200]>
# Country
# 77
# bausa+weiß+noch+nicht+wie
# <Response [200]>
# Hip-Hop/Rap
# 78
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 79
# ava+max+so+am+i
# <Response [200]>
# Pop
# 80
# marshmello+here+with+me
# <Response [200]>
# Dance
# 81
# gallo+nero+hermès
# <Response [200]>
# Rap
# 82
# dardan+sorry
# <Response [200]>
# Rap
# 83
# katy+perry+never+really+over
# <Response [200]>
# Pop
# 84
# gaullin+moonlight
# <Response [200]>
# Dance
# 85
# capital+bra+benzema
# <Response [200]>
# Hip-Hop/Rap
# 86
# robin+schulz+all+this+love+
# <Response [200]>
# Dance
# 87
# mathea+2x
# <Response [200]>
# Pop
# 88
# miley+cyrus+mothers+daughter
# <Response [200]>
# Pop
# 89
# the+prince+karma+later+bitches
# <Response [200]>
# Dance
# 90
# post+malone+wow.
# <Response [200]>
# Hip-Hop/Rap
# 91
# mahmood+soldi
# <Response [200]>
# Pop
# 92
# panic!+at+the+disco+high+hopes
# <Response [200]>
# Alternative
# 93
# seeed+ticket
# <Response [200]>
# Pop
# 94
# yg+go+loko+
# <Response [200]>
# Hip-Hop/Rap
# 95
# fero47+puerto+rico
# <Response [200]>
# Hip-Hop/Rap
# 96
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 97
# rammstein+radio
# <Response [200]>
# Metal
# 98
# fler+stress+ohne+grund+2019
# <Response [200]>
# Hip-Hop/Rap
# 99
# 18+karat+immer+auf+der+straße+
# <Response [200]>
# Hip-Hop/Rap
# 100
# kitschkrieg+standard+
# <Response [200]>
# Hip-Hop/Rap
# 101
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 102
# robin+schulz+speechless+
# <Response [200]>
# Dance
# 103
# tyler,+the+creator+earfquake
# <Response [200]>
# Hip-Hop/Rap
# 104
# kalim+bis+um+3
# <Response [200]>
# Hip-Hop/Rap
# 105
# alec+benjamin+let+me+down+slowly
# <Response [200]>
# Pop
# 106
# gamper+&+dadoni+bittersweet+symphony+
# <Response [200]>
# House
# 107
# kontra+k+kampfgeist+4
# <Response [200]>
# Hip-Hop/Rap
# 108
# giant+rooks+wild+stare
# <Response [200]>
# Rock
# 109
# billie+eilish+bury+a+friend
# <Response [200]>
# Alternative
# 110
# fero47+jaja
# <Response [200]>
# Hip-Hop/Rap
# 111
# rammstein+zeig+dich
# <Response [200]>
# Metal
# 112
# rin+dior+2001
# <Response [200]>
# lauv+im+so+tired...
# <Response [200]>
# Pop
# 114
# younotus+narcotic
# <Response [200]>
# Dance
# 115
# kianush+so+jung
# <Response [200]>
# Hip-Hop/Rap
# 116
# kontra+k+farben
# <Response [200]>
# Hip-Hop/Rap
# 117
# post+malone+sunflower+-+spider-man:+into+the+spider-verse
# <Response [200]>
# Hip-Hop/Rap
# 118
# mero+baller+los
# <Response [200]>
# Hip-Hop/Rap
# 119
# luciano+ya+salame
# <Response [200]>
# Hip-Hop/Rap
# 120
# ufo361+pass+auf+wen+du+liebst
# <Response [200]>
# Hip-Hop/Rap
# 121
# sido+tausend+tattoos
# <Response [200]>
# Hip-Hop/Rap
# 122
# daddy+yankee+con+calma+-+remix
# <Response [200]>
# Urbano latino
# 123
# eno+souvenir
# <Response [200]>
# Hip-Hop/Rap
# 124
# eno+ferrari
# <Response [200]>
# Hip-Hop/Rap
# 125
# tiësto+ritual
# <Response [200]>
# Dance
# 126
# loud+luxury+body+
# <Response [200]>
# Dance
# 127
# summer+cem+casanova
# <Response [200]>
# Hip-Hop/Rap
# 128
# rammstein+puppe
# <Response [200]>
# Metal
# 129
# calvin+harris+giant+
# <Response [200]>
# Dance
# 130
# leon+machère+copacabana
# <Response [200]>
# Pop
# 131
# azet+fragen
# <Response [200]>
# Hip-Hop/Rap
# 132
# lizzo+truth+hurts
# <Response [200]>
# Dance
# 133
# alan+walker+on+my+way
# <Response [200]>
# Dance
# 134
# billie+eilish+when+the+partys+over
# <Response [200]>
# Alternative
# 135
# jax+jones+all+day+and+night+-+jax+jones+&+martin+solveig+present+europa
# <Response [200]>
# Dance
# 136
# 18+karat+gucci+&+versace+
# <Response [200]>
# Hip-Hop/Rap
# 137
# luciano+millies
# <Response [200]>
# Hip-Hop/Rap
# 138
# vize+stars
# <Response [200]>
# Dance
# 139
# bausa+was+du+liebe+nennst
# <Response [200]>
# Hip-Hop/Rap
# 140
# mero+hobby+hobby
# <Response [200]>
# Hip-Hop/Rap
# 141
# khalid+talk+
# <Response [200]>
# R&B/Soul
# 142
# marshmello+happier
# <Response [200]>
# Dance
# 143
# halsey+without+me
# <Response [200]>
# Alternative
# 144
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 145
# sdp+viva+la+dealer
# <Response [200]>
# Pop
# 146
# juju+hardcore+high
# <Response [200]>
# Hip-Hop/Rap
# 147
# samra+cataleya
# <Response [200]>
# Hip-Hop/Rap
# 148
# qzeng+trance
# <Response [200]>
# Hip-Hop/Rap
# 149
# bonez+mc+kokain
# <Response [200]>
# Hip-Hop/Rap
# 150
# kontra+k+nur+ein+grund+
# <Response [200]>
# Hip-Hop/Rap
# 151
# a+boogie+wit+da+hoodie+look+back+at+it
# <Response [200]>
# Hip-Hop/Rap
# 152
# mark+ronson+find+u+again+
# <Response [200]>
# Pop
# 153
# rammstein+sex
# <Response [200]>
# Metal
# 154
# halsey+nightmare
# <Response [200]>
# Alternative
# 155
# capital+bra+capital+bra+je+mappelle
# <Response [200]>
# Hip-Hop/Rap
# 156
# alok+all+the+lies
# <Response [200]>
# Dance
# 157
# billie+eilish+lovely+
# <Response [200]>
# Pop
# 158
# kontra+k+weine+nicht
# <Response [200]>
# Hip-Hop/Rap
# 159
# alvaro+soler+la+libertad
# <Response [200]>
# Pop
# 160
# capital+bra+neymar
# <Response [200]>
# Hip-Hop/Rap
# 161
# dj+snake+taki+taki+
# <Response [200]>
# Dance
# 162
# bazzi+paradise
# <Response [200]>
# Pop
# 163
# mero+jay+jay
# <Response [200]>
# Hip-Hop/Rap
# 164
# david+guetta+say+my+name
# <Response [200]>
# Dance
# 165
# a+boogie+wit+da+hoodie+swervin+
# <Response [200]>
# Hip-Hop/Rap
# 166
# avicii+tough+love
# <Response [200]>
# Dance
# 167
# rammstein+was+ich+liebe
# <Response [200]>
# Metal
# 168
# dynoro+obsessed
# <Response [200]>
# Dance
# 169
# shindy+dodi
# <Response [200]>
# Rap
# 170
# petit+biscuit+sunset+lover
# <Response [200]>
# Electronic
# 171
# dardan+facetime
# <Response [200]>
# Hip-Hop
# 172
# bonez+mc+ohne+mein+team
# <Response [200]>
# rammstein+diamant
# <Response [200]>
# Metal
# 174
# post+malone+rockstar+
# <Response [200]>
# Hip-Hop/Rap
# 175
# cardi+b+press
# <Response [200]>
# Hip-Hop/Rap
# 176
# sido+wie+papa
# <Response [200]>
# Hip-Hop/Rap
# 177
# hanybal+check
# <Response [200]>
# Hip-Hop/Rap
# 178
# dean+lewis+be+alright
# <Response [200]>
# Singer/Songwriter
# 179
# benny+blanco+eastside+
# <Response [200]>
# Pop
# 180
# apache+207+kein+problem
# <Response [200]>
# Hip-Hop/Rap
# 181
# luca+hänni+she+got+me
# <Response [200]>
# Pop
# 182
# capital+bra+melodien+
# <Response [200]>
# Hip-Hop/Rap
# 183
# capo+lambo+diablo+gt+
# <Response [200]>
# Hip-Hop
# 184
# sam+smith+dancing+with+a+stranger+
# <Response [200]>
# Pop
# 185
# rammstein+weit+weg
# <Response [200]>
# Metal
# 186
# luciano+meer
# <Response [200]>
# Nature
# 187
# hugel+wtf+
# <Response [200]>
# Pop
# 188
# kontra+k+benzin
# <Response [200]>
# Hip-Hop/Rap
# 189
# wincent+weiss+kaum+erwarten
# <Response [200]>
# Pop
# 190
# rammstein+tattoo
# <Response [200]>
# Metal
# 191
# kool+savas+deine+mutter
# <Response [200]>
# Hip-Hop/Rap
# 192
# raf+camora+perfekt+
# <Response [200]>
# Rap
# 193
# max+love+me+less+
# <Response [200]>
# Pop
# 194
# alle+farben+fading
# <Response [200]>
# Dance
# 195
# tyga+taste+
# <Response [200]>
# Hip-Hop/Rap
# 196
# kina+get+you+the+moon+
# <Response [200]>
# R&B/Soul
# 197
# sami+mary+jane
# <Response [200]>
# Hip-Hop/Rap
# 198
# 5+seconds+of+summer+easier
# <Response [200]>
# Pop
# 199
# de_2019-06-07--2019-06-14.csv
# farid+bang+maghreb+gang+
# <Response [200]>
# Hip-Hop/Rap
# 0
# fero47+nenene
# <Response [200]>
# Hip-Hop/Rap
# 1
# ufo361+irina+shayk
# <Response [200]>
# Hip-Hop/Rap
# 2
# samra+wieder+lila
# <Response [200]>
# Hip-Hop/Rap
# 3
# luciano+la+haine
# <Response [200]>
# Hip-Hop/Rap
# 4
# juju+vermissen+
# <Response [200]>
# Hip-Hop/Rap
# 5
# loredana+labyrinth
# <Response [200]>
# Hip-Hop/Rap
# 6
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 7
# lil+nas+x+old+town+road+
# <Response [200]>
# Country
# 8
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 9
# kc+rebell+badewanne
# <Response [200]>
# Hip-Hop/Rap
# 10
# mero+malediven
# <Response [200]>
# Hip-Hop/Rap
# 11
# rin+vintage
# <Response [200]>
# Rock
# 12
# avicii+sos+
# <Response [200]>
# Dance
# 13
# samra+marlboro+rot
# <Response [200]>
# Hip-Hop/Rap
# 14
# shindy+nautilus
# <Response [200]>
# Rap
# 15
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 16
# dardan+coco+mama
# <Response [200]>
# Hip-Hop
# 17
# bausa+mary
# <Response [200]>
# Hip-Hop/Rap
# 18
# dardan+a+milly
# <Response [200]>
# Rap
# 19
# kontra+k+letzte+träne
# <Response [200]>
# Hip-Hop/Rap
# 20
# olexesh+barrio
# <Response [200]>
# Hip-Hop/Rap
# 21
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 22
# kontra+k+blei+
# <Response [200]>
# Hip-Hop/Rap
# 23
# capital+bra+rolex
# <Response [200]>
# Hip-Hop/Rap
# 24
# lil+nas+x+old+town+road
# <Response [200]>
# Country
# 25
# veysel+michel+vaillant
# <Response [200]>
# Hip-Hop/Rap
# 26
# martin+garrix+summer+days+
# <Response [200]>
# Dance
# 27
# capital+bra+cherry+lady
# <Response [200]>
# Hip-Hop/Rap
# 28
# ardian+bujupi+wie+im+traum
# <Response [200]>
# Pop
# 29
# sarah+connor+vincent
# <Response [200]>
# Drama
# 30
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 31
# onerepublic+rescue+me
# <Response [200]>
# Pop
# 32
# r3hab+all+around+the+world+
# <Response [200]>
# Dance
# 33
# shawn+mendes+if+i+cant+have+you
# <Response [200]>
# Pop
# 34
# tyga+haute+
# <Response [200]>
# Hip-Hop/Rap
# 35
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 36
# lena+dont+lie+to+me
# <Response [200]>
# Pop
# 37
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 38
# dominic+fike+3+nights
# <Response [200]>
# Alternative
# 39
# michael+schulte+back+to+the+start
# <Response [200]>
# Pop
# 40
# vize+glad+you+came
# <Response [200]>
# Dance
# 41
# c+arma+yapma
# <Response [200]>
# R&B/Soul
# 42
# dennis+lloyd+never+go+back
# <Response [200]>
# Alternative
# 43
# avicii+heaven
# <Response [200]>
# Dance
# 44
# the+chainsmokers+call+you+mine
# <Response [200]>
# Dance
# 45
# shirin+david+fliegst+du+mit
# <Response [200]>
# Pop
# 46
# moe+phoenix+3%+
# <Response [200]>
# Hip-Hop/Rap
# 47
# mero+wolke+10
# <Response [200]>
# Hip-Hop/Rap
# 48
# samra+harami
# <Response [200]>
# Hip-Hop/Rap
# 49
# ufo361+gib+gas
# <Response [200]>
# Hip-Hop/Rap
# 50
# ed+sheeran+cross+me+
# <Response [200]>
# Pop
# 51
# rammstein+deutschland
# <Response [200]>
# Metal
# 52
# shindy+affalterbach
# <Response [200]>
# Rap
# 53
# capital+bra+wir+ticken
# <Response [200]>
# Hip-Hop/Rap
# 54
# capital+bra+prinzessa
# <Response [200]>
# Hip-Hop/Rap
# 55
# kc+rebell+dna
# <Response [200]>
# Hip-Hop/Rap
# 56
# eno+blackberry+sky
# <Response [200]>
# Hip-Hop/Rap
# 57
# ardian+bujupi+wallah+ich+leb
# <Response [200]>
# Pop
# 58
# samra+ghetto
# <Response [200]>
# Hip-Hop/Rap
# 59
# pietro+lombardi+bella+donna
# <Response [200]>
# Pop
# 60
# nico+santos+unforgettable
# <Response [200]>
# Pop
# 61
# imagine+dragons+bad+liar
# <Response [200]>
# Alternative
# 62
# ava+max+sweet+but+psycho
# <Response [200]>
# Pop
# 63
# yg+go+loko+
# <Response [200]>
# Hip-Hop/Rap
# 64
# kc+rebell+quarterback
# <Response [200]>
# Hip-Hop/Rap
# 65
# bonez+mc+500+ps
# <Response [200]>
# Hip-Hop/Rap
# 66
# katy+perry+never+really+over
# <Response [200]>
# Pop
# 67
# ellie+goulding+sixteen
# <Response [200]>
# Pop
# 68
# kc+rebell+alleen
# <Response [200]>
# Hip-Hop/Rap
# 69
# capital+bra+bye+bye
# <Response [200]>
# Hip-Hop/Rap
# 70
# kygo+carry+on+
# <Response [200]>
# Dance
# 71
# young+thug+the+london+
# <Response [200]>
# Hip-Hop/Rap
# 72
# ufo361+next
# <Response [200]>
# Hip-Hop/Rap
# 73
# matt+simons+open+up
# <Response [200]>
# Pop
# 74
# gamper+&+dadoni+bittersweet+symphony+
# <Response [200]>
# House
# 75
# lil+lano+20+tausend+euro+bar
# <Response [200]>
# Hip-Hop/Rap
# 76
# miley+cyrus+mothers+daughter
# <Response [200]>
# Pop
# 77
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 78
# shirin+david+gib+ihm
# <Response [200]>
# Hip-Hop/Rap
# 79
# kontra+k+alles+was+sie+will
# <Response [200]>
# Hip-Hop/Rap
# 80
# robin+schulz+all+this+love+
# <Response [200]>
# Dance
# 81
# sido+das+buch
# <Response [200]>
# Hip-Hop/Rap
# 82
# bausa+weiß+noch+nicht+wie
# <Response [200]>
# Hip-Hop/Rap
# 83
# fero47+puerto+rico
# <Response [200]>
# Hip-Hop/Rap
# 84
# kontra+k+warnung
# <Response [200]>
# Hip-Hop/Rap
# 85
# capital+bra+benzema
# <Response [200]>
# Hip-Hop/Rap
# 86
# samra+shoote+ma+shoote
# <Response [200]>
# Hip-Hop/Rap
# 87
# rammstein+ausländer
# <Response [200]>
# Metal
# 88
# jonas+blue+what+i+like+about+you+
# <Response [200]>
# Dance
# 89
# sero+el+mero+ohne+sinn
# <Response [200]>
# Hip-Hop/Rap
# 90
# the+prince+karma+later+bitches
# <Response [200]>
# Dance
# 91
# younotus+narcotic
# <Response [200]>
# Dance
# 92
# gaullin+moonlight
# <Response [200]>
# Dance
# 93
# panic!+at+the+disco+high+hopes
# <Response [200]>
# Alternative
# 94
# apache+207+brot+nach+hause
# <Response [200]>
# Hip-Hop/Rap
# 95
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 96
# fero47+jaja
# <Response [200]>
# Hip-Hop/Rap
# 97
# taylor+swift+me!+
# <Response [200]>
# Country
# 98
# lx+perdono
# <Response [200]>
# Hip-Hop/Rap
# 99
# mathea+2x
# <Response [200]>
# Pop
# 100
# post+malone+wow.
# <Response [200]>
# Hip-Hop/Rap
# 101
# ava+max+so+am+i
# <Response [200]>
# Pop
# 102
# seeed+ticket
# <Response [200]>
# Pop
# 103
# jigzaw+sprudelwasser
# <Response [200]>
# Hip-Hop/Rap
# 104
# kitschkrieg+standard+
# <Response [200]>
# Hip-Hop/Rap
# 105
# robin+schulz+speechless+
# <Response [200]>
# Dance
# 106
# chris+brown+no+guidance+
# <Response [200]>
# R&B/Soul
# 107
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 108
# gallo+nero+hermès
# <Response [200]>
# Rap
# 109
# alec+benjamin+let+me+down+slowly
# <Response [200]>
# Pop
# 110
# mahmood+soldi
# <Response [200]>
# Pop
# 111
# nash+handschellen
# <Response [200]>
# Hip-Hop/Rap
# 112
# rammstein+radio
# <Response [200]>
# Metal
# 113
# avicii+tough+love+
# <Response [200]>
# Dance
# 114
# ufo361+pass+auf+wen+du+liebst
# <Response [200]>
# Hip-Hop/Rap
# 115
# kalim+bis+um+3
# <Response [200]>
# Hip-Hop/Rap
# 116
# juju+live+bitch
# <Response [200]>
# Hip-Hop/Rap
# 117
# rin+dior+2001
# <Response [200]>
# billie+eilish+bury+a+friend
# <Response [200]>
# Alternative
# 119
# mero+baller+los
# <Response [200]>
# Hip-Hop/Rap
# 120
# alvaro+soler+la+libertad
# <Response [200]>
# Pop
# 121
# post+malone+sunflower+-+spider-man:+into+the+spider-verse
# <Response [200]>
# Hip-Hop/Rap
# 122
# sido+tausend+tattoos
# <Response [200]>
# Hip-Hop/Rap
# 123
# summer+cem+casanova
# <Response [200]>
# Hip-Hop/Rap
# 124
# luciano+ya+salame
# <Response [200]>
# Hip-Hop/Rap
# 125
# loud+luxury+body+
# <Response [200]>
# Dance
# 126
# giant+rooks+wild+stare
# <Response [200]>
# Rock
# 127
# lauv+im+so+tired...
# <Response [200]>
# Pop
# 128
# marshmello+here+with+me
# <Response [200]>
# Dance
# 129
# leon+machère+copacabana
# <Response [200]>
# Pop
# 130
# tyler,+the+creator+earfquake
# <Response [200]>
# Hip-Hop/Rap
# 131
# rammstein+zeig+dich
# <Response [200]>
# Metal
# 132
# kontra+k+kampfgeist+4
# <Response [200]>
# Hip-Hop/Rap
# 133
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 134
# azet+fragen
# <Response [200]>
# Hip-Hop/Rap
# 135
# kianush+so+jung
# <Response [200]>
# Hip-Hop/Rap
# 136
# calvin+harris+giant+
# <Response [200]>
# Dance
# 137
# billie+eilish+when+the+partys+over
# <Response [200]>
# Alternative
# 138
# 18+karat+mafia+
# <Response [200]>
# Hip-Hop/Rap
# 139
# vize+stars
# <Response [200]>
# Dance
# 140
# kontra+k+farben
# <Response [200]>
# Hip-Hop/Rap
# 141
# bausa+was+du+liebe+nennst
# <Response [200]>
# Hip-Hop/Rap
# 142
# ...
# <Response [200]>
# Pop
# 156
# capital+bra+lieber+gott
# <Response [200]>
# Hip-Hop/Rap
# 157
# kitschkrieg+standard+
# <Response [200]>
# Hip-Hop/Rap
# 158
# kc+rebell+dna
# <Response [200]>
# Hip-Hop/Rap
# 159
# capital+bra+prinzessa
# <Response [200]>
# Hip-Hop/Rap
# 160
# ava+max+sweet+but+psycho
# <Response [200]>
# Pop
# 161
# lil+mosey+stuck+in+a+dream+
# <Response [200]>
# Hip-Hop/Rap
# 162
# olexesh+barrio
# <Response [200]>
# Hip-Hop/Rap
# 163
# apache+207+ferrari+testarossa
# <Response [200]>
# Hip-Hop/Rap
# 164
# ufo361+nummer
# <Response [200]>
# Hip-Hop/Rap
# 165
# pashanim+shababs+botten
# <Response [200]>
# Hip-Hop/Rap
# 166
# mabel+mad+love
# <Response [200]>
# Pop
# 167
# younotus+narcotic
# <Response [200]>
# Dance
# 168
# apache+207+nicht+wie+du
# <Response [200]>
# Hip-Hop/Rap
# 169
# luciano+la+haine
# <Response [200]>
# Hip-Hop/Rap
# 170
# summer+cem+farben+
# <Response [200]>
# Hip-Hop/Rap
# 171
# raf+camora+finale+1150
# <Response [200]>
# Hip-Hop/Rap
# 172
# lizzo+good+as+hell+
# <Response [200]>
# Pop
# 173
# azet+mango
# <Response [200]>
# Hip-Hop/Rap
# 174
# lauv+fuck,+im+lonely+
# <Response [200]>
# Pop
# 175
# shindy+nautilus
# <Response [200]>
# Rap
# 176
# sarah+connor+vincent
# <Response [200]>
# Drama
# 177
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 178
# eren+can+ist+okay
# <Response [200]>
# Hip-Hop/Rap
# 179
# raf+camora+kreiert
# <Response [200]>
# Hip-Hop/Rap
# 180
# sido+tausend+tattoos
# <Response [200]>
# Hip-Hop/Rap
# 181
# lewis+capaldi+bruises
# <Response [200]>
# Alternative
# 182
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 183
# ufo361+shot
# <Response [200]>
# Hip-Hop/Rap
# 184
# summer+cem+bayram+
# <Response [200]>
# Hip-Hop/Rap
# 185
# mariah+carey+all+i+want+for+christmas+is+you
# <Response [200]>
# Holiday
# 186
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 187
# ali+gatie+its+you
# <Response [200]>
# R&B/Soul
# 188
# 5+seconds+of+summer+teeth
# <Response [200]>
# Pop
# 189
# bausa+was+du+liebe+nennst
# <Response [200]>
# Hip-Hop/Rap
# 190
# raf+camora+traum
# <Response [200]>
# Hip-Hop/Rap
# 191
# max+giesinger+auf+das,+was+da+noch+kommt
# <Response [200]>
# Pop
# 192
# lea+immer+wenn+wir+uns+sehn+
# <Response [200]>
# Pop
# 193
# kc+rebell+neptun
# <Response [200]>
# Hip-Hop/Rap
# 194
# blanco+brown+the+git+up
# <Response [200]>
# Country
# 195
# capital+bra+cherry+lady
# <Response [200]>
# Hip-Hop/Rap
# 196
# belah+eine+nacht
# <Response [200]>
# Hip-Hop/Rap
# 197
# capo+lambo+diablo+gt+
# <Response [200]>
# Hip-Hop
# 198
# tyga+mamacita
# <Response [200]>
# Hip-Hop/Rap
# 199
# de_2019-11-15--2019-11-22.csv
# apache+207+roller
# <Response [200]>
# Hip-Hop/Rap
# 0
# tones+and+i+dance+monkey
# <Response [200]>
# Alternative
# 1
# apache+207+wieso+tust+du+dir+das+an?
# <Response [200]>
# Hip-Hop/Rap
# 2
# nimo+karma
# <Response [200]>
# Hip-Hop/Rap
# 3
# the+cratez+skifahren+
# <Response [200]>
# Rap
# 4
# apache+207+200+km/h
# <Response [200]>
# Hip-Hop/Rap
# 5
# capital+bra+110
# <Response [200]>
# Hip-Hop/Rap
# 6
# apache+207+doch+in+der+nacht
# <Response [200]>
# Hip-Hop/Rap
# 7
# sido+2002
# <Response [200]>
# Hip-Hop/Rap
# 8
# rin+keine+liebe
# <Response [200]>
# Hip-Hop/Rap
# 9
# summer+cem+swish
# <Response [200]>
# Hip-Hop/Rap
# 10
# billie+eilish+everything+i+wanted
# <Response [200]>
# Alternative
# 11
# azet+seele
# <Response [200]>
# Hip-Hop/Rap
# 12
# regard+ride+it
# <Response [200]>
# Dance
# 13
# blackbear+hot+girl+bummer
# <Response [200]>
# Pop
# 14
# brado+kafa+leyla
# <Response [200]>
# Hip-Hop/Rap
# 15
# reezy+phantom
# <Response [200]>
# Hip-Hop/Rap
# 16
# raf+camora+unnormal
# <Response [200]>
# Hip-Hop/Rap
# 17
# apache+207+sex+mit+dir
# <Response [200]>
# Hip-Hop/Rap
# 18
# jamule+1000+hits
# <Response [200]>
# Music Documentaries
# 19
# selena+gomez+lose+you+to+love+me
# <Response [200]>
# Pop
# 20
# the+cratez+honda+civic
# <Response [200]>
# Rap
# 21
# travis+scott+highest+in+the+room
# <Response [200]>
# Hip-Hop/Rap
# 22
# apache+207+kein+problem
# <Response [200]>
# Hip-Hop/Rap
# 23
# raf+camora+puta+madre+-+bonustrack
# <Response [200]>
# Hip-Hop/Rap
# 24
# arizona+zervas+roxanne
# <Response [200]>
# Hip-Hop/Rap
# 25
# dua+lipa+dont+start+now
# <Response [200]>
# Pop
# 26
# maroon+5+memories
# <Response [200]>
# Pop
# 27
# post+malone+circles
# <Response [200]>
# House
# 28
# ufo361+schwarz+&+weiss
# <Response [200]>
# Hip-Hop/Rap
# 29
# capital+bra+tilidin
# <Response [200]>
# Hip-Hop/Rap
# 30
# summer+cem+summer+cem+
# <Response [200]>
# Hip-Hop
# 31
# jerome+light
# <Response [200]>
# Hip-Hop/Rap
# 32
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 33
# meduza+lose+control
# <Response [200]>
# Dance
# 34
# tyga+ayy+macarena
# <Response [200]>
# Hip-Hop/Rap
# 35
# juju+vermissen+
# <Response [200]>
# Hip-Hop/Rap
# 36
# kollegah+alphagenetik
# <Response [200]>
# Hip-Hop/Rap
# 37
# raf+camora+adriana
# <Response [200]>
# Hip-Hop/Rap
# 38
# loredana+eiskalt
# <Response [200]>
# Hip-Hop/Rap
# 39
# lena+better
# <Response [200]>
# Fiction
# 40
# black+eyed+peas+ritmo+
# <Response [200]>
# Pop
# 41
# apache+207+beef
# <Response [200]>
# Hip-Hop/Rap
# 42
# noah+ai+ai+ai
# <Response [200]>
# Kids & Family
# 43
# ed+sheeran+south+of+the+border+
# <Response [200]>
# Pop
# 44
# tim+bendzko+hoch
# <Response [200]>
# Pop
# 45
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 46
# lum!x+monster
# <Response [200]>
# Dance
# 47
# dermot+kennedy+outnumbered
# <Response [200]>
# Music Feature Films
# 48
# loredana+kein+plan
# <Response [200]>
# Hip-Hop/Rap
# 49
# eno+sauba
# <Response [200]>
# Hip-Hop/Rap
# 50
# apache+207+2+minuten
# <Response [200]>
# Hip-Hop/Rap
# 51
# loredana+genick
# <Response [200]>
# Hip-Hop/Rap
# 52
# samra+huracan
# <Response [200]>
# Hip-Hop/Rap
# 53
# riton+turn+me+on+
# <Response [200]>
# Dance
# 54
# jamule+moneyhoneydrip
# <Response [200]>
# Hip-Hop/Rap
# 55
# apache+207+keine+fragen
# <Response [200]>
# Hip-Hop/Rap
# 56
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 57
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 58
# summer+cem+primetime
# <Response [200]>
# Hip-Hop/Rap
# 59
# samra+wieder+lila
# <Response [200]>
# Hip-Hop/Rap
# 60
# apache+207+grey+goose
# <Response [200]>
# Hip-Hop/Rap
# 61
# ssio+testo+e
# <Response [200]>
# Hip-Hop/Rap
# 62
# freschta+akbarzada+meine+3+minuten+-+from+the+voice+of+germany
# <Response [200]>
# Pop
# 63
# shaed+trampoline+
# <Response [200]>
# Alternative
# 64
# apache+207+brot+nach+hause
# <Response [200]>
# Hip-Hop/Rap
# 65
# ufo361+ykke
# <Response [200]>
# Hip-Hop/Rap
# 66
# dardan+genauso
# <Response [200]>
# Rap
# 67
# trettmann+zeit+steht
# <Response [200]>
# Music Documentaries
# 68
# fero47+47
# <Response [200]>
# Pop
# 69
# rin+fabergé
# <Response [200]>
# Hip-Hop/Rap
# 70
# capital+bra+berlin+lebt+wie+nie+zuvor
# <Response [200]>
# Hip-Hop/Rap
# 71
# sam+feldt+post+malone+
# <Response [200]>
# Dance
# 72
# mark+forster+194+länder+-+single+
# <Response [200]>
# Pop
# 73
# the+chainsmokers+takeaway+
# <Response [200]>
# Dance
# 74
# summer+cem+diamonds+
# <Response [200]>
# Hip-Hop/Rap
# 75
# kummer+bei+dir
# <Response [200]>
# Hip-Hop/Rap
# 76
# tj_beastboy+1000x+cooler
# <Response [200]>
# Hip-Hop/Rap
# 77
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 78
# mariah+carey+all+i+want+for+christmas+is+you
# <Response [200]>
# Holiday
# 79
# ava+max+torn
# <Response [200]>
# Pop
# 80
# dj+snake+loco+contigo+
# <Response [200]>
# Latino
# 81
# bonez+mc+500+ps
# <Response [200]>
# Hip-Hop/Rap
# 82
# capo+run+run+run
# <Response [200]>
# Soundtrack
# 83
# bausa+mary
# <Response [200]>
# Hip-Hop/Rap
# 84
# vize+stars
# <Response [200]>
# Dance
# 85
# loredana+jetzt+rufst+du+an
# <Response [200]>
# Hip-Hop/Rap
# 86
# ghetto+phénomène+fratello
# <Response [200]>
# Hip-Hop/Rap
# 87
# sido+pyramiden
# <Response [200]>
# Hip-Hop/Rap
# 88
# dimitri+vegas+&+like+mike+instagram
# <Response [200]>
# Electronic
# 89
# trevor+daniel+falling
# <Response [200]>
# Pop
# 90
# camila+cabello+liar
# <Response [200]>
# Pop
# 91
# freya+ridings+castles
# <Response [200]>
# Singer/Songwriter
# 92
# ellie+goulding+hate+me+
# <Response [200]>
# Pop
# 93
# capo+im+rhythmus+gefangen
# <Response [200]>
# Hip-Hop/Rap
# 94
# veysel+normal
# <Response [200]>
# Hip-Hop/Rap
# 95
# olexesh+augen+husky
# <Response [200]>
# Hip-Hop/Rap
# 96
# wham!+last+christmas
# <Response [200]>
# Holiday
# 97
# apache+207+kleine+hure
# <Response [200]>
# Hip-Hop/Rap
# 98
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 99
# rin+up+in+smoke
# <Response [200]>
# Hip-Hop/Rap
# 100
# shirin+david+nur+mit+dir+
# <Response [200]>
# Pop
# 101
# capital+bra+nummer+1
# <Response [200]>
# Hip-Hop/Rap
# 102
# doja+cat+candy
# <Response [200]>
# R&B/Soul
# 103
# gringo+plus
# <Response [200]>
# Urbano latino
# 104
# finch+asozial+finchiboy
# <Response [200]>
# Hip-Hop/Rap
# 105
# kygo+higher+love
# <Response [200]>
# Pop
# 106
# dan+++shay+10,000+hours+
# <Response [200]>
# Country
# 107
# apache+207+famous
# <Response [200]>
# Hip-Hop/Rap
# 108
# y2k+lalala
# <Response [200]>
# Hip-Hop/Rap
# 109
# sam+smith+how+do+you+sleep?
# <Response [200]>
# Pop
# 110
# mika+paradies
# <Response [200]>
# Rap
# 111
# kontra+k+letzte+träne
# <Response [200]>
# Hip-Hop/Rap
# 112
# marshmello+tongue+tied+
# <Response [200]>
# Alternative
# 113
# fero47+schau+mich+an
# <Response [200]>
# Rap
# 114
# r3hab+all+around+the+world+
# <Response [200]>
# Dance
# 115
# seeed+g€ld
# <Response [200]>
# Pop
# 116
# mozzik+delpher+dinake
# <Response [200]>
# Hip-Hop/Rap
# 117
# juju+hi+babe
# <Response [200]>
# Hip-Hop/Rap
# 118
# sido+leben+vor+dem+tod
# <Response [200]>
# Hip-Hop/Rap
# 119
# mark+forster+194+länder
# <Response [200]>
# Pop
# 120
# selena+gomez+look+at+her+now
# <Response [200]>
# Pop
# 121
# summer+cem+yallah+goodbye+
# <Response [200]>
# Hip-Hop/Rap
# 122
# juice+wrld+bandit+
# <Response [200]>
# Hip-Hop/Rap
# 123
# harry+styles+lights+up
# <Response [200]>
# Pop
# 124
# post+malone+goodbyes+
# <Response [200]>
# Hip-Hop/Rap
# 125
# onerepublic+rescue+me
# <Response [200]>
# Pop
# 126
# kalim+lowrider
# <Response [200]>
# Hip-Hop/Rap
# 127
# raf+camora+verändert
# <Response [200]>
# Hip-Hop/Rap
# 128
# lea+110+
# <Response [200]>
# Pop
# 129
# lil+nas+x+old+town+road+-+remix
# <Response [200]>
# Country
# 130
# pashanim+shababs+botten
# <Response [200]>
# Hip-Hop/Rap
# 131
# lauv+mean+it
# <Response [200]>
# Pop
# 132
# raf+camora+vendetta
# <Response [200]>
# Hip-Hop/Rap
# 133
# undacava+jayjo
# <Response [200]>
# Hip-Hop/Rap
# 134
# kanye+west+follow+god
# <Response [200]>
# Hip-Hop/Rap
# 135
# luciano+fendi+drip
# <Response [200]>
# Hip-Hop/Rap
# 136
# dardan+coco+mama
# <Response [200]>
# Hip-Hop
# 137
# summer+cem+rollerblades+
# <Response [200]>
# Hip-Hop/Rap
# 138
# capital+bra+prinzessa
# <Response [200]>
# Hip-Hop/Rap
# 139
# ssio+hash+hash
# <Response [200]>
# Hip-Hop/Rap
# 140
# timmy+trumpet+world+at+our+feet
# <Response [200]>
# Dance
# 141
# capital+bra+purple+rain
# <Response [200]>
# Hip-Hop/Rap
# 142
# kitschkrieg+standard+
# <Response [200]>
# Hip-Hop/Rap
# 143
# kontra+k+blei+
# <Response [200]>
# Hip-Hop/Rap
# 144
# samra+zombie
# <Response [200]>
# Hip-Hop/Rap
# 145
# rin+dior+2001
# <Response [200]>
# halsey+graveyard
# <Response [200]>
# Alternative
# 147
# ava+max+sweet+but+psycho
# <Response [200]>
# Pop
# 148
# kc+rebell+dna
# <Response [200]>
# Hip-Hop/Rap
# 149
# sdp+viva+la+dealer
# <Response [200]>
# Pop
# 150
# lizzo+good+as+hell+
# <Response [200]>
# Pop
# 151
# major+lazer+trigger
# <Response [200]>
# R&B/Soul
# 152
# sido+tausend+tattoos
# <Response [200]>
# Hip-Hop/Rap
# 153
# apache+207+ferrari+testarossa
# <Response [200]>
# Hip-Hop/Rap
# 154
# young+thug+hot+
# <Response [200]>
# Hip-Hop/Rap
# 155
# lewis+capaldi+bruises
# <Response [200]>
# Alternative
# 156
# taylor+swift+lover+
# <Response [200]>
# Country
# 157
# dynoro+in+my+mind
# <Response [200]>
# Dance
# 158
# shindy+nautilus
# <Response [200]>
# Rap
# 159
# olexesh+barrio
# <Response [200]>
# Hip-Hop/Rap
# 160
# billie+eilish+lovely+
# <Response [200]>
# Pop
# 161
# yung+hurn+ponny
# <Response [200]>
# Hip-Hop/Rap
# 162
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 163
# ufo361+nummer
# <Response [200]>
# Hip-Hop/Rap
# 164
# mc+bilal+bye+bye
# <Response [200]>
# Rap
# 165
# luciano+la+haine
# <Response [200]>
# Hip-Hop/Rap
# 166
# mabel+mad+love
# <Response [200]>
# Pop
# 167
# capital+bra+lieber+gott
# <Response [200]>
# Hip-Hop/Rap
# 168
# raf+camora+sag+ihnen+2
# <Response [200]>
# Hip-Hop/Rap
# 169
# younotus+narcotic
# <Response [200]>
# Dance
# 170
# sarah+connor+vincent
# <Response [200]>
# Drama
# 171
# apache+207+nicht+wie+du
# <Response [200]>
# Hip-Hop/Rap
# 172
# farid+bang+stier
# <Response [200]>
# Hip-Hop/Rap
# 173
# ariana+grande+santa+tell+me
# <Response [200]>
# Holiday
# 174
# bushido+lichter+der+stadt
# <Response [200]>
# Hip-Hop/Rap
# 175
# ufo361+shot
# <Response [200]>
# Hip-Hop/Rap
# 176
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 177
# capital+bra+cherry+lady
# <Response [200]>
# Hip-Hop/Rap
# 178
# 5+seconds+of+summer+teeth
# <Response [200]>
# Pop
# 179
# bausa+was+du+liebe+nennst
# <Response [200]>
# Hip-Hop/Rap
# 180
# max+giesinger+auf+das,+was+da+noch+kommt
# <Response [200]>
# Pop
# 181
# capo+lambo+diablo+gt+
# <Response [200]>
# Hip-Hop
# 182
# belah+eine+nacht
# <Response [200]>
# Hip-Hop/Rap
# 183
# ufo361+wir+sind+kral
# <Response [200]>
# Hip-Hop/Rap
# 184
# lea+immer+wenn+wir+uns+sehn+
# <Response [200]>
# Pop
# 185
# ali+gatie+its+you
# <Response [200]>
# R&B/Soul
# 186
# finch+asozial+abfahrt
# <Response [200]>
# Hip-Hop/Rap
# 187
# kc+rebell+neptun
# <Response [200]>
# Hip-Hop/Rap
# 188
# saint+jhn+roses+-+imanbek+remix
# <Response [200]>
# Dance
# 189
# rammstein+deutschland
# <Response [200]>
# Metal
# 190
# ufo361+04:30
# <Response [200]>
# Hip-Hop/Rap
# 191
# shirin+david+gib+ihm
# <Response [200]>
# Hip-Hop/Rap
# 192
# jonas+brothers+only+human
# <Response [200]>
# Pop
# 193
# ali471+hadi+gel+gezelim
# <Response [200]>
# Hip-Hop/Rap
# 194
# kool+savas+deine+mutter
# <Response [200]>
# Hip-Hop/Rap
# 195
# r3hab+flames+
# <Response [200]>
# Pop
# 196
# rin+vintage
# <Response [200]>
# Rock
# 197
# kontra+k+warnung
# <Response [200]>
# Hip-Hop/Rap
# 198
# alec+benjamin+let+me+down+slowly
# <Response [200]>
# Pop
# 199
# de_2019-11-22--2019-11-29.csv
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-42dcd0ca7dcf> in <module>
#      17     spotify = spotipy.Spotify(auth=token)
#      18     features = spotify.audio_features(str(df['ID'].iloc[0]))
# ---> 19     prova = extract_features(df, n_tracks=200)
#      20     output = df.join(prova.set_index('id'), on='ID')
#      21     output['genre']= "none"
#
# <ipython-input-3-e6752ace0964> in extract_features(df, n_tracks)
#       4                                      'duration_ms'])
#       5     for i in range(n_tracks):
# ----> 6         features = spotify.audio_features(str(df['ID'].iloc[i]))
#       7         dataframe.loc[i] = [ features[0]['id'],
#       8         features[0]['danceability'],
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\spotipy\client.py in audio_features(self, tracks)
#    1244         if isinstance(tracks, str):
#    1245             trackid = self._get_id("track", tracks)
# -> 1246             results = self._get("audio-features/?ids=" + trackid)
#    1247         else:
#    1248             tlist = [self._get_id("track", t) for t in tracks]
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     208             kwargs.update(args)
#     209
# --> 210         return self._internal_call("GET", url, payload, kwargs)
#     211
#     212     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     170             response = self._session.request(
#     171                 method, url, headers=headers, proxies=self.proxies,
# --> 172                 timeout=self.requests_timeout, **args
#     173             )
#     174
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     414             raise InvalidURL(e, request=request)
#     415
# --> 416         self.cert_verify(conn, request.url, verify, cert)
#     417         url = self.request_url(request, proxies)
#     418         self.add_headers(request, stream=stream, timeout=timeout, verify=verify, cert=cert, proxies=proxies)
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\adapters.py in cert_verify(self, conn, url, verify, cert)
#     226             if not cert_loc or not os.path.exists(cert_loc):
#     227                 raise IOError("Could not find a suitable TLS CA certificate bundle, "
# --> 228                               "invalid path: {}".format(cert_loc))
#     229
#     230             conn.cert_reqs = 'CERT_REQUIRED'
#
# OSError: Could not find a suitable TLS CA certificate bundle, invalid path: C:\Users\Mattia\anaconda3\envs\TrapGenerator\lib\site-packages\certifi\cacert.pem

# %%
#Testing on spotify release date.

credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)
features = spotify.audio_features(str(df['ID'].iloc[0]))
result = spotify.track('5CtI0qwDJkDQGwXD1H1cLb')
print(result)
