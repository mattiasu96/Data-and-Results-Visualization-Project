# %%
import pandas as pd
import spotipy
#from fycharts.SpotifyCharts import SpotifyCharts
from spotipy.oauth2 import SpotifyClientCredentials

# %%
df = pd.read_csv('global_2017-07-14--2017-07-21.csv')

# %%
df
# Out:
#     Unnamed: 0                                     Unnamed: 1      Unnamed: 2  \
# 0     Position                                     Track Name          Artist
# 1            1                              Despacito - Remix      Luis Fonsi
# 2            2  Wild Thoughts (feat. Rihanna & Bryson Tiller)       DJ Khaled
# 3            3                                  Unforgettable  French Montana
# 4            4                                            NaN             NaN
# ..         ...                                            ...             ...
# 196        196                              Perfect Strangers      Jonas Blue
# 197        197                  Lean On (feat. MØ & DJ Snake)     Major Lazer
# 198        198                        Wonderwall - Remastered           Oasis
# 199        199                                        Go Flex     Post Malone
# 200        200                                 September Song       JP Cooper
#
#     Note that these figures are generated using a formula that protects against any artificial inflation of chart positions.  \
# 0                                              Streams
# 1                                             37572118
# 2                                             29984654
# 3                                             25692670
# 4                                             25442248
# ..                                                 ...
# 196                                            3018660
# 197                                            3018465
# 198                                            3012734
# 199                                            3009022
# 200                                            2988624
#
#                                             Unnamed: 4
# 0                                                  URL
# 1    https://open.spotify.com/track/5CtI0qwDJkDQGwX...
# 2    https://open.spotify.com/track/1OAh8uOEOvTDqkK...
# 3    https://open.spotify.com/track/3B54sVLJ402zGa6...
# 4    https://open.spotify.com/track/3RXkboS74UYzN14...
# ..                                                 ...
# 196  https://open.spotify.com/track/5bZtRlMBU76vHuD...
# 197  https://open.spotify.com/track/4WjH9Bzt3kx7z8k...
# 198  https://open.spotify.com/track/5qqabIl2vWzo9Ap...
# 199  https://open.spotify.com/track/5yuShbu70mtHXY0...
# 200  https://open.spotify.com/track/0FuTx2s3YH1ppmt...
#
# [201 rows x 5 columns]

# %%
df.columns = df.iloc[0]

# %%
df = df.iloc[1:].reset_index()

# %%
df.URL.astype('str')
# Out:
# 0      https://open.spotify.com/track/5CtI0qwDJkDQGwX...
# 1      https://open.spotify.com/track/1OAh8uOEOvTDqkK...
# 2      https://open.spotify.com/track/3B54sVLJ402zGa6...
# 3      https://open.spotify.com/track/3RXkboS74UYzN14...
# 4      https://open.spotify.com/track/3DXncPQOG4VBw3Q...
#                              ...
# 195    https://open.spotify.com/track/5bZtRlMBU76vHuD...
# 196    https://open.spotify.com/track/4WjH9Bzt3kx7z8k...
# 197    https://open.spotify.com/track/5qqabIl2vWzo9Ap...
# 198    https://open.spotify.com/track/5yuShbu70mtHXY0...
# 199    https://open.spotify.com/track/0FuTx2s3YH1ppmt...
# Name: URL, Length: 200, dtype: object

# %%
df.URL = df.URL.apply(lambda x : x[31:])

# %%
df.rename(columns={'URL':'ID'}, inplace=True)

# %%
df
# Out:
# 0    index Position                                         Track Name  \
# 0        1        1                                  Despacito - Remix
# 1        2        2      Wild Thoughts (feat. Rihanna & Bryson Tiller)
# 2        3        3                                      Unforgettable
# 3        4        4                                                NaN
# 4        5        5  I'm the One (feat. Justin Bieber, Quavo, Chanc...
# ..     ...      ...                                                ...
# 195    196      196                                  Perfect Strangers
# 196    197      197                      Lean On (feat. MØ & DJ Snake)
# 197    198      198                            Wonderwall - Remastered
# 198    199      199                                            Go Flex
# 199    200      200                                     September Song
#
# 0            Artist   Streams                      ID
# 0        Luis Fonsi  37572118  5CtI0qwDJkDQGwXD1H1cLb
# 1         DJ Khaled  29984654  1OAh8uOEOvTDqkKFsKksCi
# 2    French Montana  25692670  3B54sVLJ402zGa6Xm4YGNe
# 3               NaN  25442248  3RXkboS74UYzN14xTqzPyY
# 4         DJ Khaled  25431396  3DXncPQOG4VBw3QHh3S817
# ..              ...       ...                     ...
# 195      Jonas Blue   3018660  5bZtRlMBU76vHuDOb1GM5u
# 196     Major Lazer   3018465  4WjH9Bzt3kx7z8kl0awxh4
# 197           Oasis   3012734  5qqabIl2vWzo9ApSC317sa
# 198     Post Malone   3009022  5yuShbu70mtHXY0yLzCQLQ
# 199       JP Cooper   2988624  0FuTx2s3YH1ppmtiM6l0zI
#
# [200 rows x 6 columns]

# %%
credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
token = credentials.get_access_token()

spotify = spotipy.Spotify(auth=token)

features = spotify.audio_features(str(df['ID'].iloc[0]))
# Out:
# C:\Users\Mattia\anaconda3\envs\TrapGenerator\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.

# %%
features
# Out:
# [{'danceability': 0.694,
#   'energy': 0.815,
#   'key': 2,
#   'loudness': -4.328,
#   'mode': 1,
#   'speechiness': 0.12,
#   'acousticness': 0.229,
#   'instrumentalness': 0,
#   'liveness': 0.0924,
#   'valence': 0.813,
#   'tempo': 88.931,
#   'type': 'audio_features',
#   'id': '5CtI0qwDJkDQGwXD1H1cLb',
#   'uri': 'spotify:track:5CtI0qwDJkDQGwXD1H1cLb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5CtI0qwDJkDQGwXD1H1cLb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CtI0qwDJkDQGwXD1H1cLb',
#   'duration_ms': 228827,
#   'time_signature': 4}]

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        print(features[0]['danceability'])
        dataframe.append({'danceability' : features[0]['danceability'],
        'energy': features[0]['energy'],
        'key' : features[0]['key'],
        'loudness' : features[0]['loudness'],
        'mode' : features[0]['mode'],
        'speechiness' : features[0]['speechiness'],
        'acousticness' : features[0]['acousticness'],
        'instrumentalness' : features[0]['instrumentalness'],
        'liveness' : features[0]['liveness'],
        'valence' : features[0]['valence'],
        'tempo' : features[0]['tempo'],
        'time_signature' : features[0]['time_signature'],
        'duration_ms' : features[0]['duration_ms']}, ignore_index=True)
    return dataframe

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        dataframe.loc[i] = [ features[0]['id'],
        features[0]['danceability'],
        features[0]['energy'],
        features[0]['key'],
        features[0]['loudness'],
        features[0]['mode'],
        features[0]['speechiness'],
        features[0]['acousticness'],
        features[0]['instrumentalness'],
        features[0]['liveness'],
        features[0]['valence'],
        features[0]['tempo'],
        features[0]['time_signature'],
        features[0]['duration_ms']]
    return dataframe

# %%
prova = extract_features(df, n_tracks=200)

# %%
prova
# Out:
#                          id  danceability  energy key  loudness mode  \
# 0    5CtI0qwDJkDQGwXD1H1cLb         0.694   0.815   2    -4.328    1
# 1    1OAh8uOEOvTDqkKFsKksCi         0.671   0.672   0    -3.094    0
# 2    3B54sVLJ402zGa6Xm4YGNe         0.726   0.769   6    -5.043    1
# 3    3RXkboS74UYzN14xTqzPyY         0.543   0.661   8    -5.855    0
# 4    3DXncPQOG4VBw3QHh3S817         0.609   0.668   7    -4.284    1
# ..                      ...           ...     ...  ..       ...  ...
# 195  5bZtRlMBU76vHuDOb1GM5u         0.739   0.833   1    -5.012    1
# 196  4WjH9Bzt3kx7z8kl0awxh4         0.723   0.809   7    -3.081    0
# 197  5qqabIl2vWzo9ApSC317sa         0.378   0.896   2    -4.066    1
# 198  5yuShbu70mtHXY0yLzCQLQ         0.665   0.498   5    -8.185    1
# 199  0FuTx2s3YH1ppmtiM6l0zI         0.623   0.654   0    -5.675    0
#
#      speechiness  acousticness instrumentalness  liveness  valence    tempo  \
# 0         0.1200      0.229000                0    0.0924    0.813   88.931
# 1         0.0688      0.032900                0    0.1180    0.632   97.979
# 2         0.1230      0.029300           0.0101    0.1040    0.733   97.985
# 3         0.0538      0.214000                0    0.2410    0.556  144.967
# 4         0.0367      0.055200                0    0.1670    0.811   80.924
# ..           ...           ...              ...       ...      ...      ...
# 195       0.0463      0.350000                0    0.2660    0.699  117.990
# 196       0.0625      0.003460          0.00123    0.5650    0.274   98.007
# 197       0.0407      0.000452                0    0.1940    0.469  174.302
# 198       0.0832      0.228000                0    0.0757    0.127   81.967
# 199       0.0372      0.054500                0    0.0838    0.401   95.921
#
#     time_signature duration_ms
# 0                4      228827
# 1                4      204173
# 2                4      233902
# 3                4      194978
# 4                4      288600
# ..             ...         ...
# 195              4      195313
# 196              4      176561
# 197              4      258773
# 198              4      179613
# 199              4      220291
#
# [200 rows x 14 columns]

# %%
output = df.join(prova.set_index('id'), on='ID')

# %%
output.to_csv('global_08-2017.csv')

# %%
output

test=output.iloc[9]
print(test)
print(type(test['Track Name']))
if type(test['Track Name']) != float and type(test['Artist']) != float:
    print('no empty')
else: 
    print('empty')
# Out:
# index                                   10
# Position                                10
# Track Name                             NaN
# Artist                                 NaN
# Streams                           20049646
# ID                  4JAyIDXOqNM6qHuZML01uX
# danceability                         0.699
# energy                               0.614
# key                                      2
# loudness                             -4.57
# mode                                     1
# speechiness                         0.0521
# acousticness                        0.0152
# instrumentalness                  5.22e-06
# liveness                            0.0734
# valence                              0.275
# tempo                               122.99
# time_signature                           4
# duration_ms                         186175
# Name: 9, dtype: object
# <class 'float'>
# empty

# %% [markdown]
# ## Testing iTunes API for genre labeling
# Simple test of quering on iTunes API

# %%
import requests
import json
entry = 'starboy+the+weeknd'
a = 'https://itunes.apple.com/search?term='+entry+'.&limit=1'
b = requests.get(a).json()
print(b['results'][0]['primaryGenreName'])
print(json.dumps(b, indent=2))
# Out:
# R&B/Soul
# {
#   "resultCount": 1,
#   "results": [
#     {
#       "wrapperType": "track",
#       "kind": "song",
#       "artistId": 479756766,
#       "collectionId": 1440871397,
#       "trackId": 1440871420,
#       "artistName": "The Weeknd",
#       "collectionName": "Starboy",
#       "trackName": "Starboy (feat. Daft Punk)",
#       "collectionCensoredName": "Starboy",
#       "trackCensoredName": "Starboy (feat. Daft Punk)",
#       "artistViewUrl": "https://music.apple.com/us/artist/the-weeknd/479756766?uo=4",
#       "collectionViewUrl": "https://music.apple.com/us/album/starboy-feat-daft-punk/1440871397?i=1440871420&uo=4",
#       "trackViewUrl": "https://music.apple.com/us/album/starboy-feat-daft-punk/1440871397?i=1440871420&uo=4",
#       "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/14/64/52/146452b1-d912-e0d4-d016-542de4bd8036/mzaf_4996492471208465628.plus.aac.p.m4a",
#       "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music113/v4/9c/a2/d5/9ca2d550-4513-d5ae-b56b-571edca70cbd/source/30x30bb.jpg",
#       "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music113/v4/9c/a2/d5/9ca2d550-4513-d5ae-b56b-571edca70cbd/source/60x60bb.jpg",
#       "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music113/v4/9c/a2/d5/9ca2d550-4513-d5ae-b56b-571edca70cbd/source/100x100bb.jpg",
#       "collectionPrice": 13.99,
#       "trackPrice": 1.29,
#       "releaseDate": "2016-09-21T12:00:00Z",
#       "collectionExplicitness": "explicit",
#       "trackExplicitness": "explicit",
#       "discCount": 1,
#       "discNumber": 1,
#       "trackCount": 18,
#       "trackNumber": 1,
#       "trackTimeMillis": 230461,
#       "country": "USA",
#       "currency": "USD",
#       "primaryGenreName": "R&B/Soul",
#       "contentAdvisoryRating": "Explicit",
#       "isStreamable": true
#     }
#   ]
# }

# %% [markdown]
# # Automatizing the feature extraction process

# %%
import pandas as pd
import spotipy
#from fycharts.SpotifyCharts import SpotifyCharts
from spotipy.oauth2 import SpotifyClientCredentials
import os
import requests
import json
import time

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        print(features[0]['danceability'])
        dataframe.append({'danceability' : features[0]['danceability'],
        'energy': features[0]['energy'],
        'key' : features[0]['key'],
        'loudness' : features[0]['loudness'],
        'mode' : features[0]['mode'],
        'speechiness' : features[0]['speechiness'],
        'acousticness' : features[0]['acousticness'],
        'instrumentalness' : features[0]['instrumentalness'],
        'liveness' : features[0]['liveness'],
        'valence' : features[0]['valence'],
        'tempo' : features[0]['tempo'],
        'time_signature' : features[0]['time_signature'],
        'duration_ms' : features[0]['duration_ms']}, ignore_index=True)
    return dataframe

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        dataframe.loc[i] = [ features[0]['id'],
        features[0]['danceability'],
        features[0]['energy'],
        features[0]['key'],
        features[0]['loudness'],
        features[0]['mode'],
        features[0]['speechiness'],
        features[0]['acousticness'],
        features[0]['instrumentalness'],
        features[0]['liveness'],
        features[0]['valence'],
        features[0]['tempo'],
        features[0]['time_signature'],
        features[0]['duration_ms']]
    return dataframe

# %%
#checking data integrity. Checks for missing fields in Artist name. Return the rows with missing values + the file name. 
#These data are missing because of copyright issues. They changed the author of the song/removed the song. 
import numpy as np

from IPython.display import display, HTML

path = os.getcwd()
file_folder = os.path.join(path,'es')

for csv_file in os.listdir(file_folder):
    file = os.path.join(file_folder,csv_file)
    #print(csv_file)
    df = pd.read_csv(file)
    #display(df)
    df.columns = df.iloc[0]
    df = df.iloc[1:].reset_index()
    df.URL.astype('str')
    df.URL = df.URL.apply(lambda x : x[31:])
    df.rename(columns={'URL':'ID'}, inplace=True)
    
    res = df.loc[df['Artist'].isnull(), 'index'].tolist()
    if len(res) != 0:
        print(res)
        print(csv_file)
# Out:
# [16, 44, 60, 100]
# es_2017-07-14--2017-07-21.csv
# [3]
# es_2017-11-03--2017-11-10.csv
# [58]
# es_2019-06-07--2019-06-14.csv
# [26]
# es_2019-06-14--2019-06-21.csv
# [20]
# es_2019-06-21--2019-06-28.csv

# %%
path = os.getcwd()
file_folder = os.path.join(path,'es 2')
save_folder_path = os.path.join(path, "es_features")
#os.mkdir(save_folder_path)

for csv_file in os.listdir(file_folder): 
    print(csv_file)
    file = os.path.join(file_folder,csv_file)
    df = pd.read_csv(file)
    df.columns = df.iloc[0]
    df = df.iloc[1:].reset_index()
    df.URL.astype('str')
    df.URL = df.URL.apply(lambda x : x[31:])
    df.rename(columns={'URL':'ID'}, inplace=True)
    credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
    token = credentials.get_access_token()
    spotify = spotipy.Spotify(auth=token)
    features = spotify.audio_features(str(df['ID'].iloc[0]))
    prova = extract_features(df, n_tracks=200)
    output = df.join(prova.set_index('id'), on='ID')
    output['genre']= "none"
    for index, row in output.iterrows():
        artist = row["Artist"]
        song = row["Track Name"]
        if type(artist) != float and type(song) != float:
            song = song.split('(')[0]
            query_entry = str(artist)+" "+str(song)
            query_entry = query_entry.replace("with", "")
            query_entry= query_entry.replace('Remastered', "")
            query_entry= query_entry.replace('Version', "")

            query_entry = query_entry.replace("'", "")
            query_entry = query_entry.replace('"', "")

            query_entry=query_entry.replace(" ", "+")

            #query_entry = query_entry[0:60]
            query_entry = query_entry.lower()
            print(query_entry)
            a = 'https://itunes.apple.com/search?term='+query_entry+'&limit=1'
            test = requests.get(a)
            print(test)
            b = test.json()
            if b['resultCount'] == 1:

                print(b['results'][0]['primaryGenreName'])
                #assign genre to song
                print(index)
                output.iloc[index, output.columns.get_loc('genre')]= b['results'][0]['primaryGenreName']
            time.sleep(1)
            #print(json.dumps(b, indent=2))
    output.to_csv(os.path.join(save_folder_path,csv_file))
# Out:
# es_2019-08-09--2019-08-16.csv
# C:\Users\Mattia\anaconda3\envs\TrapGenerator\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   app.launch_new_instance()
# anuel+aa+china
# <Response [200]>
# Urbano latino
# 0
# sech+otro+trago+-+remix
# <Response [200]>
# Latino
# 1
# bad+bunny+callaita
# <Response [200]>
# Urbano latino
# 2
# lola+indigo+lola+bunny
# <Response [200]>
# Pop Latino
# 3
# jhay+cortez+no+me+conoce+-+remix
# <Response [200]>
# Urbano latino
# 4
# j+balvin+la+canción
# <Response [200]>
# Urbano latino
# 5
# lunay+soltera+-+remix
# <Response [200]>
# Urbano latino
# 6
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 7
# rvfv+mirándote
# <Response [200]>
# Latin Rap
# 8
# j+balvin+que+pretendes
# <Response [200]>
# Urbano latino
# 9
# la+nueva+escuela+la+rubia+-+remix+2
# <Response [200]>
# Urbano latino
# 10
# dayvi+baila+conmigo+
# <Response [200]>
# Pop Latino
# 11
# dj+snake+loco+contigo+
# <Response [200]>
# Latino
# 12
# chris+viz+diavla
# <Response [200]>
# Urbano latino
# 13
# don+patricio+contando+lunares+
# <Response [200]>
# Urbano latino
# 14
# darell+velitas
# <Response [200]>
# Urbano latino
# 15
# maluma+11+pm
# <Response [200]>
# Urbano latino
# 16
# maffio+cristina+
# <Response [200]>
# Urbano latino
# 17
# rosalía+con+altura
# <Response [200]>
# Pop
# 18
# myke+towers+si+se+da+-+remix
# <Response [200]>
# Urbano latino
# 19
# dj+luian+verte+ir
# <Response [200]>
# Urbano latino
# 20
# myke+towers+inocente
# <Response [200]>
# Música tropical
# 21
# rosalía+milionària
# <Response [200]>
# Pop
# 22
# becky+g+dollar
# <Response [200]>
# Pop Latino
# 23
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 24
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 25
# bryant+myers+gan-ga
# <Response [200]>
# Urbano latino
# 26
# ozuna+te+soñé+de+nuevo
# <Response [200]>
# Urbano latino
# 27
# guaynaa+rebota+-+remix
# <Response [200]>
# Urbano latino
# 28
# david+bisbal+bésame
# <Response [200]>
# Pop
# 29
# maître+gims+hola+señorita
# <Response [200]>
# Urbano latino
# 30
# dalex+cuaderno
# <Response [200]>
# Urbano latino
# 31
# sergio+contreras+cicatrices+
# <Response [200]>
# Pop
# 32
# mahmood+soldi+
# <Response [200]>
# Pop
# 33
# duki+goteo
# <Response [200]>
# Hip-Hop/Rap
# 34
# bad+gyal+santa+maría+
# <Response [200]>
# Pop Latino
# 35
# sean+paul+contra+la+pared
# <Response [200]>
# Urbano latino
# 36
# dalex+pa+mí+-+remix
# <Response [200]>
# Urbano latino
# 37
# aitana+me+quedo
# <Response [200]>
# Pop
# 38
# ceky+viciny+ellos
# <Response [200]>
# Dance
# 39
# nicky+jam+te+robaré
# <Response [200]>
# Urbano latino
# 40
# paulo+londra+tal+vez
# <Response [200]>
# Latino
# 41
# juanfran+mi+morena
# <Response [200]>
# Urbano latino
# 42
# rels+b+¿cómo+te+va,+querida?
# <Response [200]>
# Pop
# 43
# casper+magico+no+te+veo+-+remix
# <Response [200]>
# Urbano latino
# 44
# sebastian+yatra+runaway
# <Response [200]>
# Pop Latino
# 45
# sinsinati+indios+y+vaqueros
# <Response [200]>
# Pop
# 46
# don+patricio+enchochado+de+ti
# <Response [200]>
# Urbano latino
# 47
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 48
# danny+ocean+swing
# <Response [200]>
# Pop Latino
# 49
# danny+romero+de+tranquilote
# <Response [200]>
# Latino
# 50
# maluma+hp
# <Response [200]>
# Urbano latino
# 51
# sech+otro+trago
# <Response [200]>
# Latino
# 52
# j+balvin+mojaita
# <Response [200]>
# Urbano latino
# 53
# myke+towers+la+playa
# <Response [200]>
# Urbano latino
# 54
# lalo+ebratt+déjate+querer
# <Response [200]>
# Urbano latino
# 55
# farruko+delincuente
# <Response [200]>
# Urbano latino
# 56
# morat+presiento
# <Response [200]>
# Pop
# 57
# myke+towers+si+se+da
# <Response [200]>
# Urbano latino
# 58
# $kyhook+a+escondidas
# <Response [200]>
# Pop
# 59
# bad+gyal+hookah
# <Response [200]>
# Pop Latino
# 60
# justin+quiles+que+mas+pues+-+remix
# <Response [200]>
# Urbano latino
# 61
# luis+fonsi+date+la+vuelta
# <Response [200]>
# Pop Latino
# 62
# nicky+jam+atrévete
# <Response [200]>
# Urbano latino
# 63
# nil+moliner+soldadito+de+hierro
# <Response [200]>
# Pop
# 64
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 65
# mambo+kingz+tú+no+amas
# <Response [200]>
# Urbano latino
# 66
# daddy+yankee+si+supieras
# <Response [200]>
# Urbano latino
# 67
# residente+bellacoso
# <Response [200]>
# Urbano latino
# 68
# ozuna+cambio
# <Response [200]>
# Urbano latino
# 69
# dvicio+5+sentidos
# <Response [200]>
# Pop
# 70
# sech+boomerang
# <Response [200]>
# Urbano latino
# 71
# anuel+aa+amanece
# <Response [200]>
# Urbano latino
# 72
# ozuna+baila+baila+baila+-+remix
# <Response [200]>
# Urbano latino
# 73
# ozuna+baila+baila+baila
# <Response [200]>
# Urbano latino
# 74
# becky+g+la+respuesta
# <Response [200]>
# Urbano latino
# 75
# mau+y+ricky+la+boca+-+remix
# <Response [200]>
# Pop Latino
# 76
# manuel+carrasco+qué+bonito+es+querer
# <Response [200]>
# Pop
# 77
# paulo+londra+adan+y+eva
# <Response [200]>
# Urbano latino
# 78
# prince+royce+cúrame+
# <Response [200]>
# Urbano latino
# 79
# wos+canguro
# <Response [200]>
# Hip-Hop/Rap
# 80
# eladio+carrion+kemba+walker
# <Response [200]>
# Urbano latino
# 81
# reik+aleluya
# <Response [200]>
# Pop Latino
# 82
# karol+g+ocean
# <Response [200]>
# Urbano latino
# 83
# cupido+autoestima+
# <Response [200]>
# Pop Latino
# 84
# beret+me+llama
# <Response [200]>
# Pop
# 85
# lola+indigo+maldición
# <Response [200]>
# Pop
# 86
# lil+nas+x+old+town+road+-+remix
# <Response [200]>
# Country
# 87
# aitana+nada+sale+mal
# <Response [200]>
# Pop
# 88
# sebastian+yatra+un+año
# <Response [200]>
# Pop Latino
# 89
# alejandro+sanz+mi+persona+favorita
# <Response [200]>
# Pop Latino
# 90
# anuel+aa+secreto
# <Response [200]>
# Urbano latino
# 91
# miki+núñez+celébrate
# <Response [200]>
# Pop
# 92
# anuel+aa+ella+quiere+beber+-+remix
# <Response [200]>
# Urbano latino
# 93
# ozuna+amor+genuino
# <Response [200]>
# Urbano latino
# 94
# rosalía+aute+cuture
# <Response [200]>
# Pop
# 95
# natalia+lacunza+nana+triste
# <Response [200]>
# Pop
# 96
# karol+g+punto+g
# <Response [200]>
# Urbano latino
# 97
# dimitri+vegas+&+like+mike+instagram
# <Response [200]>
# Electronic
# 98
# piso+21+una+vida+para+recordar
# <Response [200]>
# Pop Latino
# 99
# rauw+alejandro+el+efecto
# <Response [200]>
# Urbano latino
# 100
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 101
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 102
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 103
# reykon+latina+
# <Response [200]>
# Latino
# 104
# wisin+&+yandel+aullando
# <Response [200]>
# Urbano latino
# 105
# ozuna+muito+calor
# <Response [200]>
# Urbano latino
# 106
# aitana+con+la+miel+en+los+labios
# <Response [200]>
# Pop
# 107
# bizarrap+trueno:+bzrp+freestyle+sessions,+vol.+6
# <Response [200]>
# Latin Rap
# 108
# juan+magán+sobrenatural
# <Response [200]>
# Pop
# 109
# lil+tecca+ransom
# <Response [200]>
# Hip-Hop/Rap
# 110
# kidd+keo+serpiente+veneno+
# <Response [200]>
# Urbano latino
# 111
# yandel+en+cero
# <Response [200]>
# Urbano latino
# 112
# rosalía+malamente+-+cap.1:+augurio
# <Response [200]>
# Pop
# 113
# camilo+tutu
# <Response [200]>
# Urbano latino
# 114
# beret+te+echo+de+menos
# <Response [200]>
# Pop
# 115
# paulo+londra+por+eso+vine
# <Response [200]>
# Urbano latino
# 116
# aitana+vas+a+quedarte
# <Response [200]>
# Pop
# 117
# lola+indigo+mujer+bruja
# <Response [200]>
# Pop
# 118
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 119
# morat+cuando+nadie+ve
# <Response [200]>
# Pop
# 120
# nio+garcia+mírame+-+remix
# <Response [200]>
# Urbano latino
# 121
# demarco+flamenco+pa+ti+pa+mí+na+má
# <Response [200]>
# Iberia
# 122
# becky+g+sin+pijama
# <Response [200]>
# Urbano latino
# 123
# melendi+déjala+que+baile+
# <Response [200]>
# Pop Latino
# 124
# fito+y+fitipaldis+soldadito+marinero
# <Response [200]>
# Rock y Alternativo
# 125
# estopa+fuego
# <Response [200]>
# Pop
# 126
# leiva+no+te+preocupes+por+mi
# <Response [200]>
# Pop
# 127
# dvicio+qué+tienes+tú+
# <Response [200]>
# Pop
# 128
# ozuna+vaina+loca
# <Response [200]>
# Urbano latino
# 129
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 130
# dani+fernández+te+esperaré+toda+la+vida
# <Response [200]>
# Pop
# 131
# beret+lo+siento
# <Response [200]>
# Pop
# 132
# ariana+grande+boyfriend+
# <Response [200]>
# Pop
# 133
# luis+fonsi+imposible
# <Response [200]>
# Pop Latino
# 134
# justin+quiles+otra+vez
# <Response [200]>
# Urbano latino
# 135
# nacho+mona+lisa
# <Response [200]>
# Urbano latino
# 136
# bandaga+como+tu
# <Response [200]>
# Latino
# 137
# sebastian+yatra+cristina
# <Response [200]>
# Pop Latino
# 138
# pereza+princesas
# <Response [200]>
# Rock y Alternativo
# 139
# morat+besos+en+guerra
# <Response [200]>
# Pop
# 140
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 141
# lola+indigo+ya+no+quiero+ná
# <Response [200]>
# Pop
# 142
# mya+te+olvidaré
# <Response [200]>
# Pop Latino
# 143
# david+bisbal+perdón
# <Response [200]>
# Pop
# 144
# sam+smith+how+do+you+sleep?
# <Response [200]>
# Pop
# 145
# queen+bohemian+rhapsody+-+2011+mix
# <Response [200]>
# Rock
# 146
# y2k+lalala
# <Response [200]>
# Hip-Hop/Rap
# 147
# jhay+cortez+easy
# <Response [200]>
# Urbano latino
# 148
# bryant+myers+ganas+sobran
# <Response [200]>
# Urbano latino
# 149
# dani+fernández+disparos
# <Response [200]>
# Pop
# 150
# camela+cuando+zarpa+el+amor+
# <Response [200]>
# Pop
# 151
# bryant+myers+bandolera
# <Response [200]>
# Urbano latino
# 152
# bad+bunny+mia+
# <Response [200]>
# Latino
# 153
# post+malone+goodbyes+
# <Response [200]>
# Hip-Hop/Rap
# 154
# estopa+como+camarón
# <Response [200]>
# Pop Latino
# 155
# dvicio+brasilera
# <Response [200]>
# Pop
# 156
# taburete+sirenas
# <Response [200]>
# Pop
# 157
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 158
# daddy+yankee+adictiva
# <Response [200]>
# Urbano latino
# 159
# dj+snake+taki+taki+
# <Response [200]>
# Dance
# 160
# mahmood+soldi
# <Response [200]>
# Pop
# 161
# david+bisbal+a+partir+de+hoy
# <Response [200]>
# Pop
# 162
# lunay+llégale
# <Response [200]>
# Urbano latino
# 163
# mau+y+ricky+desconocidos
# <Response [200]>
# Pop Latino
# 164
# kevin+roldan+hasta+abajo
# <Response [200]>
# Urbano latino
# 165
# rels+b+mejor+no+nos+vemos
# <Response [200]>
# Urbano latino
# 166
# alvaro+soler+la+libertad
# <Response [200]>
# Pop
# 167
# guitarricadelafuente+guantanamera
# <Response [200]>
# Alternative
# 168
# greeicy+destino
# <Response [200]>
# Pop Latino
# 169
# juan+magán+usted
# <Response [200]>
# Dance
# 170
# aitana+teléfono
# <Response [200]>
# Pop
# 171
# bandaga+otra+copa
# <Response [200]>
# Urbano latino
# 172
# ali+gatie+its+you
# <Response [200]>
# R&B/Soul
# 173
# piso+21+te+vi
# <Response [200]>
# Pop Latino
# 174
# danny+ocean+me+rehúso
# <Response [200]>
# Latino
# 175
# mau+y+ricky+la+boca
# <Response [200]>
# Pop Latino
# 176
# nil+moliner+mi+religión
# <Response [200]>
# Pop
# 177
# manuel+turizo+esclavo+de+tus+besos
# <Response [200]>
# Urbano latino
# 178
# bombai+vuela
# <Response [200]>
# Pop
# 179
# c.+tangana+antes+de+morirme+
# <Response [200]>
# Pop
# 180
# cauty+ta+to+gucci+
# <Response [200]>
# Urbano latino
# 181
# pitbull+no+lo+trates
# <Response [200]>
# Urbano latino
# 182
# c.+tangana+booty
# <Response [200]>
# Hip-Hop/Rap
# 183
# j+balvin+yo+le+llego
# <Response [200]>
# Urbano latino
# 184
# lérica+solterita+de+oro
# <Response [200]>
# Pop
# 185
# juanes+la+plata+
# <Response [200]>
# Pop Latino
# 186
# sofia+reyes+r.i.p.+
# <Response [200]>
# Pop Latino
# 187
# natos+y+waor+cicatrices
# <Response [200]>
# Hip-Hop/Rap
# 188
# ava+max+sweet+but+psycho
# <Response [200]>
# Pop
# 189
# david+guetta+say+my+name
# <Response [200]>
# Dance
# 190
# c.+tangana+pa+llamar+tu+atención+
# <Response [200]>
# Hip-Hop/Rap
# 191
# ed+sheeran+nothing+on+you+
# <Response [200]>
# Pop
# 192
# panic!+at+the+disco+high+hopes
# <Response [200]>
# Alternative
# 193
# dellafuente+tenamoras
# <Response [200]>
# Pop
# 194
# lunay+soltera
# <Response [200]>
# Urbano latino
# 195
# manuel+carrasco+déjame+ser
# <Response [200]>
# Pop
# 196
# maka+vida
# <Response [200]>
# Worldwide
# 197
# marshmello+happier
# <Response [200]>
# Dance
# 198
# robgz+lhna+
# <Response [200]>
# Urbano latino
# 199
# es_2019-08-16--2019-08-23.csv
# anuel+aa+china
# <Response [200]>
# Urbano latino
# 0
# rosalía+yo+x+ti,+tu+x+mi
# <Response [200]>
# Latino
# 1
# sech+otro+trago+-+remix
# <Response [200]>
# Latino
# 2
# bad+bunny+callaita
# <Response [200]>
# Urbano latino
# 3
# jhay+cortez+no+me+conoce+-+remix
# <Response [200]>
# Urbano latino
# 4
# j+balvin+la+canción
# <Response [200]>
# Urbano latino
# 5
# lunay+soltera+
# <Response [200]>
# Urbano latino
# 6
# lola+indigo+lola+bunny
# <Response [200]>
# Pop Latino
# 7
# la+nueva+escuela+la+rubia+-+remix+2
# <Response [200]>
# Urbano latino
# 8
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 9
# chris+viz+diavla
# <Response [200]>
# Urbano latino
# 10
# dayvi+baila+conmigo+
# <Response [200]>
# Pop Latino
# 11
# j+balvin+que+pretendes
# <Response [200]>
# Urbano latino
# 12
# dj+snake+loco+contigo+
# <Response [200]>
# Latino
# 13
# danny+romero+de+tranquilote
# <Response [200]>
# Latino
# 14
# rvfv+mirándote
# <Response [200]>
# Latin Rap
# 15
# don+patricio+contando+lunares+
# <Response [200]>
# Urbano latino
# 16
# darell+velitas
# <Response [200]>
# Urbano latino
# 17
# duki+goteo
# <Response [200]>
# Hip-Hop/Rap
# 18
# bryant+myers+gan-ga
# <Response [200]>
# Urbano latino
# 19
# becky+g+dollar
# <Response [200]>
# Pop Latino
# 20
# maluma+11+pm
# <Response [200]>
# Urbano latino
# 21
# myke+towers+si+se+da+-+remix
# <Response [200]>
# Urbano latino
# 22
# maffio+cristina+
# <Response [200]>
# Urbano latino
# 23
# rosalía+con+altura
# <Response [200]>
# Pop
# 24
# sinsinati+indios+y+vaqueros
# <Response [200]>
# Pop
# 25
# dj+luian+verte+ir
# <Response [200]>
# Urbano latino
# 26
# myke+towers+inocente
# <Response [200]>
# Música tropical
# 27
# rosalía+milionària
# <Response [200]>
# Pop
# 28
# guaynaa+rebota+-+remix
# <Response [200]>
# Urbano latino
# 29
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 30
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 31
# ozuna+te+soñé+de+nuevo
# <Response [200]>
# Urbano latino
# 32
# dalex+cuaderno
# <Response [200]>
# Urbano latino
# 33
# david+bisbal+bésame
# <Response [200]>
# Pop
# 34
# maître+gims+hola+señorita
# <Response [200]>
# Urbano latino
# 35
# mahmood+soldi+
# <Response [200]>
# Pop
# 36
# $kyhook+a+escondidas
# <Response [200]>
# Pop
# 37
# ceky+viciny+ellos
# <Response [200]>
# Dance
# 38
# bad+gyal+santa+maría+
# <Response [200]>
# Pop Latino
# 39
# sergio+contreras+cicatrices+
# <Response [200]>
# Pop
# 40
# sebastian+yatra+runaway
# <Response [200]>
# Pop Latino
# 41
# juanfran+mi+morena
# <Response [200]>
# Urbano latino
# 42
# casper+magico+no+te+veo+-+remix
# <Response [200]>
# Urbano latino
# 43
# sean+paul+contra+la+pared
# <Response [200]>
# Urbano latino
# 44
# rels+b+¿cómo+te+va,+querida?
# <Response [200]>
# Pop
# 45
# paulo+londra+tal+vez
# <Response [200]>
# Latino
# 46
# don+patricio+enchochado+de+ti
# <Response [200]>
# Urbano latino
# 47
# nicky+jam+te+robaré
# <Response [200]>
# Urbano latino
# 48
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 49
# aitana+me+quedo
# <Response [200]>
# Pop
# 50
# danny+ocean+swing
# <Response [200]>
# Pop Latino
# 51
# maluma+hp
# <Response [200]>
# Urbano latino
# 52
# myke+towers+la+playa
# <Response [200]>
# Urbano latino
# 53
# lalo+ebratt+déjate+querer
# <Response [200]>
# Urbano latino
# 54
# dalex+pa+mí+-+remix
# <Response [200]>
# Urbano latino
# 55
# j+balvin+mojaita
# <Response [200]>
# Urbano latino
# 56
# nil+moliner+soldadito+de+hierro
# <Response [200]>
# Pop
# 57
# sech+otro+trago
# <Response [200]>
# Latino
# 58
# morat+presiento
# <Response [200]>
# Pop
# 59
# farruko+delincuente
# <Response [200]>
# Urbano latino
# 60
# bad+gyal+hookah
# <Response [200]>
# Pop Latino
# 61
# nicky+jam+atrévete
# <Response [200]>
# Urbano latino
# 62
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 63
# luis+fonsi+date+la+vuelta
# <Response [200]>
# Pop Latino
# 64
# wos+canguro
# <Response [200]>
# Hip-Hop/Rap
# 65
# cupido+autoestima+
# <Response [200]>
# Pop Latino
# 66
# myke+towers+si+se+da
# <Response [200]>
# Urbano latino
# 67
# eladio+carrion+kemba+walker
# <Response [200]>
# Urbano latino
# 68
# dvicio+5+sentidos
# <Response [200]>
# Pop
# 69
# daddy+yankee+si+supieras
# <Response [200]>
# Urbano latino
# 70
# manuel+carrasco+qué+bonito+es+querer
# <Response [200]>
# Pop
# 71
# jhay+cortez+easy
# <Response [200]>
# Urbano latino
# 72
# justin+quiles+que+mas+pues+-+remix
# <Response [200]>
# Urbano latino
# 73
# residente+bellacoso
# <Response [200]>
# Urbano latino
# 74
# sech+boomerang
# <Response [200]>
# Urbano latino
# 75
# mau+y+ricky+la+boca+-+remix
# <Response [200]>
# Pop Latino
# 76
# camilo+tutu
# <Response [200]>
# Urbano latino
# 77
# anuel+aa+amanece
# <Response [200]>
# Urbano latino
# 78
# beret+me+llama
# <Response [200]>
# Pop
# 79
# reik+aleluya
# <Response [200]>
# Pop Latino
# 80
# ozuna+baila+baila+baila
# <Response [200]>
# Urbano latino
# 81
# ozuna+baila+baila+baila+-+remix
# <Response [200]>
# Urbano latino
# 82
# paulo+londra+adan+y+eva
# <Response [200]>
# Urbano latino
# 83
# aitana+nada+sale+mal
# <Response [200]>
# Pop
# 84
# alejandro+sanz+mi+persona+favorita
# <Response [200]>
# Pop Latino
# 85
# karol+g+ocean
# <Response [200]>
# Urbano latino
# 86
# bizarrap+trueno:+bzrp+freestyle+sessions,+vol.+6
# <Response [200]>
# Latin Rap
# 87
# lola+indigo+maldición
# <Response [200]>
# Pop
# 88
# prince+royce+cúrame+
# <Response [200]>
# Urbano latino
# 89
# lil+nas+x+old+town+road+-+remix
# <Response [200]>
# Country
# 90
# bizarrap+nicki+nicole:+bzrp+music+sessions,+vol.+13
# <Response [200]>
# Hip-Hop/Rap
# 91
# sebastian+yatra+un+año
# <Response [200]>
# Pop Latino
# 92
# mambo+kingz+tú+no+amas
# <Response [200]>
# Urbano latino
# 93
# miki+núñez+celébrate
# <Response [200]>
# Pop
# 94
# ozuna+cambio
# <Response [200]>
# Urbano latino
# 95
# piso+21+una+vida+para+recordar
# <Response [200]>
# Pop Latino
# 96
# anuel+aa+secreto
# <Response [200]>
# Urbano latino
# 97
# ozuna+amor+genuino
# <Response [200]>
# Urbano latino
# 98
# becky+g+la+respuesta
# <Response [200]>
# Urbano latino
# 99
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 100
# natalia+lacunza+nana+triste
# <Response [200]>
# Pop
# 101
# noriel+cuerpo+en+venta
# <Response [200]>
# Latino
# 102
# ozuna+muito+calor
# <Response [200]>
# Urbano latino
# 103
# lil+tecca+ransom
# <Response [200]>
# Hip-Hop/Rap
# 104
# anuel+aa+ella+quiere+beber+-+remix
# <Response [200]>
# Urbano latino
# 105
# rosalía+aute+cuture
# <Response [200]>
# Pop
# 106
# dimitri+vegas+&+like+mike+instagram
# <Response [200]>
# Electronic
# 107
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 108
# locoplaya+esa+carita+que+me+llevas
# <Response [200]>
# Hip-Hop/Rap
# 109
# aitana+con+la+miel+en+los+labios
# <Response [200]>
# Pop
# 110
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 111
# karol+g+punto+g
# <Response [200]>
# Urbano latino
# 112
# nio+garcia+mírame+-+remix
# <Response [200]>
# Urbano latino
# 113
# rosalía+malamente+-+cap.1:+augurio
# <Response [200]>
# Pop
# 114
# juan+magán+sobrenatural
# <Response [200]>
# Pop
# 115
# y2k+lalala
# <Response [200]>
# Hip-Hop/Rap
# 116
# beret+te+echo+de+menos
# <Response [200]>
# Pop
# 117
# aitana+vas+a+quedarte
# <Response [200]>
# Pop
# 118
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 119
# yandel+en+cero
# <Response [200]>
# Urbano latino
# 120
# kidd+keo+serpiente+veneno+
# <Response [200]>
# Urbano latino
# 121
# reykon+latina+
# <Response [200]>
# Latino
# 122
# leiva+no+te+preocupes+por+mi
# <Response [200]>
# Pop
# 123
# paulo+londra+por+eso+vine
# <Response [200]>
# Urbano latino
# 124
# fito+y+fitipaldis+soldadito+marinero
# <Response [200]>
# Rock y Alternativo
# 125
# juancho+marqués+benicàssim+
# <Response [200]>
# Urbano latino
# 126
# bandaga+como+tu
# <Response [200]>
# Latino
# 127
# dani+fernández+te+esperaré+toda+la+vida
# <Response [200]>
# Pop
# 128
# lola+indigo+mujer+bruja
# <Response [200]>
# Pop
# 129
# melendi+déjala+que+baile+
# <Response [200]>
# Pop Latino
# 130
# demarco+flamenco+pa+ti+pa+mí+na+má
# <Response [200]>
# Iberia
# 131
# estopa+fuego
# <Response [200]>
# Pop
# 132
# wisin+&+yandel+aullando
# <Response [200]>
# Urbano latino
# 133
# morat+cuando+nadie+ve
# <Response [200]>
# Pop
# 134
# dvicio+qué+tienes+tú+
# <Response [200]>
# Pop
# 135
# becky+g+sin+pijama
# <Response [200]>
# Urbano latino
# 136
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 137
# pereza+princesas
# <Response [200]>
# Rock y Alternativo
# 138
# beret+lo+siento
# <Response [200]>
# Pop
# 139
# sam+smith+how+do+you+sleep?
# <Response [200]>
# Pop
# 140
# ozuna+vaina+loca
# <Response [200]>
# Urbano latino
# 141
# sebastian+yatra+cristina
# <Response [200]>
# Pop Latino
# 142
# rauw+alejandro+el+efecto
# <Response [200]>
# Urbano latino
# 143
# luis+fonsi+imposible
# <Response [200]>
# Pop Latino
# 144
# justin+quiles+otra+vez
# <Response [200]>
# Urbano latino
# 145
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 146
# dani+fernández+disparos
# <Response [200]>
# Pop
# 147
# morat+besos+en+guerra
# <Response [200]>
# Pop
# 148
# david+bisbal+perdón
# <Response [200]>
# Pop
# 149
# lola+indigo+ya+no+quiero+ná
# <Response [200]>
# Pop
# 150
# mya+te+olvidaré
# <Response [200]>
# Pop Latino
# 151
# queen+bohemian+rhapsody+-+2011+mix
# <Response [200]>
# Rock
# 152
# camela+cuando+zarpa+el+amor+
# <Response [200]>
# Pop
# 153
# bryant+myers+bandolera
# <Response [200]>
# Urbano latino
# 154
# estopa+como+camarón
# <Response [200]>
# Pop Latino
# 155
# maka+vida
# <Response [200]>
# Worldwide
# 156
# ariana+grande+boyfriend+
# <Response [200]>
# Pop
# 157
# post+malone+goodbyes+
# <Response [200]>
# Hip-Hop/Rap
# 158
# dvicio+brasilera
# <Response [200]>
# Pop
# 159
# bandaga+otra+copa
# <Response [200]>
# Urbano latino
# 160
# taburete+sirenas
# <Response [200]>
# Pop
# 161
# nil+moliner+mi+religión
# <Response [200]>
# Pop
# 162
# daddy+yankee+adictiva
# <Response [200]>
# Urbano latino
# 163
# mau+y+ricky+desconocidos
# <Response [200]>
# Pop Latino
# 164
# guitarricadelafuente+guantanamera
# <Response [200]>
# Alternative
# 165
# bad+bunny+mia+
# <Response [200]>
# Latino
# 166
# david+bisbal+a+partir+de+hoy
# <Response [200]>
# Pop
# 167
# nacho+mona+lisa
# <Response [200]>
# Urbano latino
# 168
# bombai+vuela
# <Response [200]>
# Pop
# 169
# kevin+roldan+hasta+abajo
# <Response [200]>
# Urbano latino
# 170
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 171
# aitana+teléfono
# <Response [200]>
# Pop
# 172
# rels+b+mejor+no+nos+vemos
# <Response [200]>
# Urbano latino
# 173
# mahmood+soldi
# <Response [200]>
# Pop
# 174
# bryant+myers+ganas+sobran
# <Response [200]>
# Urbano latino
# 175
# beret+lo+siento+
# <Response [200]>
# Pop
# 176
# dj+snake+taki+taki+
# <Response [200]>
# Dance
# 177
# ali+gatie+its+you
# <Response [200]>
# R&B/Soul
# 178
# natos+y+waor+cicatrices
# <Response [200]>
# Hip-Hop/Rap
# 179
# juan+magán+usted
# <Response [200]>
# Dance
# 180
# leiva+como+si+fueras+a+morir+mañana
# <Response [200]>
# Pop
# 181
# danny+ocean+me+rehúso
# <Response [200]>
# Latino
# 182
# manuel+carrasco+déjame+ser
# <Response [200]>
# Pop
# 183
# eklectico+nota+loca+-+remix
# <Response [200]>
# Latino
# 184
# manuel+turizo+esclavo+de+tus+besos
# <Response [200]>
# Urbano latino
# 185
# mau+y+ricky+la+boca
# <Response [200]>
# Pop Latino
# 186
# alvaro+soler+la+libertad
# <Response [200]>
# Pop
# 187
# piso+21+te+vi
# <Response [200]>
# Pop Latino
# 188
# cauty+ta+to+gucci+
# <Response [200]>
# Urbano latino
# 189
# lunay+llégale
# <Response [200]>
# Urbano latino
# 190
# c.+tangana+antes+de+morirme+
# <Response [200]>
# Pop
# 191
# panic!+at+the+disco+high+hopes
# <Response [200]>
# Alternative
# 192
# chocquibtown+que+me+baile
# <Response [200]>
# Urbano latino
# 193
# ava+max+sweet+but+psycho
# <Response [200]>
# Pop
# 194
# greeicy+destino
# <Response [200]>
# Pop Latino
# 195
# lunay+soltera
# <Response [200]>
# Urbano latino
# 196
# j+balvin+yo+le+llego
# <Response [200]>
# Urbano latino
# 197
# taylor+swift+lover
# <Response [200]>
# Country
# 198
# nyno+vargas+ve+y+dile+
# <Response [200]>
# Pop Latino
# 199
# es_2019-08-23--2019-08-30.csv
# anuel+aa+china
# <Response [200]>
# Urbano latino
# 0
# rosalía+yo+x+ti,+tu+x+mi
# <Response [200]>
# Latino
# 1
# sech+otro+trago+-+remix
# <Response [200]>
# Latino
# 2
# tainy+adicto+
# <Response [200]>
# Latino
# 3
# bad+bunny+callaita
# <Response [200]>
# Urbano latino
# 4
# danny+romero+de+tranquilote
# <Response [200]>
# Latino
# 5
# j+balvin+la+canción
# <Response [200]>
# Urbano latino
# 6
# la+nueva+escuela+la+rubia+-+remix+2
# <Response [200]>
# Urbano latino
# 7
# jhay+cortez+no+me+conoce+-+remix
# <Response [200]>
# Urbano latino
# 8
# chris+viz+diavla
# <Response [200]>
# Urbano latino
# 9
# duki+goteo
# <Response [200]>
# Hip-Hop/Rap
# 10
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 11
# lola+indigo+lola+bunny
# <Response [200]>
# Pop Latino
# 12
# lunay+soltera+
# <Response [200]>
# Urbano latino
# 13
# dayvi+baila+conmigo+
# <Response [200]>
# Pop Latino
# 14
# j+balvin+que+pretendes
# <Response [200]>
# Urbano latino
# 15
# dj+snake+loco+contigo+
# <Response [200]>
# Latino
# 16
# darell+velitas
# <Response [200]>
# Urbano latino
# 17
# becky+g+dollar
# <Response [200]>
# Pop Latino
# 18
# bryant+myers+gan-ga
# <Response [200]>
# Urbano latino
# 19
# don+patricio+contando+lunares+
# <Response [200]>
# Urbano latino
# 20
# rvfv+mirándote
# <Response [200]>
# Latin Rap
# 21
# myke+towers+si+se+da+-+remix
# <Response [200]>
# Urbano latino
# 22
# sinsinati+indios+y+vaqueros
# <Response [200]>
# Pop
# 23
# maluma+11+pm
# <Response [200]>
# Urbano latino
# 24
# $kyhook+a+escondidas
# <Response [200]>
# Pop
# 25
# rosalía+con+altura
# <Response [200]>
# Pop
# 26
# guaynaa+rebota+-+remix
# <Response [200]>
# Urbano latino
# 27
# myke+towers+inocente
# <Response [200]>
# Música tropical
# 28
# rosalía+milionària
# <Response [200]>
# Pop
# 29
# dj+luian+verte+ir
# <Response [200]>
# Urbano latino
# 30
# maffio+cristina+
# <Response [200]>
# Urbano latino
# 31
# dalex+cuaderno
# <Response [200]>
# Urbano latino
# 32
# ozuna+te+soñé+de+nuevo
# <Response [200]>
# Urbano latino
# 33
# casper+magico+no+te+veo+-+remix
# <Response [200]>
# Urbano latino
# 34
# david+bisbal+bésame
# <Response [200]>
# Pop
# 35
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 36
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 37
# bad+gyal+santa+maría+
# <Response [200]>
# Pop Latino
# 38
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 39
# maître+gims+hola+señorita
# <Response [200]>
# Urbano latino
# 40
# juanfran+mi+morena
# <Response [200]>
# Urbano latino
# 41
# don+patricio+enchochado+de+ti
# <Response [200]>
# Urbano latino
# 42
# ceky+viciny+ellos
# <Response [200]>
# Dance
# 43
# mahmood+soldi+
# <Response [200]>
# Pop
# 44
# rels+b+¿cómo+te+va,+querida?
# <Response [200]>
# Pop
# 45
# sebastian+yatra+runaway
# <Response [200]>
# Pop Latino
# 46
# nil+moliner+soldadito+de+hierro
# <Response [200]>
# Pop
# 47
# sergio+contreras+cicatrices+
# <Response [200]>
# Pop
# 48
# jhay+cortez+easy
# <Response [200]>
# Urbano latino
# 49
# nicky+jam+atrévete
# <Response [200]>
# Urbano latino
# 50
# sean+paul+contra+la+pared
# <Response [200]>
# Urbano latino
# 51
# manuel+turizo+te+quemaste
# <Response [200]>
# Urbano latino
# 52
# j+balvin+mojaita
# <Response [200]>
# Urbano latino
# 53
# paulo+londra+tal+vez
# <Response [200]>
# Latino
# 54
# camilo+tutu
# <Response [200]>
# Urbano latino
# 55
# nicky+jam+te+robaré
# <Response [200]>
# Urbano latino
# 56
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 57
# aitana+me+quedo
# <Response [200]>
# Pop
# 58
# morat+presiento
# <Response [200]>
# Pop
# 59
# myke+towers+la+playa
# <Response [200]>
# Urbano latino
# 60
# bad+gyal+hookah
# <Response [200]>
# Pop Latino
# 61
# sech+otro+trago
# <Response [200]>
# Latino
# 62
# noriel+cuerpo+en+venta
# <Response [200]>
# Latino
# 63
# farruko+delincuente
# <Response [200]>
# Urbano latino
# 64
# eladio+carrion+kemba+walker
# <Response [200]>
# Urbano latino
# 65
# lalo+ebratt+déjate+querer
# <Response [200]>
# Urbano latino
# 66
# wos+canguro
# <Response [200]>
# Hip-Hop/Rap
# 67
# danny+ocean+swing
# <Response [200]>
# Pop Latino
# 68
# maluma+hp
# <Response [200]>
# Urbano latino
# 69
# manuel+carrasco+qué+bonito+es+querer
# <Response [200]>
# Pop
# 70
# nio+garcia+mírame+-+remix
# <Response [200]>
# Urbano latino
# 71
# dvicio+5+sentidos
# <Response [200]>
# Pop
# 72
# dalex+pa+mí+-+remix
# <Response [200]>
# Urbano latino
# 73
# y2k+lalala
# <Response [200]>
# Hip-Hop/Rap
# 74
# cupido+autoestima+
# <Response [200]>
# Pop Latino
# 75
# daddy+yankee+si+supieras
# <Response [200]>
# Urbano latino
# 76
# sech+boomerang
# <Response [200]>
# Urbano latino
# 77
# luis+fonsi+date+la+vuelta
# <Response [200]>
# Pop Latino
# 78
# mau+y+ricky+la+boca+-+remix
# <Response [200]>
# Pop Latino
# 79
# bizarrap+trueno:+bzrp+freestyle+sessions,+vol.+6
# <Response [200]>
# Latin Rap
# 80
# rosalía+aute+cuture
# <Response [200]>
# Pop
# 81
# bizarrap+nicki+nicole:+bzrp+music+sessions,+vol.+13
# <Response [200]>
# Hip-Hop/Rap
# 82
# residente+bellacoso
# <Response [200]>
# Urbano latino
# 83
# reik+indeciso
# <Response [200]>
# Urbano latino
# 84
# beret+me+llama
# <Response [200]>
# Pop
# 85
# ozuna+baila+baila+baila+-+remix
# <Response [200]>
# Urbano latino
# 86
# aitana+nada+sale+mal
# <Response [200]>
# Pop
# 87
# myke+towers+si+se+da
# <Response [200]>
# Urbano latino
# 88
# ozuna+muito+calor
# <Response [200]>
# Urbano latino
# 89
# piso+21+una+vida+para+recordar
# <Response [200]>
# Pop Latino
# 90
# sebastian+yatra+un+año
# <Response [200]>
# Pop Latino
# 91
# lil+nas+x+old+town+road+-+remix
# <Response [200]>
# Country
# 92
# rosalía+malamente+-+cap.1:+augurio
# <Response [200]>
# Pop
# 93
# alejandro+sanz+mi+persona+favorita
# <Response [200]>
# Pop Latino
# 94
# paulo+londra+adan+y+eva
# <Response [200]>
# Urbano latino
# 95
# karol+g+ocean
# <Response [200]>
# Urbano latino
# 96
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 97
# justin+quiles+que+mas+pues+-+remix
# <Response [200]>
# Urbano latino
# 98
# lil+tecca+ransom
# <Response [200]>
# Hip-Hop/Rap
# 99
# reik+aleluya
# <Response [200]>
# Pop Latino
# 100
# ozuna+amor+genuino
# <Response [200]>
# Urbano latino
# 101
# ozuna+cambio
# <Response [200]>
# Urbano latino
# 102
# natalia+lacunza+nana+triste
# <Response [200]>
# Pop
# 103
# aitana+con+la+miel+en+los+labios
# <Response [200]>
# Pop
# 104
# mambo+kingz+tú+no+amas
# <Response [200]>
# Urbano latino
# 105
# prince+royce+cúrame+
# <Response [200]>
# Urbano latino
# 106
# lola+indigo+maldición
# <Response [200]>
# Pop
# 107
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 108
# anuel+aa+secreto
# <Response [200]>
# Urbano latino
# 109
# anuel+aa+amanece
# <Response [200]>
# Urbano latino
# 110
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 111
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 112
# miki+núñez+celébrate
# <Response [200]>
# Pop
# 113
# becky+g+la+respuesta
# <Response [200]>
# Urbano latino
# 114
# juan+magán+sobrenatural
# <Response [200]>
# Pop
# 115
# anuel+aa+ella+quiere+beber+-+remix
# <Response [200]>
# Urbano latino
# 116
# aitana+vas+a+quedarte
# <Response [200]>
# Pop
# 117
# ozuna+baila+baila+baila
# <Response [200]>
# Urbano latino
# 118
# beret+te+echo+de+menos
# <Response [200]>
# Pop
# 119
# paulo+londra+por+eso+vine
# <Response [200]>
# Urbano latino
# 120
# taylor+swift+lover
# <Response [200]>
# Country
# 121
# leiva+no+te+preocupes+por+mi
# <Response [200]>
# Pop
# 122
# dimitri+vegas+&+like+mike+instagram
# <Response [200]>
# Electronic
# 123
# bandaga+como+tu
# <Response [200]>
# Latino
# 124
# kidd+keo+serpiente+veneno+
# <Response [200]>
# Urbano latino
# 125
# dani+fernández+te+esperaré+toda+la+vida
# <Response [200]>
# Pop
# 126
# estopa+fuego
# <Response [200]>
# Pop
# 127
# demarco+flamenco+pa+ti+pa+mí+na+má
# <Response [200]>
# Iberia
# 128
# dani+fernández+disparos
# <Response [200]>
# Pop
# 129
# melendi+déjala+que+baile+
# <Response [200]>
# Pop Latino
# 130
# fito+y+fitipaldis+soldadito+marinero
# <Response [200]>
# Rock y Alternativo
# 131
# pereza+princesas
# <Response [200]>
# Rock y Alternativo
# 132
# dvicio+qué+tienes+tú+
# <Response [200]>
# Pop
# 133
# pol+granch+te+quiodio
# <Response [200]>
# Pop
# 134
# beret+lo+siento
# <Response [200]>
# Pop
# 135
# wisin+&+yandel+aullando
# <Response [200]>
# Urbano latino
# 136
# reykon+latina+
# <Response [200]>
# Latino
# 137
# lola+indigo+mujer+bruja
# <Response [200]>
# Pop
# 138
# sebastian+yatra+cristina
# <Response [200]>
# Pop Latino
# 139
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 140
# sam+smith+how+do+you+sleep?
# <Response [200]>
# Pop
# 141
# morat+cuando+nadie+ve
# <Response [200]>
# Pop
# 142
# becky+g+sin+pijama
# <Response [200]>
# Urbano latino
# 143
# nil+moliner+mi+religión
# <Response [200]>
# Pop
# 144
# justin+quiles+otra+vez
# <Response [200]>
# Urbano latino
# 145
# yandel+en+cero
# <Response [200]>
# Urbano latino
# 146
# maka+vida
# <Response [200]>
# Worldwide
# 147
# mya+te+olvidaré
# <Response [200]>
# Pop Latino
# 148
# rauw+alejandro+el+efecto
# <Response [200]>
# Urbano latino
# 149
# locoplaya+esa+carita+que+me+llevas
# <Response [200]>
# Hip-Hop/Rap
# 150
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 151
# karol+g+punto+g
# <Response [200]>
# Urbano latino
# 152
# bryant+myers+bandolera
# <Response [200]>
# Urbano latino
# 153
# camela+cuando+zarpa+el+amor+
# <Response [200]>
# Pop
# 154
# juancho+marqués+benicàssim+
# <Response [200]>
# Urbano latino
# 155
# bombai+vuela
# <Response [200]>
# Pop
# 156
# david+bisbal+perdón
# <Response [200]>
# Pop
# 157
# leiva+como+si+fueras+a+morir+mañana
# <Response [200]>
# Pop
# 158
# ozuna+vaina+loca
# <Response [200]>
# Urbano latino
# 159
# cazzu+nada
# <Response [200]>
# Urbano latino
# 160
# luis+fonsi+imposible
# <Response [200]>
# Pop Latino
# 161
# estopa+como+camarón
# <Response [200]>
# Pop Latino
# 162
# israel+b+yyanosé
# <Response [200]>
# Hip-Hop
# 163
# post+malone+goodbyes+
# <Response [200]>
# Hip-Hop/Rap
# 164
# morat+besos+en+guerra
# <Response [200]>
# Pop
# 165
# queen+bohemian+rhapsody+-+2011+mix
# <Response [200]>
# Rock
# 166
# david+bisbal+a+partir+de+hoy
# <Response [200]>
# Pop
# 167
# taburete+sirenas
# <Response [200]>
# Pop
# 168
# aitana+teléfono
# <Response [200]>
# Pop
# 169
# manuel+turizo+esclavo+de+tus+besos
# <Response [200]>
# Urbano latino
# 170
# bandaga+otra+copa
# <Response [200]>
# Urbano latino
# 171
# dvicio+brasilera
# <Response [200]>
# Pop
# 172
# nacho+mona+lisa
# <Response [200]>
# Urbano latino
# 173
# guitarricadelafuente+guantanamera
# <Response [200]>
# Alternative
# 174
# lola+indigo+ya+no+quiero+ná
# <Response [200]>
# Pop
# 175
# bad+bunny+mia+
# <Response [200]>
# Latino
# 176
# ariana+grande+boyfriend+
# <Response [200]>
# Pop
# 177
# eklectico+nota+loca+-+remix
# <Response [200]>
# Latino
# 178
# kevin+roldan+hasta+abajo
# <Response [200]>
# Urbano latino
# 179
# taylor+swift+the+man
# <Response [200]>
# Pop
# 180
# c.+tangana+antes+de+morirme+
# <Response [200]>
# Pop
# 181
# rosalía+pienso+en+tu+mirá+-+cap.3:+celos
# <Response [200]>
# Pop
# 182
# ali+gatie+its+you
# <Response [200]>
# R&B/Soul
# 183
# natos+y+waor+cicatrices
# <Response [200]>
# Hip-Hop/Rap
# 184
# mau+y+ricky+desconocidos
# <Response [200]>
# Pop Latino
# 185
# taylor+swift+you+need+to+calm+down
# <Response [200]>
# Pop
# 186
# ariana+grande+7+rings
# <Response [200]>
# Pop
# 187
# rels+b+mejor+no+nos+vemos
# <Response [200]>
# Urbano latino
# 188
# daddy+yankee+adictiva
# <Response [200]>
# Urbano latino
# 189
# piso+21+te+vi
# <Response [200]>
# Pop Latino
# 190
# bryant+myers+ganas+sobran
# <Response [200]>
# Urbano latino
# 191
# mau+y+ricky+la+boca
# <Response [200]>
# Pop Latino
# 192
# maldita+nerea+un+planeta+llamado+nosotros
# <Response [200]>
# Pop
# 193
# manuel+carrasco+déjame+ser
# <Response [200]>
# Pop
# 194
# panic!+at+the+disco+high+hopes
# <Response [200]>
# Alternative
# 195
# juan+magán+usted
# <Response [200]>
# Dance
# 196
# mahmood+soldi
# <Response [200]>
# Pop
# 197
# arnau+griso+quiero,+quiero+y+quiero
# <Response [200]>
# Pop
# 198
# efecto+pasillo+no+te+enamores
# <Response [200]>
# Pop
# 199
# es_2019-08-30--2019-09-06.csv
# anuel+aa+china
# <Response [200]>
# Urbano latino
# 0
# rosalía+yo+x+ti,+tu+x+mi
# <Response [200]>
# Latino
# 1
# tainy+adicto+
# <Response [200]>
# Latino
# 2
# sech+otro+trago+-+remix
# <Response [200]>
# Latino
# 3
# duki+goteo
# <Response [200]>
# Hip-Hop/Rap
# 4
# danny+romero+de+tranquilote
# <Response [200]>
# Latino
# 5
# bad+bunny+callaita
# <Response [200]>
# Urbano latino
# 6
# la+nueva+escuela+la+rubia+-+remix+2
# <Response [200]>
# Urbano latino
# 7
# jhay+cortez+no+me+conoce+-+remix
# <Response [200]>
# Urbano latino
# 8
# j+balvin+la+canción
# <Response [200]>
# Urbano latino
# 9
# chris+viz+diavla
# <Response [200]>
# Urbano latino
# 10
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 11
# lunay+soltera+
# <Response [200]>
# Urbano latino
# 12
# j+balvin+que+pretendes
# <Response [200]>
# Urbano latino
# 13
# lola+indigo+lola+bunny
# <Response [200]>
# Pop Latino
# 14
# dayvi+baila+conmigo+
# <Response [200]>
# Pop Latino
# 15
# dj+snake+loco+contigo+
# <Response [200]>
# Latino
# 16
# darell+velitas
# <Response [200]>
# Urbano latino
# 17
# don+patricio+contando+lunares+
# <Response [200]>
# Urbano latino
# 18
# becky+g+dollar
# <Response [200]>
# Pop Latino
# 19
# bryant+myers+gan-ga
# <Response [200]>
# Urbano latino
# 20
# sinsinati+indios+y+vaqueros
# <Response [200]>
# Pop
# 21
# $kyhook+a+escondidas
# <Response [200]>
# Pop
# 22
# myke+towers+si+se+da+-+remix
# <Response [200]>
# Urbano latino
# 23
# maluma+11+pm
# <Response [200]>
# Urbano latino
# 24
# camilo+tutu
# <Response [200]>
# Urbano latino
# 25
# rosalía+con+altura
# <Response [200]>
# Pop
# 26
# rvfv+mirándote
# <Response [200]>
# Latin Rap
# 27
# jhay+cortez+easy
# <Response [200]>
# Urbano latino
# 28
# manuel+turizo+te+quemaste
# <Response [200]>
# Urbano latino
# 29
# guaynaa+rebota+-+remix
# <Response [200]>
# Urbano latino
# 30
# maffio+cristina+
# <Response [200]>
# Urbano latino
# 31
# myke+towers+inocente
# <Response [200]>
# Música tropical
# 32
# dj+luian+verte+ir
# <Response [200]>
# Urbano latino
# 33
# rosalía+milionària
# <Response [200]>
# Pop
# 34
# david+bisbal+bésame
# <Response [200]>
# Pop
# 35
# dalex+cuaderno
# <Response [200]>
# Urbano latino
# 36
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 37
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 38
# ozuna+te+soñé+de+nuevo
# <Response [200]>
# Urbano latino
# 39
# casper+magico+no+te+veo+-+remix
# <Response [200]>
# Urbano latino
# 40
# mahmood+soldi+
# <Response [200]>
# Pop
# 41
# ceky+viciny+ellos
# <Response [200]>
# Dance
# 42
# bad+gyal+santa+maría+
# <Response [200]>
# Pop Latino
# 43
# dímelo+flow+el+favor+
# <Response [200]>
# Urbano latino
# 44
# maître+gims+hola+señorita
# <Response [200]>
# Urbano latino
# 45
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 46
# don+patricio+enchochado+de+ti
# <Response [200]>
# Urbano latino
# 47
# nicky+jam+atrévete
# <Response [200]>
# Urbano latino
# 48
# y2k+lalala
# <Response [200]>
# Hip-Hop/Rap
# 49
# rels+b+¿cómo+te+va,+querida?
# <Response [200]>
# Pop
# 50
# juanfran+mi+morena
# <Response [200]>
# Urbano latino
# 51
# sergio+contreras+cicatrices+
# <Response [200]>
# Pop
# 52
# noriel+cuerpo+en+venta
# <Response [200]>
# Latino
# 53
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 54
# nil+moliner+soldadito+de+hierro
# <Response [200]>
# Pop
# 55
# nicky+jam+te+robaré
# <Response [200]>
# Urbano latino
# 56
# paulo+londra+tal+vez
# <Response [200]>
# Latino
# 57
# aitana+me+quedo
# <Response [200]>
# Pop
# 58
# danny+ocean+swing
# <Response [200]>
# Pop Latino
# 59
# lalo+ebratt+déjate+querer
# <Response [200]>
# Urbano latino
# 60
# wos+canguro
# <Response [200]>
# Hip-Hop/Rap
# 61
# sebastian+yatra+runaway
# <Response [200]>
# Pop Latino
# 62
# morat+presiento
# <Response [200]>
# Pop
# 63
# j+balvin+mojaita
# <Response [200]>
# Urbano latino
# 64
# maluma+hp
# <Response [200]>
# Urbano latino
# 65
# manuel+carrasco+qué+bonito+es+querer
# <Response [200]>
# Pop
# 66
# nio+garcia+mírame+-+remix
# <Response [200]>
# Urbano latino
# 67
# bad+gyal+hookah
# <Response [200]>
# Pop Latino
# 68
# sech+otro+trago
# <Response [200]>
# Latino
# 69
# farruko+delincuente
# <Response [200]>
# Urbano latino
# 70
# dalex+pa+mí+-+remix
# <Response [200]>
# Urbano latino
# 71
# eladio+carrion+kemba+walker
# <Response [200]>
# Urbano latino
# 72
# luis+fonsi+date+la+vuelta
# <Response [200]>
# Pop Latino
# 73
# sean+paul+contra+la+pared
# <Response [200]>
# Urbano latino
# 74
# dvicio+5+sentidos
# <Response [200]>
# Pop
# 75
# bizarrap+trueno:+bzrp+freestyle+sessions,+vol.+6
# <Response [200]>
# Latin Rap
# 76
# myke+towers+la+playa
# <Response [200]>
# Urbano latino
# 77
# mau+y+ricky+la+boca+-+remix
# <Response [200]>
# Pop Latino
# 78
# reik+indeciso
# <Response [200]>
# Urbano latino
# 79
# daddy+yankee+si+supieras
# <Response [200]>
# Urbano latino
# 80
# lil+tecca+ransom
# <Response [200]>
# Hip-Hop/Rap
# 81
# sech+boomerang
# <Response [200]>
# Urbano latino
# 82
# rosalía+aute+cuture
# <Response [200]>
# Pop
# 83
# bizarrap+nicki+nicole:+bzrp+music+sessions,+vol.+13
# <Response [200]>
# Hip-Hop/Rap
# 84
# cupido+autoestima+
# <Response [200]>
# Pop Latino
# 85
# myke+towers+si+se+da
# <Response [200]>
# Urbano latino
# 86
# reik+aleluya
# <Response [200]>
# Pop Latino
# 87
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 88
# beret+me+llama
# <Response [200]>
# Pop
# 89
# sebastian+yatra+un+año
# <Response [200]>
# Pop Latino
# 90
# aitana+nada+sale+mal
# <Response [200]>
# Pop
# 91
# rosalía+malamente+-+cap.1:+augurio
# <Response [200]>
# Pop
# 92
# justin+quiles+que+mas+pues+-+remix
# <Response [200]>
# Urbano latino
# 93
# alejandro+sanz+mi+persona+favorita
# <Response [200]>
# Pop Latino
# 94
# lil+nas+x+old+town+road+-+remix
# <Response [200]>
# Country
# 95
# piso+21+una+vida+para+recordar
# <Response [200]>
# Pop Latino
# 96
# residente+bellacoso
# <Response [200]>
# Urbano latino
# 97
# karol+g+ocean
# <Response [200]>
# Urbano latino
# 98
# paulo+londra+adan+y+eva
# <Response [200]>
# Urbano latino
# 99
# miki+núñez+celébrate
# <Response [200]>
# Pop
# 100
# natalia+lacunza+nana+triste
# <Response [200]>
# Pop
# 101
# anuel+aa+amanece
# <Response [200]>
# Urbano latino
# 102
# dimitri+vegas+&+like+mike+instagram
# <Response [200]>
# Electronic
# 103
# lola+indigo+maldición
# <Response [200]>
# Pop
# 104
# lady+gaga+shallow
# <Response [200]>
# Soundtrack
# 105
# anuel+aa+ella+quiere+beber+-+remix
# <Response [200]>
# Urbano latino
# 106
# ozuna+amor+genuino
# <Response [200]>
# Urbano latino
# 107
# aitana+con+la+miel+en+los+labios
# <Response [200]>
# Pop
# 108
# ozuna+baila+baila+baila
# <Response [200]>
# Urbano latino
# 109
# ozuna+muito+calor
# <Response [200]>
# Urbano latino
# 110
# ozuna+baila+baila+baila+-+remix
# <Response [200]>
# Urbano latino
# 111
# anuel+aa+secreto
# <Response [200]>
# Urbano latino
# 112
# mambo+kingz+tú+no+amas
# <Response [200]>
# Urbano latino
# 113
# ozuna+cambio
# <Response [200]>
# Urbano latino
# 114
# becky+g+la+respuesta
# <Response [200]>
# Urbano latino
# 115
# leiva+no+te+preocupes+por+mi
# <Response [200]>
# Pop
# 116
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 117
# aitana+vas+a+quedarte
# <Response [200]>
# Pop
# 118
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 119
# fito+y+fitipaldis+soldadito+marinero
# <Response [200]>
# Rock y Alternativo
# 120
# beret+te+echo+de+menos
# <Response [200]>
# Pop
# 121
# juan+magán+sobrenatural
# <Response [200]>
# Pop
# 122
# dani+fernández+disparos
# <Response [200]>
# Pop
# 123
# prince+royce+cúrame+
# <Response [200]>
# Urbano latino
# 124
# dani+fernández+te+esperaré+toda+la+vida
# <Response [200]>
# Pop
# 125
# dvicio+qué+tienes+tú+
# <Response [200]>
# Pop
# 126
# pereza+princesas
# <Response [200]>
# Rock y Alternativo
# 127
# cazzu+nada
# <Response [200]>
# Urbano latino
# 128
# morat+cuando+nadie+ve
# <Response [200]>
# Pop
# 129
# israel+b+yyanosé
# <Response [200]>
# Hip-Hop
# 130
# estopa+fuego
# <Response [200]>
# Pop
# 131
# melendi+déjala+que+baile+
# <Response [200]>
# Pop Latino
# 132
# paulo+londra+por+eso+vine
# <Response [200]>
# Urbano latino
# 133
# sam+smith+how+do+you+sleep?
# <Response [200]>
# Pop
# 134
# demarco+flamenco+pa+ti+pa+mí+na+má
# <Response [200]>
# Iberia
# 135
# maluma+no+se+me+quita+
# <Response [200]>
# Urbano latino
# 136
# bandaga+como+tu
# <Response [200]>
# Latino
# 137
# kidd+keo+serpiente+veneno+
# <Response [200]>
# Urbano latino
# 138
# reykon+latina+
# <Response [200]>
# Latino
# 139
# becky+g+sin+pijama
# <Response [200]>
# Urbano latino
# 140
# rvfv+apriétala
# <Response [200]>
# Latin Rap
# 141
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 142
# wisin+&+yandel+aullando
# <Response [200]>
# Urbano latino
# 143
# ozuna+vaina+loca
# <Response [200]>
# Urbano latino
# 144
# beret+lo+siento
# <Response [200]>
# Pop
# 145
# yandel+en+cero
# <Response [200]>
# Urbano latino
# 146
# post+malone+circles
# <Response [200]>
# House
# 147
# maka+vida
# <Response [200]>
# Worldwide
# 148
# sebastian+yatra+cristina
# <Response [200]>
# Pop Latino
# 149
# david+bisbal+perdón
# <Response [200]>
# Pop
# 150
# bombai+vuela
# <Response [200]>
# Pop
# 151
# guitarricadelafuente+guantanamera
# <Response [200]>
# Alternative
# 152
# lola+indigo+mujer+bruja
# <Response [200]>
# Pop
# 153
# estopa+como+camarón
# <Response [200]>
# Pop Latino
# 154
# nil+moliner+mi+religión
# <Response [200]>
# Pop
# 155
# morat+besos+en+guerra
# <Response [200]>
# Pop
# 156
# rauw+alejandro+el+efecto
# <Response [200]>
# Urbano latino
# 157
# bryant+myers+bandolera
# <Response [200]>
# Urbano latino
# 158
# guitarricadelafuente+abc
# <Response [200]>
# Alternative Folk
# 159
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 160
# luis+fonsi+imposible
# <Response [200]>
# Pop Latino
# 161
# aitana+teléfono
# <Response [200]>
# Pop
# 162
# leiva+como+si+fueras+a+morir+mañana
# <Response [200]>
# Pop
# 163
# camela+cuando+zarpa+el+amor+
# <Response [200]>
# Pop
# 164
# karol+g+punto+g
# <Response [200]>
# Urbano latino
# 165
# mya+te+olvidaré
# <Response [200]>
# Pop Latino
# 166
# lola+indigo+ya+no+quiero+ná
# <Response [200]>
# Pop
# 167
# rauw+alejandro+fantasias
# <Response [200]>
# Urbano latino
# 168
# rvfv+prendío
# <Response [200]>
# Urbano latino
# 169
# keen+levy+borracho+&+loco
# <Response [200]>
# Flamenco
# 170
# david+bisbal+a+partir+de+hoy
# <Response [200]>
# Pop
# 171
# las+chuches+como+ronea+
# <Response [200]>
# Flamenco
# 172
# c.+tangana+antes+de+morirme+
# <Response [200]>
# Pop
# 173
# post+malone+goodbyes+
# <Response [200]>
# Hip-Hop/Rap
# 174
# dvicio+brasilera
# <Response [200]>
# Pop
# 175
# justin+quiles+otra+vez
# <Response [200]>
# Urbano latino
# 176
# pol+granch+te+quiodio
# <Response [200]>
# Pop
# 177
# queen+bohemian+rhapsody+-+2011+mix
# <Response [200]>
# Rock
# 178
# taburete+sirenas
# <Response [200]>
# Pop
# 179
# nacho+mona+lisa
# <Response [200]>
# Urbano latino
# 180
# juan+magán+usted
# <Response [200]>
# Dance
# 181
# rosalía+pienso+en+tu+mirá+-+cap.3:+celos
# <Response [200]>
# Pop
# 182
# manuel+turizo+esclavo+de+tus+besos
# <Response [200]>
# Urbano latino
# 183
# bandaga+otra+copa
# <Response [200]>
# Urbano latino
# 184
# mau+y+ricky+desconocidos
# <Response [200]>
# Pop Latino
# 185
# maldita+nerea+un+planeta+llamado+nosotros
# <Response [200]>
# Pop
# 186
# manuel+carrasco+déjame+ser
# <Response [200]>
# Pop
# 187
# arnau+griso+quiero,+quiero+y+quiero
# <Response [200]>
# Pop
# 188
# natos+y+waor+cicatrices
# <Response [200]>
# Hip-Hop/Rap
# 189
# mau+y+ricky+la+boca
# <Response [200]>
# Pop Latino
# 190
# juancho+marqués+benicàssim+
# <Response [200]>
# Urbano latino
# 191
# kevin+roldan+hasta+abajo
# <Response [200]>
# Urbano latino
# 192
# rels+b+mejor+no+nos+vemos
# <Response [200]>
# Urbano latino
# 193
# bad+bunny+mia+
# <Response [200]>
# Latino
# 194
# taylor+swift+lover
# <Response [200]>
# Country
# 195
# dj+snake+taki+taki+
# <Response [200]>
# Dance
# 196
# bryant+myers+ganas+sobran
# <Response [200]>
# Urbano latino
# 197
# eklectico+nota+loca+-+remix
# <Response [200]>
# Latino
# 198
# daddy+yankee+adictiva
# <Response [200]>
# Urbano latino
# 199
# es_2019-09-06--2019-09-13.csv
# anuel+aa+china
# <Response [200]>
# Urbano latino
# 0
# rosalía+yo+x+ti,+tu+x+mi
# <Response [200]>
# Latino
# 1
# tainy+adicto+
# <Response [200]>
# Latino
# 2
# duki+goteo
# <Response [200]>
# Hip-Hop/Rap
# 3
# danny+romero+de+tranquilote
# <Response [200]>
# Latino
# 4
# sech+otro+trago+-+remix
# <Response [200]>
# Latino
# 5
# bad+bunny+callaita
# <Response [200]>
# Urbano latino
# 6
# la+nueva+escuela+la+rubia+-+remix+2
# <Response [200]>
# Urbano latino
# 7
# jhay+cortez+no+me+conoce+-+remix
# <Response [200]>
# Urbano latino
# 8
# manuel+turizo+te+quemaste
# <Response [200]>
# Urbano latino
# 9
# chris+viz+diavla
# <Response [200]>
# Urbano latino
# 10
# j+balvin+la+canción
# <Response [200]>
# Urbano latino
# 11
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 12
# lunay+soltera+
# <Response [200]>
# Urbano latino
# 13
# camilo+tutu
# <Response [200]>
# Urbano latino
# 14
# lola+indigo+lola+bunny
# <Response [200]>
# Pop Latino
# 15
# j+balvin+que+pretendes
# <Response [200]>
# Urbano latino
# 16
# darell+velitas
# <Response [200]>
# Urbano latino
# 17
# don+patricio+contando+lunares+
# <Response [200]>
# Urbano latino
# 18
# bryant+myers+gan-ga
# <Response [200]>
# Urbano latino
# 19
# dayvi+baila+conmigo+
# <Response [200]>
# Pop Latino
# 20
# dj+snake+loco+contigo+
# <Response [200]>
# Latino
# 21
# becky+g+dollar
# <Response [200]>
# Pop Latino
# 22
# sinsinati+indios+y+vaqueros
# <Response [200]>
# Pop
# 23
# $kyhook+a+escondidas
# <Response [200]>
# Pop
# 24
# jhay+cortez+easy
# <Response [200]>
# Urbano latino
# 25
# myke+towers+si+se+da+-+remix
# <Response [200]>
# Urbano latino
# 26
# rosalía+con+altura
# <Response [200]>
# Pop
# 27
# maluma+11+pm
# <Response [200]>
# Urbano latino
# 28
# dímelo+flow+el+favor+
# <Response [200]>
# Urbano latino
# 29
# rvfv+mirándote
# <Response [200]>
# Latin Rap
# 30
# david+bisbal+bésame
# <Response [200]>
# Pop
# 31
# guaynaa+rebota+-+remix
# <Response [200]>
# Urbano latino
# 32
# y2k+lalala
# <Response [200]>
# Hip-Hop/Rap
# 33
# noriel+cuerpo+en+venta
# <Response [200]>
# Latino
# 34
# myke+towers+inocente
# <Response [200]>
# Música tropical
# 35
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 36
# dalex+cuaderno
# <Response [200]>
# Urbano latino
# 37
# maffio+cristina+
# <Response [200]>
# Urbano latino
# 38
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 39
# casper+magico+no+te+veo+-+remix
# <Response [200]>
# Urbano latino
# 40
# ozuna+te+soñé+de+nuevo
# <Response [200]>
# Urbano latino
# 41
# ceky+viciny+ellos
# <Response [200]>
# Dance
# 42
# rosalía+milionària
# <Response [200]>
# Pop
# 43
# wos+canguro
# <Response [200]>
# Hip-Hop/Rap
# 44
# mahmood+soldi+
# <Response [200]>
# Pop
# 45
# bad+gyal+santa+maría+
# <Response [200]>
# Pop Latino
# 46
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 47
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 48
# maître+gims+hola+señorita
# <Response [200]>
# Urbano latino
# 49
# dj+luian+verte+ir
# <Response [200]>
# Urbano latino
# 50
# nicky+jam+atrévete
# <Response [200]>
# Urbano latino
# 51
# sergio+contreras+cicatrices+
# <Response [200]>
# Pop
# 52
# nicky+jam+te+robaré
# <Response [200]>
# Urbano latino
# 53
# rauw+alejandro+fantasias
# <Response [200]>
# Urbano latino
# 54
# rels+b+¿cómo+te+va,+querida?
# <Response [200]>
# Pop
# 55
# lalo+ebratt+déjate+querer
# <Response [200]>
# Urbano latino
# 56
# paulo+londra+tal+vez
# <Response [200]>
# Latino
# 57
# aitana+me+quedo
# <Response [200]>
# Pop
# 58
# morat+presiento
# <Response [200]>
# Pop
# 59
# don+patricio+enchochado+de+ti
# <Response [200]>
# Urbano latino
# 60
# danny+ocean+swing
# <Response [200]>
# Pop Latino
# 61
# manuel+carrasco+qué+bonito+es+querer
# <Response [200]>
# Pop
# 62
# juanfran+mi+morena
# <Response [200]>
# Urbano latino
# 63
# sebastian+yatra+runaway
# <Response [200]>
# Pop Latino
# 64
# nil+moliner+soldadito+de+hierro
# <Response [200]>
# Pop
# 65
# bad+gyal+hookah
# <Response [200]>
# Pop Latino
# 66
# justin+quiles+dj+no+pare+
# <Response [200]>
# Urbano latino
# 67
# maluma+hp
# <Response [200]>
# Urbano latino
# 68
# nio+garcia+mírame+-+remix
# <Response [200]>
# Urbano latino
# 69
# reik+indeciso
# <Response [200]>
# Urbano latino
# 70
# j+balvin+mojaita
# <Response [200]>
# Urbano latino
# 71
# lil+tecca+ransom
# <Response [200]>
# Hip-Hop/Rap
# 72
# dalex+pa+mí+-+remix
# <Response [200]>
# Urbano latino
# 73
# sech+otro+trago
# <Response [200]>
# Latino
# 74
# farruko+delincuente
# <Response [200]>
# Urbano latino
# 75
# eladio+carrion+kemba+walker
# <Response [200]>
# Urbano latino
# 76
# luis+fonsi+date+la+vuelta
# <Response [200]>
# Pop Latino
# 77
# bizarrap+trueno:+bzrp+freestyle+sessions,+vol.+6
# <Response [200]>
# Latin Rap
# 78
# dvicio+5+sentidos
# <Response [200]>
# Pop
# 79
# mau+y+ricky+la+boca+-+remix
# <Response [200]>
# Pop Latino
# 80
# sean+paul+contra+la+pared
# <Response [200]>
# Urbano latino
# 81
# myke+towers+la+playa
# <Response [200]>
# Urbano latino
# 82
# sech+boomerang
# <Response [200]>
# Urbano latino
# 83
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 84
# bizarrap+nicki+nicole:+bzrp+music+sessions,+vol.+13
# <Response [200]>
# Hip-Hop/Rap
# 85
# beret+me+llama
# <Response [200]>
# Pop
# 86
# rvfv+apriétala
# <Response [200]>
# Latin Rap
# 87
# aitana+nada+sale+mal
# <Response [200]>
# Pop
# 88
# alejandro+sanz+mi+persona+favorita
# <Response [200]>
# Pop Latino
# 89
# post+malone+circles
# <Response [200]>
# House
# 90
# myke+towers+si+se+da
# <Response [200]>
# Urbano latino
# 91
# daddy+yankee+si+supieras
# <Response [200]>
# Urbano latino
# 92
# reik+aleluya
# <Response [200]>
# Pop Latino
# 93
# sebastian+yatra+un+año
# <Response [200]>
# Pop Latino
# 94
# miki+núñez+celébrate
# <Response [200]>
# Pop
# 95
# israel+b+yyanosé
# <Response [200]>
# Hip-Hop
# 96
# rosalía+aute+cuture
# ...
# <Response [200]>
# Pop
# 134
# sean+paul+contra+la+pared
# <Response [200]>
# Urbano latino
# 135
# anuel+aa+ella+quiere+beber+-+remix
# <Response [200]>
# Urbano latino
# 136
# alejandro+sanz+mi+persona+favorita
# <Response [200]>
# Pop Latino
# 137
# miki+núñez+celébrate
# <Response [200]>
# Pop
# 138
# nio+garcia+mírame+-+remix
# <Response [200]>
# Urbano latino
# 139
# leiva+como+si+fueras+a+morir+mañana
# <Response [200]>
# Pop
# 140
# selena+gomez+lose+you+to+love+me
# <Response [200]>
# Pop
# 141
# becky+g+mala+santa
# <Response [200]>
# Pop Latino
# 142
# pereza+princesas
# <Response [200]>
# Rock y Alternativo
# 143
# reik+aleluya
# <Response [200]>
# Pop Latino
# 144
# bizarrap+nicki+nicole:+bzrp+music+sessions,+vol.+13
# <Response [200]>
# Hip-Hop/Rap
# 145
# estopa+corazón+sin+salida
# <Response [200]>
# Pop
# 146
# anuel+aa+amanece
# <Response [200]>
# Urbano latino
# 147
# manuel+turizo+bailemos
# <Response [200]>
# Urbano latino
# 148
# maldita+nerea+un+planeta+llamado+nosotros
# <Response [200]>
# Pop
# 149
# paulo+londra+party+
# <Response [200]>
# Pop Latino
# 150
# natos+y+waor+tranquilito
# <Response [200]>
# Hip-Hop/Rap
# 151
# maka+vida
# <Response [200]>
# Worldwide
# 152
# guitarricadelafuente+guantanamera
# <Response [200]>
# Alternative
# 153
# nil+moliner+mi+religión
# <Response [200]>
# Pop
# 154
# camilo+tutu+-+remix
# <Response [200]>
# Urbano latino
# 155
# melendi+déjala+que+baile+
# <Response [200]>
# Pop Latino
# 156
# lil+nas+x+old+town+road+-+remix
# <Response [200]>
# Country
# 157
# bombai+vuela
# <Response [200]>
# Pop
# 158
# maluma+no+se+me+quita+
# <Response [200]>
# Urbano latino
# 159
# leiva+superpoderes
# <Response [200]>
# Pop in Spanish
# 160
# sebastian+yatra+cristina
# <Response [200]>
# Pop Latino
# 161
# natti+natasha+la+mejor+versión+de+mi+-+remix
# <Response [200]>
# Urbano latino
# 162
# dvicio+qué+tienes+tú+
# <Response [200]>
# Pop
# 163
# estopa+como+camarón
# <Response [200]>
# Pop Latino
# 164
# morat+cuando+nadie+ve
# <Response [200]>
# Pop
# 165
# melendi+el+ciego
# <Response [200]>
# Pop Latino
# 166
# juan+magán+sobrenatural
# <Response [200]>
# Pop
# 167
# myke+towers+si+se+da
# <Response [200]>
# Urbano latino
# 168
# farruko+delincuente
# <Response [200]>
# Urbano latino
# 169
# dimitri+vegas+&+like+mike+instagram
# <Response [200]>
# Electronic
# 170
# rosalía+malamente+-+cap.1:+augurio
# <Response [200]>
# Pop
# 171
# rich+music+ltd+uniforme
# <Response [200]>
# Urbano latino
# 172
# anuel+aa+secreto
# <Response [200]>
# Urbano latino
# 173
# ozuna+baila+baila+baila+-+remix
# <Response [200]>
# Urbano latino
# 174
# las+chuches+como+ronea+
# <Response [200]>
# Flamenco
# 175
# fernandocosta+pa+que+lo+gocen
# <Response [200]>
# becky+g+sin+pijama
# <Response [200]>
# Urbano latino
# 177
# aitana+nada+sale+mal
# <Response [200]>
# Pop
# 178
# meduza+piece+of+your+heart
# <Response [200]>
# Dance
# 179
# arnau+griso+quiero,+quiero+y+quiero
# <Response [200]>
# Pop
# 180
# piso+21+una+vida+para+recordar
# <Response [200]>
# Pop Latino
# 181
# mahmood+soldi+
# <Response [200]>
# Pop
# 182
# juanfran+mi+morena
# <Response [200]>
# Urbano latino
# 183
# yera+mejores+amigos
# <Response [200]>
# Pop Latino
# 184
# mabel+dont+call+me+up
# <Response [200]>
# Pop
# 185
# bizarrap+aleman:+bzrp+music+sessions,+vol.+15
# <Response [200]>
# Latin Rap
# 186
# blas+cantó+si+te+vas
# <Response [200]>
# Pop
# 187
# morad+profesores
# <Response [200]>
# Urbano latino
# 188
# c.+tangana+antes+de+morirme+
# <Response [200]>
# Pop
# 189
# demarco+flamenco+pa+ti+pa+mí+na+má
# <Response [200]>
# Iberia
# 190
# camela+cuando+zarpa+el+amor+
# <Response [200]>
# Pop
# 191
# beret+lo+siento+
# <Response [200]>
# Pop
# 192
# daddy+yankee+si+supieras
# <Response [200]>
# Urbano latino
# 193
# jonas+brothers+sucker
# <Response [200]>
# Pop
# 194
# maître+gims+hola+señorita
# <Response [200]>
# Urbano latino
# 195
# juancho+marqués+ibiza+
# <Response [200]>
# Hip-Hop
# 196
# morat+besos+en+guerra
# <Response [200]>
# Pop
# 197
# becky+g+24/7
# <Response [200]>
# Pop Latino
# 198
# rels+b+mejor+no+nos+vemos
# <Response [200]>
# Urbano latino
# 199
# es_2019-10-25--2019-11-01.csv
# omar+montes+alocao+
# <Response [200]>
# Urbano latino
# 0
# anuel+aa+china
# <Response [200]>
# Urbano latino
# 1
# black+eyed+peas+ritmo+
# <Response [200]>
# Pop
# 2
# rauw+alejandro+fantasias
# <Response [200]>
# Urbano latino
# 3
# tainy+adicto+
# <Response [200]>
# Latino
# 4
# manuel+turizo+te+quemaste
# <Response [200]>
# Urbano latino
# 5
# beret+si+por+mi+fuera
# <Response [200]>
# Pop
# 6
# rosalía+yo+x+ti,+tu+x+mi
# <Response [200]>
# Latino
# 7
# reik+indeciso
# <Response [200]>
# Urbano latino
# 8
# sech+si+te+vas
# <Response [200]>
# Latino
# 9
# la+nueva+escuela+la+rubia+-+remix+2
# <Response [200]>
# Urbano latino
# 10
# lunay+aventura
# <Response [200]>
# Urbano latino
# 11
# duki+goteo
# <Response [200]>
# Hip-Hop/Rap
# 12
# tones+and+i+dance+monkey
# <Response [200]>
# Alternative
# 13
# rvfv+prendío
# <Response [200]>
# Urbano latino
# 14
# justin+quiles+dj+no+pare+
# <Response [200]>
# Urbano latino
# 15
# danny+romero+de+tranquilote
# <Response [200]>
# Latino
# 16
# jhay+cortez+easy
# <Response [200]>
# Urbano latino
# 17
# chimbala+rueda
# <Response [200]>
# Latino
# 18
# c.+tangana+no+te+debí+besar
# <Response [200]>
# Urbano latino
# 19
# major+lazer+que+calor+
# <Response [200]>
# Urbano latino
# 20
# rich+music+ltd+quizas
# <Response [200]>
# Urbano latino
# 21
# lunay+la+cama
# <Response [200]>
# Urbano latino
# 22
# camilo+tutu
# <Response [200]>
# Urbano latino
# 23
# jhay+cortez+no+me+conoce+-+remix
# <Response [200]>
# Urbano latino
# 24
# beret+sueño+
# <Response [200]>
# Pop
# 25
# sech+otro+trago+-+remix
# <Response [200]>
# Latino
# 26
# bad+bunny+callaita
# <Response [200]>
# Urbano latino
# 27
# noriel+cuerpo+en+venta
# <Response [200]>
# Latino
# 28
# selena+gomez+lose+you+to+love+me
# <Response [200]>
# Pop
# 29
# rvssian+b11+
# <Response [200]>
# Urbano latino
# 30
# $kyhook+a+escondidas
# <Response [200]>
# Pop
# 31
# beret+me+vas+a+ver
# <Response [200]>
# Pop
# 32
# kevvo+105+f+remix
# <Response [200]>
# Urbano latino
# 33
# maluma+qué+pena
# <Response [200]>
# Urbano latino
# 34
# sinsinati+indios+y+vaqueros
# <Response [200]>
# Pop
# 35
# don+patricio+contando+lunares+
# <Response [200]>
# Urbano latino
# 36
# daddy+yankee+que+tire+pa+lante
# <Response [200]>
# Urbano latino
# 37
# shawn+mendes+señorita
# <Response [200]>
# Pop
# 38
# israel+b+yyanosé
# <Response [200]>
# Hip-Hop
# 39
# j+balvin+la+canción
# <Response [200]>
# Urbano latino
# 40
# chris+viz+diavla
# <Response [200]>
# Urbano latino
# 41
# aya+nakamura+djadja
# <Response [200]>
# R&B/Soul
# 42
# bryant+myers+gan-ga
# <Response [200]>
# Urbano latino
# 43
# lunay+soltera+-+remix
# <Response [200]>
# Urbano latino
# 44
# beret+desde+cero+
# <Response [200]>
# Pop
# 45
# haze+piensan
# <Response [200]>
# rvfv+apriétala
# <Response [200]>
# Latin Rap
# 47
# beret+me+llama
# <Response [200]>
# Pop
# 48
# lola+indigo+lola+bunny
# <Response [200]>
# Pop Latino
# 49
# bad+gyal+hookah
# <Response [200]>
# Pop Latino
# 50
# dímelo+flow+el+favor+
# <Response [200]>
# Urbano latino
# 51
# darell+velitas
# <Response [200]>
# Urbano latino
# 52
# rels+b+sin+mirar+las+señales
# <Response [200]>
# R&B/Soul
# 53
# rels+b+la+latina
# <Response [200]>
# R&B/Soul
# 54
# myke+towers+si+se+da+-+remix
# <Response [200]>
# Urbano latino
# 55
# manuel+carrasco+qué+bonito+es+querer
# <Response [200]>
# Pop
# 56
# rosalía+con+altura
# <Response [200]>
# Pop
# 57
# j+balvin+que+pretendes
# <Response [200]>
# Urbano latino
# 58
# nicky+jam+atrévete
# <Response [200]>
# Urbano latino
# 59
# antonio+josé+me+equivocaré
# <Response [200]>
# Pop Latino
# 60
# david+bisbal+bésame
# <Response [200]>
# Pop
# 61
# beret+lo+siento
# <Response [200]>
# Pop
# 62
# rvfv+mirándote
# <Response [200]>
# Latin Rap
# 63
# farruko+nadie+
# <Response [200]>
# Urbano latino
# 64
# morat+presiento
# <Response [200]>
# Pop
# 65
# casper+magico+no+te+veo+-+remix
# <Response [200]>
# Urbano latino
# 66
# maluma+11+pm
# <Response [200]>
# Urbano latino
# 67
# dayvi+baila+conmigo+
# <Response [200]>
# Pop Latino
# 68
# beret+prisma
# <Response [200]>
# Pop
# 69
# dj+snake+loco+contigo+
# <Response [200]>
# Latino
# 70
# lewis+capaldi+someone+you+loved
# <Response [200]>
# Alternative
# 71
# billie+eilish+bad+guy
# <Response [200]>
# Alternative
# 72
# ed+sheeran+i+dont+care+
# <Response [200]>
# Pop
# 73
# daddy+yankee+con+calma
# <Response [200]>
# Urbano latino
# 74
# beret+te+echo+de+menos
# <Response [200]>
# Pop
# 75
# nil+moliner+soldadito+de+hierro
# <Response [200]>
# Pop
# 76
# bizarrap+trueno:+bzrp+music+sessions,+vol.+16
# <Response [200]>
# Latin Rap
# 77
# pedro+capó+calma+-+remix
# <Response [200]>
# Pop Latino
# 78
# maroon+5+memories
# <Response [200]>
# Pop
# 79
# juanes+bonita
# <Response [200]>
# Pop Latino
# 80
# sergio+contreras+cicatrices+
# <Response [200]>
# Pop
# 81
# myke+towers+inocente
# <Response [200]>
# Música tropical
# 82
# estopa+fuego
# <Response [200]>
# Pop
# 83
# guaynaa+rebota+-+remix
# <Response [200]>
# Urbano latino
# 84
# nicky+jam+te+robaré
# <Response [200]>
# Urbano latino
# 85
# lalo+ebratt+déjate+querer
# <Response [200]>
# Urbano latino
# 86
# dani+fernández+disparos
# <Response [200]>
# Pop
# 87
# aitana+me+quedo
# <Response [200]>
# Pop
# 88
# beret+me+mata
# <Response [200]>
# Pop
# 89
# travis+scott+highest+in+the+room
# <Response [200]>
# Hip-Hop/Rap
# 90
# rels+b+otro+cheke
# <Response [200]>
# R&B/Soul
# 91
# nicky+jam+whine+up
# <Response [200]>
# Urbano latino
# 92
# post+malone+circles
# <Response [200]>
# House
# 93
# rosalía+milionària
# <Response [200]>
# Pop
# 94
# dj+luian+verte+ir
# <Response [200]>
# Urbano latino
# 95
# don+patricio+enchochado+de+ti
# <Response [200]>
# Urbano latino
# 96
# becky+g+dollar
# <Response [200]>
# Pop Latino
# 97
# ed+sheeran+beautiful+people+
# <Response [200]>
# Pop
# 98
# selena+gomez+look+at+her+now
# <Response [200]>
# Pop
# 99
# y2k+lalala
# <Response [200]>
# Hip-Hop/Rap
# 100
# maffio+cristina+
# <Response [200]>
# Urbano latino
# 101
# dalex+bellaquita
# <Response [200]>
# Urbano latino
# 102
# bad+gyal+santa+maría+
# <Response [200]>
# Pop Latino
# 103
# dalex+cuaderno
# <Response [200]>
# Urbano latino
# 104
# eladio+carrion+kemba+walker
# <Response [200]>
# Urbano latino
# 105
# alba+reche+caronte
# <Response [200]>
# Pop Latino
# 106
# dvicio+5+sentidos
# <Response [200]>
# Pop
# 107
# danny+ocean+swing
# <Response [200]>
# Pop Latino
# 108
# camila+cabello+liar
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [WinError 10060] Impossibile stabilire la connessione. Risposta non corretta della parte connessa dopo l'intervallo di tempo oppure mancata risposta dall'host collegato
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\connection.py in connect(self)
#     299         # Add certificate verification
# --> 300         conn = self._new_conn()
#     301         hostname = self.host
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e
#     170             )
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x000002C8BB600BC8>: Failed to establish a new connection: [WinError 10060] Impossibile stabilire la connessione. Risposta non corretta della parte connessa dopo l'intervallo di tempo oppure mancata risposta dall'host collegato
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='itunes.apple.com', port=443): Max retries exceeded with url: /search?term=camila+cabello+liar&limit=1 (Caused by NewConnectionError("<urllib3.connection.VerifiedHTTPSConnection object at 0x000002C8BB600BC8>: Failed to establish a new connection: [WinError 10060] Impossibile stabilire la connessione. Risposta non corretta della parte connessa dopo l'intervallo di tempo oppure mancata risposta dall'host collegato"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-18-7bf2b3721766> in <module>
#      39             print(query_entry)
#      40             a = 'https://itunes.apple.com/search?term='+query_entry+'&limit=1'
# ---> 41             test = requests.get(a)
#      42             print(test)
#      43             b = test.json()
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='itunes.apple.com', port=443): Max retries exceeded with url: /search?term=camila+cabello+liar&limit=1 (Caused by NewConnectionError("<urllib3.connection.VerifiedHTTPSConnection object at 0x000002C8BB600BC8>: Failed to establish a new connection: [WinError 10060] Impossibile stabilire la connessione. Risposta non corretta della parte connessa dopo l'intervallo di tempo oppure mancata risposta dall'host collegato"))

# %%
string = 'sia+helium+-+from+"fifty+shades+darker+'
string=string.replace('"', "")
print(string)
# Out:
# sia+helium+-+from+fifty+shades+darker+
