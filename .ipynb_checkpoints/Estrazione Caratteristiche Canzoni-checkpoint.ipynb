# %%
import pandas as pd
import spotipy
#from fycharts.SpotifyCharts import SpotifyCharts
from spotipy.oauth2 import SpotifyClientCredentials

# %%
df = pd.read_csv('global_2020-07-24--2020-07-31.csv')

# %%
df
# Out:
#     Unnamed: 0                        Unnamed: 1           Unnamed: 2  \
# 0     Position                        Track Name               Artist
# 1            1                          cardigan         Taylor Swift
# 2            2      ROCKSTAR (feat. Roddy Ricch)               DaBaby
# 3            3  Savage Love (Laxed - Siren Beat)            Jawsh 685
# 4            4            exile (feat. Bon Iver)         Taylor Swift
# ..         ...                               ...                  ...
# 196        196                       Hit My Line                Logic
# 197        197                        Youngblood  5 Seconds of Summer
# 198        198     Get You The Moon (feat. Snøw)                 Kina
# 199        199        The Less I Know The Better          Tame Impala
# 200        200                        Como Llora             Juanfran
#
#     Note that these figures are generated using a formula that protects against any artificial inflation of chart positions.  \
# 0                                              Streams
# 1                                             35783009
# 2                                             33271598
# 3                                             32819332
# 4                                             30941803
# ..                                                 ...
# 196                                            4621205
# 197                                            4601526
# 198                                            4586506
# 199                                            4585170
# 200                                            4579773
#
#                                             Unnamed: 4
# 0                                                  URL
# 1    https://open.spotify.com/track/4R2kfaDFhslZEMJ...
# 2    https://open.spotify.com/track/7ytR5pFWmSjzHJI...
# 3    https://open.spotify.com/track/1xQ6trAsedVPCdb...
# 4    https://open.spotify.com/track/4pvb0WLRcMtbPGm...
# ..                                                 ...
# 196  https://open.spotify.com/track/24FR8mXTaiGZPrx...
# 197  https://open.spotify.com/track/2iUXsYOEPhVqEBw...
# 198  https://open.spotify.com/track/4ZLzoOkj0MPWrTL...
# 199  https://open.spotify.com/track/6K4t31amVTZDgR3...
# 200  https://open.spotify.com/track/52zq2a71SGs3f1v...
#
# [201 rows x 5 columns]

# %%
df.columns = df.iloc[0]

# %%
df = df.iloc[1:].reset_index()

# %%
df.URL.astype('str')
# Out:
# 0      https://open.spotify.com/track/4R2kfaDFhslZEMJ...
# 1      https://open.spotify.com/track/7ytR5pFWmSjzHJI...
# 2      https://open.spotify.com/track/1xQ6trAsedVPCdb...
# 3      https://open.spotify.com/track/4pvb0WLRcMtbPGm...
# 4      https://open.spotify.com/track/0Jlcvv8IykzHaSm...
#                              ...
# 195    https://open.spotify.com/track/24FR8mXTaiGZPrx...
# 196    https://open.spotify.com/track/2iUXsYOEPhVqEBw...
# 197    https://open.spotify.com/track/4ZLzoOkj0MPWrTL...
# 198    https://open.spotify.com/track/6K4t31amVTZDgR3...
# 199    https://open.spotify.com/track/52zq2a71SGs3f1v...
# Name: URL, Length: 200, dtype: object

# %%
df.URL = df.URL.apply(lambda x : x[31:])

# %%
df.rename(columns={'URL':'ID'}, inplace=True)

# %%
df
# Out:
# 0    index Position                        Track Name               Artist  \
# 0        1        1                          cardigan         Taylor Swift
# 1        2        2      ROCKSTAR (feat. Roddy Ricch)               DaBaby
# 2        3        3  Savage Love (Laxed - Siren Beat)            Jawsh 685
# 3        4        4            exile (feat. Bon Iver)         Taylor Swift
# 4        5        5                             the 1         Taylor Swift
# ..     ...      ...                               ...                  ...
# 195    196      196                       Hit My Line                Logic
# 196    197      197                        Youngblood  5 Seconds of Summer
# 197    198      198     Get You The Moon (feat. Snøw)                 Kina
# 198    199      199        The Less I Know The Better          Tame Impala
# 199    200      200                        Como Llora             Juanfran
#
# 0     Streams                      ID
# 0    35783009  4R2kfaDFhslZEMJqAFNpdd
# 1    33271598  7ytR5pFWmSjzHJIeQkgog4
# 2    32819332  1xQ6trAsedVPCdbtDAmk0c
# 3    30941803  4pvb0WLRcMtbPGmtejJJ6y
# 4    29021470  0Jlcvv8IykzHaSmj49uNW8
# ..        ...                     ...
# 195   4621205  24FR8mXTaiGZPrxnkf1kcP
# 196   4601526  2iUXsYOEPhVqEBwsqP70rE
# 197   4586506  4ZLzoOkj0MPWrTLvooIuaa
# 198   4585170  6K4t31amVTZDgR3sKmwUJJ
# 199   4579773  52zq2a71SGs3f1vJuv59ui
#
# [200 rows x 6 columns]

# %%
credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
token = credentials.get_access_token()

spotify = spotipy.Spotify(auth=token)

features = spotify.audio_features(str(df['ID'].iloc[0]))
# Out:
# /Users/Antonio/OneDrive - Politecnico di Milano/Università_Magistrale/Materiale_Corsi/II_Anno/Data_Viz/env/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.

# %%
features
# Out:
# [{'danceability': 0.543,
#   'energy': 0.677,
#   'key': 11,
#   'loudness': -4.915,
#   'mode': 0,
#   'speechiness': 0.0993,
#   'acousticness': 0.0148,
#   'instrumentalness': 6.21e-06,
#   'liveness': 0.13,
#   'valence': 0.294,
#   'tempo': 103.809,
#   'type': 'audio_features',
#   'id': '2rb5MvYT7ZIxbKW5hfcHx8',
#   'uri': 'spotify:track:2rb5MvYT7ZIxbKW5hfcHx8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2rb5MvYT7ZIxbKW5hfcHx8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2rb5MvYT7ZIxbKW5hfcHx8',
#   'duration_ms': 189440,
#   'time_signature': 4}]

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        print(features[0]['danceability'])
        dataframe.append({'danceability' : features[0]['danceability'],
        'energy': features[0]['energy'],
        'key' : features[0]['key'],
        'loudness' : features[0]['loudness'],
        'mode' : features[0]['mode'],
        'speechiness' : features[0]['speechiness'],
        'acousticness' : features[0]['acousticness'],
        'instrumentalness' : features[0]['instrumentalness'],
        'liveness' : features[0]['liveness'],
        'valence' : features[0]['valence'],
        'tempo' : features[0]['tempo'],
        'time_signature' : features[0]['time_signature'],
        'duration_ms' : features[0]['duration_ms']}, ignore_index=True)
    return dataframe

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        dataframe.loc[i] = [ features[0]['id'],
        features[0]['danceability'],
        features[0]['energy'],
        features[0]['key'],
        features[0]['loudness'],
        features[0]['mode'],
        features[0]['speechiness'],
        features[0]['acousticness'],
        features[0]['instrumentalness'],
        features[0]['liveness'],
        features[0]['valence'],
        features[0]['tempo'],
        features[0]['time_signature'],
        features[0]['duration_ms']]
    return dataframe

# %%
prova = extract_features(df, n_tracks=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-581b4cc5892d> in <module>
# ----> 1 prova = extract_features(df, n_tracks=200)
#
# <ipython-input-21-e6752ace0964> in extract_features(df, n_tracks)
#       4                                      'duration_ms'])
#       5     for i in range(n_tracks):
# ----> 6         features = spotify.audio_features(str(df['ID'].iloc[i]))
#       7         dataframe.loc[i] = [ features[0]['id'],
#       8         features[0]['danceability'],
#
# NameError: name 'spotify' is not defined

# %%
prova
# Out:
#                          id  danceability  energy key  loudness mode  \
# 0    2rb5MvYT7ZIxbKW5hfcHx8         0.543   0.677  11    -4.915    0
# 1    5CtI0qwDJkDQGwXD1H1cLb         0.694   0.815   2    -4.328    1
# 2    1OAh8uOEOvTDqkKFsKksCi         0.671   0.672   0    -3.094    0
# 3    3B54sVLJ402zGa6Xm4YGNe         0.726   0.769   6    -5.043    1
# 4    5bcTCxgc7xVfSaMV3RuVke         0.893   0.745  11    -3.105    0
# ..                      ...           ...     ...  ..       ...  ...
# 195  7DM4BPaS7uofFul3ywMe46         0.663   0.920  11    -4.070    0
# 196  1EaKU4dMbesXXd3BrLCtYG         0.748   0.705   4    -4.547    0
# 197  5qqabIl2vWzo9ApSC317sa         0.378   0.896   2    -4.066    1
# 198  61HHDBLqF3AmSvLfHKNGd2         0.664   0.576   7    -5.395    0
# 199  4tCtwWceOPWzenK2HAIJSb         0.803   0.585   8    -5.861    1
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.0993      0.014800          0.000006    0.1300    0.294  103.809
# 1         0.1200      0.229000          0.000000    0.0924    0.813   88.931
# 2         0.0688      0.032900          0.000000    0.1180    0.632   97.979
# 3         0.1230      0.029300          0.010100    0.1040    0.733   97.985
# 4         0.0571      0.064200          0.000000    0.0943    0.872  101.018
# ..           ...           ...               ...       ...      ...      ...
# 195       0.2260      0.004310          0.000017    0.1010    0.533   99.935
# 196       0.4850      0.204000          0.000000    0.2460    0.483  189.891
# 197       0.0407      0.000452          0.000000    0.1940    0.469  174.302
# 198       0.0349      0.007300          0.000063    0.0912    0.121  134.934
# 199       0.0432      0.103000          0.000004    0.0644    0.593  105.017
#
#     time_signature duration_ms
# 0                4      189440
# 1                4      228827
# 2                4      204173
# 3                4      233902
# 4                4      223413
# ..             ...         ...
# 195              4      259196
# 196              4      208733
# 197              4      258773
# 198              4      233293
# 199              4      214480
#
# [200 rows x 14 columns]

# %%
output = df.join(prova.set_index('id'), on='ID')

# %%
output.to_csv('global_08-2017.csv')

# %%
output
# Out:
#      index Position                                         Track Name  \
# 0        1        1                                           Mi Gente
# 1        2        2                                  Despacito - Remix
# 2        3        3      Wild Thoughts (feat. Rihanna & Bryson Tiller)
# 3        4        4                                      Unforgettable
# 4        5        5  Feels (feat. Pharrell Williams, Katy Perry & B...
# ..     ...      ...                                                ...
# 195    196      196                        Vente Pa' Ca (feat. Maluma)
# 196    197      197                                           ELEMENT.
# 197    198      198                            Wonderwall - Remastered
# 198    199      199                                     Ahora Me Llama
# 199    200      200               Work from Home (feat. Ty Dolla $ign)
#
#              Artist   Streams                      ID  danceability  energy  \
# 0          J Balvin  32361062  2rb5MvYT7ZIxbKW5hfcHx8         0.543   0.677
# 1        Luis Fonsi  28238094  5CtI0qwDJkDQGwXD1H1cLb         0.694   0.815
# 2         DJ Khaled  25365011  1OAh8uOEOvTDqkKFsKksCi         0.671   0.672
# 3    French Montana  23957823  3B54sVLJ402zGa6Xm4YGNe         0.726   0.769
# 4     Calvin Harris  23208440  5bcTCxgc7xVfSaMV3RuVke         0.893   0.745
# ..              ...       ...                     ...           ...     ...
# 195    Ricky Martin   3003473  7DM4BPaS7uofFul3ywMe46         0.663   0.920
# 196  Kendrick Lamar   2987571  1EaKU4dMbesXXd3BrLCtYG         0.748   0.705
# 197           Oasis   2975831  5qqabIl2vWzo9ApSC317sa         0.378   0.896
# 198         KAROL G   2971762  61HHDBLqF3AmSvLfHKNGd2         0.664   0.576
# 199   Fifth Harmony   2970256  4tCtwWceOPWzenK2HAIJSb         0.803   0.585
#
#     key  loudness mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    11    -4.915    0       0.0993      0.014800          0.000006    0.1300
# 1     2    -4.328    1       0.1200      0.229000          0.000000    0.0924
# 2     0    -3.094    0       0.0688      0.032900          0.000000    0.1180
# 3     6    -5.043    1       0.1230      0.029300          0.010100    0.1040
# 4    11    -3.105    0       0.0571      0.064200          0.000000    0.0943
# ..   ..       ...  ...          ...           ...               ...       ...
# 195  11    -4.070    0       0.2260      0.004310          0.000017    0.1010
# 196   4    -4.547    0       0.4850      0.204000          0.000000    0.2460
# 197   2    -4.066    1       0.0407      0.000452          0.000000    0.1940
# 198   7    -5.395    0       0.0349      0.007300          0.000063    0.0912
# 199   8    -5.861    1       0.0432      0.103000          0.000004    0.0644
#
#      valence    tempo time_signature duration_ms
# 0      0.294  103.809              4      189440
# 1      0.813   88.931              4      228827
# 2      0.632   97.979              4      204173
# 3      0.733   97.985              4      233902
# 4      0.872  101.018              4      223413
# ..       ...      ...            ...         ...
# 195    0.533   99.935              4      259196
# 196    0.483  189.891              4      208733
# 197    0.469  174.302              4      258773
# 198    0.121  134.934              4      233293
# 199    0.593  105.017              4      214480
#
# [200 rows x 19 columns]

# %% [markdown]
# ## Testing iTunes API for genre labeling

# %%
import requests
import json
entry = 'starboy+the+weeknd'
a = 'https://itunes.apple.com/search?term='+entry+'.&limit=1'
b = requests.get(a).json()
print(b['results'][0]['primaryGenreName'])
print(json.dumps(b, indent=2))
# Out:
# R&B/Soul
# {
#   "resultCount": 1,
#   "results": [
#     {
#       "wrapperType": "track",
#       "kind": "song",
#       "artistId": 479756766,
#       "collectionId": 1440871397,
#       "trackId": 1440871420,
#       "artistName": "The Weeknd",
#       "collectionName": "Starboy",
#       "trackName": "Starboy (feat. Daft Punk)",
#       "collectionCensoredName": "Starboy",
#       "trackCensoredName": "Starboy (feat. Daft Punk)",
#       "artistViewUrl": "https://music.apple.com/us/artist/the-weeknd/479756766?uo=4",
#       "collectionViewUrl": "https://music.apple.com/us/album/starboy-feat-daft-punk/1440871397?i=1440871420&uo=4",
#       "trackViewUrl": "https://music.apple.com/us/album/starboy-feat-daft-punk/1440871397?i=1440871420&uo=4",
#       "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/14/64/52/146452b1-d912-e0d4-d016-542de4bd8036/mzaf_4996492471208465628.plus.aac.p.m4a",
#       "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music113/v4/9c/a2/d5/9ca2d550-4513-d5ae-b56b-571edca70cbd/source/30x30bb.jpg",
#       "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music113/v4/9c/a2/d5/9ca2d550-4513-d5ae-b56b-571edca70cbd/source/60x60bb.jpg",
#       "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music113/v4/9c/a2/d5/9ca2d550-4513-d5ae-b56b-571edca70cbd/source/100x100bb.jpg",
#       "collectionPrice": 13.99,
#       "trackPrice": 1.29,
#       "releaseDate": "2016-09-21T12:00:00Z",
#       "collectionExplicitness": "explicit",
#       "trackExplicitness": "explicit",
#       "discCount": 1,
#       "discNumber": 1,
#       "trackCount": 18,
#       "trackNumber": 1,
#       "trackTimeMillis": 230461,
#       "country": "USA",
#       "currency": "USD",
#       "primaryGenreName": "R&B/Soul",
#       "contentAdvisoryRating": "Explicit",
#       "isStreamable": true
#     }
#   ]
# }

# %%
import os
path = os.getcwd()
file = 'global_2017-05-26--2017-06-02.csv'
print(path)

file_path = os.path.join(path,'global',file)
print(file_path)
df = pd.read_csv(file_path)
# Out:
# C:\Users\Mattia\Desktop\Polimi\Magistrale\Data Visualization\Data-and-Results-Visualization-Project
# C:\Users\Mattia\Desktop\Polimi\Magistrale\Data Visualization\Data-and-Results-Visualization-Project\global\global_2017-05-26--2017-06-02.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-ecac7ccfdcd6> in <module>
#       6 file_path = os.path.join(path,'global',file)
#       7 print(file_path)
# ----> 8 df = pd.read_csv(file_path)
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~\anaconda3\envs\TrapGenerator\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Mattia\\Desktop\\Polimi\\Magistrale\\Data Visualization\\Data-and-Results-Visualization-Project\\global\\global_2017-05-26--2017-06-02.csv'

# %%
df
# Out:
#     Unnamed: 0                           Unnamed: 1     Unnamed: 2  \
# 0     Position                           Track Name         Artist
# 1            1                            Fake Love          Drake
# 2            2  Bad and Boujee (feat. Lil Uzi Vert)          Migos
# 3            3                              Starboy     The Weeknd
# 4            4                        Black Beatles   Rae Sremmurd
# ..         ...                                  ...            ...
# 196        196       Dynamite (feat. Pretty Sister)          Nause
# 197        197                 Versace on the Floor     Bruno Mars
# 198        198                              No Type   Rae Sremmurd
# 199        199                             Unsteady  X Ambassadors
# 200        200                       A Lonely Night     The Weeknd
#
#     Note that these figures are generated using a formula that protects against any artificial inflation of chart positions.  \
# 0                                              Streams
# 1                                              8618267
# 2                                              7946032
# 3                                              7738517
# 4                                              6209336
# ..                                                 ...
# 196                                            1013332
# 197                                            1011536
# 198                                            1003471
# 199                                            1002415
# 200                                             994402
#
#                                             Unnamed: 4
# 0                                                  URL
# 1    https://open.spotify.com/track/343YBumqHu19cGo...
# 2    https://open.spotify.com/track/4Km5HrUvYTaSUfi...
# 3    https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 4    https://open.spotify.com/track/6fujklziTHa8uoM...
# ..                                                 ...
# 196  https://open.spotify.com/track/2Ae5awwKvQpTBKQ...
# 197  https://open.spotify.com/track/0kN8xEmgMW9mh7U...
# 198  https://open.spotify.com/track/4scpF6J5uMBvoh6...
# 199  https://open.spotify.com/track/7lGKEWMXVWWTt3X...
# 200  https://open.spotify.com/track/4UknpXoLjlB7Mao...
#
# [201 rows x 5 columns]

# %%
df.columns = df.iloc[0]

# %%
df = df.iloc[1:].reset_index()

# %%
df.URL.astype('str')
# Out:
# 0      https://open.spotify.com/track/343YBumqHu19cGo...
# 1      https://open.spotify.com/track/4Km5HrUvYTaSUfi...
# 2      https://open.spotify.com/track/5aAx2yezTd8zXrk...
# 3      https://open.spotify.com/track/6fujklziTHa8uoM...
# 4      https://open.spotify.com/track/7BKLCZ1jbUBVqRi...
#                              ...
# 195    https://open.spotify.com/track/2Ae5awwKvQpTBKQ...
# 196    https://open.spotify.com/track/0kN8xEmgMW9mh7U...
# 197    https://open.spotify.com/track/4scpF6J5uMBvoh6...
# 198    https://open.spotify.com/track/7lGKEWMXVWWTt3X...
# 199    https://open.spotify.com/track/4UknpXoLjlB7Mao...
# Name: URL, Length: 200, dtype: object

# %%
df.URL = df.URL.apply(lambda x : x[31:])

# %%
df.rename(columns={'URL':'ID'}, inplace=True)

# %%
credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
token = credentials.get_access_token()

spotify = spotipy.Spotify(auth=token)

features = spotify.audio_features(str(df['ID'].iloc[0]))
# Out:
# C:\Users\Mattia\anaconda3\envs\TrapGenerator\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.

# %%
features
# Out:
# [{'danceability': 0.928,
#   'energy': 0.481,
#   'key': 9,
#   'loudness': -9.35,
#   'mode': 0,
#   'speechiness': 0.287,
#   'acousticness': 0.105,
#   'instrumentalness': 0,
#   'liveness': 0.176,
#   'valence': 0.613,
#   'tempo': 134.007,
#   'type': 'audio_features',
#   'id': '343YBumqHu19cGoGARUTsd',
#   'uri': 'spotify:track:343YBumqHu19cGoGARUTsd',
#   'track_href': 'https://api.spotify.com/v1/tracks/343YBumqHu19cGoGARUTsd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/343YBumqHu19cGoGARUTsd',
#   'duration_ms': 210937,
#   'time_signature': 4}]

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        print(features[0]['danceability'])
        dataframe.append({'danceability' : features[0]['danceability'],
        'energy': features[0]['energy'],
        'key' : features[0]['key'],
        'loudness' : features[0]['loudness'],
        'mode' : features[0]['mode'],
        'speechiness' : features[0]['speechiness'],
        'acousticness' : features[0]['acousticness'],
        'instrumentalness' : features[0]['instrumentalness'],
        'liveness' : features[0]['liveness'],
        'valence' : features[0]['valence'],
        'tempo' : features[0]['tempo'],
        'time_signature' : features[0]['time_signature'],
        'duration_ms' : features[0]['duration_ms']}, ignore_index=True)
    return dataframe

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        dataframe.loc[i] = [ features[0]['id'],
        features[0]['danceability'],
        features[0]['energy'],
        features[0]['key'],
        features[0]['loudness'],
        features[0]['mode'],
        features[0]['speechiness'],
        features[0]['acousticness'],
        features[0]['instrumentalness'],
        features[0]['liveness'],
        features[0]['valence'],
        features[0]['tempo'],
        features[0]['time_signature'],
        features[0]['duration_ms']]
    return dataframe

# %%
prova = extract_features(df, n_tracks=200)
prova
# Out:
#                          id  danceability  energy key  loudness mode  \
# 0    343YBumqHu19cGoGARUTsd         0.928   0.481   9    -9.350    0
# 1    4Km5HrUvYTaSUfiSGPJeQR         0.927   0.665  11    -5.313    1
# 2    5aAx2yezTd8zXrkmtKl66Z         0.681   0.594   7    -7.028    1
# 3    6fujklziTHa8uoM5OQSfIo         0.794   0.632   0    -6.163    1
# 4    7BKLCZ1jbUBVqRi2FVlTVw         0.748   0.524   8    -5.599    1
# ..                      ...           ...     ...  ..       ...  ...
# 195  2Ae5awwKvQpTBKQHr1TYCg         0.811   0.801   9    -6.000    0
# 196  0kN8xEmgMW9mh7UmDYHlJP         0.578   0.574   2    -6.209    1
# 197  4scpF6J5uMBvoh6sFB7EL1         0.891   0.486   6    -7.803    1
# 198  7lGKEWMXVWWTt3X71Bv44I         0.389   0.665   0    -6.169    1
# 199  4UknpXoLjlB7Mao4UWcJ2o         0.853   0.663   7    -6.955    0
#
#      speechiness  acousticness instrumentalness  liveness  valence    tempo  \
# 0         0.2870        0.1050                0    0.1760    0.613  134.007
# 1         0.2440        0.0610                0    0.1230    0.175  127.076
# 2         0.2820        0.1650         3.49e-06    0.1340    0.535  186.054
# 3         0.0649        0.1420                0    0.1280    0.355  145.926
# 4         0.0338        0.4140                0    0.1110    0.661   95.010
# ..           ...           ...              ...       ...      ...      ...
# 195       0.0802        0.0548         2.09e-05    0.0742    0.693  105.055
# 196       0.0454        0.1960                0    0.0830    0.301  174.152
# 197       0.1590        0.0158         3.78e-06    0.0925    0.239  125.010
# 198       0.0644        0.1780         0.000732    0.1160    0.199  117.055
# 199       0.0755        0.0431         8.65e-06    0.0891    0.864  113.999
#
#     time_signature duration_ms
# 0                4      210937
# 1                4      343150
# 2                4      230453
# 3                4      291893
# 4                4      244960
# ..             ...         ...
# 195              4      195429
# 196              4      261240
# 197              4      200080
# 198              4      193547
# 199              4      220173
#
# [200 rows x 14 columns]

# %%
output = df.join(prova.set_index('id'), on='ID')
output
# Out:
#      index Position                           Track Name            Artist  \
# 0        1        1                            Fake Love             Drake
# 1        2        2  Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 2        3        3                              Starboy        The Weeknd
# 3        4        4                        Black Beatles      Rae Sremmurd
# 4        5        5                               Closer  The Chainsmokers
# ..     ...      ...                                  ...               ...
# 195    196      196       Dynamite (feat. Pretty Sister)             Nause
# 196    197      197                 Versace on the Floor        Bruno Mars
# 197    198      198                              No Type      Rae Sremmurd
# 198    199      199                             Unsteady     X Ambassadors
# 199    200      200                       A Lonely Night        The Weeknd
#
#      Streams                      ID  danceability  energy key  loudness mode  \
# 0    8618267  343YBumqHu19cGoGARUTsd         0.928   0.481   9    -9.350    0
# 1    7946032  4Km5HrUvYTaSUfiSGPJeQR         0.927   0.665  11    -5.313    1
# 2    7738517  5aAx2yezTd8zXrkmtKl66Z         0.681   0.594   7    -7.028    1
# 3    6209336  6fujklziTHa8uoM5OQSfIo         0.794   0.632   0    -6.163    1
# 4    5813157  7BKLCZ1jbUBVqRi2FVlTVw         0.748   0.524   8    -5.599    1
# ..       ...                     ...           ...     ...  ..       ...  ...
# 195  1013332  2Ae5awwKvQpTBKQHr1TYCg         0.811   0.801   9    -6.000    0
# 196  1011536  0kN8xEmgMW9mh7UmDYHlJP         0.578   0.574   2    -6.209    1
# 197  1003471  4scpF6J5uMBvoh6sFB7EL1         0.891   0.486   6    -7.803    1
# 198  1002415  7lGKEWMXVWWTt3X71Bv44I         0.389   0.665   0    -6.169    1
# 199   994402  4UknpXoLjlB7Mao4UWcJ2o         0.853   0.663   7    -6.955    0
#
#      speechiness  acousticness instrumentalness  liveness  valence    tempo  \
# 0         0.2870        0.1050                0    0.1760    0.613  134.007
# 1         0.2440        0.0610                0    0.1230    0.175  127.076
# 2         0.2820        0.1650         3.49e-06    0.1340    0.535  186.054
# 3         0.0649        0.1420                0    0.1280    0.355  145.926
# 4         0.0338        0.4140                0    0.1110    0.661   95.010
# ..           ...           ...              ...       ...      ...      ...
# 195       0.0802        0.0548         2.09e-05    0.0742    0.693  105.055
# 196       0.0454        0.1960                0    0.0830    0.301  174.152
# 197       0.1590        0.0158         3.78e-06    0.0925    0.239  125.010
# 198       0.0644        0.1780         0.000732    0.1160    0.199  117.055
# 199       0.0755        0.0431         8.65e-06    0.0891    0.864  113.999
#
#     time_signature duration_ms
# 0                4      210937
# 1                4      343150
# 2                4      230453
# 3                4      291893
# 4                4      244960
# ..             ...         ...
# 195              4      195429
# 196              4      261240
# 197              4      200080
# 198              4      193547
# 199              4      220173
#
# [200 rows x 19 columns]

# %%
output['genre']= "none"

# %%
output
# Out:
#      index Position                           Track Name            Artist  \
# 0        1        1                            Fake Love             Drake
# 1        2        2  Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 2        3        3                              Starboy        The Weeknd
# 3        4        4                        Black Beatles      Rae Sremmurd
# 4        5        5                               Closer  The Chainsmokers
# ..     ...      ...                                  ...               ...
# 195    196      196       Dynamite (feat. Pretty Sister)             Nause
# 196    197      197                 Versace on the Floor        Bruno Mars
# 197    198      198                              No Type      Rae Sremmurd
# 198    199      199                             Unsteady     X Ambassadors
# 199    200      200                       A Lonely Night        The Weeknd
#
#      Streams                      ID  danceability  energy key  loudness mode  \
# 0    8618267  343YBumqHu19cGoGARUTsd         0.928   0.481   9    -9.350    0
# 1    7946032  4Km5HrUvYTaSUfiSGPJeQR         0.927   0.665  11    -5.313    1
# 2    7738517  5aAx2yezTd8zXrkmtKl66Z         0.681   0.594   7    -7.028    1
# 3    6209336  6fujklziTHa8uoM5OQSfIo         0.794   0.632   0    -6.163    1
# 4    5813157  7BKLCZ1jbUBVqRi2FVlTVw         0.748   0.524   8    -5.599    1
# ..       ...                     ...           ...     ...  ..       ...  ...
# 195  1013332  2Ae5awwKvQpTBKQHr1TYCg         0.811   0.801   9    -6.000    0
# 196  1011536  0kN8xEmgMW9mh7UmDYHlJP         0.578   0.574   2    -6.209    1
# 197  1003471  4scpF6J5uMBvoh6sFB7EL1         0.891   0.486   6    -7.803    1
# 198  1002415  7lGKEWMXVWWTt3X71Bv44I         0.389   0.665   0    -6.169    1
# 199   994402  4UknpXoLjlB7Mao4UWcJ2o         0.853   0.663   7    -6.955    0
#
#      speechiness  acousticness instrumentalness  liveness  valence    tempo  \
# 0         0.2870        0.1050                0    0.1760    0.613  134.007
# 1         0.2440        0.0610                0    0.1230    0.175  127.076
# 2         0.2820        0.1650         3.49e-06    0.1340    0.535  186.054
# 3         0.0649        0.1420                0    0.1280    0.355  145.926
# 4         0.0338        0.4140                0    0.1110    0.661   95.010
# ..           ...           ...              ...       ...      ...      ...
# 195       0.0802        0.0548         2.09e-05    0.0742    0.693  105.055
# 196       0.0454        0.1960                0    0.0830    0.301  174.152
# 197       0.1590        0.0158         3.78e-06    0.0925    0.239  125.010
# 198       0.0644        0.1780         0.000732    0.1160    0.199  117.055
# 199       0.0755        0.0431         8.65e-06    0.0891    0.864  113.999
#
#     time_signature duration_ms genre
# 0                4      210937  none
# 1                4      343150  none
# 2                4      230453  none
# 3                4      291893  none
# 4                4      244960  none
# ..             ...         ...   ...
# 195              4      195429  none
# 196              4      261240  none
# 197              4      200080  none
# 198              4      193547  none
# 199              4      220173  none
#
# [200 rows x 20 columns]

# %%
import requests
import json
import time

for index, row in output.iterrows():
    artist = row["Artist"]
    song = row["Track Name"]
    print(song)
    song = song.split('(')[0]
    query_entry = str(artist)+" "+str(song)
    query_entry = query_entry.replace("with", "")
    query_entry=query_entry.replace(" ", "+")
    #query_entry = query_entry[0:60]
    query_entry = query_entry.lower()
    print(query_entry)
    a = 'https://itunes.apple.com/search?term='+query_entry+'&limit=1'
    b = requests.get(a).json()
    print(b['results'][0]['primaryGenreName'])
    #assign genre to song
    print(index)
    output.iloc[index, output.columns.get_loc('genre')]= b['results'][0]['primaryGenreName']
    time.sleep(2)
    #print(json.dumps(b, indent=2))
# Out:
# Despacito - Remix
# luis+fonsi+despacito+-+remix
# Pop
# 0
# Wild Thoughts (feat. Rihanna & Bryson Tiller)
# dj+khaled+wild+thoughts+
# Hip-Hop/Rap
# 1
# Unforgettable
# french+montana+unforgettable
# Hip-Hop/Rap
# 2
# nan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-9e90e86b979a> in <module>
#       7     song = row["Track Name"]
#       8     print(song)
# ----> 9     song = song.split('(')[0]
#      10     query_entry = str(artist)+" "+str(song)
#      11     query_entry = query_entry.replace("with", "")
#
# AttributeError: 'float' object has no attribute 'split'

# %%
query_entry = 'sia+helium'
a = 'https://itunes.apple.com/search?term='+query_entry+'&limit=1'
print(a)
test = requests.get(a)
print(test)
b = requests.get(a).json()
if b['resultCount'] == 1:
    print(b)
    print(b['results'][0]['primaryGenreName'])
else:
    print('no result')
# Out:
# https://itunes.apple.com/search?term=sia+helium&limit=1
# <Response [200]>
# {'resultCount': 1, 'results': [{'wrapperType': 'track', 'kind': 'song', 'artistId': 13493906, 'collectionId': 1440880777, 'trackId': 1440881266, 'artistName': 'Sia', 'collectionName': 'Fifty Shades Darker (Original Motion Picture Soundtrack)', 'trackName': 'Helium', 'collectionCensoredName': 'Fifty Shades Darker (Original Motion Picture Soundtrack)', 'trackCensoredName': 'Helium', 'collectionArtistId': 36270, 'collectionArtistName': 'Various Artists', 'artistViewUrl': 'https://music.apple.com/us/artist/sia/13493906?uo=4', 'collectionViewUrl': 'https://music.apple.com/us/album/helium/1440880777?i=1440881266&uo=4', 'trackViewUrl': 'https://music.apple.com/us/album/helium/1440880777?i=1440881266&uo=4', 'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/ff/e4/5b/ffe45b8a-8237-4957-3d40-ee65d8696aa6/mzaf_972595110792278268.plus.aac.p.m4a', 'artworkUrl30': 'https://is3-ssl.mzstatic.com/image/thumb/Music118/v4/e3/05/c3/e305c32a-6f0d-69ff-2e14-99058139ba95/source/30x30bb.jpg', 'artworkUrl60': 'https://is3-ssl.mzstatic.com/image/thumb/Music118/v4/e3/05/c3/e305c32a-6f0d-69ff-2e14-99058139ba95/source/60x60bb.jpg', 'artworkUrl100': 'https://is3-ssl.mzstatic.com/image/thumb/Music118/v4/e3/05/c3/e305c32a-6f0d-69ff-2e14-99058139ba95/source/100x100bb.jpg', 'collectionPrice': 13.99, 'trackPrice': 1.29, 'releaseDate': '2017-02-10T12:00:00Z', 'collectionExplicitness': 'notExplicit', 'trackExplicitness': 'notExplicit', 'discCount': 1, 'discNumber': 1, 'trackCount': 19, 'trackNumber': 9, 'trackTimeMillis': 252320, 'country': 'USA', 'currency': 'USD', 'primaryGenreName': 'Soundtrack', 'isStreamable': True}]}
# Soundtrack

# %%
output
# Out:
#      index Position                           Track Name            Artist  \
# 0        1        1                            Fake Love             Drake
# 1        2        2  Bad and Boujee (feat. Lil Uzi Vert)             Migos
# 2        3        3                              Starboy        The Weeknd
# 3        4        4                        Black Beatles      Rae Sremmurd
# 4        5        5                               Closer  The Chainsmokers
# ..     ...      ...                                  ...               ...
# 195    196      196       Dynamite (feat. Pretty Sister)             Nause
# 196    197      197                 Versace on the Floor        Bruno Mars
# 197    198      198                              No Type      Rae Sremmurd
# 198    199      199                             Unsteady     X Ambassadors
# 199    200      200                       A Lonely Night        The Weeknd
#
#      Streams                      ID  danceability  energy key  loudness mode  \
# 0    8618267  343YBumqHu19cGoGARUTsd         0.928   0.481   9    -9.350    0
# 1    7946032  4Km5HrUvYTaSUfiSGPJeQR         0.927   0.665  11    -5.313    1
# 2    7738517  5aAx2yezTd8zXrkmtKl66Z         0.681   0.594   7    -7.028    1
# 3    6209336  6fujklziTHa8uoM5OQSfIo         0.794   0.632   0    -6.163    1
# 4    5813157  7BKLCZ1jbUBVqRi2FVlTVw         0.748   0.524   8    -5.599    1
# ..       ...                     ...           ...     ...  ..       ...  ...
# 195  1013332  2Ae5awwKvQpTBKQHr1TYCg         0.811   0.801   9    -6.000    0
# 196  1011536  0kN8xEmgMW9mh7UmDYHlJP         0.578   0.574   2    -6.209    1
# 197  1003471  4scpF6J5uMBvoh6sFB7EL1         0.891   0.486   6    -7.803    1
# 198  1002415  7lGKEWMXVWWTt3X71Bv44I         0.389   0.665   0    -6.169    1
# 199   994402  4UknpXoLjlB7Mao4UWcJ2o         0.853   0.663   7    -6.955    0
#
#      speechiness  acousticness instrumentalness  liveness  valence    tempo  \
# 0         0.2870        0.1050                0    0.1760    0.613  134.007
# 1         0.2440        0.0610                0    0.1230    0.175  127.076
# 2         0.2820        0.1650         3.49e-06    0.1340    0.535  186.054
# 3         0.0649        0.1420                0    0.1280    0.355  145.926
# 4         0.0338        0.4140                0    0.1110    0.661   95.010
# ..           ...           ...              ...       ...      ...      ...
# 195       0.0802        0.0548         2.09e-05    0.0742    0.693  105.055
# 196       0.0454        0.1960                0    0.0830    0.301  174.152
# 197       0.1590        0.0158         3.78e-06    0.0925    0.239  125.010
# 198       0.0644        0.1780         0.000732    0.1160    0.199  117.055
# 199       0.0755        0.0431         8.65e-06    0.0891    0.864  113.999
#
#     time_signature duration_ms        genre
# 0                4      210937  Hip-Hop/Rap
# 1                4      343150      Hip-Hop
# 2                4      230453     R&B/Soul
# 3                4      291893  Hip-Hop/Rap
# 4                4      244960        Dance
# ..             ...         ...          ...
# 195              4      195429        Dance
# 196              4      261240          Pop
# 197              4      200080  Hip-Hop/Rap
# 198              4      193547  Alternative
# 199              4      220173     R&B/Soul
#
# [200 rows x 20 columns]

# %% [markdown]
# # Automatizing the feature extraction process

# %%
import pandas as pd
import spotipy
#from fycharts.SpotifyCharts import SpotifyCharts
from spotipy.oauth2 import SpotifyClientCredentials
import os
import requests
import json
import time

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        print(features[0]['danceability'])
        dataframe.append({'danceability' : features[0]['danceability'],
        'energy': features[0]['energy'],
        'key' : features[0]['key'],
        'loudness' : features[0]['loudness'],
        'mode' : features[0]['mode'],
        'speechiness' : features[0]['speechiness'],
        'acousticness' : features[0]['acousticness'],
        'instrumentalness' : features[0]['instrumentalness'],
        'liveness' : features[0]['liveness'],
        'valence' : features[0]['valence'],
        'tempo' : features[0]['tempo'],
        'time_signature' : features[0]['time_signature'],
        'duration_ms' : features[0]['duration_ms']}, ignore_index=True)
    return dataframe

# %%
def extract_features(df, n_tracks = 50):
    dataframe = pd.DataFrame(columns=['id','danceability','energy','key','loudness','mode','speechiness',
                                     'acousticness','instrumentalness','liveness','valence','tempo','time_signature',
                                     'duration_ms'])
    for i in range(n_tracks):
        features = spotify.audio_features(str(df['ID'].iloc[i]))
        dataframe.loc[i] = [ features[0]['id'],
        features[0]['danceability'],
        features[0]['energy'],
        features[0]['key'],
        features[0]['loudness'],
        features[0]['mode'],
        features[0]['speechiness'],
        features[0]['acousticness'],
        features[0]['instrumentalness'],
        features[0]['liveness'],
        features[0]['valence'],
        features[0]['tempo'],
        features[0]['time_signature'],
        features[0]['duration_ms']]
    return dataframe

# %%
#checking data integrity. Checks for missing fields in Artist name. 
import numpy as np

from IPython.display import display, HTML

path = os.getcwd()
file_folder = os.path.join(path,'global')

for csv_file in os.listdir(file_folder):
    file = os.path.join(file_folder,csv_file)
    #print(csv_file)
    df = pd.read_csv(file)
    #display(df)
    df.columns = df.iloc[0]
    df = df.iloc[1:].reset_index()
    df.URL.astype('str')
    df.URL = df.URL.apply(lambda x : x[31:])
    df.rename(columns={'URL':'ID'}, inplace=True)
    
    res = df.loc[df['Artist'].isnull(), 'index'].tolist()
    if len(res) != 0:
        print(res)
        print(csv_file)
# Out:
# [4, 10, 30, 40]
# global_2017-07-14--2017-07-21.csv
# [32]
# global_2017-11-03--2017-11-10.csv

# %%
path = os.getcwd()
file_folder = os.path.join(path,'global')
save_folder_path = os.path.join(path, "global_features")
os.mkdir(save_folder_path)

for csv_file in os.listdir(file_folder): 
    print(csv_file)
    file = os.path.join(file_folder,csv_file)
    df = pd.read_csv(file)
    df.columns = df.iloc[0]
    df = df.iloc[1:].reset_index()
    df.URL.astype('str')
    df.URL = df.URL.apply(lambda x : x[31:])
    df.rename(columns={'URL':'ID'}, inplace=True)
    credentials = SpotifyClientCredentials(client_id="6b8119b6cec94f538151d6bb7fd99acd", client_secret="bb3cc9f8fdb04ddb9516ab01c7bfc257")
    token = credentials.get_access_token()
    spotify = spotipy.Spotify(auth=token)
    features = spotify.audio_features(str(df['ID'].iloc[0]))
    prova = extract_features(df, n_tracks=200)
    output = df.join(prova.set_index('id'), on='ID')
    output['genre']= "none"
    for index, row in output.iterrows():
        artist = row["Artist"]
        song = row["Track Name"]
        song = song.split('(')[0]
        query_entry = str(artist)+" "+str(song)
        query_entry = query_entry.replace("with", "")
        query_entry= query_entry.replace('Remastered', "")
        query_entry= query_entry.replace('Version', "")

        query_entry = query_entry.replace("'", "")
        query_entry = query_entry.replace('"', "")

        query_entry=query_entry.replace(" ", "+")

        #query_entry = query_entry[0:60]
        query_entry = query_entry.lower()
        print(query_entry)
        a = 'https://itunes.apple.com/search?term='+query_entry+'&limit=1'
        test = requests.get(a)
        print(test)
        b = test.json()
        if b['resultCount'] == 1:

            print(b['results'][0]['primaryGenreName'])
            #assign genre to song
            print(index)
            output.iloc[index, output.columns.get_loc('genre')]= b['results'][0]['primaryGenreName']
        time.sleep(0.5)
        #print(json.dumps(b, indent=2))
    output.to_csv(os.path.join(save_folder_path,csv_file))
# Out:
# global_2016-12-23--2016-12-30.csv
# C:\Users\Mattia\anaconda3\envs\TrapGenerator\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   app.launch_new_instance()
# the+weeknd+starboy
# <Response [200]>
# R&B/Soul
# 0
# the+chainsmokers+closer
# <Response [200]>
# Dance
# 1
# clean+bandit+rockabye+
# <Response [200]>
# Dance
# 2
# dj+snake+let+me+love+you
# <Response [200]>
# Dance
# 3
# maroon+5+dont+wanna+know
# <Response [200]>
# Pop
# 4
# rae+sremmurd+black+beatles
# <Response [200]>
# Hip-Hop/Rap
# 5
# zayn+i+don’t+wanna+live+forever+
# <Response [200]>
# Soundtrack
# 6
# drake+fake+love
# <Response [200]>
# Hip-Hop/Rap
# 7
# bruno+mars+24k+magic
# <Response [200]>
# Pop
# 8
# james+arthur+say+you+wont+let+go
# <Response [200]>
# Pop
# 9
# mariah+carey+all+i+want+for+christmas+is+you
# <Response [200]>
# Holiday
# 10
# the+weeknd+i+feel+it+coming
# <Response [200]>
# R&B/Soul
# 11
# drake+one+dance
# <Response [200]>
# Hip-Hop/Rap
# 12
# major+lazer+cold+water+
# <Response [200]>
# Pop
# 13
# sia+the+greatest
# <Response [200]>
# Pop
# 14
# martin+garrix+in+the+name+of+love
# <Response [200]>
# Dance
# 15
# starley+call+on+me+-+ryan+riback+extended+remix
# <Response [200]>
# Dance
# 16
# shakira+chantaje+
# <Response [200]>
# Pop Latino
# 17
# ariana+grande+side+to+side
# <Response [200]>
# Pop
# 18
# steve+aoki+just+hold+on
# <Response [200]>
# Dance
# 19
# wham!+last+christmas
# <Response [200]>
# Holiday
# 20
# hailee+steinfeld+starving
# <Response [200]>
# Pop
# 21
# migos+bad+and+boujee+
# <Response [200]>
# Hip-Hop
# 22
# machine+gun+kelly+bad+things+
# <Response [200]>
# Hip-Hop/Rap
# 23
# shawn+mendes+mercy
# <Response [200]>
# Pop
# 24
# calvin+harris+my+way
# <Response [200]>
# Dance
# 25
# twenty+one+pilots+heathens
# <Response [200]>
# Alternative
# 26
# the+chainsmokers+all+we+know+
# <Response [200]>
# Dance
# 27
# the+chainsmokers+dont+let+me+down
# <Response [200]>
# Dance
# 28
# shawn+mendes+treat+you+better
# <Response [200]>
# Pop
# 29
# alessia+cara+scars+to+your+beautiful
# <Response [200]>
# Pop
# 30
# cnco+reggaetón+lento+
# <Response [200]>
# Pop
# 31
# john+legend+love+me+now
# <Response [200]>
# R&B/Soul
# 32
# the+vamps+all+night
# <Response [200]>
# Pop
# 33
# justin+timberlake+cant+stop+the+feeling!+
# <Response [200]>
# Soundtrack
# 34
# sage+the+gemini+now+and+later
# <Response [200]>
# Hip-Hop
# 35
# nevada+the+mack
# <Response [200]>
# Dance
# 36
# jonas+blue+by+your+side
# <Response [200]>
# Dance
# 37
# charlie+puth+we+dont+talk+anymore+
# <Response [200]>
# Pop
# 38
# alan+walker+alone
# <Response [200]>
# Dance
# 39
# michael+bublé+its+beginning+to+look+a+lot+like+christmas
# <Response [200]>
# Holiday
# 40
# zara+larsson+i+would+like
# <Response [200]>
# Dance
# 41
# the+weeknd+party+monster
# <Response [200]>
# R&B/Soul
# 42
# j+balvin+safari
# <Response [200]>
# Urbano latino
# 43
# andy+williams+its+the+most+wonderful+time+of+the+year
# <Response [200]>
# Holiday
# 44
# sia+cheap+thrills
# <Response [200]>
# Pop
# 45
# j.+cole+deja+vu
# <Response [200]>
# Hip-Hop/Rap
# 46
# dram+broccoli+
# <Response [200]>
# Hip-Hop/Rap
# 47
# mike+posner+i+took+a+pill+in+ibiza+-+seeb+remix
# <Response [200]>
# Dance
# 48
# aminé+caroline
# <Response [200]>
# Hip-Hop/Rap
# 49
# bobby+helms+jingle+bell+rock
# <Response [200]>
# Holiday
# 50
# ricky+martin+vente+pa+ca+
# <Response [200]>
# Pop Latino
# 51
# zion+&+lennox+otra+vez+
# <Response [200]>
# Urbano latino
# 52
# twenty+one+pilots+ride
# <Response [200]>
# Alternative
# 53
# robin+schulz+shed+a+light
# <Response [200]>
# Dance
# 54
# alessia+cara+how+far+ill+go+-+from+moana
# <Response [200]>
# Soundtrack
# 55
# alok+hear+me+now
# <Response [200]>
# Pop
# 56
# neiked+sexual
# <Response [200]>
# Dance
# 57
# frank+sinatra+let+it+snow!+let+it+snow!+let+it+snow!+
# <Response [200]>
# Holiday
# 58
# bing+crosby+white+christmas
# <Response [200]>
# Holiday
# 59
# jonas+blue+perfect+strangers
# <Response [200]>
# Dance
# 60
# calvin+harris+this+is+what+you+came+for+
# <Response [200]>
# Dance
# 61
# big+sean+bounce+back
# <Response [200]>
# Hip-Hop/Rap
# 62
# drake+too+good
# <Response [200]>
# Hip-Hop/Rap
# 63
# twenty+one+pilots+stressed+out
# <Response [200]>
# Alternative
# 64
# brenda+lee+rockin+around+the+christmas+tree+-+single+
# <Response [200]>
# Holiday
# 65
# gnash+i+hate+u,+i+love+u+
# <Response [200]>
# Pop
# 66
# josé+feliciano+feliz+navidad
# <Response [200]>
# Holiday
# 67
# fifth+harmony+work+from+home+
# <Response [200]>
# Pop
# 68
# band+aid+do+they+know+its+christmas?+-+1984+
# <Response [200]>
# Rock
# 69
# ragnbone+man+human
# <Response [200]>
# Alternative
# 70
# alan+walker+faded
# <Response [200]>
# Dance
# 71
# desiigner+panda
# <Response [200]>
# Hip-Hop/Rap
# 72
# justin+bieber+love+yourself
# <Response [200]>
# Pop
# 73
# rihanna+work
# <Response [200]>
# Pop
# 74
# justin+bieber+sorry
# <Response [200]>
# Pop
# 75
# elvis+presley+blue+christmas
# <Response [200]>
# Christmas
# 76
# lil+wayne+sucker+for+pain+
# <Response [200]>
# Hip-Hop/Rap
# 77
# martin+jensen+solo+dance
# <Response [200]>
# Dance
# 78
# zay+hilfigerrr+juju+on+that+beat+
# <Response [200]>
# Dance
# 79
# the+chainsmokers+setting+fires
# <Response [200]>
# Dance
# 80
# shakin+stevens+merry+christmas+everyone+-+
# <Response [200]>
# Rock
# 81
# noah+cyrus+make+me+
# <Response [200]>
# Pop
# 82
# ariana+grande+santa+tell+me
# <Response [200]>
# Holiday
# 83
# carlos+vives+la+bicicleta
# <Response [200]>
# Pop Latino
# 84
# rob+$tone+chill+bill+
# <Response [200]>
# Hip-Hop/Rap
# 85
# john+lennon+happy+xmas+
# <Response [200]>
# Pop
# 86
# little+mix+shout+out+to+my+ex
# <Response [200]>
# Pop
# 87
# luke+christopher+lot+to+learn
# <Response [200]>
# Hip-Hop/Rap
# 88
# justin+bieber+mistletoe
# <Response [200]>
# Holiday
# 89
# sebastian+yatra+traicionera
# <Response [200]>
# Pop Latino
# 90
# drake+controlla
# <Response [200]>
# Hip-Hop/Rap
# 91
# adele+water+under+the+bridge
# <Response [200]>
# Pop
# 92
# mike+perry+the+ocean+
# <Response [200]>
# Dance
# 93
# coldplay+hymn+for+the+weekend+-+seeb+remix
# <Response [200]>
# Dance
# 94
# rihanna+needed+me
# <Response [200]>
# Pop
# 95
# cashmere+cat+trust+nobody+
# <Response [200]>
# Electronic
# 96
# the+weeknd+sidewalks
# <Response [200]>
# R&B/Soul
# 97
# nat+king+cole+the+christmas+song+
# <Response [200]>
# Pop
# 98
# 21+savage+x+
# <Response [200]>
# Rap
# 99
# daddy+yankee+shaky+shaky
# <Response [200]>
# Urbano latino
# 100
# major+lazer+light+it+up+
# <Response [200]>
# Hip-Hop/Rap
# 101
# dnce+cake+by+the+ocean
# <Response [200]>
# Pop
# 102
# lukas+graham+7+years
# <Response [200]>
# Pop
# 103
# bruno+mars+versace+on+the+floor
# <Response [200]>
# Pop
# 104
# petit+biscuit+sunset+lover
# <Response [200]>
# Electronic
# 105
# drake+sneakin’
# <Response [200]>
# Hip-Hop/Rap
# 106
# the+weeknd+six+feet+under
# <Response [200]>
# R&B/Soul
# 107
# 21+savage+no+heart
# <Response [200]>
# Rap
# 108
# the+pogues+fairytale+of+new+york+
# <Response [200]>
# Alternative
# 109
# pentatonix+hallelujah
# <Response [200]>
# Pop
# 110
# dj+snake+middle
# <Response [200]>
# Dance
# 111
# vice+steady+1234+
# <Response [200]>
# Pop
# 112
# frenship+capsize
# <Response [200]>
# Pop
# 113
# ariana+grande+into+you
# <Response [200]>
# Pop
# 114
# kungs+this+girl+
# <Response [200]>
# Dance
# 115
# mc+g15+deu+onda
# <Response [200]>
# Funk
# 116
# enrique+iglesias+duele+el+corazon+
# <Response [200]>
# Pop Latino
# 117
# andy+grammer+fresh+eyes
# <Response [200]>
# Pop
# 118
# j.+cole+neighbors
# <Response [200]>
# Hip-Hop/Rap
# 119
# childish+gambino+redbone
# <Response [200]>
# R&B/Soul
# 120
# bebe+rexha+i+got+you
# <Response [200]>
# Pop
# 121
# ed+sheeran+photograph
# <Response [200]>
# Pop
# 122
# adele+send+my+love+
# <Response [200]>
# Pop
# 123
# young+m.a+ooouuu
# <Response [200]>
# Rap
# 124
# g-eazy+me,+myself+&+i
# <Response [200]>
# Hip-Hop/Rap
# 125
# niall+horan+this+town
# <Response [200]>
# Pop
# 126
# iamchino+ay+mi+dios+
# <Response [200]>
# Urbano latino
# 127
# jon+bellion+all+time+low
# <Response [200]>
# Pop
# 128
# jonas+blue+fast+car
# <Response [200]>
# Dance
# 129
# j.+cole+immortal
# <Response [200]>
# Hip-Hop/Rap
# 130
# the+weeknd+reminder
# <Response [200]>
# R&B/Soul
# 131
# ozuna+dile+que+tu+me+quieres
# <Response [200]>
# Urbano latino
# 132
# mø+final+song
# <Response [200]>
# Pop
# 133
# major+lazer+lean+on+
# <Response [200]>
# Electronic
# 134
# paul+mccartney+wonderful+christmastime+-++2011+/+edited+
# <Response [200]>
# Rock
# 135
# phil+spector+sleigh+ride
# <Response [200]>
# Holiday
# 136
# chuck+berry+run+rudolph+run+-+single+
# <Response [200]>
# Holiday
# 137
# perry+como+its+beginning+to+look+a+lot+like+christmas+
# <Response [200]>
# Holiday
# 138
# burl+ives+a+holly+jolly+christmas+-+single+
# <Response [200]>
# Holiday
# 139
# maluma+borro+cassette
# <Response [200]>
# Música tropical
# 140
# michael+bublé+white+christmas+
# <Response [200]>
# Holiday
# 141
# hearts+&+colors+lighthouse+-+andrelli+remix
# <Response [200]>
# Pop
# 142
# galantis+love+on+me
# <Response [200]>
# Dance
# 143
# the+weeknd+rockin’
# <Response [200]>
# R&B/Soul
# 144
# ajr+weak
# <Response [200]>
# Alternative
# 145
# nause+dynamite+
# <Response [200]>
# Dance
# 146
# calum+scott+dancing+on+my+own
# <Response [200]>
# Pop
# 147
# shawn+mendes+stitches
# <Response [200]>
# Pop
# 148
# ed+sheeran+thinking+out+loud
# <Response [200]>
# Pop
# 149
# adele+hello
# <Response [200]>
# Pop
# 150
# elton+john+step+into+christmas
# <Response [200]>
# Holiday
# 151
# chino+&+nacho+andas+en+mi+cabeza
# <Response [200]>
# Reggae
# 152
# the+chainsmokers+roses
# <Response [200]>
# Dance
# 153
# justin+bieber+what+do+you+mean?
# <Response [200]>
# Pop
# 154
# michael+bublé+holly+jolly+christmas
# <Response [200]>
# Holiday
# 155
# zara+larsson+aint+my+fault
# <Response [200]>
# Dance
# 156
# zara+larsson+lush+life
# <Response [200]>
# Pop
# 157
# bruce+springsteen+santa+claus+is+comin+to+town+-+live+at+c.w.+post+college,+greenvale,+ny+-+december+1975
# <Response [200]>
# Holiday
# 158
# cheat+codes+sex
# <Response [200]>
# Dance
# 159
# rihanna+love+on+the+brain
# <Response [200]>
# Pop
# 160
# eartha+kitt+santa+baby+
# <Response [200]>
# Holiday
# 161
# maluma+cuatro+babys+
# <Response [200]>
# Urbano latino
# 162
# george+michael+careless+whisper
# <Response [200]>
# Pop
# 163
# zayn+pillowtalk
# <Response [200]>
# Pop
# 164
# michael+bublé+santa+claus+is+coming+to+town
# <Response [200]>
# Holiday
# 165
# young+thug+pick+up+the+phone
# <Response [200]>
# Hip-Hop/Rap
# 166
# chance+the+rapper+no+problem+
# <Response [200]>
# Hip-Hop/Rap
# 167
# sam+smith+have+yourself+a+merry+little+christmas
# <Response [200]>
# Holiday
# 168
# state+of+sound+wake+up+where+you+are
# <Response [200]>
# Pop
# 169
# mykola+dmytrovych+leontovych+carol+of+the+bells
# <Response [200]>
# Classical
# 170
# bruno+mars+thats+what+i+like
# <Response [200]>
# Pop
# 171
# michael+bublé+jingle+bells+
# <Response [200]>
# Holiday
# 172
# drake+hotline+bling
# <Response [200]>
# Hip-Hop/Rap
# 173
# galantis+no+money
# <Response [200]>
# Dance
# 174
# boney+m.+marys+boy+child+/+oh+my+lord
# <Response [200]>
# Pop
# 175
# lil+uzi+vert+you+was+right
# <Response [200]>
# Hip-Hop
# 176
# wisin+vacaciones
# <Response [200]>
# Urbano latino
# 177
# the+weeknd+die+for+you
# <Response [200]>
# R&B/Soul
# 178
# the+weeknd+the+hills
# <Response [200]>
# R&B/Soul
# 179
# james+hersey+miss+you
# <Response [200]>
# Alternative
# 180
# drake+jumpman
# <Response [200]>
# Hip-Hop/Rap
# 181
# g-eazy+some+kind+of+drug+
# <Response [200]>
# Hip-Hop/Rap
# 182
# san+holo+light
# <Response [200]>
# Dance
# 183
# britney+spears+my+only+wish+
# <Response [200]>
# Holiday
# 184
# kyle+ispy+
# <Response [200]>
# Hip-Hop/Rap
# 185
# michael+bublé+all+i+want+for+christmas+is+you
# <Response [200]>
# Holiday
# 186
# coldplay+christmas+lights
# <Response [200]>
# Christmas
# 187
# piso+21+me+llamas+
# <Response [200]>
# Pop Latino
# 188
# charly+black+gyal+you+a+party+animal+-+remix
# <Response [200]>
# Dance
# 189
# the+weeknd+secrets
# <Response [200]>
# R&B/Soul
# 190
# george+michael+faith+-+
# <Response [200]>
# Pop
# 191
# dante+klein+let+me+hold+you+
# <Response [200]>
# Dance
# 192
# future+low+life+
# <Response [200]>
# Hip-Hop/Rap
# 193
# future+used+to+this+
# <Response [200]>
# Hip-Hop/Rap
# 194
# j.+cole+no+role+modelz
# <Response [200]>
# Hip-Hop/Rap
# 195
# rae+sremmurd+swang
# <Response [200]>
# Hip-Hop/Rap
# 196
# kream+taped+up+heart+
# <Response [200]>
# Dance
# 197
# marc+e.+bassy+you+&+me
# <Response [200]>
# Pop
# 198
# coldplay+hymn+for+the+weekend
# <Response [200]>
# Alternative
# 199
# global_2016-12-30--2017-01-06.csv
# the+weeknd+starboy
# <Response [200]>
# R&B/Soul
# 0
# the+chainsmokers+closer
# <Response [200]>
# Dance
# 1
# clean+bandit+rockabye+
# <Response [200]>
# Dance
# 2
# dj+snake+let+me+love+you
# <Response [200]>
# Dance
# 3
# zayn+i+don’t+wanna+live+forever+
# <Response [200]>
# Soundtrack
# 4
# maroon+5+dont+wanna+know
# <Response [200]>
# Pop
# 5
# drake+fake+love
# <Response [200]>
# Hip-Hop/Rap
# 6
# james+arthur+say+you+wont+let+go
# <Response [200]>
# Pop
# 7
# bruno+mars+24k+magic
# <Response [200]>
# Pop
# 8
# the+weeknd+i+feel+it+coming
# <Response [200]>
# R&B/Soul
# 9
# rae+sremmurd+black+beatles
# <Response [200]>
# Hip-Hop/Rap
# 10
# drake+one+dance
# <Response [200]>
# Hip-Hop/Rap
# 11
# shakira+chantaje+
# <Response [200]>
# Pop Latino
# 12
# major+lazer+cold+water+
# <Response [200]>
# Pop
# 13
# starley+call+on+me+-+ryan+riback+extended+remix
# <Response [200]>
# Dance
# 14
# martin+garrix+in+the+name+of+love
# <Response [200]>
# Dance
# 15
# migos+bad+and+boujee+
# <Response [200]>
# Hip-Hop
# 16
# ariana+grande+side+to+side
# <Response [200]>
# Pop
# 17
# steve+aoki+just+hold+on
# <Response [200]>
# Dance
# 18
# hailee+steinfeld+starving
# <Response [200]>
# Pop
# 19
# machine+gun+kelly+bad+things+
# <Response [200]>
# Hip-Hop/Rap
# 20
# shawn+mendes+mercy
# <Response [200]>
# Pop
# 21
# calvin+harris+my+way
# <Response [200]>
# Dance
# 22
# the+chainsmokers+all+we+know+
# <Response [200]>
# Dance
# 23
# the+chainsmokers+dont+let+me+down
# <Response [200]>
# Dance
# 24
# shawn+mendes+treat+you+better
# <Response [200]>
# Pop
# 25
# twenty+one+pilots+heathens
# <Response [200]>
# Alternative
# 26
# justin+timberlake+cant+stop+the+feeling!+
# <Response [200]>
# Soundtrack
# 27
# alessia+cara+scars+to+your+beautiful
# <Response [200]>
# Pop
# 28
# the+vamps+all+night
# <Response [200]>
# Pop
# 29
# sia+cheap+thrills
# <Response [200]>
# Pop
# 30
# sage+the+gemini+now+and+later
# <Response [200]>
# Hip-Hop
# 31
# john+legend+love+me+now
# <Response [200]>
# R&B/Soul
# 32
# jonas+blue+by+your+side
# <Response [200]>
# Dance
# 33
# cnco+reggaetón+lento+
# <Response [200]>
# Pop
# 34
# alan+walker+alone
# <Response [200]>
# Dance
# 35
# nevada+the+mack
# <Response [200]>
# Dance
# 36
# zara+larsson+i+would+like
# <Response [200]>
# Dance
# 37
# robin+schulz+shed+a+light
# <Response [200]>
# Dance
# 38
# mike+posner+i+took+a+pill+in+ibiza+-+seeb+remix
# <Response [200]>
# Dance
# 39
# charlie+puth+we+dont+talk+anymore+
# <Response [200]>
# Pop
# 40
# alok+hear+me+now
# <Response [200]>
# Pop
# 41
# j+balvin+safari
# <Response [200]>
# Urbano latino
# 42
# dram+broccoli+
# <Response [200]>
# Hip-Hop/Rap
# 43
# calvin+harris+this+is+what+you+came+for+
# <Response [200]>
# Dance
# 44
# alessia+cara+how+far+ill+go+-+from+moana
# <Response [200]>
# Soundtrack
# 45
# aminé+caroline
# <Response [200]>
# Hip-Hop/Rap
# 46
# fifth+harmony+work+from+home+
# <Response [200]>
# Pop
# 47
# ricky+martin+vente+pa+ca+
# <Response [200]>
# Pop Latino
# 48
# zion+&+lennox+otra+vez+
# <Response [200]>
# Urbano latino
# 49
# the+weeknd+party+monster
# <Response [200]>
# R&B/Soul
# 50
# neiked+sexual
# <Response [200]>
# Dance
# 51
# jonas+blue+perfect+strangers
# <Response [200]>
# Dance
# 52
# sia+the+greatest+
# <Response [200]>
# Pop
# 53
# twenty+one+pilots+ride
# <Response [200]>
# Alternative
# 54
# big+sean+bounce+back
# <Response [200]>
# Hip-Hop/Rap
# 55
# j.+cole+deja+vu
# <Response [200]>
# Hip-Hop/Rap
# 56
# martin+jensen+solo+dance
# <Response [200]>
# Dance
# 57
# rihanna+work
# <Response [200]>
# Pop
# 58
# drake+too+good
# <Response [200]>
# Hip-Hop/Rap
# 59
# ragnbone+man+human
# <Response [200]>
# Alternative
# 60
# justin+bieber+love+yourself
# <Response [200]>
# Pop
# 61
# twenty+one+pilots+stressed+out
# <Response [200]>
# Alternative
# 62
# alan+walker+faded
# <Response [200]>
# Dance
# 63
# justin+bieber+sorry
# <Response [200]>
# Pop
# 64
# desiigner+panda
# <Response [200]>
# Hip-Hop/Rap
# 65
# gnash+i+hate+u,+i+love+u+
# <Response [200]>
# Pop
# 66
# noah+cyrus+make+me+
# <Response [200]>
# Pop
# 67
# adele+water+under+the+bridge
# <Response [200]>
# Pop
# 68
# dnce+cake+by+the+ocean
# <Response [200]>
# Pop
# 69
# sia+the+greatest
# <Response [200]>
# Pop
# 70
# coldplay+hymn+for+the+weekend+-+seeb+remix
# <Response [200]>
# Dance
# 71
# mike+perry+the+ocean+
# <Response [200]>
# Dance
# 72
# luke+christopher+lot+to+learn
# <Response [200]>
# Hip-Hop/Rap
# 73
# lil+wayne+sucker+for+pain+
# <Response [200]>
# Hip-Hop/Rap
# 74
# major+lazer+light+it+up+
# <Response [200]>
# Hip-Hop/Rap
# 75
# the+chainsmokers+setting+fires
# <Response [200]>
# Dance
# 76
# drake+controlla
# <Response [200]>
# Hip-Hop/Rap
# 77
# mc+g15+deu+onda
# <Response [200]>
# Funk
# 78
# carlos+vives+la+bicicleta
# <Response [200]>
# Pop Latino
# 79
# little+mix+shout+out+to+my+ex
# <Response [200]>
# Pop
# 80
# ariana+grande+into+you
# <Response [200]>
# Pop
# 81
# cashmere+cat+trust+nobody+
# <Response [200]>
# Electronic
# 82
# sebastian+yatra+traicionera
# <Response [200]>
# Pop Latino
# 83
# petit+biscuit+sunset+lover
# <Response [200]>
# Electronic
# 84
# 21+savage+x+
# <Response [200]>
# Rap
# 85
# rob+$tone+chill+bill+
# <Response [200]>
# Hip-Hop/Rap
# 86
# rihanna+needed+me
# <Response [200]>
# Pop
# 87
# lukas+graham+7+years
# <Response [200]>
# Pop
# 88
# zay+hilfigerrr+juju+on+that+beat+
# <Response [200]>
# Dance
# 89
# jon+bellion+all+time+low
# <Response [200]>
# Pop
# 90
# frenship+capsize
# <Response [200]>
# Pop
# 91
# adele+send+my+love+
# <Response [200]>
# Pop
# 92
# jonas+blue+fast+car
# <Response [200]>
# Dance
# 93
# bruno+mars+versace+on+the+floor
# <Response [200]>
# Pop
# 94
# drake+sneakin’
# <Response [200]>
# Hip-Hop/Rap
# 95
# kungs+this+girl+
# <Response [200]>
# Dance
# 96
# daddy+yankee+shaky+shaky
# <Response [200]>
# Urbano latino
# 97
# enrique+iglesias+duele+el+corazon+
# <Response [200]>
# Pop Latino
# 98
# vice+steady+1234+
# <Response [200]>
# Pop
# 99
# the+weeknd+sidewalks
# <Response [200]>
# R&B/Soul
# 100
# dj+snake+middle
# <Response [200]>
# Dance
# 101
# ed+sheeran+photograph
# <Response [200]>
# Pop
# 102
# cheat+codes+sex
# <Response [200]>
# Dance
# 103
# mø+final+song
# <Response [200]>
# Pop
# 104
# bebe+rexha+i+got+you
# <Response [200]>
# Pop
# 105
# g-eazy+me,+myself+&+i
# <Response [200]>
# Hip-Hop/Rap
# 106
# andy+grammer+fresh+eyes
# <Response [200]>
# Pop
# 107
# hearts+&+colors+lighthouse+-+andrelli+remix
# <Response [200]>
# Pop
# 108
# 21+savage+no+heart
# <Response [200]>
# Rap
# 109
# the+weeknd+six+feet+under
# <Response [200]>
# R&B/Soul
# 110
# ozuna+dile+que+tu+me+quieres
# <Response [200]>
# Urbano latino
# 111
# major+lazer+lean+on+
# <Response [200]>
# Electronic
# 112
# iamchino+ay+mi+dios+
# <Response [200]>
# Urbano latino
# 113
# galantis+love+on+me
# <Response [200]>
# Dance
# 114
# young+m.a+ooouuu
# <Response [200]>
# Rap
# 115
# niall+horan+this+town
# <Response [200]>
# Pop
# 116
# childish+gambino+redbone
# <Response [200]>
# R&B/Soul
# 117
# ajr+weak
# <Response [200]>
# Alternative
# 118
# ed+sheeran+thinking+out+loud
# <Response [200]>
# Pop
# 119
# calum+scott+dancing+on+my+own
# <Response [200]>
# Pop
# 120
# zayn+pillowtalk
# <Response [200]>
# Pop
# 121
# nause+dynamite+
# <Response [200]>
# Dance
# 122
# zara+larsson+lush+life
# <Response [200]>
# Pop
# 123
# zara+larsson+aint+my+fault
# <Response [200]>
# Dance
# 124
# chance+the+rapper+no+problem+
# <Response [200]>
# Hip-Hop/Rap
# 125
# adele+hello
# <Response [200]>
# Pop
# 126
# flume+never+be+like+you
# <Response [200]>
# Electronic
# 127
# the+chainsmokers+roses
# <Response [200]>
# Dance
# 128
# kyle+ispy+
# <Response [200]>
# Hip-Hop/Rap
# 129
# galantis+no+money
# <Response [200]>
# Dance
# 130
# rihanna+love+on+the+brain
# <Response [200]>
# Pop
# 131
# maluma+borro+cassette
# <Response [200]>
# Música tropical
# 132
# young+thug+pick+up+the+phone
# <Response [200]>
# Hip-Hop/Rap
# 133
# g-eazy+some+kind+of+drug+
# <Response [200]>
# Hip-Hop/Rap
# 134
# justin+bieber+what+do+you+mean?
# <Response [200]>
# Pop
# 135
# shawn+mendes+stitches
# <Response [200]>
# Pop
# 136
# j.+cole+neighbors
# <Response [200]>
# Hip-Hop/Rap
# 137
# chino+&+nacho+andas+en+mi+cabeza
# <Response [200]>
# Reggae
# 138
# wisin+vacaciones
# <Response [200]>
# Urbano latino
# 139
# lil+uzi+vert+you+was+right
# <Response [200]>
# Hip-Hop
# 140
# sean+paul+no+lie
# <Response [200]>
# Reggae
# 141
# piso+21+me+llamas+
# <Response [200]>
# Pop Latino
# 142
# san+holo+light
# <Response [200]>
# Dance
# 143
# state+of+sound+wake+up+where+you+are
# <Response [200]>
# Pop
# 144
# the+weeknd+reminder
# <Response [200]>
# R&B/Soul
# 145
# drake+hotline+bling
# <Response [200]>
# Hip-Hop/Rap
# 146
# dante+klein+let+me+hold+you+
# <Response [200]>
# Dance
# 147
# james+hersey+miss+you
# <Response [200]>
# Alternative
# 148
# drake+jumpman
# <Response [200]>
# Hip-Hop/Rap
# 149
# j.+cole+immortal
# <Response [200]>
# Hip-Hop/Rap
# 150
# bruno+mars+thats+what+i+like
# <Response [200]>
# Pop
# 151
# rae+sremmurd+swang
# <Response [200]>
# Hip-Hop/Rap
# 152
# the+weeknd+rockin’
# <Response [200]>
# R&B/Soul
# 153
# anne-marie+alarm
# <Response [200]>
# Pop
# 154
# kream+taped+up+heart+
# <Response [200]>
# Dance
# 155
# the+weeknd+the+hills
# <Response [200]>
# R&B/Soul
# 156
# kiiara+gold
# <Response [200]>
# Pop
# 157
# little+mix+touch
# <Response [200]>
# Pop
# 158
# david+guetta+would+i+lie+to+you+-+radio+edit
# <Response [200]>
# Dance
# 159
# maluma+cuatro+babys+
# <Response [200]>
# Urbano latino
# 160
# tove+lo+cool+girl
# <Response [200]>
# Alternative
# 161
# james+bay+let+it+go
# <Response [200]>
# Alternative
# 162
# charly+black+gyal+you+a+party+animal+-+remix
# <Response [200]>
# Dance
# 163
# mic+lowry+oh+lord
# <Response [200]>
# R&B/Soul
# 164
# future+low+life+
# <Response [200]>
# Hip-Hop/Rap
# 165
# joel+adams+please+dont+go
# <Response [200]>
# Pop
# 166
# the+weeknd+cant+feel+my+face
# <Response [200]>
# R&B/Soul
# 167
# jp+cooper+september+song
# <Response [200]>
# Singer/Songwriter
# 168
# the+weeknd+die+for+you
# <Response [200]>
# R&B/Soul
# 169
# eminem+lose+yourself+-+from+8+mile+soundtrack
# <Response [200]>
# Soundtrack
# 170
# coldplay+hymn+for+the+weekend
# <Response [200]>
# Alternative
# 171
# marc+e.+bassy+you+&+me
# <Response [200]>
# Pop
# 172
# dvbbs+not+going+home
# <Response [200]>
# Dance
# 173
# flume+say+it+
# <Response [200]>
# Electronic
# 174
# j.+cole+no+role+modelz
# <Response [200]>
# Hip-Hop/Rap
# 175
# lady+gaga+million+reasons
# <Response [200]>
# Pop
# 176
# the+weeknd+secrets
# <Response [200]>
# R&B/Soul
# 177
# future+used+to+this+
# <Response [200]>
# Hip-Hop/Rap
# 178
# mura+masa+love$ick
# <Response [200]>
# Electronic
# 179
# mark+ronson+uptown+funk+
# <Response [200]>
# Pop
# 180
# foster+the+people+pumped+up+kicks
# <Response [200]>
# Alternative
# 181
# queen+bohemian+rhapsody+-++2011
# <Response [200]>
# Rock
# 182
# farruko+chillax+
# <Response [200]>
# Urbano latino
# 183
# flo+rida+my+house
# <Response [200]>
# Hip-Hop/Rap
# 184
# robin+schulz+sugar+
# <Response [200]>
# Dance
# 185
# the+weeknd+true+colors
# <Response [200]>
# R&B/Soul
# 186
# milky+chance+cocoon
# <Response [200]>
# Alternative
# 187
# coldplay+adventure+of+a+lifetime
# <Response [200]>
# Dance
# 188
# macklemore+&+ryan+lewis+cant+hold+us+-+feat.+ray+dalton
# <Response [200]>
# Hip-Hop
# 189
# nicky+jam+hasta+el+amanecer
# <Response [200]>
# Pop
# 190
# travis+scott+goosebumps
# <Response [200]>
# Hip-Hop/Rap
# 191
# the+killers+mr.+brightside
# <Response [200]>
# Rock
# 192
# kygo+stay+
# <Response [200]>
# Dance
# 193
# post+malone+white+iverson
# <Response [200]>
# Hip-Hop/Rap
# 194
# kanye+west+famous
# <Response [200]>
# Hip-Hop/Rap
# 195
# john+legend+all+of+me
# <Response [200]>
# R&B/Soul
# 196
# maroon+5+sugar
# <Response [200]>
# Pop
# 197
# passenger+let+her+go
# <Response [200]>
# Alternative
# 198
# j+balvin+bobo
# <Response [200]>
# Pop
# 199
# global_2017-01-06--2017-01-13.csv
# ed+sheeran+shape+of+you
# <Response [200]>
# Pop
# 0
# ed+sheeran+castle+on+the+hill
# <Response [200]>
# Pop
# 1
# the+weeknd+starboy
# <Response [200]>
# R&B/Soul
# 2
# clean+bandit+rockabye+
# <Response [200]>
# Dance
# 3
# zayn+i+don’t+wanna+live+forever+
# <Response [200]>
# Soundtrack
# 4
# the+chainsmokers+closer
# <Response [200]>
# Dance
# 5
# james+arthur+say+you+wont+let+go
# <Response [200]>
# Pop
# 6
# maroon+5+dont+wanna+know
# <Response [200]>
# Pop
# 7
# the+weeknd+i+feel+it+coming
# <Response [200]>
# R&B/Soul
# 8
# drake+fake+love
# <Response [200]>
# Hip-Hop/Rap
# 9
# dj+snake+let+me+love+you
# <Response [200]>
# Dance
# 10
# bruno+mars+24k+magic
# <Response [200]>
# Pop
# 11
# migos+bad+and+boujee+
# <Response [200]>
# Hip-Hop
# 12
# starley+call+on+me+-+ryan+riback+extended+remix
# <Response [200]>
# Dance
# 13
# shakira+chantaje+
# <Response [200]>
# Pop Latino
# 14
# rae+sremmurd+black+beatles
# <Response [200]>
# Hip-Hop/Rap
# 15
# steve+aoki+just+hold+on
# <Response [200]>
# Dance
# 16
# machine+gun+kelly+bad+things+
# <Response [200]>
# Hip-Hop/Rap
# 17
# drake+one+dance
# <Response [200]>
# Hip-Hop/Rap
# 18
# martin+garrix+in+the+name+of+love
# <Response [200]>
# Dance
# 19
# major+lazer+cold+water+
# <Response [200]>
# Pop
# 20
# ariana+grande+side+to+side
# <Response [200]>
# Pop
# 21
# shawn+mendes+mercy
# <Response [200]>
# Pop
# 22
# the+chainsmokers+all+we+know+
# <Response [200]>
# Dance
# 23
# hailee+steinfeld+starving
# <Response [200]>
# Pop
# 24
# calvin+harris+my+way
# <Response [200]>
# Dance
# 25
# the+vamps+all+night
# <Response [200]>
# Pop
# 26
# twenty+one+pilots+heathens
# <Response [200]>
# Alternative
# 27
# zara+larsson+i+would+like
# <Response [200]>
# Dance
# 28
# alessia+cara+scars+to+your+beautiful
# <Response [200]>
# Pop
# 29
# robin+schulz+shed+a+light
# <Response [200]>
# Dance
# 30
# sage+the+gemini+now+and+later
# <Response [200]>
# Hip-Hop
# 31
# alok+hear+me+now
# <Response [200]>
# Pop
# 32
# john+legend+love+me+now
# <Response [200]>
# R&B/Soul
# 33
# shawn+mendes+treat+you+better
# <Response [200]>
# Pop
# 34
# alessia+cara+how+far+ill+go+-+from+moana
# <Response [200]>
# Soundtrack
# 35
# jonas+blue+by+your+side
# <Response [200]>
# Dance
# 36
# the+chainsmokers+dont+let+me+down
# <Response [200]>
# Dance
# 37
# cnco+reggaetón+lento+
# <Response [200]>
# Pop
# 38
# alan+walker+alone
# <Response [200]>
# Dance
# 39
# ed+sheeran+photograph
# <Response [200]>
# Pop
# 40
# aminé+caroline
# <Response [200]>
# Hip-Hop/Rap
# 41
# nevada+the+mack
# <Response [200]>
# Dance
# 42
# justin+timberlake+cant+stop+the+feeling!+
# <Response [200]>
# Soundtrack
# 43
# charlie+puth+we+dont+talk+anymore+
# <Response [200]>
# Pop
# 44
# big+sean+bounce+back
# <Response [200]>
# Hip-Hop/Rap
# 45
# sia+cheap+thrills
# <Response [200]>
# Pop
# 46
# dram+broccoli+
# <Response [200]>
# Hip-Hop/Rap
# 47
# sia+the+greatest+
# <Response [200]>
# Pop
# 48
# j+balvin+safari
# <Response [200]>
# Urbano latino
# 49
# martin+jensen+solo+dance
# <Response [200]>
# Dance
# 50
# mike+posner+i+took+a+pill+in+ibiza+-+seeb+remix
# <Response [200]>
# Dance
# 51
# ragnbone+man+human
# <Response [200]>
# Alternative
# 52
# ricky+martin+vente+pa+ca+
# <Response [200]>
# Pop Latino
# 53
# zion+&+lennox+otra+vez+
# <Response [200]>
# Urbano latino
# 54
# jon+bellion+all+time+low
# <Response [200]>
# Pop
# 55
# the+weeknd+party+monster
# <Response [200]>
# R&B/Soul
# 56
# ed+sheeran+thinking+out+loud
# <Response [200]>
# Pop
# 57
# neiked+sexual
# <Response [200]>
# Dance
# 58
# calvin+harris+this+is+what+you+came+for+
# <Response [200]>
# Dance
# 59
# noah+cyrus+make+me+
# <Response [200]>
# Pop
# 60
# adele+water+under+the+bridge
# <Response [200]>
# Pop
# 61
# j.+cole+deja+vu
# <Response [200]>
# Hip-Hop/Rap
# 62
# jonas+blue+perfect+strangers
# <Response [200]>
# Dance
# 63
# petit+biscuit+sunset+lover
# <Response [200]>
# Electronic
# 64
# luke+christopher+lot+to+learn
# <Response [200]>
# Hip-Hop/Rap
# 65
# twenty+one+pilots+ride
# <Response [200]>
# Alternative
# 66
# drake+too+good
# <Response [200]>
# Hip-Hop/Rap
# 67
# fifth+harmony+work+from+home+
# <Response [200]>
# Pop
# 68
# gnash+i+hate+u,+i+love+u+
# <Response [200]>
# Pop
# 69
# twenty+one+pilots+stressed+out
# <Response [200]>
# Alternative
# 70
# the+chainsmokers+setting+fires
# <Response [200]>
# Dance
# 71
# alan+walker+faded
# <Response [200]>
# Dance
# 72
# desiigner+panda
# <Response [200]>
# Hip-Hop/Rap
# 73
# rob+$tone+chill+bill+
# <Response [200]>
# Hip-Hop/Rap
# 74
# cashmere+cat+trust+nobody+
# <Response [200]>
# Electronic
# 75
# justin+bieber+love+yourself
# <Response [200]>
# Pop
# 76
# bebe+rexha+i+got+you
# <Response [200]>
# Pop
# 77
# snakehips+dont+leave
# <Response [200]>
# Pop
# 78
# lil+wayne+sucker+for+pain+
# <Response [200]>
# Hip-Hop/Rap
# 79
# 21+savage+x+
# <Response [200]>
# Rap
# 80
# bruno+mars+versace+on+the+floor
# <Response [200]>
# Pop
# 81
# rihanna+work
# <Response [200]>
# Pop
# 82
# justin+bieber+sorry
# <Response [200]>
# Pop
# 83
# kyle+ispy+
# <Response [200]>
# Hip-Hop/Rap
# 84
# mike+perry+the+ocean+
# <Response [200]>
# Dance
# 85
# coldplay+hymn+for+the+weekend+-+seeb+remix
# <Response [200]>
# Dance
# 86
# little+mix+shout+out+to+my+ex
# <Response [200]>
# Pop
# 87
# drake+controlla
# <Response [200]>
# Hip-Hop/Rap
# 88
# vice+steady+1234+
# <Response [200]>
# Pop
# 89
# drake+sneakin’
# <Response [200]>
# Hip-Hop/Rap
# 90
# sebastian+yatra+traicionera
# <Response [200]>
# Pop Latino
# 91
# 21+savage+no+heart
# <Response [200]>
# Rap
# 92
# childish+gambino+redbone
# <Response [200]>
# R&B/Soul
# 93
# hearts+&+colors+lighthouse+-+andrelli+remix
# <Response [200]>
# Pop
# 94
# carlos+vives+la+bicicleta
# <Response [200]>
# Pop Latino
# 95
# the+weeknd+sidewalks
# <Response [200]>
# R&B/Soul
# 96
# ajr+weak
# <Response [200]>
# Alternative
# 97
# rihanna+needed+me
# <Response [200]>
# Pop
# 98
# frenship+capsize
# <Response [200]>
# Pop
# 99
# major+lazer+light+it+up+
# <Response [200]>
# Hip-Hop/Rap
# 100
# ed+sheeran+the+a+team
# <Response [200]>
# Pop
# 101
# andy+grammer+fresh+eyes
# <Response [200]>
# Pop
# 102
# the+weeknd+six+feet+under
# <Response [200]>
# R&B/Soul
# 103
# lukas+graham+7+years
# <Response [200]>
# Pop
# 104
# dnce+cake+by+the+ocean
# <Response [200]>
# Pop
# 105
# niall+horan+this+town
# <Response [200]>
# Pop
# 106
# ozuna+dile+que+tu+me+quieres
# <Response [200]>
# Urbano latino
# 107
# zay+hilfigerrr+juju+on+that+beat+
# <Response [200]>
# Dance
# 108
# iamchino+ay+mi+dios+
# <Response [200]>
# Urbano latino
# 109
# ariana+grande+into+you
# <Response [200]>
# Pop
# 110
# g-eazy+some+kind+of+drug+
# <Response [200]>
# Hip-Hop/Rap
# 111
# dj+snake+middle
# <Response [200]>
# Dance
# 112
# mc+g15+deu+onda
# <Response [200]>
# Funk
# 113
# calum+scott+dancing+on+my+own
# <Response [200]>
# Pop
# 114
# sean+paul+no+lie
# <Response [200]>
# Reggae
# 115
# adele+send+my+love+
# <Response [200]>
# Pop
# 116
# daddy+yankee+shaky+shaky
# <Response [200]>
# Urbano latino
# 117
# rihanna+love+on+the+brain
# <Response [200]>
# Pop
# 118
# lil+uzi+vert+you+was+right
# <Response [200]>
# Hip-Hop
# 119
# nause+dynamite+
# <Response [200]>
# Dance
# 120
# kungs+this+girl+
# <Response [200]>
# Dance
# 121
# mø+final+song
# <Response [200]>
# Pop
# 122
# galantis+love+on+me
# <Response [200]>
# Dance
# 123
# jonas+blue+fast+car
# <Response [200]>
# Dance
# 124
# chance+the+rapper+no+problem+
# <Response [200]>
# Hip-Hop/Rap
# 125
# little+mix+touch
# <Response [200]>
# Pop
# 126
# sia+the+greatest
# <Response [200]>
# Pop
# 127
# major+lazer+lean+on+
# <Response [200]>
# Electronic
# 128
# young+thug+pick+up+the+phone
# <Response [200]>
# Hip-Hop/Rap
# 129
# piso+21+me+llamas+
# <Response [200]>
# Pop Latino
# 130
# rae+sremmurd+swang
# <Response [200]>
# Hip-Hop/Rap
# 131
# enrique+iglesias+duele+el+corazon+
# <Response [200]>
# Pop Latino
# 132
# g-eazy+me,+myself+&+i
# <Response [200]>
# Hip-Hop/Rap
# 133
# ed+sheeran+i+see+fire+-+from+the+hobbit+-+the+desolation+of+smaug
# <Response [200]>
# Musicals
# 134
# jp+cooper+september+song
# <Response [200]>
# Singer/Songwriter
# 135
# san+holo+light
# <Response [200]>
# Dance
# 136
# dvbbs+not+going+home
# <Response [200]>
# Dance
# 137
# wisin+vacaciones
# <Response [200]>
# Urbano latino
# 138
# isaiah+firebrace+its+gotta+be+you
# <Response [200]>
# Pop
# 139
# adele+hello
# <Response [200]>
# Pop
# 140
# young+m.a+ooouuu
# <Response [200]>
# Rap
# 141
# j.+cole+neighbors
# <Response [200]>
# Hip-Hop/Rap
# 142
# cheat+codes+sex
# <Response [200]>
# Dance
# 143
# james+hersey+miss+you
# <Response [200]>
# Alternative
# 144
# the+chainsmokers+roses
# <Response [200]>
# Dance
# 145
# shawn+mendes+stitches
# <Response [200]>
# Pop
# 146
# zara+larsson+lush+life
# <Response [200]>
# Pop
# 147
# bruno+mars+thats+what+i+like
# <Response [200]>
# Pop
# 148
# james+bay+let+it+go
# <Response [200]>
# Alternative
# 149
# chino+&+nacho+andas+en+mi+cabeza
# <Response [200]>
# Reggae
# 150
# the+weeknd+reminder
# <Response [200]>
# R&B/Soul
# 151
# maluma+borro+cassette
# <Response [200]>
# Música tropical
# 152
# kream+taped+up+heart+
# <Response [200]>
# Dance
# 153
# zara+larsson+aint+my+fault
# <Response [200]>
# Dance
# 154
# ed+sheeran+dont
# <Response [200]>
# Pop
# 155
# zayn+pillowtalk
# <Response [200]>
# Pop
# 156
# eminem+lose+yourself+-+from+8+mile+soundtrack
# <Response [200]>
# Soundtrack
# 157
# mic+lowry+oh+lord
# <Response [200]>
# R&B/Soul
# 158
# ed+sheeran+tenerife+sea
# <Response [200]>
# Pop
# 159
# justin+bieber+what+do+you+mean?
# <Response [200]>
# Pop
# 160
# flo+rida+cake+-+challenge+
# <Response [200]>
# Hip-Hop/Rap
# 161
# dante+klein+let+me+hold+you+
# <Response [200]>
# Dance
# 162
# the+weeknd+the+hills
# <Response [200]>
# R&B/Soul
# 163
# drake+hotline+bling
# <Response [200]>
# Hip-Hop/Rap
# 164
# drake+jumpman
# <Response [200]>
# Hip-Hop/Rap
# 165
# the+weeknd+die+for+you
# <Response [200]>
# R&B/Soul
# 166
# ed+sheeran+give+me+love
# <Response [200]>
# Pop
# 167
# mura+masa+love$ick
# <Response [200]>
# Electronic
# 168
# lady+gaga+million+reasons
# <Response [200]>
# Pop
# 169
# maluma+cuatro+babys+
# <Response [200]>
# Urbano latino
# 170
# flume+never+be+like+you
# <Response [200]>
# Electronic
# 171
# the+weeknd+rockin’
# <Response [200]>
# R&B/Soul
# 172
# future+low+life+
# <Response [200]>
# Hip-Hop/Rap
# 173
# future+used+to+this+
# <Response [200]>
# Hip-Hop/Rap
# 174
# j.+cole+no+role+modelz
# <Response [200]>
# Hip-Hop/Rap
# 175
# j.+cole+immortal
# <Response [200]>
# Hip-Hop/Rap
# 176
# big+sean+moves
# <Response [200]>
# Hip-Hop/Rap
# 177
# galantis+no+money
# <Response [200]>
# Dance
# 178
# milky+chance+cocoon
# <Response [200]>
# Alternative
# 179
# tove+lo+cool+girl
# <Response [200]>
# Alternative
# 180
# state+of+sound+wake+up+where+you+are
# <Response [200]>
# Pop
# 181
# marc+e.+bassy+you+&+me
# <Response [200]>
# Pop
# 182
# joel+adams+please+dont+go
# <Response [200]>
# Pop
# 183
# charly+black+gyal+you+a+party+animal+-+remix
# <Response [200]>
# Dance
# 184
# travis+scott+goosebumps
# <Response [200]>
# Hip-Hop/Rap
# 185
# chris+brown+party+
# <Response [200]>
# R&B/Soul
# 186
# kiiara+gold
# <Response [200]>
# Pop
# 187
# eminem+till+i+collapse
# <Response [200]>
# Hip-Hop/Rap
# 188
# passenger+let+her+go
# <Response [200]>
# Alternative
# 189
# john+legend+all+of+me
# <Response [200]>
# R&B/Soul
# 190
# jax+jones+you+dont+know+me+-+radio+edit
# <Response [200]>
# Alternative
# 191
# the+weeknd+cant+feel+my+face
# <Response [200]>
# R&B/Soul
# 192
# flume+say+it+
# <Response [200]>
# Electronic
# 193
# david+guetta+would+i+lie+to+you+-+radio+edit
# <Response [200]>
# Dance
# 194
# coldplay+hymn+for+the+weekend
# <Response [200]>
# Alternative
# 195
# farruko+chillax+
# <Response [200]>
# Urbano latino
# 196
# post+malone+white+iverson
# <Response [200]>
# Hip-Hop/Rap
# 197
# the+weeknd+true+colors
# <Response [200]>
# R&B/Soul
# 198
# the+weeknd+secrets
# <Response [200]>
# R&B/Soul
# 199
# global_2017-01-13--2017-01-20.csv
# ed+sheeran+shape+of+you
# <Response [200]>
# Pop
# 0
# ed+sheeran+castle+on+the+hill
# <Response [200]>
# Pop
# 1
# the+chainsmokers+paris
# <Response [200]>
# Dance
# 2
# the+weeknd+starboy
# <Response [200]>
# R&B/Soul
# 3
# zayn+i+don’t+wanna+live+forever+
# <Response [200]>
# Soundtrack
# 4
# clean+bandit+rockabye+
# <Response [200]>
# Dance
# 5
# the+chainsmokers+closer
# <Response [200]>
# Dance
# 6
# james+arthur+say+you+wont+let+go
# <Response [200]>
# Pop
# 7
# the+weeknd+i+feel+it+coming
# <Response [200]>
# R&B/Soul
# 8
# maroon+5+dont+wanna+know
# <Response [200]>
# Pop
# 9
# drake+fake+love
# <Response [200]>
# Hip-Hop/Rap
# 10
# migos+bad+and+boujee+
# <Response [200]>
# Hip-Hop
# 11
# starley+call+on+me+-+ryan+riback+extended+remix
# <Response [200]>
# Dance
# 12
# dj+snake+let+me+love+you
# <Response [200]>
# Dance
# 13
# shakira+chantaje+
# <Response [200]>
# Pop Latino
# 14
# bruno+mars+24k+magic
# <Response [200]>
# Pop
# 15
# steve+aoki+just+hold+on
# <Response [200]>
# Dance
# 16
# machine+gun+kelly+bad+things+
# <Response [200]>
# Hip-Hop/Rap
# 17
# rae+sremmurd+black+beatles
# <Response [200]>
# Hip-Hop/Rap
# 18
# ariana+grande+side+to+side
# <Response [200]>
# Pop
# 19
# drake+one+dance
# <Response [200]>
# Hip-Hop/Rap
# 20
# major+lazer+cold+water+
# <Response [200]>
# Pop
# 21
# shawn+mendes+mercy
# <Response [200]>
# Pop
# 22
# martin+garrix+in+the+name+of+love
# <Response [200]>
# Dance
# 23
# the+chainsmokers+all+we+know+
# <Response [200]>
# Dance
# 24
# alessia+cara+how+far+ill+go+-+from+moana
# <Response [200]>
# Soundtrack
# 25
# the+vamps+all+night
# <Response [200]>
# Pop
# 26
# alok+hear+me+now
# <Response [200]>
# Pop
# 27
# sage+the+gemini+now+and+later
# <Response [200]>
# Hip-Hop
# 28
# zara+larsson+i+would+like
# <Response [200]>
# Dance
# 29
# robin+schulz+shed+a+light
# <Response [200]>
# Dance
# 30
# calvin+harris+my+way
# <Response [200]>
# Dance
# 31
# hailee+steinfeld+starving
# <Response [200]>
# Pop
# 32
# alessia+cara+scars+to+your+beautiful
# <Response [200]>
# Pop
# 33
# john+legend+love+me+now
# <Response [200]>
# R&B/Soul
# 34
# jonas+blue+by+your+side
# <Response [200]>
# Dance
# 35
# twenty+one+pilots+heathens
# <Response [200]>
# Alternative
# 36
# martin+jensen+solo+dance
# <Response [200]>
# Dance
# 37
# alan+walker+alone
# <Response [200]>
# Dance
# 38
# cnco+reggaetón+lento+
# <Response [200]>
# Pop
# 39
# shawn+mendes+treat+you+better
# <Response [200]>
# Pop
# 40
# big+sean+bounce+back
# <Response [200]>
# Hip-Hop/Rap
# 41
# the+chainsmokers+dont+let+me+down
# <Response [200]>
# Dance
# 42
# aminé+caroline
# <Response [200]>
# Hip-Hop/Rap
# 43
# jon+bellion+all+time+low
# <Response [200]>
# Pop
# 44
# justin+timberlake+cant+stop+the+feeling!+
# <Response [200]>
# Soundtrack
# 45
# charlie+puth+we+dont+talk+anymore+
# <Response [200]>
# Pop
# 46
# j+balvin+safari
# <Response [200]>
# Urbano latino
# 47
# sia+the+greatest+
# <Response [200]>
# Pop
# 48
# luis+fonsi+despacito+
# <Response [200]>
# Pop
# 49
# dram+broccoli+
# <Response [200]>
# Hip-Hop/Rap
# 50
# sia+cheap+thrills
# <Response [200]>
# Pop
# 51
# ed+sheeran+photograph
# <Response [200]>
# Pop
# 52
# ragnbone+man+human
# <Response [200]>
# Alternative
# 53
# noah+cyrus+make+me+
# <Response [200]>
# Pop
# 54
# the+weeknd+party+monster
# <Response [200]>
# R&B/Soul
# 55
# adele+water+under+the+bridge
# <Response [200]>
# Pop
# 56
# zion+&+lennox+otra+vez+
# <Response [200]>
# Urbano latino
# 57
# petit+biscuit+sunset+lover
# <Response [200]>
# Electronic
# 58
# luke+christopher+lot+to+learn
# <Response [200]>
# Hip-Hop/Rap
# 59
# nevada+the+mack
# <Response [200]>
# Dance
# 60
# neiked+sexual
# <Response [200]>
# Dance
# 61
# kyle+ispy+
# <Response [200]>
# Hip-Hop/Rap
# 62
# snakehips+dont+leave
# <Response [200]>
# Pop
# 63
# ajr+weak
# <Response [200]>
# Alternative
# 64
# mike+posner+i+took+a+pill+in+ibiza+-+seeb+remix
# <Response [200]>
# Dance
# 65
# bebe+rexha+i+got+you
# <Response [200]>
# Pop
# 66
# ricky+martin+vente+pa+ca+
# <Response [200]>
# Pop Latino
# 67
# j.+cole+deja+vu
# <Response [200]>
# Hip-Hop/Rap
# 68
# the+chainsmokers+setting+fires
# <Response [200]>
# Dance
# 69
# calvin+harris+this+is+what+you+came+for+
# <Response [200]>
# Dance
# 70
# twenty+one+pilots+ride
# <Response [200]>
# Alternative
# 71
# jonas+blue+perfect+strangers
# <Response [200]>
# Dance
# 72
# ed+sheeran+thinking+out+loud
# <Response [200]>
# Pop
# 73
# drake+too+good
# <Response [200]>
# Hip-Hop/Rap
# 74
# hearts+&+colors+lighthouse+-+andrelli+remix
# <Response [200]>
# Pop
# 75
# cashmere+cat+trust+nobody+
# <Response [200]>
# Electronic
# 76
# twenty+one+pilots+stressed+out
# <Response [200]>
# Alternative
# 77
# rob+$tone+chill+bill+
# <Response [200]>
# Hip-Hop/Rap
# 78
# alan+walker+faded
# <Response [200]>
# Dance
# 79
# childish+gambino+redbone
# <Response [200]>
# R&B/Soul
# 80
# gnash+i+hate+u,+i+love+u+
# <Response [200]>
# Pop
# 81
# desiigner+panda
# <Response [200]>
# Hip-Hop/Rap
# 82
# 21+savage+x+
# <Response [200]>
# Rap
# 83
# fifth+harmony+work+from+home+
# <Response [200]>
# Pop
# 84
# vice+steady+1234+
# <Response [200]>
# Pop
# 85
# justin+bieber+love+yourself
# <Response [200]>
# Pop
# 86
# g-eazy+some+kind+of+drug+
# <Response [200]>
# Hip-Hop/Rap
# 87
# bruno+mars+versace+on+the+floor
# <Response [200]>
# Pop
# 88
# lil+wayne+sucker+for+pain+
# <Response [200]>
# Hip-Hop/Rap
# 89
# justin+bieber+sorry
# <Response [200]>
# Pop
# 90
# coldplay+hymn+for+the+weekend+-+seeb+remix
# <Response [200]>
# Dance
# 91
# 21+savage+no+heart
# <Response [200]>
# Rap
# 92
# sean+paul+no+lie
# <Response [200]>
# Reggae
# 93
# rihanna+work
# <Response [200]>
# Pop
# 94
# mike+perry+the+ocean+
# <Response [200]>
# Dance
# 95
# little+mix+shout+out+to+my+ex
# <Response [200]>
# Pop
# 96
# drake+sneakin’
# <Response [200]>
# Hip-Hop/Rap
# 97
# sebastian+yatra+traicionera
# <Response [200]>
# Pop Latino
# 98
# isaiah+firebrace+its+gotta+be+you
# <Response [200]>
# Pop
# 99
# drake+controlla
# <Response [200]>
# Hip-Hop/Rap
# 100
# carlos+vives+la+bicicleta
# <Response [200]>
# Pop Latino
# 101
# the+xx+on+hold
# <Response [200]>
# Alternative
# 102
# dvbbs+not+going+home
# <Response [200]>
# Dance
# 103
# iamchino+ay+mi+dios+
# <Response [200]>
# Urbano latino
# 104
# the+weeknd+sidewalks
# <Response [200]>
# R&B/Soul
# 105
# the+weeknd+six+feet+under
# <Response [200]>
# R&B/Soul
# 106
# frenship+capsize
# <Response [200]>
# Pop
# 107
# major+lazer+light+it+up+
# <Response [200]>
# Hip-Hop/Rap
# 108
# rihanna+needed+me
# <Response [200]>
# Pop
# 109
# andy+grammer+fresh+eyes
# <Response [200]>
# Pop
# 110
# san+holo+light
# <Response [200]>
# Dance
# 111
# ozuna+dile+que+tu+me+quieres
# <Response [200]>
# Urbano latino
# 112
# lukas+graham+7+years
# <Response [200]>
# Pop
# 113
# jp+cooper+september+song
# <Response [200]>
# Singer/Songwriter
# 114
# niall+horan+this+town
# <Response [200]>
# Pop
# 115
# rihanna+love+on+the+brain
# <Response [200]>
# Pop
# 116
# dnce+cake+by+the+ocean
# <Response [200]>
# Pop
# 117
# flo+rida+cake+-+challenge+
# <Response [200]>
# Hip-Hop/Rap
# 118
# the+xx+say+something+loving
# <Response [200]>
# Alternative
# 119
# wisin+vacaciones
# <Response [200]>
# Urbano latino
# 120
# lil+uzi+vert+you+was+right
# <Response [200]>
# Hip-Hop
# 121
# piso+21+me+llamas+
# <Response [200]>
# Pop Latino
# 122
# ariana+grande+into+you
# <Response [200]>
# Pop
# 123
# calum+scott+dancing+on+my+own
# <Response [200]>
# Pop
# 124
# dj+snake+middle
# <Response [200]>
# Dance
# 125
# daddy+yankee+shaky+shaky
# <Response [200]>
# Urbano latino
# 126
# little+mix+touch
# <Response [200]>
# Pop
# 127
# rae+sremmurd+swang
# <Response [200]>
# Hip-Hop/Rap
# 128
# zay+hilfigerrr+juju+on+that+beat+
# <Response [200]>
# Dance
# 129
# galantis+love+on+me
# <Response [200]>
# Dance
# 130
# kungs+this+girl+
# <Response [200]>
# Dance
# 131
# adele+send+my+love+
# <Response [200]>
# Pop
# 132
# jax+jones+you+dont+know+me+-+radio+edit
# <Response [200]>
# Alternative
# 133
# major+lazer+lean+on+
# <Response [200]>
# Electronic
# 134
# chance+the+rapper+no+problem+
# <Response [200]>
# Hip-Hop/Rap
# 135
# jonas+blue+fast+car
# <Response [200]>
# Dance
# 136
# migos+t-shirt
# <Response [200]>
# Hip-Hop
# 137
# mø+final+song
# <Response [200]>
# Pop
# 138
# kream+taped+up+heart+
# <Response [200]>
# Dance
# 139
# a+r+i+z+o+n+a+oceans+away
# <Response [200]>
# Alternative
# 140
# mic+lowry+oh+lord
# <Response [200]>
# R&B/Soul
# 141
# enrique+iglesias+duele+el+corazon+
# <Response [200]>
# Pop Latino
# 142
# the+xx+dangerous
# <Response [200]>
# Alternative
# 143
# young+thug+pick+up+the+phone
# <Response [200]>
# Hip-Hop/Rap
# 144
# the+chainsmokers+roses
# <Response [200]>
# Dance
# 145
# g-eazy+me,+myself+&+i
# <Response [200]>
# Hip-Hop/Rap
# 146
# adele+hello
# <Response [200]>
# Pop
# 147
# chino+&+nacho+andas+en+mi+cabeza
# <Response [200]>
# Reggae
# 148
# sia+the+greatest
# <Response [200]>
# Pop
# 149
# eminem+lose+yourself+-+from+8+mile+soundtrack
# <Response [200]>
# Soundtrack
# 150
# bruno+mars+thats+what+i+like
# <Response [200]>
# Pop
# 151
# olivia+holt+history
# <Response [200]>
# Pop
# 152
# shawn+mendes+stitches
# <Response [200]>
# Pop
# 153
# cheat+codes+sex
# <Response [200]>
# Dance
# 154
# james+bay+let+it+go
# <Response [200]>
# Alternative
# 155
# zara+larsson+lush+life
# <Response [200]>
# Pop
# 156
# the+weeknd+reminder
# <Response [200]>
# R&B/Soul
# 157
# young+m.a+ooouuu
# <Response [200]>
# Rap
# 158
# mura+masa+love$ick
# <Response [200]>
# Electronic
# 159
# maluma+cuatro+babys+
# <Response [200]>
# Urbano latino
# 160
# mc+g15+deu+onda
# <Response [200]>
# Funk
# 161
# the+weeknd+the+hills
# <Response [200]>
# R&B/Soul
# 162
# justin+bieber+what+do+you+mean?
# <Response [200]>
# Pop
# 163
# j.+cole+neighbors
# <Response [200]>
# Hip-Hop/Rap
# 164
# maluma+borro+cassette
# <Response [200]>
# Música tropical
# 165
# milky+chance+cocoon
# <Response [200]>
# Alternative
# 166
# zayn+pillowtalk
# <Response [200]>
# Pop
# 167
# zara+larsson+aint+my+fault
# <Response [200]>
# Dance
# 168
# stanaj+romantic+-+notd+remix
# <Response [200]>
# Dance
# 169
# dante+klein+let+me+hold+you+
# <Response [200]>
# Dance
# 170
# big+sean+moves
# <Response [200]>
# Hip-Hop/Rap
# 171
# the+weeknd+die+for+you
# <Response [200]>
# R&B/Soul
# 172
# charly+black+gyal+you+a+party+animal+-+remix
# <Response [200]>
# Dance
# 173
# future+used+to+this+
# <Response [200]>
# Hip-Hop/Rap
# 174
# lauv+the+other
# <Response [200]>
# Pop
# 175
# drake+hotline+bling
# <Response [200]>
# Hip-Hop/Rap
# 176
# future+low+life+
# <Response [200]>
# Hip-Hop/Rap
# 177
# travis+scott+goosebumps
# <Response [200]>
# Hip-Hop/Rap
# 178
# j.+cole+no+role+modelz
# <Response [200]>
# Hip-Hop/Rap
# 179
# drake+jumpman
# <Response [200]>
# Hip-Hop/Rap
# 180
# ed+sheeran+i+see+fire+-+from+the+hobbit+-+the+desolation+of+smaug
# <Response [200]>
# Musicals
# 181
# tiësto+on+my+way
# <Response [200]>
# Dance
# 182
# lady+gaga+million+reasons
# <Response [200]>
# Pop
# 183
# chris+brown+party+
# <Response [200]>
# R&B/Soul
# 184
# eminem+till+i+collapse
# <Response [200]>
# Hip-Hop/Rap
# 185
# nause+dynamite+
# <Response [200]>
# Dance
# 186
# julia+michaels+issues
# <Response [200]>
# Pop
# 187
# halsey+not+afraid+anymore
# <Response [200]>
# Alternative
# 188
# passenger+let+her+go
# <Response [200]>
# Alternative
# 189
# flume+never+be+like+you
# <Response [200]>
# Electronic
# 190
# the+weeknd+rockin’
# <Response [200]>
# R&B/Soul
# 191
# john+legend+all+of+me
# <Response [200]>
# R&B/Soul
# 192
# farruko+chillax+
# <Response [200]>
# Urbano latino
# 193
# don+omar+te+quiero+pa´mi
# <Response [200]>
# Urbano latino
# 194
# vérité+somebody+else
# <Response [200]>
# Alternative
# 195
# galantis+no+money
# <Response [200]>
# Dance
# 196
# the+xx+lips
# <Response [200]>
# Alternative
# 197
# the+weeknd+cant+feel+my+face
# <Response [200]>
# R&B/Soul
# 198
# the+xx+i+dare+you
# <Response [200]>
# Alternative
# 199
# global_2017-01-20--2017-01-27.csv
# ed+sheeran+shape+of+you
# <Response [200]>
# Pop
# 0
# the+chainsmokers+paris
# <Response [200]>
# Dance
# 1
# ed+sheeran+castle+on+the+hill
# <Response [200]>
# Pop
# 2
# zayn+i+don’t+wanna+live+forever+
# <Response [200]>
# Soundtrack
# 3
# the+weeknd+starboy
# <Response [200]>
# R&B/Soul
# 4
# clean+bandit+rockabye+
# <Response [200]>
# Dance
# 5
# the+chainsmokers+closer
# <Response [200]>
# Dance
# 6
# james+arthur+say+you+wont+let+go
# <Response [200]>
# Pop
# 7
# the+weeknd+i+feel+it+coming
# <Response [200]>
# R&B/Soul
# 8
# maroon+5+dont+wanna+know
# <Response [200]>
# Pop
# 9
# drake+fake+love
# <Response [200]>
# Hip-Hop/Rap
# 10
# migos+bad+and+boujee+
# <Response [200]>
# Hip-Hop
# 11
# starley+call+on+me+-+ryan+riback+extended+remix
# <Response [200]>
# Dance
# 12
# luis+fonsi+despacito+
# <Response [200]>
# Pop
# 13
# shakira+chantaje+
# <Response [200]>
# Pop Latino
# 14
# dj+snake+let+me+love+you
# <Response [200]>
# Dance
# 15
# steve+aoki+just+hold+on
# <Response [200]>
# Dance
# 16
# machine+gun+kelly+bad+things+
# <Response [200]>
# Hip-Hop/Rap
# 17
# bruno+mars+24k+magic
# <Response [200]>
# Pop
# 18
# alessia+cara+how+far+ill+go+-+from+moana
# <Response [200]>
# Soundtrack
# 19
# rae+sremmurd+black+beatles
# <Response [200]>
# Hip-Hop/Rap
# 20
# drake+one+dance
# <Response [200]>
# Hip-Hop/Rap
# 21
# ariana+grande+side+to+side
# <Response [200]>
# Pop
# 22
# major+lazer+cold+water+
# <Response [200]>
# Pop
# 23
# the+vamps+all+night
# <Response [200]>
# Pop
# 24
# shawn+mendes+mercy
# <Response [200]>
# Pop
# 25
# martin+garrix+in+the+name+of+love
# <Response [200]>
# Dance
# 26
# alok+hear+me+now
# <Response [200]>
# Pop
# 27
# sage+the+gemini+now+and+later
# <Response [200]>
# Hip-Hop
# 28
# robin+schulz+shed+a+light
# <Response [200]>
# Dance
# 29
# martin+jensen+solo+dance
# <Response [200]>
# Dance
# 30
# zara+larsson+i+would+like
# <Response [200]>
# Dance
# 31
# john+legend+love+me+now
# <Response [200]>
# R&B/Soul
# 32
# alessia+cara+scars+to+your+beautiful
# <Response [200]>
# Pop
# 33
# calvin+harris+my+way
# <Response [200]>
# Dance
# 34
# hailee+steinfeld+starving
# <Response [200]>
# Pop
# 35
# cnco+reggaetón+lento+
# <Response [200]>
# Pop
# 36
# jonas+blue+by+your+side
# <Response [200]>
# Dance
# 37
# the+chainsmokers+all+we+know+
# <Response [200]>
# Dance
# 38
# jon+bellion+all+time+low
# <Response [200]>
# Pop
# 39
# big+sean+bounce+back
# <Response [200]>
# Hip-Hop/Rap
# 40
# alan+walker+alone
# <Response [200]>
# Dance
# 41
# twenty+one+pilots+heathens
# <Response [200]>
# Alternative
# 42
# shawn+mendes+treat+you+better
# <Response [200]>
# Pop
# 43
# aminé+caroline
# <Response [200]>
# Hip-Hop/Rap
# 44
# the+chainsmokers+dont+let+me+down
# <Response [200]>
# Dance
# 45
# j+balvin+safari
# <Response [200]>
# Urbano latino
# 46
# justin+timberlake+cant+stop+the+feeling!+
# <Response [200]>
# Soundtrack
# 47
# charlie+puth+we+dont+talk+anymore+
# <Response [200]>
# Pop
# 48
# ajr+weak
# <Response [200]>
# Alternative
# 49
# snakehips+dont+leave
# <Response [200]>
# Pop
# 50
# kyle+ispy+
# <Response [200]>
# Hip-Hop/Rap
# 51
# ragnbone+man+human
# <Response [200]>
# Alternative
# 52
# noah+cyrus+make+me+
# <Response [200]>
# Pop
# 53
# zion+&+lennox+otra+vez+
# <Response [200]>
# Urbano latino
# 54
# adele+water+under+the+bridge
# <Response [200]>
# Pop
# 55
# petit+biscuit+sunset+lover
# <Response [200]>
# Electronic
# 56
# julia+michaels+issues
# <Response [200]>
# Pop
# 57
# sia+the+greatest+
# <Response [200]>
# Pop
# 58
# luke+christopher+lot+to+learn
# <Response [200]>
# Hip-Hop/Rap
# 59
# dram+broccoli+
# <Response [200]>
# Hip-Hop/Rap
# 60
# ed+sheeran+photograph
# <Response [200]>
# Pop
# 61
# the+weeknd+party+monster
# <Response [200]>
# R&B/Soul
# 62
# neiked+sexual
# <Response [200]>
# Dance
# 63
# bebe+rexha+i+got+you
# <Response [200]>
# Pop
# 64
# ricky+martin+vente+pa+ca+
# <Response [200]>
# Pop Latino
# 65
# mike+posner+i+took+a+pill+in+ibiza+-+seeb+remix
# <Response [200]>
# Dance
# 66
# sia+cheap+thrills
# <Response [200]>
# Pop
# 67
# nevada+the+mack
# <Response [200]>
# Dance
# 68
# nicky+jam+el+amante
# <Response [200]>
# Urbano latino
# 69
# little+mix+touch
# <Response [200]>
# Pop
# 70
# childish+gambino+redbone
# <Response [200]>
# R&B/Soul
# 71
# isaiah+firebrace+its+gotta+be+you
# <Response [200]>
# Pop
# 72
# migos+t-shirt
# <Response [200]>
# Hip-Hop
# 73
# j.+cole+deja+vu
# <Response [200]>
# Hip-Hop/Rap
# 74
# jonas+blue+perfect+strangers
# <Response [200]>
# Dance
# 75
# twenty+one+pilots+ride
# <Response [200]>
# Alternative
# 76
# calvin+harris+this+is+what+you+came+for+
# <Response [200]>
# Dance
# 77
# 21+savage+x+
# <Response [200]>
# Rap
# 78
# hearts+&+colors+lighthouse+-+andrelli+remix
# <Response [200]>
# Pop
# 79
# ed+sheeran+thinking+out+loud
# <Response [200]>
# Pop
# 80
# twenty+one+pilots+stressed+out
# <Response [200]>
# Alternative
# 81
# rob+$tone+chill+bill+
# <Response [200]>
# Hip-Hop/Rap
# 82
# alan+walker+faded
# <Response [200]>
# Dance
# 83
# fifth+harmony+work+from+home+
# <Response [200]>
# Pop
# 84
# gnash+i+hate+u,+i+love+u+
# <Response [200]>
# Pop
# 85
# desiigner+panda
# <Response [200]>
# Hip-Hop/Rap
# 86
# bruno+mars+versace+on+the+floor
# <Response [200]>
# Pop
# 87
# jax+jones+you+dont+know+me+-+radio+edit
# <Response [200]>
# Alternative
# 88
# drake+too+good
# <Response [200]>
# Hip-Hop/Rap
# 89
# sean+paul+no+lie
# <Response [200]>
# Reggae
# 90
# g-eazy+some+kind+of+drug+
# <Response [200]>
# Hip-Hop/Rap
# 91
# vice+steady+1234+
# <Response [200]>
# Pop
# 92
# the+chainsmokers+setting+fires
# <Response [200]>
# Dance
# 93
# justin+bieber+love+yourself
# <Response [200]>
# Pop
# 94
# iamchino+ay+mi+dios+
# <Response [200]>
# Urbano latino
# 95
# lil+wayne+sucker+for+pain+
# <Response [200]>
# Hip-Hop/Rap
# 96
# justin+bieber+sorry
# <Response [200]>
# Pop
# 97
# jp+cooper+september+song
# <Response [200]>
# Singer/Songwriter
# 98
# cashmere+cat+trust+nobody+
# <Response [200]>
# Electronic
# 99
# ...
# <Response [200]>
# Pop Latino
# 111
# charlie+puth+we+dont+talk+anymore+
# <Response [200]>
# Pop
# 112
# lorde+homemade+dynamite
# <Response [200]>
# Alternative
# 113
# justin+timberlake+cant+stop+the+feeling!+
# <Response [200]>
# Soundtrack
# 114
# shawn+mendes+treat+you+better
# <Response [200]>
# Pop
# 115
# shawn+hook+reminding+me
# <Response [200]>
# Pop
# 116
# drake+fake+love
# <Response [200]>
# Hip-Hop/Rap
# 117
# dj+khaled+dont+quit+
# <Response [200]>
# Hip-Hop/Rap
# 118
# calvin+harris+prayers+up+
# <Response [200]>
# Dance
# 119
# alan+walker+tired
# <Response [200]>
# Dance
# 120
# katy+perry+bon+appétit
# <Response [200]>
# Pop
# 121
# ariana+grande+side+to+side
# <Response [200]>
# Pop
# 122
# big+sean+bounce+back
# <Response [200]>
# Hip-Hop/Rap
# 123
# major+lazer+cold+water+
# <Response [200]>
# Pop
# 124
# calvin+harris+heatstroke+
# <Response [200]>
# Dance
# 125
# g-eazy+good+life+
# <Response [200]>
# Hip-Hop/Rap
# 126
# kodak+black+tunnel+vision
# <Response [200]>
# Hip-Hop
# 127
# 2+chainz+its+a+vibe
# <Response [200]>
# Hip-Hop/Rap
# 128
# mø+nights+with+you
# <Response [200]>
# Pop
# 129
# maroon+5+cold
# <Response [200]>
# Pop
# 130
# katy+perry+chained+to+the+rhythm
# <Response [200]>
# Pop
# 131
# lorde+green+light
# <Response [200]>
# Alternative
# 132
# xxxtentacion+look+at+me!
# <Response [200]>
# Hip-Hop/Rap
# 133
# khalid+young+dumb+&+broke
# <Response [200]>
# R&B/Soul
# 134
# ajr+weak
# <Response [200]>
# Alternative
# 135
# martin+garrix+in+the+name+of+love
# <Response [200]>
# Dance
# 136
# mike+posner+i+took+a+pill+in+ibiza+-+seeb+remix
# <Response [200]>
# Dance
# 137
# ed+sheeran+thinking+out+loud
# <Response [200]>
# Pop
# 138
# rae+sremmurd+swang
# <Response [200]>
# Hip-Hop/Rap
# 139
# ofenbach+be+mine
# <Response [200]>
# Electronic
# 140
# sia+cheap+thrills
# <Response [200]>
# Pop
# 141
# moon+taxi+two+high
# <Response [200]>
# Pop
# 142
# nicky+jam+si+tú+la+ves+
# <Response [200]>
# Urbano latino
# 143
# piso+21+besándote
# <Response [200]>
# Pop Latino
# 144
# alok+hear+me+now
# <Response [200]>
# Pop
# 145
# ariana+grande+one+last+time
# <Response [200]>
# Pop
# 146
# migos+t-shirt
# <Response [200]>
# Hip-Hop
# 147
# felix+jaehn+hot2touch
# <Response [200]>
# Dance
# 148
# calvin+harris+faking+it+
# <Response [200]>
# Dance
# 149
# sebastian+yatra+alguien+robo
# <Response [200]>
# Pop Latino
# 150
# justin+bieber+love+yourself
# <Response [200]>
# Pop
# 151
# italobrothers+summer+air
# <Response [200]>
# Dance
# 152
# anitta+paradinha
# <Response [200]>
# Brazilian
# 153
# kendrick+lamar+element.
# <Response [200]>
# Hip-Hop/Rap
# 154
# ed+sheeran+happier
# <Response [200]>
# Pop
# 155
# ricky+martin+vente+pa+ca+
# <Response [200]>
# Pop Latino
# 156
# bebe+rexha+the+way+i+are+
# <Response [200]>
# Pop
# 157
# ayo+&+teo+rolex
# <Response [200]>
# Hip-Hop/Rap
# 158
# james+arthur+can+i+be+him
# <Response [200]>
# Pop
# 159
# calvin+harris+skrt+on+me+
# <Response [200]>
# Dance
# 160
# tyler,+the+creator+911+/+mr.+lonely+
# <Response [200]>
# Hip-Hop/Rap
# 161
# lord+huron+the+night+we+met
# <Response [200]>
# Indie Rock
# 162
# twenty+one+pilots+ride
# <Response [200]>
# Alternative
# 163
# alessia+cara+how+far+ill+go+-+from+moana
# <Response [200]>
# Soundtrack
# 164
# alan+walker+faded
# <Response [200]>
# Dance
# 165
# shawn+mendes+mercy
# <Response [200]>
# Pop
# 166
# calvin+harris+this+is+what+you+came+for+
# <Response [200]>
# Dance
# 167
# tyler,+the+creator+who+dat+boy+
# <Response [200]>
# Hip-Hop/Rap
# 168
# maroon+5+dont+wanna+know
# <Response [200]>
# Pop
# 169
# twenty+one+pilots+heathens
# <Response [200]>
# Alternative
# 170
# twenty+one+pilots+stressed+out
# <Response [200]>
# Alternative
# 171
# zayn+still+got+time+
# <Response [200]>
# Pop
# 172
# drake+gyalchester
# <Response [200]>
# Hip-Hop/Rap
# 173
# blackbear+do+re+mi
# <Response [200]>
# R&B/Soul
# 174
# justin+bieber+sorry
# <Response [200]>
# Pop
# 175
# fifth+harmony+work+from+home+
# <Response [200]>
# Pop
# 176
# sebastian+yatra+traicionera
# <Response [200]>
# Pop Latino
# 177
# j+balvin+safari
# <Response [200]>
# Urbano latino
# 178
# sza+love+galore+
# <Response [200]>
# R&B/Soul
# 179
# post+malone+white+iverson
# <Response [200]>
# Hip-Hop/Rap
# 180
# coldplay+the+scientist
# <Response [200]>
# Alternative
# 181
# don+omar+te+quiero+pa´mi
# <Response [200]>
# Urbano latino
# 182
# dram+broccoli+
# <Response [200]>
# Hip-Hop/Rap
# 183
# major+lazer+lean+on+
# <Response [200]>
# Electronic
# 184
# jonas+blue+perfect+strangers
# <Response [200]>
# Dance
# 185
# j+balvin+si+tu+novio+te+deja+sola
# <Response [200]>
# Urbano latino
# 186
# jp+cooper+september+song
# <Response [200]>
# Singer/Songwriter
# 187
# playboi+carti+wokeuplikethis*
# <Response [200]>
# Hip-Hop/Rap
# 188
# desiigner+panda
# <Response [200]>
# Hip-Hop/Rap
# 189
# rihanna+love+on+the+brain
# <Response [200]>
# Pop
# 190
# ed+sheeran+dive
# <Response [200]>
# Pop
# 191
# major+lazer+light+it+up+
# <Response [200]>
# Hip-Hop/Rap
# 192
# oasis+wonderwall+-+
# <Response [200]>
# Alternative
# 193
# anne-marie+ciao+adios
# <Response [200]>
# Pop
# 194
# julia+michaels+uh+huh
# <Response [200]>
# Pop
# 195
# little+mix+touch
# <Response [200]>
# Pop
# 196
# rae+sremmurd+black+beatles
# <Response [200]>
# Hip-Hop/Rap
# 197
# thomas+rhett+craving+you
# <Response [200]>
# Country
# 198
# little+mix+power+
# <Response [200]>
# Pop
# 199
# global_2017-07-07--2017-07-14.csv
# luis+fonsi+despacito+-+remix
# <Response [200]>
# Pop
# 0
# dj+khaled+wild+thoughts+
# <Response [200]>
# Hip-Hop/Rap
# 1
# dj+khaled+im+the+one+
# <Response [200]>
# Hip-Hop/Rap
# 2
# david+guetta+2u+
# <Response [200]>
# Dance
# 3
# french+montana+unforgettable
# <Response [200]>
# Hip-Hop/Rap
# 4
# ed+sheeran+shape+of+you
# <Response [200]>
# Pop
# 5
# calvin+harris+feels+
# <Response [200]>
# Dance
# 6
# charlie+puth+attention
# <Response [200]>
# Pop
# 7
# j+balvin+mi+gente
# <Response [200]>
# Urbano latino
# 8
# imagine+dragons+thunder
# <Response [200]>
# Alternative
# 9
# liam+payne+strip+that+down
# <Response [200]>
# Pop
# 10
# jonas+blue+mama
# <Response [200]>
# Dance
# 11
# shawn+mendes+theres+nothing+holdin+me+back
# <Response [200]>
# Pop
# 12
# lil+uzi+vert+xo+tour+llif3
# <Response [200]>
# Hip-Hop/Rap
# 13
# luis+fonsi+despacito+
# <Response [200]>
# Pop
# 14
# the+chainsmokers+something+just+like+this
# <Response [200]>
# Dance
# 15
# jason+derulo+swalla+
# <Response [200]>
# Pop
# 16
# kendrick+lamar+humble.
# <Response [200]>
# Hip-Hop/Rap
# 17
# martin+garrix+there+for+you
# <Response [200]>
# Dance
# 18
# calvin+harris+slide+
# <Response [200]>
# Dance
# 19
# axwell+/\+ingrosso+more+than+you+know
# <Response [200]>
# Dance
# 20
# imagine+dragons+believer
# <Response [200]>
# Alternative
# 21
# maluma+felices+los+4
# <Response [200]>
# Música tropical
# 22
# drake+signs
# <Response [200]>
# Hip-Hop/Rap
# 23
# post+malone+congratulations
# <Response [200]>
# Hip-Hop/Rap
# 24
# maggie+lindemann+pretty+girl+-+cheat+codes+x+cade+remix
# <Response [200]>
# Pop
# 25
# danny+ocean+me+rehúso
# <Response [200]>
# Latino
# 26
# selena+gomez+bad+liar
# <Response [200]>
# Pop
# 27
# clean+bandit+symphony+
# <Response [200]>
# Dance
# 28
# zedd+stay+
# <Response [200]>
# Dance
# 29
# rita+ora+your+song
# <Response [200]>
# Pop
# 30
# bruno+mars+thats+what+i+like
# <Response [200]>
# Pop
# 31
# major+lazer+know+no+better+
# <Response [200]>
# Electronic
# 32
# niall+horan+slow+hands
# <Response [200]>
# Pop
# 33
# camila+cabello+crying+in+the+club
# <Response [200]>
# Pop
# 34
# future+mask+off
# <Response [200]>
# Hip-Hop/Rap
# 35
# childish+gambino+redbone
# <Response [200]>
# R&B/Soul
# 36
# kygo+it+aint+me+
# <Response [200]>
# Pop
# 37
# enrique+iglesias+subeme+la+radio+
# <Response [200]>
# Pop Latino
# 38
# wisin+escápate+conmigo
# <Response [200]>
# Urbano latino
# 39
# cheat+codes+no+promises+
# <Response [200]>
# Pop
# 40
# ed+sheeran+galway+girl
# <Response [200]>
# Pop
# 41
# khalid+location
# <Response [200]>
# R&B/Soul
# 42
# calvin+harris+rollin+
# <Response [200]>
# Dance
# 43
# miley+cyrus+malibu
# <Response [200]>
# Pop
# 44
# chris+jeday+ahora+dice
# <Response [200]>
# Urbano latino
# 45
# kendrick+lamar+dna.
# <Response [200]>
# Hip-Hop/Rap
# 46
# kygo+first+time
# <Response [200]>
# Dance
# 47
# kesha+praying
# <Response [200]>
# Pop
# 48
# lauv+i+like+me+better
# <Response [200]>
# Pop
# 49
# zedd+get+low+
# <Response [200]>
# Dance
# 50
# drake+passionfruit
# <Response [200]>
# Hip-Hop/Rap
# 51
# cnco+hey+dj
# <Response [200]>
# Pop Latino
# 52
# manuel+turizo+una+lady+como+tú
# <Response [200]>
# Urbano latino
# 53
# halsey+now+or+never
# <Response [200]>
# Alternative
# 54
# logic+1-800-273-8255
# <Response [200]>
# Hip-Hop/Rap
# 55
# travis+scott+butterfly+effect
# <Response [200]>
# Hip-Hop/Rap
# 56
# j+balvin+bonita
# <Response [200]>
# Urbano latino
# 57
# hailee+steinfeld+most+girls
# <Response [200]>
# Pop
# 58
# robin+schulz+ok
# <Response [200]>
# Dance
# 59
# travis+scott+goosebumps
# <Response [200]>
# Hip-Hop/Rap
# 60
# sam+hunt+body+like+a+back+road
# <Response [200]>
# Country
# 61
# 21+savage+bank+account
# <Response [200]>
# Hip-Hop/Rap
# 62
# james+arthur+say+you+wont+let+go
# <Response [200]>
# Pop
# 63
# julia+michaels+issues
# <Response [200]>
# Pop
# 64
# harry+styles+sign+of+the+times
# <Response [200]>
# Pop
# 65
# clean+bandit+rockabye+
# <Response [200]>
# Dance
# 66
# fifth+harmony+down
# <Response [200]>
# Pop
# 67
# the+chainsmokers+closer
# <Response [200]>
# Dance
# 68
# playboi+carti+magnolia
# <Response [200]>
# Hip-Hop/Rap
# 69
# katy+perry+swish+swish
# <Response [200]>
# Pop
# 70
# shakira+me+enamoré
# <Response [200]>
# Pop Latino
# 71
# migos+slippery+
# <Response [200]>
# Hip-Hop
# 72
# ozuna+tu+foto
# <Response [200]>
# Urbano latino
# 73
# martin+garrix+scared+to+be+lonely
# <Response [200]>
# Dance
# 74
# kyle+ispy+
# <Response [200]>
# Hip-Hop/Rap
# 75
# nicky+jam+el+amante
# <Response [200]>
# Urbano latino
# 76
# daddy+yankee+la+rompe+corazones
# <Response [200]>
# Urbano latino
# 77
# onerepublic+no+vacancy
# <Response [200]>
# Pop
# 78
# zayn+i+don’t+wanna+live+forever+
# <Response [200]>
# Soundtrack
# 79
# j+balvin+sigo+extrañándote
# <Response [200]>
# Urbano latino
# 80
# the+weeknd+i+feel+it+coming
# <Response [200]>
# R&B/Soul
# 81
# pitbull+hey+ma+
# <Response [200]>
# Latino
# 82
# sigala+came+here+for+love
# <Response [200]>
# Dance
# 83
# ed+sheeran+castle+on+the+hill
# <Response [200]>
# Pop
# 84
# drake+one+dance
# <Response [200]>
# Hip-Hop/Rap
# 85
# shakira+chantaje+
# <Response [200]>
# Pop Latino
# 86
# burak+yeter+tuesday
# <Response [200]>
# Dance
# 87
# the+weeknd+starboy
# <Response [200]>
# R&B/Soul
# 88
# martin+jensen+solo+dance
# <Response [200]>
# Dance
# 89
# the+chainsmokers+paris
# <Response [200]>
# Dance
# 90
# zion+&+lennox+otra+vez+
# <Response [200]>
# Urbano latino
# 91
# kendrick+lamar+love.+feat.+zacari.
# <Response [200]>
# Hip-Hop/Rap
# 92
# ed+sheeran+perfect
# <Response [200]>
# Pop
# 93
# starley+call+on+me+-+ryan+riback+extended+remix
# <Response [200]>
# Dance
# 94
# anuel+aa+sola+
# <Response [200]>
# Urbano latino
# 95
# imagine+dragons+whatever+it+takes
# <Response [200]>
# Alternative
# 96
# nacho+báilame
# <Response [200]>
# Urbano latino
# 97
# jax+jones+you+dont+know+me+-+radio+edit
# <Response [200]>
# Alternative
# 98
# dj+snake+let+me+love+you
# <Response [200]>
# Dance
# 99
# a+boogie+wit+da+hoodie+drowning+
# <Response [200]>
# Hip-Hop/Rap
# 100
# kendrick+lamar+loyalty.+feat.+rihanna.
# <Response [200]>
# Hip-Hop/Rap
# 101
# 2+chainz+4+am
# <Response [200]>
# Hip-Hop/Rap
# 102
# metro+boomin+no+complaints
# <Response [200]>
# Hip-Hop/Rap
# 103
# the+chainsmokers+dont+let+me+down
# <Response [200]>
# Dance
# 104
# lady+gaga+the+cure
# <Response [200]>
# Pop
# 105
# khalid+young+dumb+&+broke
# <Response [200]>
# R&B/Soul
# 106
# ed+sheeran+photograph
# <Response [200]>
# Pop
# 107
# cnco+reggaetón+lento+
# <Response [200]>
# Pop
# 108
# galantis+hunter
# <Response [200]>
# Dance
# 109
# piso+21+me+llamas+
# <Response [200]>
# Pop Latino
# 110
# bruno+mars+24k+magic
# <Response [200]>
# Pop
# 111
# hailee+steinfeld+starving
# <Response [200]>
# Pop
# 112
# 2+chainz+its+a+vibe
# <Response [200]>
# Hip-Hop/Rap
# 113
# moon+taxi+two+high
# <Response [200]>
# Pop
# 114
# charlie+puth+we+dont+talk+anymore+
# <Response [200]>
# Pop
# 115
# shawn+mendes+treat+you+better
# <Response [200]>
# Pop
# 116
# 21+savage+numb
# <Response [200]>
# Hip-Hop/Rap
# 117
# shawn+hook+reminding+me
# <Response [200]>
# Pop
# 118
# justin+timberlake+cant+stop+the+feeling!+
# <Response [200]>
# Soundtrack
# 119
# alan+walker+tired
# <Response [200]>
# Dance
# 120
# demi+lovato+sorry+not+sorry
# <Response [200]>
# Pop
# 121
# drake+portland
# <Response [200]>
# Hip-Hop/Rap
# 122
# ariana+grande+side+to+side
# <Response [200]>
# Pop
# 123
# migos+bad+and+boujee+
# <Response [200]>
# Hip-Hop
# 124
# major+lazer+cold+water+
# <Response [200]>
# Pop
# 125
# lorde+homemade+dynamite
# <Response [200]>
# Alternative
# 126
# nicky+jam+si+tú+la+ves+
# <Response [200]>
# Urbano latino
# 127
# felix+jaehn+hot2touch
# <Response [200]>
# Dance
# 128
# ed+sheeran+thinking+out+loud
# <Response [200]>
# Pop
# 129
# piso+21+besándote
# <Response [200]>
# Pop Latino
# 130
# mø+nights+with+you
# <Response [200]>
# Pop
# 131
# italobrothers+summer+air
# <Response [200]>
# Dance
# 132
# big+sean+bounce+back
# <Response [200]>
# Hip-Hop/Rap
# 133
# drake+fake+love
# <Response [200]>
# Hip-Hop/Rap
# 134
# mike+posner+i+took+a+pill+in+ibiza+-+seeb+remix
# <Response [200]>
# Dance
# 135
# g-eazy+good+life+
# <Response [200]>
# Hip-Hop/Rap
# 136
# macklemore+glorious+
# <Response [200]>
# Hip-Hop/Rap
# 137
# ed+sheeran+happier
# <Response [200]>
# Pop
# 138
# martin+garrix+in+the+name+of+love
# <Response [200]>
# Dance
# 139
# sebastian+yatra+alguien+robo
# <Response [200]>
# Pop Latino
# 140
# xxxtentacion+look+at+me!
# <Response [200]>
# Hip-Hop/Rap
# 141
# anitta+paradinha
# <Response [200]>
# Brazilian
# 142
# katy+perry+chained+to+the+rhythm
# <Response [200]>
# Pop
# 143
# maroon+5+cold
# <Response [200]>
# Pop
# 144
# alok+hear+me+now
# <Response [200]>
# Pop
# 145
# katy+perry+bon+appétit
# <Response [200]>
# Pop
# 146
# rae+sremmurd+swang
# <Response [200]>
# Hip-Hop/Rap
# 147
# kodak+black+tunnel+vision
# <Response [200]>
# Hip-Hop
# 148
# sia+cheap+thrills
# <Response [200]>
# Pop
# 149
# ofenbach+be+mine
# <Response [200]>
# Electronic
# 150
# dua+lipa+new+rules
# <Response [200]>
# Pop
# 151
# bebe+rexha+the+way+i+are+
# <Response [200]>
# Pop
# 152
# james+arthur+can+i+be+him
# <Response [200]>
# Pop
# 153
# ariana+grande+one+last+time
# <Response [200]>
# Pop
# 154
# justin+bieber+love+yourself
# <Response [200]>
# Pop
# 155
# sza+love+galore+
# <Response [200]>
# R&B/Soul
# 156
# ajr+weak
# <Response [200]>
# Alternative
# 157
# lorde+green+light
# <Response [200]>
# Alternative
# 158
# lord+huron+the+night+we+met
# <Response [200]>
# Indie Rock
# 159
# migos+t-shirt
# <Response [200]>
# Hip-Hop
# 160
# ricky+martin+vente+pa+ca+
# <Response [200]>
# Pop Latino
# 161
# shawn+mendes+mercy
# <Response [200]>
# Pop
# 162
# kendrick+lamar+element.
# <Response [200]>
# Hip-Hop/Rap
# 163
# alessia+cara+how+far+ill+go+-+from+moana
# <Response [200]>
# Soundtrack
# 164
# ayo+&+teo+rolex
# <Response [200]>
# Hip-Hop/Rap
# 165
# alan+walker+faded
# <Response [200]>
# Dance
# 166
# coldplay+the+scientist
# <Response [200]>
# Alternative
# 167
# twenty+one+pilots+heathens
# <Response [200]>
# Alternative
# 168
# calvin+harris+this+is+what+you+came+for+
# <Response [200]>
# Dance
# 169
# blackbear+do+re+mi
# <Response [200]>
# R&B/Soul
# 170
# j+balvin+safari
# <Response [200]>
# Urbano latino
# 171
# thomas+rhett+craving+you
# <Response [200]>
# Country
# 172
# fifth+harmony+work+from+home+
# <Response [200]>
# Pop
# 173
# post+malone+white+iverson
# <Response [200]>
# Hip-Hop/Rap
# 174
# twenty+one+pilots+ride
# <Response [200]>
# Alternative
# 175
# don+omar+te+quiero+pa´mi
# <Response [200]>
# Urbano latino
# 176
# justin+bieber+sorry
# <Response [200]>
# Pop
# 177
# 21+savage+famous
# <Response [200]>
# Hip-Hop/Rap
# 178
# maroon+5+dont+wanna+know
# <Response [200]>
# Pop
# 179
# zayn+still+got+time+
# <Response [200]>
# Pop
# 180
# ed+sheeran+dive
# <Response [200]>
# Pop
# 181
# twenty+one+pilots+stressed+out
# <Response [200]>
# Alternative
# 182
# sebastian+yatra+traicionera
# <Response [200]>
# Pop Latino
# 183
# j+balvin+si+tu+novio+te+deja+sola
# <Response [200]>
# Urbano latino
# 184
# jp+cooper+september+song
# <Response [200]>
# Singer/Songwriter
# 185
# jennifer+lopez+ni+tú+ni+yo+
# <Response [200]>
# Pop Latino
# 186
# jonas+blue+perfect+strangers
# <Response [200]>
# Dance
# 187
# major+lazer+lean+on+
# <Response [200]>
# Electronic
# 188
# sean+paul+no+lie
# <Response [200]>
# Reggae
# 189
# desiigner+panda
# <Response [200]>
# Hip-Hop/Rap
# 190
# oasis+wonderwall+-+
# <Response [200]>
# Alternative
# 191
# playboi+carti+wokeuplikethis*
# <Response [200]>
# Hip-Hop/Rap
# 192
# wisin+vacaciones
# <Response [200]>
# Urbano latino
# 193
# rihanna+love+on+the+brain
# <Response [200]>
# Pop
# 194
# eminem+lose+yourself+-+from+8+mile+soundtrack
# <Response [200]>
# Soundtrack
# 195
# the+killers+mr.+brightside
# <Response [200]>
# Rock
# 196
# drake+gyalchester
# <Response [200]>
# Hip-Hop/Rap
# 197
# dram+broccoli+
# <Response [200]>
# Hip-Hop/Rap
# 198
# post+malone+go+flex
# <Response [200]>
# Hip-Hop/Rap
# 199
# global_2017-07-14--2017-07-21.csv
# luis+fonsi+despacito+-+remix
# <Response [200]>
# Pop
# 0
# dj+khaled+wild+thoughts+
# <Response [200]>
# Hip-Hop/Rap
# 1
# french+montana+unforgettable
# <Response [200]>
# Hip-Hop/Rap
# 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-e22631411948> in <module>
#      23         artist = row["Artist"]
#      24         song = row["Track Name"]
# ---> 25         song = song.split('(')[0]
#      26         query_entry = str(artist)+" "+str(song)
#      27         query_entry = query_entry.replace("with", "")
#
# AttributeError: 'float' object has no attribute 'split'

# %%
string = 'sia+helium+-+from+"fifty+shades+darker+'
string=string.replace('"', "")
print(string)
# Out:
# sia+helium+-+from+fifty+shades+darker+
